# %% [markdown]
# In this notebook I will create a training table equivalent to ml_model_run_details

# %% [markdown]
# # Define Library

# %%
# %% [markdown]
# # Jupyter Notebook Loading Header
#
# This is a custom loading header for Jupyter Notebooks in Visual Studio Code.
# It includes common imports and settings to get you started quickly.
# %% [markdown]
## Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery
from google.cloud import storage
import os
import tempfile
import time
from datetime import datetime
import uuid
import joblib
import uuid

import gcsfs
import duckdb as dd
import pickle
import joblib
from typing import Union
import io
path = r'C:\Users\Dwaipayan\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = path
client = bigquery.Client(project='prj-prod-dataplatform')
os.environ["GOOGLE_CLOUD_PROJECT"] = "prj-prod-dataplatform"

# %% [markdown]
## Configure Settings
# Set options or configurations as needed
pd.set_option('display.max_columns', None)
pd.set_option("Display.max_rows", 100)

# %% [markdown]
# ### Function

# %% [markdown]
# #### expand_calc_features

# %%
import pandas as pd
import json

def expand_calc_features(df):
    """
    Expand the calcFeatures JSON column into separate columns and return the complete DataFrame.

    Parameters:
    df (pd.DataFrame): Input DataFrame with calcFeatures column containing JSON data

    Returns:
    pd.DataFrame: Expanded DataFrame with all original columns plus JSON features as separate columns
    """

    # Make a copy to avoid modifying the original DataFrame
    df_expanded = df.copy()

    # Parse the calcFeatures JSON column
    calc_features_list = []

    for idx, calc_features_str in enumerate(df['calcFeatures']):
        try:
            # Parse the JSON string
            features_dict = json.loads(calc_features_str.replace("'", '"'))  # Replace single quotes with double quotes for valid JSON
            calc_features_list.append(features_dict)
        except (json.JSONDecodeError, AttributeError) as e:
            # If parsing fails, create an empty dict and print warning
            print(f"Warning: Could not parse calcFeatures at index {idx}: {e}")
            calc_features_list.append({})

    # Create DataFrame from the parsed JSON data
    calc_features_df = pd.DataFrame(calc_features_list)

    # Add prefix to JSON-derived columns to avoid conflicts
    calc_features_df = calc_features_df.add_prefix('calc_')

    # Reset index to ensure proper alignment
    df_expanded = df_expanded.reset_index(drop=True)
    calc_features_df = calc_features_df.reset_index(drop=True)

    # Combine original DataFrame with expanded calcFeatures
    result_df = pd.concat([df_expanded, calc_features_df], axis=1)

    return result_df

# %% [markdown]
# #### expand_calc_features_robust

# %%
import pandas as pd
import json

def expand_calc_features_robust(df):
    """
    Expand the calcFeatures JSON column into separate columns with better error handling.

    Parameters:
    df (pd.DataFrame): Input DataFrame with calcFeatures column containing JSON data

    Returns:
    pd.DataFrame: Expanded DataFrame with all original columns plus JSON features as separate columns
    """

    # Make a copy to avoid modifying the original DataFrame
    df_expanded = df.copy()

    # Parse the calcFeatures JSON column
    calc_features_data = []

    for idx, row in df.iterrows():
        calc_features_str = row['calcFeatures']

        if pd.isna(calc_features_str) or calc_features_str == '':
            calc_features_data.append({})
            continue

        try:
            # Clean the string and parse JSON
            cleaned_str = calc_features_str.replace("'", '"').replace('None', 'null').replace('True', 'true').replace('False', 'false')
            features_dict = json.loads(cleaned_str)
            calc_features_data.append(features_dict)
        except Exception as e:
            print(f"Warning: Could not parse calcFeatures at index {idx}: {e}")
            print(f"Problematic string: {calc_features_str[:100]}...")  # Print first 100 chars
            calc_features_data.append({})

    # Create DataFrame from the parsed JSON data
    calc_features_df = pd.DataFrame(calc_features_data)

    # Add prefix to JSON-derived columns to avoid conflicts with existing columns
    calc_features_df = calc_features_df.add_prefix('feat_')

    # Combine DataFrames
    result_df = pd.concat([df_expanded, calc_features_df], axis=1)

    print(f"Original DataFrame shape: {df.shape}")
    print(f"Expanded DataFrame shape: {result_df.shape}")
    print(f"Added {len(calc_features_df.columns)} new columns from calcFeatures")

    return result_df

# %% [markdown]
# #### transform_data

# %%
# import pandas as pd
# import json
# import uuid
# from datetime import datetime
# from typing import List

# def transform_data(d1: pd.DataFrame, feature_column: List[str], a='demo_score', modelDisplayName = 'Cash_beta_trench1_Demo_backscore', subscription_name = 'sil_march 25 models'):
#     # Read the input CSV file
#     df = d1.copy()
    
#     # Create the output DataFrame with the required structure
#     output_data = []
    
#     for _, row in df.iterrows():
#         # Create the calcFeature JSON with all the feature columns
#         feature_columns = feature_column
        
#         calc_feature = {}
#         for col in feature_columns:
#             if col in row and pd.notna(row[col]):
#                 # Convert Timestamp objects to string
#                 if isinstance(row[col], pd.Timestamp):
#                     calc_feature[col] = row[col].isoformat()
#                 else:
#                     calc_feature[col] = row[col]
        
       
#         # Get current timestamp
#         current_time = datetime.now().isoformat()
        
#         # Create the output row
#         output_row = {
#             "customerId": row['customer_id'],
#             "digitalLoanAccountId": row['digitalLoanAccountId'],
#             "crifApplicationId": str(uuid.uuid4()),  # Generate random UUID
#             "prediction": row.get(a, 0),
#             "start_time": current_time,
#             "end_time": current_time,
#             "modelDisplayName":modelDisplayName,
#             "modelVersionId":"v1",
#             "subscription_name": subscription_name,
#             "message_id": str(uuid.uuid4()),  # Generate random UUID
#             "publish_time": current_time,
#             "attributes": "{}",  # Empty JSON object
#             "calcFeature": json.dumps(calc_feature, default=str)  # Use default=str to handle non-serializable objects
            
#         }
        
#         output_data.append(output_row)
    
#     # Create DataFrame from the output data
#     output_df = pd.DataFrame(output_data)
    
#     return output_df

# # Example usage:
# # transformeddata = 'cash_beta_trench1_applied_loans_backscored_20241001_20250831'
# # transform_data(f'{LOCALPATH}/{transformeddata}.csv')

# %% [markdown]
# ## Transform data v1

# %%
import pandas as pd
import json
import uuid
from datetime import datetime
from typing import List

def transform_data(
    d1: pd.DataFrame, 
    feature_column: List[str], 
    a: str = 'demo_score', 
    modelDisplayName: str = 'Cash_beta_trench1_Demo_backscore', 
    tc: str = "", 
    subscription_name: str = 'sil_march 25 models'
) -> pd.DataFrame:
    """
    Transforms input data into a structured format suitable for model scoring output.

    Parameters:
    - d1 (pd.DataFrame): Input DataFrame containing raw data.
    - feature_column (List[str]): List of column names to include in the 'calcFeature' JSON.
    - a (str): Column name containing the prediction score. Default is 'demo_score'.
    - modelDisplayName (str): Name of the model used for scoring.
    - tc (str): Trench category (optional).
    - do (str): Device operating system. Default is 'android'.
    - subscription_name (str): Name of the subscription or model group.

    Returns:
    - pd.DataFrame: Transformed DataFrame with structured output.
    """

    # Make a copy of the input DataFrame to avoid modifying the original
    df = d1.copy()
    
    # Initialize an empty list to store transformed rows
    output_data = []
    
    # Iterate over each row in the DataFrame
    for _, row in df.iterrows():
        # Initialize dictionary to hold feature values
        calc_feature = {}
        
        # Loop through each feature column and extract its value from the row
        for col in feature_column:
            if col in row and pd.notna(row[col]):
                # Convert datetime values to ISO format strings
                if isinstance(row[col], pd.Timestamp):
                    calc_feature[col] = row[col].isoformat()
                else:
                    calc_feature[col] = row[col]
        
        # Get the current timestamp for start_time, end_time, and publish_time
        current_time = datetime.now().isoformat()
        
        # Construct the output row dictionary with required fields
        output_row = {
            "customerId": row['customer_id'],  # Unique customer identifier
            "digitalLoanAccountId": row['digitalLoanAccountId'],  # Loan account ID
            "crifApplicationId": str(uuid.uuid4()),  # Random UUID for application ID
            "prediction": row.get(a, 0),  # Prediction score from specified column
            "start_time": current_time,  # Timestamp when processing starts
            "end_time": current_time,    # Timestamp when processing ends
            "modelDisplayName": modelDisplayName,  # Name of the model used
            "modelVersionId": "v1",  # Static model version
            "calcFeature": json.dumps(calc_feature, default=str),  # Features as JSON string
            "subscription_name": subscription_name,  # Subscription name
            "message_id": str(uuid.uuid4()),  # Random UUID for message ID
            "publish_time": current_time,  # Timestamp when message is published
            "attributes": "{}",  # Placeholder for additional attributes
            "trenchCategory": tc,  # Optional trench category
            "deviceOs": row['osType'],
            "Data_selection": row['Data_selection'],  # Data selection
            "Application_date": row['application_date'],
        }
        
        # Append the transformed row to the output list
        output_data.append(output_row)
    
    # Convert the list of dictionaries to a DataFrame
    output_df = pd.DataFrame(output_data)
    
    # Return the transformed DataFrame
    return output_df

# %% [markdown]
# # transform_datav2

# %%
import pandas as pd
import json
import uuid
from datetime import datetime
from typing import List

def transform_datav2(
    d1: pd.DataFrame, 
    feature_column: List[str], 
    a: str = 'demo_score', 
    modelDisplayName: str = 'Cash_beta_trench1_Demo_backscore', 
    tc: str = "", 
    subscription_name: str = 'sil_march 25 models'
) -> pd.DataFrame:
    """
    Transforms input data into a structured format suitable for model scoring output.

    Parameters:
    - d1 (pd.DataFrame): Input DataFrame containing raw data.
    - feature_column (List[str]): List of column names to include in the 'calcFeature' JSON.
    - a (str): Column name containing the prediction score. Default is 'demo_score'.
    - modelDisplayName (str): Name of the model used for scoring.
    - tc (str): Trench category (optional).
    - do (str): Device operating system. Default is 'android'.
    - subscription_name (str): Name of the subscription or model group.

    Returns:
    - pd.DataFrame: Transformed DataFrame with structured output.
    """

    # Make a copy of the input DataFrame to avoid modifying the original
    df = d1.copy()
    
    # Initialize an empty list to store transformed rows
    output_data = []
    
    # Iterate over each row in the DataFrame
    for _, row in df.iterrows():
        # Initialize dictionary to hold feature values
        calc_feature = {}
        
        # Loop through each feature column and extract its value from the row
        for col in feature_column:
            if col in row and pd.notna(row[col]):
                # Convert datetime values to ISO format strings
                if isinstance(row[col], pd.Timestamp):
                    calc_feature[col] = row[col].isoformat()
                else:
                    calc_feature[col] = row[col]
        
        # Get the current timestamp for start_time, end_time, and publish_time
        current_time = datetime.now().isoformat()
        
        # Construct the output row dictionary with required fields
        output_row = {
            "customerId": row['customer_id'],  # Unique customer identifier
            "digitalLoanAccountId": row['digitalLoanAccountId'],  # Loan account ID
            "crifApplicationId": str(uuid.uuid4()),  # Random UUID for application ID
            "prediction": row.get(a, 0),  # Prediction score from specified column
            "start_time": current_time,  # Timestamp when processing starts
            "end_time": current_time,    # Timestamp when processing ends
            "modelDisplayName": modelDisplayName,  # Name of the model used
            "modelVersionId": "v2",  # Static model version
            "calcFeature": json.dumps(calc_feature, default=str),  # Features as JSON string
            "subscription_name": subscription_name,  # Subscription name
            "message_id": str(uuid.uuid4()),  # Random UUID for message ID
            "publish_time": current_time,  # Timestamp when message is published
            "attributes": "{}",  # Placeholder for additional attributes
            "trenchCategory": tc,  # Optional trench category
            "deviceOs": row['osType'],  # Device operating system
            "Data_selection": row['Data_selection'],  # Data selection
            "Application_date": row['application_date'],
        }
        
        # Append the transformed row to the output list
        output_data.append(output_row)
    
    # Convert the list of dictionaries to a DataFrame
    output_df = pd.DataFrame(output_data)
    
    # Return the transformed DataFrame
    return output_df

# %% [markdown]
# #### PSI Functions new

# %%
## Updated on 27-10-2025 - Modified for Training Period Baseline
import pandas as pd
import numpy as np
from typing import List, Dict, Tuple
import warnings
warnings.filterwarnings('ignore')

def identify_feature_types(df: pd.DataFrame, feature_list: List[str]) -> Dict[str, List[str]]:
    """
    Identify categorical and numerical features from the feature list.

    Parameters:
    -----------
    df : pd.DataFrame
        Input dataframe
    feature_list : List[str]
        List of features to classify

    Returns:
    --------
    Dict with 'categorical' and 'numerical' keys containing respective feature lists
    """
    categorical_features = []
    numerical_features = []

    for feature in feature_list:
        if feature not in df.columns:
            print(f"Warning: Feature '{feature}' not found in dataframe")
            continue

        # Check if feature is numeric
        if pd.api.types.is_numeric_dtype(df[feature]):
            # If unique values are less than 15 and all integers, treat as categorical
            unique_vals = df[feature].nunique()
            if unique_vals < 15 and df[feature].dropna().apply(lambda x: x == int(x) if isinstance(x, (int, float)) else False).all():
                categorical_features.append(feature)
            else:
                numerical_features.append(feature)
        else:
            categorical_features.append(feature)

    return {
        'categorical': categorical_features,
        'numerical': numerical_features
    }


def create_bins_for_features(df: pd.DataFrame,
                             numerical_features: List[str],
                             categorical_features: List[str],
                             train_period_df: pd.DataFrame) -> Dict:
    """
    Create bins for numerical features (deciles with fallback) and categorical features (top 6 + others)
    based on the entire training period data.

    Parameters:
    -----------
    df : pd.DataFrame
        Full input dataframe
    numerical_features : List[str]
        List of numerical features
    categorical_features : List[str]
        List of categorical features
    train_period_df : pd.DataFrame
        Training period dataframe (June 2024 to March 2025)

    Returns:
    --------
    Dictionary containing binning information for each feature
    """
    binning_info = {}

    # Create bins for numerical features with fallback strategy
    for feature in numerical_features:
        valid_data = train_period_df[feature].dropna()

        if len(valid_data) == 0:
            binning_info[feature] = {'type': 'numerical', 'bins': None, 'bin_ranges': {}}
            continue

        bins = None
        bin_count = None

        # Try 10 bins (deciles)
        try:
            test_bins = np.percentile(valid_data, np.arange(0, 101, 10))
            test_bins = np.unique(test_bins)
            if len(test_bins) >= 11:  # 11 edges = 10 bins
                bins = test_bins
                bin_count = 10
        except Exception as e:
            pass

        # If 10 bins not possible, try 5 bins
        if bins is None:
            try:
                test_bins = np.percentile(valid_data, np.arange(0, 101, 20))
                test_bins = np.unique(test_bins)
                if len(test_bins) >= 6:  # 6 edges = 5 bins
                    bins = test_bins
                    bin_count = 5
            except Exception as e:
                pass

        # If 5 bins not possible, try 3 bins
        if bins is None:
            try:
                test_bins = np.percentile(valid_data, [0, 33.33, 66.67, 100])
                test_bins = np.unique(test_bins)
                if len(test_bins) >= 4:  # 4 edges = 3 bins
                    bins = test_bins
                    bin_count = 3
            except Exception as e:
                pass

        # If still no bins possible, use equal distance bins of 5
        if bins is None:
            print(f"Warning: Feature '{feature}' has insufficient variance - cannot create standard bins")
            print(f"Feature '{feature}': Using equal distance bins of 5")

            min_val = valid_data.min()
            max_val = valid_data.max()

            # Create 5 equal distance bins
            bins = np.linspace(min_val, max_val, 6)  # 6 edges = 5 bins
            bins = np.unique(bins)
            bin_count = len(bins) - 1

            # If all values are the same, add slight buffer
            if bin_count == 1:
                bins = np.array([min_val - 0.1, min_val, min_val + 0.1])
                bin_count = 2
                print(f"Feature '{feature}': Constant value ({min_val}). Created 2 equal distance bins with buffer")

        # Add infinity edges to capture all values
        bins = bins.copy()
        bins[0] = -np.inf
        bins[-1] = np.inf

        print(f"Feature '{feature}': Created {bin_count} bins")

        # Create bin ranges dictionary
        bin_ranges = {}
        for i in range(len(bins)-1):
            bin_name = f"Bin_{i+1}"
            bin_ranges[bin_name] = {
                'min': bins[i],
                'max': bins[i+1],
                'range_str': f"[{bins[i]:.2f}, {bins[i+1]:.2f}]" if not np.isinf(bins[i]) and not np.isinf(bins[i+1]) else f"({bins[i]}, {bins[i+1]})"
            }

        binning_info[feature] = {
            'type': 'numerical',
            'bins': bins,
            'bin_ranges': bin_ranges,
            'bin_count': bin_count
        }

    # Create bins for categorical features (top 6 + others) using training period
    for feature in categorical_features:
        value_counts = train_period_df[feature].value_counts()
        unique_categories = value_counts.index.tolist()
        print(f"Unique categories: {unique_categories}")

        if len(unique_categories) <= 6:
            # Treat each category as a separate bin
            top_categories = unique_categories
        else:
            # Use top 6 categories only
            top_categories = value_counts.nlargest(6).index.tolist()

        print(f"Top categories for feature '{feature}': {top_categories}")

        binning_info[feature] = {
                'type': 'categorical',
                'top_categories': top_categories,
                'bin_ranges': {}  # No ranges for categorical
            }

    return binning_info


def apply_binning(df: pd.DataFrame,
                  feature: str,
                  binning_info: Dict) -> pd.Series:
    """
    Apply binning to a feature based on binning information.

    Parameters:
    -----------
    df : pd.DataFrame
        Input dataframe
    feature : str
        Feature name
    binning_info : Dict
        Binning information for the feature

    Returns:
    --------
    pd.Series with binned values
    """
    if binning_info['type'] == 'numerical':
        if binning_info['bins'] is None:
            return pd.Series(['Missing'] * len(df), index=df.index)

        bins = binning_info['bins']
        labels = [f"Bin_{i+1}" for i in range(len(bins)-1)]

        binned = pd.cut(df[feature],
                       bins=bins,
                       labels=labels,
                       include_lowest=True,
                       duplicates='drop')

        # Handle nulls - convert to string and then replace
        binned = binned.astype(str)
        binned[df[feature].isna()] = 'Missing'

        return binned

    else:  # categorical
        top_cats = binning_info['top_categories']

        # Convert to string for consistent comparison
        if pd.api.types.is_categorical_dtype(df[feature]):
            feature_data = df[feature].astype(str)
        else:
            feature_data = df[feature].astype(str)

        # Replace NaN string representation with 'Missing'
        feature_data = feature_data.replace('nan', 'Missing')

        # Convert top_cats to strings for comparison
        top_cats_str = [str(cat) for cat in top_cats]

        # Apply binning logic: use category name if in top_cats, else 'Others' (except for Missing)
        binned = feature_data.apply(lambda x: x if x in top_cats_str else ('Others' if x != 'Missing' else 'Missing'))

        return binned


def calculate_psi(expected_pct: pd.Series,
                  actual_pct: pd.Series,
                  epsilon: float = 0.0001) -> float:
    """
    Calculate Population Stability Index with proper epsilon handling and renormalization.

    Parameters:
    -----------
    expected_pct : pd.Series
        Expected (baseline) percentages
    actual_pct : pd.Series
        Actual percentages
    epsilon : float
        Small value to avoid log(0)

    Returns:
    --------
    PSI value
    """
    # Align indices
    all_bins = expected_pct.index.union(actual_pct.index)
    expected_pct = expected_pct.reindex(all_bins, fill_value=0)
    actual_pct = actual_pct.reindex(all_bins, fill_value=0)

    # Only add epsilon where values are zero
    expected_pct = expected_pct.apply(lambda x: epsilon if x == 0 else x)
    actual_pct = actual_pct.apply(lambda x: epsilon if x == 0 else x)

    # Renormalize to ensure they sum to 1 after adding epsilon
    expected_pct = expected_pct / expected_pct.sum()
    actual_pct = actual_pct / actual_pct.sum()

    # Calculate PSI
    psi_value = np.sum((actual_pct - expected_pct) * np.log(actual_pct / expected_pct))

    return psi_value


def calculate_month_on_month_psi(df: pd.DataFrame,
                                 feature_list: List[str],
                                 segment_columns: List[str],
                                 month_col: str = 'Application_month',
                                 data_selection_col: str = 'Data_selection',
                                 account_id_col: str = 'digitalLoanAccountId') -> pd.DataFrame:
    """
    Calculate PSI for each feature comparing training period (June 2024 to March 2025)
    vs each month after March 2025, overall and by segments.

    Parameters:
    -----------
    df : pd.DataFrame
        Input dataframe
    feature_list : List[str]
        List of features to calculate PSI for
    segment_columns : List[str]
        List of segment columns
    month_col : str
        Name of month column
    data_selection_col : str
        Name of data selection column (identifies train period)
    account_id_col : str
        Name of account ID column for counting distinct accounts

    Returns:
    --------
    pd.DataFrame with PSI values with one row per feature-month-segment combination
    """
    # Create a copy to avoid modifying original
    df = df.copy()

    # Identify training and test periods
    train_df = df[df[data_selection_col] == 'Train'].copy()
    test_df = df[df[data_selection_col] != 'Train'].copy()

    if len(train_df) == 0:
        raise ValueError("No training data found. Check Data_selection column.")

    print(f"Training period: {train_df[month_col].min()} to {train_df[month_col].max()}")
    print(f"Test period: {test_df[month_col].min()} to {test_df[month_col].max()}")

    # Identify feature types
    feature_types = identify_feature_types(df, feature_list)

    # Create binning strategy based on training period
    binning_info = create_bins_for_features(
        df,
        feature_types['numerical'],
        feature_types['categorical'],
        train_df
    )

    # Get sorted test months
    test_months = sorted(test_df[month_col].unique())

    results = []

    # Calculate overall PSI
    for feature in feature_list:
        if feature not in df.columns:
            continue

        # Apply binning to entire dataset
        df[f'{feature}_binned'] = apply_binning(df, feature, binning_info[feature])
        # print(f"Feature binned {df[f'{feature}_binned']}")
        # Get training period distribution (baseline)
        train_baseline = df[df[data_selection_col] == 'Train'][f'{feature}_binned'].value_counts(normalize=True)

        # Calculate PSI for each test month
        for month in test_months:
            actual_dist = df[df[month_col] == month][f'{feature}_binned'].value_counts(normalize=True)
            psi_value = calculate_psi(train_baseline, actual_dist)

            # Calculate average percentages across all bins
            expected_avg_pct = train_baseline.mean() * 100
            actual_avg_pct = actual_dist.mean() * 100

            # # Count distinct accounts for segment
            # base_segment_count = train_segment[account_id_col].nunique()
            # actual_segment_count = actual_segment[account_id_col].nunique()


            results.append({
                'Feature': feature,
                'Feature_Type': binning_info[feature]['type'],
                'Segment_Column': 'Overall',
                'Segment_Value': 'All',
                'Month': f"{month}",
                'Base_Month': 'Train (Jun 2024 - Mar 2025)',
                'Current_Month': month,
                'Expected_Percentage': expected_avg_pct,
                'Actual_Percentage': actual_avg_pct,
                'PSI': psi_value
            })

    # Calculate PSI by segments
    for segment_col in segment_columns:
        if segment_col not in df.columns:
            continue

        segments = df[segment_col].dropna().unique()

        for segment_val in segments:
            segment_df = df[df[segment_col] == segment_val]

            for feature in feature_list:
                if feature not in df.columns:
                    continue

                # Get training period distribution for segment
                train_segment = segment_df[segment_df[data_selection_col] == 'Train']
                if len(train_segment) == 0:
                    continue

                train_baseline = train_segment[f'{feature}_binned'].value_counts(normalize=True)

                # Calculate PSI for each test month
                for month in test_months:
                    actual_segment = segment_df[segment_df[month_col] == month]
                    if len(actual_segment) == 0:
                        continue

                    actual_dist = actual_segment[f'{feature}_binned'].value_counts(normalize=True)
                    psi_value = calculate_psi(train_baseline, actual_dist)

                    # Calculate average percentages across all bins
                    expected_avg_pct = train_baseline.mean() * 100
                    actual_avg_pct = actual_dist.mean() * 100

                    # Count distinct accounts for segment
                    base_segment_count = train_segment[account_id_col].nunique()
                    actual_segment_count = actual_segment[account_id_col].nunique()

                    results.append({
                        'Feature': feature,
                        'Feature_Type': binning_info[feature]['type'],
                        'Segment_Column': segment_col,
                        'Segment_Value': segment_val,
                        'Month': f"{month}",
                        'Base_Month': 'Train (Jun 2024 - Mar 2025)',
                        'Current_Month': month,
                        'Base_Count': base_segment_count,
                        'Actual_Count': actual_segment_count,
                        'Expected_Percentage': expected_avg_pct,
                        'Actual_Percentage': actual_avg_pct,
                        'PSI': psi_value
                    })

    return pd.DataFrame(results)


def calculate_bin_level_psi(df: pd.DataFrame,
                            feature_list: List[str],
                            segment_columns: List[str],
                            month_col: str = 'Application_month',
                            data_selection_col: str = 'Data_selection',
                            account_id_col: str = 'digitalLoanAccountId') -> pd.DataFrame:
    """
    Calculate bin-level PSI for each feature comparing training period
    vs each month after March 2025, overall and by segments.

    Parameters:
    -----------
    df : pd.DataFrame
        Input dataframe
    feature_list : List[str]
        List of features to calculate PSI for
    segment_columns : List[str]
        List of segment columns
    month_col : str
        Name of month column
    data_selection_col : str
        Name of data selection column
    account_id_col : str
        Name of account ID column for counting distinct accounts

    Returns:
    --------
    pd.DataFrame with bin-level PSI details including bin ranges
    """
    # Create a copy to avoid modifying original
    df = df.copy()

    # Identify training and test periods
    train_df = df[df[data_selection_col] == 'Train'].copy()
    test_df = df[df[data_selection_col] != 'Train'].copy()

    if len(train_df) == 0:
        raise ValueError("No training data found. Check Data_selection column.")

    print(f"Training period: {train_df[month_col].min()} to {train_df[month_col].max()}")
    print(f"Test period: {test_df[month_col].min()} to {test_df[month_col].max()}")

    # Identify feature types
    feature_types = identify_feature_types(df, feature_list)

    # Create binning strategy based on training period
    binning_info = create_bins_for_features(
        df,
        feature_types['numerical'],
        feature_types['categorical'],
        train_df
    )

    # Get sorted test months
    test_months = sorted(test_df[month_col].unique())

    results = []
    epsilon = 0.0001

    # Calculate overall bin-level PSI
    for feature in feature_list:
        if feature not in df.columns:
            continue

        # Apply binning to entire dataset
        df[f'{feature}_binned'] = apply_binning(df, feature, binning_info[feature])
        # print(df[f'{feature}_binned'])

        # Get training period distribution (baseline)
        train_baseline = df[df[data_selection_col] == 'Train'][f'{feature}_binned'].value_counts(normalize=True)

        # Calculate bin-level PSI for each test month
        for month in test_months:
            month_data = df[df[month_col] == month]
            actual_dist = month_data[f'{feature}_binned'].value_counts(normalize=True)

            # Count distinct accounts
            base_count = df[df[data_selection_col] == 'Train'][account_id_col].nunique()
            actual_count = month_data[account_id_col].nunique()

            # Get all bins
            all_bins = train_baseline.index.union(actual_dist.index)

            for bin_name in all_bins:
                # Simplified epsilon logic - no redundancy
                expected_pct = train_baseline.get(bin_name, 0)
                actual_pct = actual_dist.get(bin_name, 0)

                # Add epsilon only if zero
                expected_pct = epsilon if expected_pct == 0 else expected_pct
                actual_pct = epsilon if actual_pct == 0 else actual_pct

                # Calculate bin-level PSI
                bin_psi = (actual_pct - expected_pct) * np.log(actual_pct / expected_pct)

                # Get bin range information
                bin_ranges = binning_info[feature]['bin_ranges']
                if bin_name in bin_ranges:
                    bin_min = bin_ranges[bin_name]['min']
                    bin_max = bin_ranges[bin_name]['max']
                    bin_range = bin_ranges[bin_name]['range_str']
                else:
                    # For categorical or special bins (Missing, Others)
                    bin_min = None
                    bin_max = None
                    bin_range = bin_name

                results.append({
                    'Feature': feature,
                    'Feature_Type': binning_info[feature]['type'],
                    'Segment_Column': 'Overall',
                    'Segment_Value': 'All',
                    'Month': f"{month}",
                    'Base_Month': 'Train (Jun 2024 - Mar 2025)',
                    'Current_Month': month,
                    'Base_Count': base_count,
                    'Actual_Count': actual_count,
                    'Bin': bin_name,
                    'Bin_Range': bin_range,
                    'Bin_Min': bin_min,
                    'Bin_Max': bin_max,
                    'Base_Percentage': (train_baseline.get(bin_name, 0) * 100),
                    'Actual_Percentage': (actual_dist.get(bin_name, 0) * 100),
                    'Bin_PSI': bin_psi
                })

    # Calculate bin-level PSI by segments
    for segment_col in segment_columns:
        if segment_col not in df.columns:
            continue

        segments = df[segment_col].dropna().unique()

        for segment_val in segments:
            segment_df = df[df[segment_col] == segment_val]

            for feature in feature_list:
                if feature not in df.columns:
                    continue

                # Get training period distribution for segment
                train_segment = segment_df[segment_df[data_selection_col] == 'Train']
                if len(train_segment) == 0:
                    continue

                train_baseline = train_segment[f'{feature}_binned'].value_counts(normalize=True)

                # Calculate bin-level PSI for each test month
                for month in test_months:
                    actual_segment = segment_df[segment_df[month_col] == month]
                    if len(actual_segment) == 0:
                        continue

                    actual_dist = actual_segment[f'{feature}_binned'].value_counts(normalize=True)

                    # Count distinct accounts for segment
                    base_segment_count = train_segment[account_id_col].nunique()
                    actual_segment_count = actual_segment[account_id_col].nunique()

                    # Get all bins
                    all_bins = train_baseline.index.union(actual_dist.index)

                    for bin_name in all_bins:
                        # Simplified epsilon logic - no redundancy
                        expected_pct = train_baseline.get(bin_name, 0)
                        actual_pct = actual_dist.get(bin_name, 0)

                        # Add epsilon only if zero
                        expected_pct = epsilon if expected_pct == 0 else expected_pct
                        actual_pct = epsilon if actual_pct == 0 else actual_pct

                        # Calculate bin-level PSI
                        bin_psi = (actual_pct - expected_pct) * np.log(actual_pct / expected_pct)

                        # Get bin range information
                        bin_ranges = binning_info[feature]['bin_ranges']
                        if bin_name in bin_ranges:
                            bin_min = bin_ranges[bin_name]['min']
                            bin_max = bin_ranges[bin_name]['max']
                            bin_range = bin_ranges[bin_name]['range_str']
                        else:
                            # For categorical or special bins (Missing, Others)
                            bin_min = None
                            bin_max = None
                            bin_range = bin_name

                        results.append({
                            'Feature': feature,
                            'Feature_Type': binning_info[feature]['type'],
                            'Segment_Column': segment_col,
                            'Segment_Value': segment_val,
                            'Month': f"{month}",
                            'Base_Month': 'Train (Jun 2024 - Mar 2025)',
                            'Current_Month': month,
                            'Base_Count': base_segment_count,
                            'Actual_Count': actual_segment_count,
                            'Bin': bin_name,
                            'Bin_Range': bin_range,
                            'Bin_Min': bin_min,
                            'Bin_Max': bin_max,
                            'Base_Percentage': (train_baseline.get(bin_name, 0) * 100),
                            'Actual_Percentage': (actual_dist.get(bin_name, 0) * 100),
                            'Bin_PSI': bin_psi
                        })

    return pd.DataFrame(results)

# %% [markdown]
# # SIL V1

# %% [markdown]
# ## SIL

# %% [markdown]
# #### Query from risk_mart.sil_risk_ds_master_20230101_20250309_v2

# %% [markdown]
# ##### 'Alpha - CIC-SIL-Model'

# %%
sq = """select distinct
    r.customerId customer_id ,
    r.digitalLoanAccountId,
    r.cic_score,
    r.cic_Personal_Loans_granted_contracts_amt_24M,
    r.cic_days_since_last_inquiry, 
    r.cic_cnt_active_contracts,
    r.cic_vel_contract_nongranted_cnt_12on24,
    r.cic_max_amt_granted_24M, 
    r.cic_zero_non_granted_ever_flag,
    r.cic_tot_active_contracts_util,
    r.cic_vel_contract_granted_amt_12on24,
    r.cic_zero_granted_ever_flag,
    case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
    when lower(loanmaster.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
    date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
    case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
         between '2024-06-01' and '2024-09-30' then 'Dev_Train'
         when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-06-01' then 'Pre_Train'
                  else 'Dev_Test' end as Data_selection 
from risk_mart.sil_risk_ds_master_20230101_20250309_v2 r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where cic_score is not null
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-03-24'
;"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 07f74d21-e436-4b84-bd78-6ba07bdaa89f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (204452, 15)

# %%
feature_column = ['cic_Personal_Loans_granted_contracts_amt_24M',
       'cic_days_since_last_inquiry', 'cic_cnt_active_contracts',
       'cic_vel_contract_nongranted_cnt_12on24', 'cic_max_amt_granted_24M',
       'cic_zero_non_granted_ever_flag', 'cic_tot_active_contracts_util',
       'cic_vel_contract_granted_amt_12on24', 'cic_zero_granted_ever_flag']

# %%
dfd = transform_data(data, feature_column, a='cic_score', modelDisplayName='Alpha - CIC-SIL-Model') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3158206  c39ad1ba-a964-4e64-8243-738f06e558d9
# 1     3225922  b570689e-786d-4a35-88f7-1a30e1b6198d
# 2     3128551  751a6d85-c838-4ea0-9f88-9c3a4bb0e59e
# 3     3030181  97456544-c064-4ffb-ac9f-d0e766006c0b
# 4     3134968  6d5b39aa-2be5-4307-9d62-53d2fb8e3803
#
#                       crifApplicationId  prediction  \
# 0  8c74024c-b8af-4e2f-a3b7-f28d918854b9    0.111643
# 1  5920139b-10ac-46d2-946e-53a2a6531a0e    0.062540
# 2  027f939b-394d-4fc1-b40a-69f8833cb588    0.126979
# 3  f21b9b43-6647-44b4-b25e-14654a6398e9    0.171253
# 4  652a5041-72b7-44e6-bfb7-902ac19503bc    0.123928
#
#                    start_time                    end_time  \
# 0  2026-01-16T18:58:04.150981  2026-01-16T18:58:04.150981
# 1  2026-01-16T18:58:04.150981  2026-01-16T18:58:04.150981
# 2  2026-01-16T18:58:04.150981  2026-01-16T18:58:04.150981
# 3  2026-01-16T18:58:04.150981  2026-01-16T18:58:04.150981
# 4  2026-01-16T18:58:04.150981  2026-01-16T18:58:04.150981
#
#         modelDisplayName modelVersionId  \
# 0  Alpha - CIC-SIL-Model             v1
# 1  Alpha - CIC-SIL-Model             v1
# 2  Alpha - CIC-SIL-Model             v1
# 3  Alpha - CIC-SIL-Model             v1
# 4  Alpha - CIC-SIL-Model             v1
#
#                                          calcFeature    subscription_name  \
# 0  {"cic_Personal_Loans_granted_contracts_amt_24M...  sil_march 25 models
# 1  {"cic_Personal_Loans_granted_contracts_amt_24M...  sil_march 25 models
# 2  {"cic_days_since_last_inquiry": 1788.0, "cic_z...  sil_march 25 models
# 3  {"cic_days_since_last_inquiry": 580.0, "cic_cn...  sil_march 25 models
# 4  {"cic_days_since_last_inquiry": 2139.0, "cic_z...  sil_march 25 models
#
#                              message_id                publish_time  \
# 0  8e558cd3-2f4f-4ece-bcd6-b9d4bc0e96f9  2026-01-16T18:58:04.150981
# 1  c7abafdb-743d-4f67-a167-47a45e9b588f  2026-01-16T18:58:04.150981
# 2  7c1b7555-8ab6-43a1-9dd0-442e61de3ab9  2026-01-16T18:58:04.150981
# 3  706b5699-c9cf-4163-8df4-26af06804cd4  2026-01-16T18:58:04.150981
# 4  987f55ae-475a-42ac-957d-d82ba03d921e  2026-01-16T18:58:04.150981
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}                 android       Dev_Test       2024-12-31
# 1         {}                 android       Dev_Test       2025-01-30
# 2         {}                 android       Dev_Test       2024-12-22
# 3         {}                 android       Dev_Test       2024-11-16
# 4         {}                 android       Dev_Test       2024-12-24

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      105730           2024-10-01
# 1      Dev_Train                       62128           2024-06-01
# 2      Pre_Train                       36594           2023-01-10
#
#   Application_date_max
# 0           2025-03-08
# 1           2024-09-30
# 2           2024-05-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_TRUNCATE",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=5ae69575-5225-426e-b3a5-e1e29dfdda46>

# %% [markdown]
# ##### Alpha Sil Stack Model

# %%
sq = """ 
select distinct 
r.customerId customer_id ,
r.digitalLoanAccountId,
r.alpha_stack_score,
r.beta_demo_score,
r.cic_score,
r.apps_score,
r.credo_gen_score,
    case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
    when lower(loanmaster.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
        between '2024-06-01' and '2024-09-30' then 'Dev_Train'
        when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-06-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from `risk_mart.sil_risk_ds_master_20230101_20250309_v2` r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where alpha_stack_score is not null
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-03-24'
;
"""

data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 0d121a81-367e-4a65-864d-f931045c7181 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (204452, 10)

# %%
data.columns
data.rename(columns={'beta_demo_score':'sb_demo_score', 'cic_score':'s_cic_score', 
                    'apps_score':'s_apps_score', 'credo_gen_score':'s_credo_score'}, inplace = True)
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'alpha_stack_score',
#        'sb_demo_score', 's_cic_score', 's_apps_score', 's_credo_score',
#        'osType', 'application_date', 'Data_selection'],
#       dtype='object')

# %%
feature_column = ['sb_demo_score',
       's_cic_score', 's_apps_score',
       's_credo_score']

dfd = transform_data(data, feature_column, a='alpha_stack_score', modelDisplayName='Alpha - StackingModel') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3087990  8468bd95-9923-4e0b-acce-1587086bbca0
# 1     2992547  74caa9f6-12a6-41f3-ad18-9395c8fe8332
# 2     2625018  b66871f0-93e6-4911-aea5-adc28e5bfc39
# 3     3282225  112cbc02-e738-4b58-b024-3a2465d912c9
# 4     3151085  bde4c009-cbcd-4efd-9c48-1f6110ac4885
#
#                       crifApplicationId  prediction  \
# 0  5873f52e-1973-43b1-9597-efd3dc6b374b    0.104518
# 1  ab82c81b-c52d-454d-80d0-eae47408ad94    0.169490
# 2  5f27eb96-874c-4f24-b0d5-f09211f4929d    0.168892
# 3  f1867ddc-7a44-4f59-8b91-146576afd606    0.064417
# 4  e17833e0-4666-40a1-a71a-0d5e7d627eda    0.062758
#
#                    start_time                    end_time  \
# 0  2026-01-16T18:58:42.049315  2026-01-16T18:58:42.049315
# 1  2026-01-16T18:58:42.049315  2026-01-16T18:58:42.049315
# 2  2026-01-16T18:58:42.049859  2026-01-16T18:58:42.049859
# 3  2026-01-16T18:58:42.049859  2026-01-16T18:58:42.049859
# 4  2026-01-16T18:58:42.049859  2026-01-16T18:58:42.049859
#
#         modelDisplayName modelVersionId  \
# 0  Alpha - StackingModel             v1
# 1  Alpha - StackingModel             v1
# 2  Alpha - StackingModel             v1
# 3  Alpha - StackingModel             v1
# 4  Alpha - StackingModel             v1
#
#                                          calcFeature    subscription_name  \
# 0  {"sb_demo_score": 0.04610937573196949, "s_cic_...  sil_march 25 models
# 1  {"sb_demo_score": 0.050932196445083365, "s_cic...  sil_march 25 models
# 2  {"sb_demo_score": 0.040556951574585776, "s_cic...  sil_march 25 models
# 3  {"sb_demo_score": 0.06461247927584647, "s_cic_...  sil_march 25 models
# 4  {"sb_demo_score": 0.037545327221006786, "s_cic...  sil_march 25 models
#
#                              message_id                publish_time  \
# 0  f8c6ed09-e42c-4ad4-a828-e7a67cd7b52f  2026-01-16T18:58:42.049315
# 1  b29bcd42-f1ed-4acd-bcf4-ba25eabc626c  2026-01-16T18:58:42.049315
# 2  c6d2fe5d-dad6-4fd4-b0a3-dad4ebf4e063  2026-01-16T18:58:42.049859
# 3  d966d84c-a972-4ffb-b5e2-d66d71a321bd  2026-01-16T18:58:42.049859
# 4  6c4dad92-ac8a-487f-a66b-b23fed29280a  2026-01-16T18:58:42.049859
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}                     ios       Dev_Test       2024-12-08
# 1         {}                 android       Dev_Test       2024-11-02
# 2         {}                 android       Dev_Test       2024-12-18
# 3         {}                 android       Dev_Test       2025-02-23
# 4         {}                 android       Dev_Test       2024-12-29

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      105730           2024-10-01
# 1      Dev_Train                       62128           2024-06-01
# 2      Pre_Train                       36594           2023-01-10
#
#   Application_date_max
# 0           2025-03-08
# 1           2024-09-30
# 2           2024-05-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=7a3fe889-039c-4262-8a10-a51c78b64996>

# %% [markdown]
# ##### Beta Sil App Score

# %%
sq = """ 
select distinct
r.customerId customer_id ,
r.digitalLoanAccountId,
r.apps_score,
r.app_cnt_absence_tag_30d,
r.app_cnt_absence_tag_90d ,
r.app_cnt_business_ever ,
r.app_cnt_competitors_30d ,
r.app_cnt_competitors_90d ,
r.app_cnt_education_ever ,
r.app_cnt_finance_7d ,
r.app_cnt_finance_90d ,
r.app_cnt_music_and_audio_ever ,
r.app_cnt_payday_90d ,
r.app_cnt_rated_for_3plus_ever ,
r.app_cnt_travel_and_local_ever ,
r.app_first_competitors_install_to_apply_days ,
r.app_first_payday_install_to_apply_days ,
r.app_median_time_bw_installed_mins_30d ,
r.app_vel_finance_30_over_365 ,
    case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
    when lower(loanmaster.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
    date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
    case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
         between '2023-12-01' and '2024-06-30' then 'Dev_Train'
         when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2023-12-01' then 'Pre_Train'
                  else 'Dev_Test' end as Data_selection 
from `risk_mart.sil_risk_ds_master_20230101_20250309_v2` r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where apps_score is not null
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-03-20'
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID dfba6daf-fada-414c-875d-5f74247176d8 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (317384, 22)

# %%
feature_column = ['app_cnt_rated_for_3plus_ever',
       'app_cnt_education_ever', 'app_cnt_business_ever',
       'app_cnt_music_and_audio_ever',
       'app_cnt_travel_and_local_ever', 'app_cnt_finance_7d',
       'app_cnt_competitors_30d', 'app_cnt_absence_tag_30d',
        'app_cnt_absence_tag_90d',
       'app_cnt_finance_90d', 'app_cnt_competitors_90d',
       'app_cnt_payday_90d',
       'app_median_time_bw_installed_mins_30d',
       'app_first_competitors_install_to_apply_days',
       'app_first_payday_install_to_apply_days',
       'app_vel_finance_30_over_365']

dfd = transform_data(data, feature_column, a='apps_score', modelDisplayName='Beta - AppsScoreModel') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3103458  cc62d316-c660-44c9-8c05-ff1663e721e5
# 1     3070608  1414bc01-1610-481b-9138-3a5025a52e7b
# 2     2651145  627782b6-b173-4d80-85fe-d18b45fd6d94
# 3     3068948  6c6bff11-f5f3-447e-8563-cd58aa1047ca
# 4     2597384  3dc38d31-1f65-418c-b5dd-26592a512f7d
#
#                       crifApplicationId  prediction  \
# 0  f93a6db6-79df-42f4-a75a-a1d5fc42718d    0.453011
# 1  2cbe2d03-1ebf-4141-bc0f-6809a2bcd0e1    0.449715
# 2  51a8eac9-48f5-47c3-817b-2f74d0075875    0.344799
# 3  af311097-89cd-4cd7-80ff-1af7e318ac37    0.674630
# 4  9f9146db-2df3-4d53-bf47-b2f86cdd8530    0.547522
#
#                    start_time                    end_time  \
# 0  2026-01-16T18:59:13.660184  2026-01-16T18:59:13.660184
# 1  2026-01-16T18:59:13.660184  2026-01-16T18:59:13.660184
# 2  2026-01-16T18:59:13.660184  2026-01-16T18:59:13.660184
# 3  2026-01-16T18:59:13.660184  2026-01-16T18:59:13.660184
# 4  2026-01-16T18:59:13.661124  2026-01-16T18:59:13.661124
#
#         modelDisplayName modelVersionId  \
# 0  Beta - AppsScoreModel             v1
# 1  Beta - AppsScoreModel             v1
# 2  Beta - AppsScoreModel             v1
# 3  Beta - AppsScoreModel             v1
# 4  Beta - AppsScoreModel             v1
#
#                                          calcFeature    subscription_name  \
# 0  {"app_cnt_rated_for_3plus_ever": 15.0, "app_cn...  sil_march 25 models
# 1  {"app_cnt_rated_for_3plus_ever": 17.0, "app_cn...  sil_march 25 models
# 2  {"app_cnt_rated_for_3plus_ever": 31.0, "app_cn...  sil_march 25 models
# 3  {"app_cnt_rated_for_3plus_ever": 6.0, "app_cnt...  sil_march 25 models
# 4  {"app_cnt_rated_for_3plus_ever": 16.0, "app_cn...  sil_march 25 models
#
#                              message_id                publish_time  \
# 0  98eb37dc-59b3-4bda-b57f-78063f6cfc08  2026-01-16T18:59:13.660184
# 1  70cc6b9b-0d8d-4e9f-97a4-afd28eb3f45d  2026-01-16T18:59:13.660184
# 2  5d107aa1-c2e9-4f0a-90a0-5cb3067c212a  2026-01-16T18:59:13.660184
# 3  db3301bc-7e29-4e8e-9522-fd6dc02d6723  2026-01-16T18:59:13.660184
# 4  399b63b8-b589-4f22-8c06-796f9907db14  2026-01-16T18:59:13.661124
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}                 android       Dev_Test       2024-12-14
# 1         {}                 android       Dev_Test       2024-12-01
# 2         {}                 android       Dev_Test       2024-07-11
# 3         {}                 android       Dev_Test       2024-12-01
# 4         {}                 android      Dev_Train       2024-06-21

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      200327           2024-07-01
# 1      Dev_Train                       86480           2023-12-01
# 2      Pre_Train                       30577           2023-01-02
#
#   Application_date_max
# 0           2025-03-08
# 1           2024-06-30
# 2           2023-11-30

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=b6d0efbe-991d-4846-8187-f2753fe65cf8>

# %% [markdown]
# ##### Beta SIL Demo Score

# %%
sq = """
select distinct
r.customerId customer_id ,
r.digitalLoanAccountId,
r.beta_demo_score,
r.beta_de_ln_vas_opted_flag ,
r.beta_de_ln_doc_type_rolled ,
r.beta_de_ln_marital_status ,
r.beta_de_ln_age_bin ,
r.beta_de_ln_province_bin ,
r.beta_de_ln_ref2_type ,
r.beta_de_ln_education_level ,
r.beta_de_ln_ref1_type ,
r.beta_de_ln_industry_new_bin ,
r.beta_de_ln_appln_day_of_week ,
r.beta_de_onb_name_email_match_score ,
r.beta_de_ln_employment_type_new_bin ,
r.beta_de_ln_telconame ,
r.beta_de_time_bw_onb_loan_appln_mins ,
r.beta_de_ln_source_of_funds_new_bin ,
r.beta_de_ln_brand_bin ,
r.beta_de_ln_email_primary_domain ,
    case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
    when lower(loanmaster.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
        between '2023-07-01' and '2024-06-30' then 'Dev_Train'
        when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2023-07-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from `risk_mart.sil_risk_ds_master_20230101_20250309_v2` r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where beta_demo_score is not null
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-03-20'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 9646855d-b148-4a37-a2a4-685814524afb successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (349206, 23)

# %%
feature_column = ['beta_de_ln_vas_opted_flag',
       'beta_de_ln_doc_type_rolled', 'beta_de_ln_marital_status',
       'beta_de_ln_age_bin', 'beta_de_ln_province_bin',
       'beta_de_ln_ref2_type', 'beta_de_ln_education_level',
       'beta_de_ln_ref1_type', 'beta_de_ln_industry_new_bin',
       'beta_de_ln_appln_day_of_week',
       'beta_de_onb_name_email_match_score',
       'beta_de_ln_employment_type_new_bin', 'beta_de_ln_telconame',
       'beta_de_time_bw_onb_loan_appln_mins',
       'beta_de_ln_source_of_funds_new_bin', 'beta_de_ln_brand_bin',
       'beta_de_ln_email_primary_domain']

dfd = transform_data(data, feature_column, a='beta_demo_score', modelDisplayName='Beta - DemoScoreModel') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2561460  eb3dd89c-76cc-4560-b166-0ea16f506462
# 1     3158206  c39ad1ba-a964-4e64-8243-738f06e558d9
# 2     2455037  dd176042-215f-4a0e-9a65-3095319dd6dd
# 3     2386268  9bcd390e-abea-48f0-b796-474665136faa
# 4     2314459  60958308-f1c8-4302-b68e-c56e8a79a479
#
#                       crifApplicationId  prediction  \
# 0  bb8dd8c9-0453-4c55-866f-ea9161062e95    0.137240
# 1  00f63b95-b135-4845-8e85-5ffe4fc7e7bb    0.024513
# 2  8b51fa67-fa72-46bc-9881-34e0442d9d45    0.030435
# 3  044d0b85-ff89-4e9d-a66a-d5460c1fde94    0.138983
# 4  cfcb3ded-07ef-42de-9402-6b4def498383    0.033254
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:00:28.376357  2026-01-16T19:00:28.376357
# 1  2026-01-16T19:00:28.377489  2026-01-16T19:00:28.377489
# 2  2026-01-16T19:00:28.378212  2026-01-16T19:00:28.378212
# 3  2026-01-16T19:00:28.378682  2026-01-16T19:00:28.378682
# 4  2026-01-16T19:00:28.378682  2026-01-16T19:00:28.378682
#
#         modelDisplayName modelVersionId  \
# 0  Beta - DemoScoreModel             v1
# 1  Beta - DemoScoreModel             v1
# 2  Beta - DemoScoreModel             v1
# 3  Beta - DemoScoreModel             v1
# 4  Beta - DemoScoreModel             v1
#
#                                          calcFeature    subscription_name  \
# 0  {"beta_de_ln_vas_opted_flag": "1", "beta_de_ln...  sil_march 25 models
# 1  {"beta_de_ln_vas_opted_flag": "0", "beta_de_ln...  sil_march 25 models
# 2  {"beta_de_ln_vas_opted_flag": "0", "beta_de_ln...  sil_march 25 models
# 3  {"beta_de_ln_vas_opted_flag": "1", "beta_de_ln...  sil_march 25 models
# 4  {"beta_de_ln_vas_opted_flag": "0", "beta_de_ln...  sil_march 25 models
#
#                              message_id                publish_time  \
# 0  8a1a28b3-6663-46e3-b9d9-1b76cbd7819e  2026-01-16T19:00:28.376357
# 1  c40fbffa-ad0a-4ed7-bae5-8a772a24254e  2026-01-16T19:00:28.377489
# 2  5a3c45a8-ad4b-4c2e-aadc-287c12ce6226  2026-01-16T19:00:28.378212
# 3  0dede965-4a7b-4520-9cf6-ce8d0ab83a18  2026-01-16T19:00:28.378682
# 4  10ca105e-720e-434c-934a-d5aab4e8bd49  2026-01-16T19:00:28.378682
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}                 android      Dev_Train       2024-06-08
# 1         {}                 android       Dev_Test       2024-12-31
# 2         {}                 android      Dev_Train       2024-04-07
# 3         {}                 android       Dev_Test       2024-09-11
# 4         {}                 android      Dev_Train       2023-11-25

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      219881           2024-07-01
# 1      Dev_Train                      121661           2023-07-01
# 2      Pre_Train                        7664           2023-01-02
#
#   Application_date_max
# 0           2025-03-08
# 1           2024-06-30
# 2           2023-06-30

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=1fead81f-3ad7-4bf8-8ca5-1ebf6f6b7440>

# %% [markdown]
# ##### Beta SIL STACK Score Model

# %%
sq = """ 
select  distinct
r.customerId customer_id ,
r.digitalLoanAccountId,
r.beta_stack_score,
r.apps_score,
r.credo_gen_score,
r.beta_demo_score,
    case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
    when lower(loanmaster.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
        between '2023-07-01' and '2024-06-30' then 'Dev_Train'
        when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2023-07-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from `risk_mart.sil_risk_ds_master_20230101_20250309_v2` r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where beta_stack_score is not null
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-03-20'
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 70e4c027-4e3a-4fb5-9a96-c467d448081c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (349206, 9)

# %%
feature_column = ['apps_score', 'credo_gen_score', 'beta_demo_score']
dfd = transform_data(data, feature_column, a='beta_stack_score', modelDisplayName='Beta - StackScoreModel') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2130424  734dca99-1855-4e7d-98da-ffce2c046821
# 1     2952382  65e263cb-eaf1-443f-9597-050f80e62115
# 2     3167088  9f603063-d9df-42a4-ada4-67afb4b7e1a0
# 3     3269771  bcb5a3b1-7cf9-466a-ad02-85d759f63815
# 4     2828784  ca693717-f845-454c-9849-090dbd3fa2c2
#
#                       crifApplicationId  prediction  \
# 0  62d28ebe-f399-4a9e-964a-16b4ec13f290    0.224589
# 1  c6b022fd-c28a-4142-8d1b-a462e2ec1b61    0.126538
# 2  dda174d3-ca28-4d24-9a18-d260fd4958ab    0.037583
# 3  ee89b2f9-a037-4ad5-8e84-142e0bf150f8    0.140824
# 4  b5356837-e140-40d8-92a0-9186fe1885b2    0.219287
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:02:30.543857  2026-01-16T19:02:30.543857
# 1  2026-01-16T19:02:30.543857  2026-01-16T19:02:30.543857
# 2  2026-01-16T19:02:30.543857  2026-01-16T19:02:30.543857
# 3  2026-01-16T19:02:30.543857  2026-01-16T19:02:30.543857
# 4  2026-01-16T19:02:30.543857  2026-01-16T19:02:30.543857
#
#          modelDisplayName modelVersionId  \
# 0  Beta - StackScoreModel             v1
# 1  Beta - StackScoreModel             v1
# 2  Beta - StackScoreModel             v1
# 3  Beta - StackScoreModel             v1
# 4  Beta - StackScoreModel             v1
#
#                                          calcFeature    subscription_name  \
# 0  {"apps_score": 0.6629442952561168, "credo_gen_...  sil_march 25 models
# 1  {"apps_score": 0.6466370819141358, "credo_gen_...  sil_march 25 models
# 2  {"apps_score": 0.483975863828331, "credo_gen_s...  sil_march 25 models
# 3  {"apps_score": 0.5683297917922486, "credo_gen_...  sil_march 25 models
# 4  {"apps_score": 0.6306743857175309, "credo_gen_...  sil_march 25 models
#
#                              message_id                publish_time  \
# 0  6c1c922c-5c24-4d00-a303-e64c2b48f95e  2026-01-16T19:02:30.543857
# 1  f082ba45-b1ba-4db4-8850-c33c7645ae60  2026-01-16T19:02:30.543857
# 2  5615abc2-ee2e-402f-a33e-67a5cb13cd9c  2026-01-16T19:02:30.543857
# 3  d77b9e76-3117-42ae-9c25-e88c1b62372d  2026-01-16T19:02:30.543857
# 4  d8a66e5c-b108-4206-91d2-7bfeb60e3b72  2026-01-16T19:02:30.543857
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}                 android       Dev_Test       2024-09-21
# 1         {}                 android       Dev_Test       2024-10-18
# 2         {}                 android       Dev_Test       2025-01-04
# 3         {}                 android       Dev_Test       2025-02-18
# 4         {}                 android       Dev_Test       2024-09-07

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      219881           2024-07-01
# 1      Dev_Train                      121661           2023-07-01
# 2      Pre_Train                        7664           2023-01-02
#
#   Application_date_max
# 0           2025-03-08
# 1           2024-06-30
# 2           2023-06-30

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=2a0fde92-56b5-4433-846a-a2b7f3528ecc>

# %% [markdown]
# ##### Alpha  - IncomeEstimationModel

# %%
# sq = """  
# Select 
# distinct
# r.customerId customer_id ,
# r.digitalLoanAccountId,
# r.alpha_estimated_income,
# r.inc_alpha_cic_credit_avg_credit_limit,
# r.inc_alpha_cic_max_active_contracts_amt,
# r.inc_alpha_ln_company_name,
# r.inc_alpha_ln_age,
# r.inc_alpha_doc_type_rolled,
# r.inc_alpha_ln_brand,
# r.inc_alpha_ln_city,
# r.inc_alpha_ln_cnt_dependents,
# r.inc_alpha_ln_education_level,
# r.inc_alpha_ln_employment_type_new,
# r.inc_alpha_ln_gender,
# r.inc_alpha_ln_industry_new,
# r.inc_alpha_ln_loan_prod_type,
# r.inc_alpha_ln_marital_status_new,
# r.inc_alpha_ln_nature_of_work_new,
# r.inc_alpha_ln_osversion_bin,
# r.inc_alpha_ln_purpose,
# r.inc_alpha_ln_source_of_funds_new,
# r.inc_alpha_loan_monthly_income,
# r.inc_alpha_encoded_company_name_grouped,
#     case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
#     when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
#     when lower(loanmaster.deviceType) like '%andro%' then 'android'
#     else 'ios' end osType,
# from `risk_mart.sil_risk_ds_master_20230101_20250309_v2` r
# left join risk_credit_mis.loan_master_table loanmaster
#   ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
# where r.alpha_estimated_income is not null
# ;
# """
# data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
# print(f"The shape of the dataframe is:\t {data.shape}")

# %%
# feature_column = ['inc_alpha_cic_credit_avg_credit_limit',
#        'inc_alpha_cic_max_active_contracts_amt', 'inc_alpha_ln_age',
#        'inc_alpha_doc_type_rolled', 'inc_alpha_ln_brand', 'inc_alpha_ln_city',
#        'inc_alpha_ln_cnt_dependents', 'inc_alpha_ln_education_level',
#        'inc_alpha_ln_employment_type_new', 'inc_alpha_ln_gender',
#        'inc_alpha_ln_industry_new', 'inc_alpha_ln_loan_prod_type',
#        'inc_alpha_ln_marital_status_new', 'inc_alpha_ln_nature_of_work_new',
#        'inc_alpha_ln_osversion_bin', 'inc_alpha_ln_purpose',
#        'inc_alpha_ln_source_of_funds_new',
#        'inc_alpha_encoded_company_name_grouped']
# dfd = transform_data(data, feature_column, a='alpha_estimated_income', modelDisplayName='Alpha  - IncomeEstimationModel') 
# dfd.head()

# %%
# # Upload to BigQuery
# table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details"
# job_config = bigquery.LoadJobConfig(
#     write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
# )
# job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
# job.result()

# %% [markdown]
# ##### Beta - IncomeEstimationModel

# %%
# sq = """ 
# select
# distinct
# r.customerId customer_id ,
# r.digitalLoanAccountId,
# r.beta_estimated_income,
# r.inc_beta_ln_loan_type,
# r.inc_beta_ln_education_level,
# r.inc_beta_ln_employment_type_new,
# r.inc_beta_ln_industry_new,
# r.inc_beta_ln_age,
# r.inc_beta_ln_brand,
# r.inc_beta_ln_city,
# r.inc_beta_ln_purpose,
# r.inc_beta_ln_osversion_bin,
# r.inc_beta_ln_postal_code,
# r.inc_beta_ln_gender,
# r.inc_beta_ln_doc_type_rolled,
# r.inc_beta_ln_cnt_dependents,
# r.inc_beta_ln_source_of_funds_new,
# r.inc_beta_ln_marital_status_new,
# r.inc_beta_encoded_company_name_grouped,
#     case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
#     when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
#     when lower(loanmaster.deviceType) like '%andro%' then 'android'
#     else 'ios' end osType,
# from `risk_mart.sil_risk_ds_master_20230101_20250309_v2` r
# left join risk_credit_mis.loan_master_table loanmaster
#   ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
# where r.alpha_estimated_income is not null
# ;
# """

# # data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
# data = client.query(sq).result().to_arrow().to_pandas()
# print(f"The shape of the dataframe is:\t {data.shape}")

# %%
# feature_column = ['inc_beta_ln_loan_type',
#        'inc_beta_ln_education_level', 'inc_beta_ln_employment_type_new',
#        'inc_beta_ln_industry_new', 'inc_beta_ln_age', 'inc_beta_ln_brand',
#        'inc_beta_ln_city', 'inc_beta_ln_purpose', 'inc_beta_ln_osversion_bin',
#        'inc_beta_ln_postal_code', 'inc_beta_ln_gender',
#        'inc_beta_ln_doc_type_rolled', 'inc_beta_ln_cnt_dependents',
#        'inc_beta_ln_source_of_funds_new', 'inc_beta_ln_marital_status_new',
#        'inc_beta_encoded_company_name_grouped',]

# dfd = transform_data(data, feature_column, a='beta_estimated_income', modelDisplayName='Beta - IncomeEstimationModel') 
# dfd.head()

# %%
# # Upload to BigQuery
# table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details"
# job_config = bigquery.LoadJobConfig(
#     write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
# )
# job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
# job.result()

# %% [markdown]
# # Cash V1

# %% [markdown]
# ## Cash

# %% [markdown]
# ##### Alpha Cash Stack Model

# %% [markdown]
# ###### Trench 1

# %%
sq = """ 
select 
  r.customer_id,
  r.digitalLoanAccountId, 
  r.stack_score,
  r.demo_score,
  r.apps_score,
  r.credo_score,
  r.cic_score,
  r.stack_score_norm,
  r.ln_os_type osType,
   date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
    case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
         between '2024-10-01' and '2025-02-28' then 'Dev_Train'
         when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-10-01' then 'Pre_Train'
                  else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.cash_alpha_trench1_applied_loans_backscored_20241001_20250930 r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where r.stack_score is not null
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
< '2025-09-24'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID bf2a6d7f-914b-4152-98c0-c646abbca54d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (66557, 11)

# %%
feature_column = ['demo_score', 'apps_score', 'credo_score', 'cic_score', 'stack_score_norm']

dfd = transform_data(data, feature_column, a='stack_score', modelDisplayName='Alpha-Cash-Stack-Model', tc='Trench 1', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3539916  d9fc0103-3b8c-40b7-8d8f-08134a93ea40
# 1     3205807  29054353-e84c-4a9c-a1e2-f1d8909c4688
# 2     2935267  ef3ab600-5807-4ab4-a90b-d2782f3ab7e0
# 3     2998273  59c1820a-1856-4ea0-a650-d964e39c161e
# 4     3649023  1ddeda21-9080-49b6-8463-39c270675282
#
#                       crifApplicationId  prediction  \
# 0  ff6be8a5-2d10-4dda-9783-c33eb22a1eb2    0.649931
# 1  7b0c5b0e-8f06-4ddf-9b38-4763dafb5bf3    0.278879
# 2  72bf4e46-087f-41ba-9d3d-33b2cb505013    0.660423
# 3  557723f2-b3b7-4e2f-b0ec-757dcc3b039e    0.424680
# 4  f1653080-b33f-46c7-9d89-41aec3c4e79b    0.072850
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:03:36.251926  2026-01-16T19:03:36.251926
# 1  2026-01-16T19:03:36.251926  2026-01-16T19:03:36.251926
# 2  2026-01-16T19:03:36.251926  2026-01-16T19:03:36.251926
# 3  2026-01-16T19:03:36.251926  2026-01-16T19:03:36.251926
# 4  2026-01-16T19:03:36.251926  2026-01-16T19:03:36.251926
#
#          modelDisplayName modelVersionId  \
# 0  Alpha-Cash-Stack-Model             v1
# 1  Alpha-Cash-Stack-Model             v1
# 2  Alpha-Cash-Stack-Model             v1
# 3  Alpha-Cash-Stack-Model             v1
# 4  Alpha-Cash-Stack-Model             v1
#
#                                          calcFeature  \
# 0  {"demo_score": 0.6710895323120418, "apps_score...
# 1  {"demo_score": 0.3578060436820136, "apps_score...
# 2  {"demo_score": 0.45709714420066894, "apps_scor...
# 3  {"demo_score": 0.5780086653092011, "apps_score...
# 4  {"demo_score": 0.3100500464022585, "apps_score...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  a5eb8476-3733-403b-9390-9a659eedfd1a
# 1  Cash September 25 Models  61bfea04-3fd8-4af5-98cf-36db19963bae
# 2  Cash September 25 Models  af7c9af8-f7e8-4c0c-9885-67d15c0dc3af
# 3  Cash September 25 Models  af79b697-0624-476f-be18-37431f732111
# 4  Cash September 25 Models  b1a7d73d-b5a3-4179-a4d8-da036e1cefea
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:03:36.251926         {}       Trench 1  Android
# 1  2026-01-16T19:03:36.251926         {}       Trench 1  Android
# 2  2026-01-16T19:03:36.251926         {}       Trench 1  Android
# 3  2026-01-16T19:03:36.251926         {}       Trench 1  Android
# 4  2026-01-16T19:03:36.251926         {}       Trench 1  Android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-07-05
# 1      Dev_Train       2025-01-21
# 2      Dev_Train       2024-10-13
# 3      Dev_Train       2024-11-04
# 4       Dev_Test       2025-08-29

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       33061           2025-03-01
# 1      Dev_Train                       33496           2024-10-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=57e02e01-9832-419f-a085-25ed5056c8cd>

# %% [markdown]
# ###### Trench 2

# %%
sq = """ 
select 
  r.customer_id,
  r.digitalLoanAccountId, 
  r.stack_score,
  r.demo_score,
  r.apps_score,
  r.credo_score,
  r.cic_score,
  r.stack_score_norm,
  r.ln_os_type osType,
  date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
    case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
         between '2024-10-01' and '2025-02-28' then 'Dev_Train'
         when date(if(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-10-01' then 'Pre_Train'
                  else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.cash_alpha_trench2_applied_loans_backscored_20241001_20250930 r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where r.stack_score is not null
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 53234f9b-c76a-440b-91c9-1b307e9c6702 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (42288, 11)

# %%
feature_column = ['demo_score', 'apps_score', 'credo_score', 'cic_score', 'stack_score_norm']

dfd = transform_data(data, feature_column, a='stack_score', modelDisplayName='Alpha-Cash-Stack-Model', tc='Trench 2', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2550501  c6df6a9e-22af-4465-9a41-f93293eecf16
# 1     3452143  eb3d4ed3-ed7e-4a90-8555-a40d5650759c
# 2     2330008  bb56be1a-177b-498c-ac47-12eb91154be5
# 3     1071950  a79b513c-82ca-4eb3-a506-9b6e7e0ca9de
# 4     2512975  104cb6c6-3eb3-4d50-b9d3-cbee0bdc051b
#
#                       crifApplicationId  prediction  \
# 0  57354796-fd4e-4607-9ca7-6166a267de5b    0.819094
# 1  0ed7f199-1623-4ff4-be54-04b2d0240f18    0.374286
# 2  917274fd-96b2-4e80-a536-ae8048dfc96e    0.488352
# 3  c0b9b03d-3fc7-4a5d-a74c-3c361f69e806    0.388656
# 4  321859f9-10c1-4f4f-8e41-6489cadc696c    0.350265
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:03:57.502026  2026-01-16T19:03:57.502026
# 1  2026-01-16T19:03:57.502026  2026-01-16T19:03:57.502026
# 2  2026-01-16T19:03:57.502026  2026-01-16T19:03:57.502026
# 3  2026-01-16T19:03:57.502026  2026-01-16T19:03:57.502026
# 4  2026-01-16T19:03:57.502026  2026-01-16T19:03:57.502026
#
#          modelDisplayName modelVersionId  \
# 0  Alpha-Cash-Stack-Model             v1
# 1  Alpha-Cash-Stack-Model             v1
# 2  Alpha-Cash-Stack-Model             v1
# 3  Alpha-Cash-Stack-Model             v1
# 4  Alpha-Cash-Stack-Model             v1
#
#                                          calcFeature  \
# 0  {"demo_score": 0.5692332217370547, "apps_score...
# 1  {"demo_score": 0.5797325737583162, "apps_score...
# 2  {"demo_score": 0.4540164082018209, "apps_score...
# 3  {"demo_score": 0.6700070194575577, "apps_score...
# 4  {"demo_score": 0.526530330630122, "apps_score"...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  72afe0cb-eede-4963-aef0-66c6bae7072c
# 1  Cash September 25 Models  6b2f2a59-2342-4c48-a41e-52a22683282e
# 2  Cash September 25 Models  18d19cf9-f065-456d-a93b-b3615806e3c6
# 3  Cash September 25 Models  115c75d0-a4bd-4be2-a067-437cc04e3206
# 4  Cash September 25 Models  448ac944-3104-4f6a-8dea-5e95286ba74d
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:03:57.502026         {}       Trench 2  Android
# 1  2026-01-16T19:03:57.502026         {}       Trench 2  Android
# 2  2026-01-16T19:03:57.502026         {}       Trench 2  Android
# 3  2026-01-16T19:03:57.502026         {}       Trench 2  Android
# 4  2026-01-16T19:03:57.502026         {}       Trench 2  Android
#
#   Data_selection Application_date
# 0      Dev_Train       2024-11-30
# 1       Dev_Test       2025-08-26
# 2       Dev_Test       2025-08-22
# 3      Dev_Train       2025-02-12
# 4      Dev_Train       2025-02-18

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       24849           2025-03-01
# 1      Dev_Train                       17439           2024-10-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=32c25936-3f92-4fcc-a9c8-2b5fa0f15559>

# %% [markdown]
# ###### Trench 3

# %%
sq = """ 
select 
  r.customer_id,
  r.digitalLoanAccountId, 
  r.stack_score,
  r.demo_score,
  r.apps_score,
  r.credo_score,
  r.cic_score,
  r.stack_score_norm,
  r.ln_os_type osType,
  date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
    case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
         between '2024-10-01' and '2025-02-28' then 'Dev_Train'
         when date(if(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-10-01' then 'Pre_Train'
                  else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.cash_alpha_trench3_applied_loans_backscored_20241001_20250930 r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where r.stack_score is not null
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))< '2025-09-24'
;
""" 
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID ff190199-6a17-49e7-aa40-5ae5e297bdde successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (17937, 11)

# %%
feature_column = ['demo_score', 'apps_score', 'credo_score', 'cic_score', 'stack_score_norm']

dfd = transform_data(data, feature_column, a='stack_score', modelDisplayName='Alpha-Cash-Stack-Model', tc='Trench 3', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2624399  d790f5f3-a08d-4486-b7af-d297e039f321
# 1     3227672  4f9ec89b-8763-4a6e-89f5-a72277f0a85c
# 2     1549141  c19db874-4a3d-4022-b5c0-62782fbd4b8b
# 3     1365293  8e10ab95-08ad-4b06-8029-59a8bd2e1c71
# 4     2710488  9adfdad4-4aca-4f50-a7fb-c49060f910ce
#
#                       crifApplicationId  prediction  \
# 0  81683f61-3c0a-4747-9911-380d773a72e4    0.411537
# 1  7bfcea53-48f4-4b70-907b-370ddec1cc02    0.695057
# 2  6b286ab5-5358-4386-a89d-c26373700447    0.331909
# 3  0a830de4-7820-493f-8d31-1c61f37f790a    0.638280
# 4  8928125e-5758-4c46-b913-41fbc22930d0    0.793719
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:04:12.734208  2026-01-16T19:04:12.734208
# 1  2026-01-16T19:04:12.734208  2026-01-16T19:04:12.734208
# 2  2026-01-16T19:04:12.734208  2026-01-16T19:04:12.734208
# 3  2026-01-16T19:04:12.734208  2026-01-16T19:04:12.734208
# 4  2026-01-16T19:04:12.734208  2026-01-16T19:04:12.734208
#
#          modelDisplayName modelVersionId  \
# 0  Alpha-Cash-Stack-Model             v1
# 1  Alpha-Cash-Stack-Model             v1
# 2  Alpha-Cash-Stack-Model             v1
# 3  Alpha-Cash-Stack-Model             v1
# 4  Alpha-Cash-Stack-Model             v1
#
#                                          calcFeature  \
# 0  {"demo_score": 0.5184751063484533, "apps_score...
# 1  {"demo_score": 0.5479647928070218, "apps_score...
# 2  {"demo_score": 0.30562466123846155, "apps_scor...
# 3  {"demo_score": 0.41047368948967267, "apps_scor...
# 4  {"demo_score": 0.5986404769159818, "apps_score...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  12a4cfcd-bc30-4240-bc01-377f3b74a483
# 1  Cash September 25 Models  9ef816cd-8936-4104-b939-be3b2a3ced08
# 2  Cash September 25 Models  d884fb11-c69b-4de3-9f66-5af25e452727
# 3  Cash September 25 Models  9e839dd7-e2dd-4999-a845-8fd3aea8d403
# 4  Cash September 25 Models  acdcca25-65bd-4afc-9ee5-f21c96dc4dbc
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:04:12.734208         {}       Trench 3  Android
# 1  2026-01-16T19:04:12.734208         {}       Trench 3  Android
# 2  2026-01-16T19:04:12.734208         {}       Trench 3  Android
# 3  2026-01-16T19:04:12.734208         {}       Trench 3  Android
# 4  2026-01-16T19:04:12.734208         {}       Trench 3  Android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-05-01
# 1       Dev_Test       2025-07-20
# 2       Dev_Test       2025-03-16
# 3       Dev_Test       2025-06-10
# 4      Dev_Train       2024-10-27

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       11563           2025-03-01
# 1      Dev_Train                        6374           2024-10-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=ff0adfd6-ce15-488d-9759-07390bb53b6b>

# %% [markdown]
# ##### Alpha Cash CIC Model

# %% [markdown]
# ###### Trench 1

# %%
sq = """ 
select 
lmt.customerId customer_id,
r.digitalLoanAccountId,
r.ca_cic_score,
r.max_age_all_contracts_snapshot,
r.ratio_overdue_contracts_to_granted_contracts,
r.ScoreRange,
r.ln_loan_level_user_type,
r.has_ever_been_overdue,
r.latest_granted_contract_overdue_flag,
r.ratio_closed_over_new_granted_cnt_24M,
r.ratio_risky_contracts_to_granted_contracts,
r.Short_and_Term_Loans_granted_contracts_cnt_24M,
r.flg_zero_non_granted_ever,
r.Personal_Loans_granted_contracts_amt_24M,
r.CreditAvgCreditLimit,
r.flg_zero_granted_ever,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-09-01' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-09-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection  
from worktable_data_analysis.cash_alpha_cic_all_applied_backscored_20240901_20250930 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where trench_category = 'Trench 1'
and r.ca_cic_score is not null 
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;
"""

data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 1085c529-1d2a-447f-9860-1eb417930f03 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (76716, 19)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'ca_cic_score',
#        'max_age_all_contracts_snapshot',
#        'ratio_overdue_contracts_to_granted_contracts', 'ScoreRange',
#        'ln_loan_level_user_type', 'has_ever_been_overdue',
#        'latest_granted_contract_overdue_flag',
#        'ratio_closed_over_new_granted_cnt_24M',
#        'ratio_risky_contracts_to_granted_contracts',
#        'Short_and_Term_Loans_granted_contracts_cnt_24M',
#        'flg_zero_non_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
#        'CreditAvgCreditLimit', 'flg_zero_granted_ever', 'osType',
#        'application_date', 'Data_selection'],
#       dtype='object')

# %%
feature_column = ['max_age_all_contracts_snapshot',
       'ratio_overdue_contracts_to_granted_contracts', 'ScoreRange',
       'ln_loan_level_user_type', 'has_ever_been_overdue',
       'latest_granted_contract_overdue_flag',
       'ratio_closed_over_new_granted_cnt_24M',
       'ratio_risky_contracts_to_granted_contracts',
       'Short_and_Term_Loans_granted_contracts_cnt_24M',
       'flg_zero_non_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
       'CreditAvgCreditLimit', 'flg_zero_granted_ever', 'ca_cic_score']

dfd = transform_data(data, feature_column, a='ca_cic_score', modelDisplayName='Alpha-Cash-CIC-Model', tc='Trench 1', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3221788  f0ac7117-9e38-4995-81b1-c206c0338e9e
# 1     3082374  bc80ed7d-b723-4361-b906-9cf6fd2de0bb
# 2     3662927  3bdd36e1-516c-463e-80bf-e901f5a5e941
# 3     3366539  b7ca7d59-a533-4010-a948-157e6897265f
# 4     3283548  8a60cb80-62d4-47aa-b1ac-047607aa865b
#
#                       crifApplicationId  prediction  \
# 0  d4f02995-15aa-4c4f-ba01-ce538da33a51    0.497043
# 1  5eccea69-fafa-4413-95cc-5e885886b504    0.538369
# 2  e3419d44-56c0-4cd1-bc42-8246f2c01eb4    0.667763
# 3  895d1d5b-f0ef-414b-b795-c7451469abbd    0.456770
# 4  12f9fa20-fbae-44d8-b9a0-5d07864ae087    0.570899
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:04:22.569018  2026-01-16T19:04:22.569018
# 1  2026-01-16T19:04:22.570017  2026-01-16T19:04:22.570017
# 2  2026-01-16T19:04:22.570017  2026-01-16T19:04:22.570017
# 3  2026-01-16T19:04:22.570017  2026-01-16T19:04:22.570017
# 4  2026-01-16T19:04:22.571017  2026-01-16T19:04:22.571017
#
#        modelDisplayName modelVersionId  \
# 0  Alpha-Cash-CIC-Model             v1
# 1  Alpha-Cash-CIC-Model             v1
# 2  Alpha-Cash-CIC-Model             v1
# 3  Alpha-Cash-CIC-Model             v1
# 4  Alpha-Cash-CIC-Model             v1
#
#                                          calcFeature  \
# 0  {"max_age_all_contracts_snapshot": 918.0, "rat...
# 1  {"max_age_all_contracts_snapshot": 839.0, "rat...
# 2  {"max_age_all_contracts_snapshot": 304.0, "rat...
# 3  {"max_age_all_contracts_snapshot": 3820.0, "ra...
# 4  {"max_age_all_contracts_snapshot": 2081.0, "ra...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  9ea94980-d20b-4d01-87b1-166bf85264ef
# 1  Cash September 25 Models  b2e0f295-cc48-4184-beb7-fcbb58527cb5
# 2  Cash September 25 Models  55098391-7d88-430e-ab5a-837e6a434231
# 3  Cash September 25 Models  59bbb51d-fc11-4223-8a3e-03fe0d311977
# 4  Cash September 25 Models  62d24823-b9a3-405a-8b70-f29ea214f71b
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:04:22.569018         {}       Trench 1      ios
# 1  2026-01-16T19:04:22.570017         {}       Trench 1  android
# 2  2026-01-16T19:04:22.570017         {}       Trench 1      ios
# 3  2026-01-16T19:04:22.570017         {}       Trench 1  android
# 4  2026-01-16T19:04:22.571017         {}       Trench 1      ios
#
#   Data_selection Application_date
# 0       Dev_Test       2025-02-25
# 1      Dev_Train       2024-12-06
# 2       Dev_Test       2025-09-04
# 3       Dev_Test       2025-04-08
# 4       Dev_Test       2025-02-24

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       38878           2025-02-01
# 1      Dev_Train                       37838           2024-09-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=d0030be3-05c8-4368-b053-ac3b8abf086f>

# %% [markdown]
# ###### Trench 2

# %%
sq = """ 
select 
lmt.customerId customer_id,
r.digitalLoanAccountId,
r.ca_cic_score,
r.max_age_all_contracts_snapshot,
r.ratio_overdue_contracts_to_granted_contracts,
r.ScoreRange,
r.ln_loan_level_user_type,
r.has_ever_been_overdue,
r.latest_granted_contract_overdue_flag,
r.ratio_closed_over_new_granted_cnt_24M,
r.ratio_risky_contracts_to_granted_contracts,
r.Short_and_Term_Loans_granted_contracts_cnt_24M,
r.flg_zero_non_granted_ever,
r.Personal_Loans_granted_contracts_amt_24M,
r.CreditAvgCreditLimit,
r.flg_zero_granted_ever,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-09-01' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-09-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection  
from worktable_data_analysis.cash_alpha_cic_all_applied_backscored_20240901_20250930 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where trench_category = 'Trench 2'
and r.ca_cic_score is not null 
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;
"""


data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 1368b08a-7a37-4a8a-8359-44bbac16e247 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (47776, 19)

# %%
feature_column = ['max_age_all_contracts_snapshot',
       'ratio_overdue_contracts_to_granted_contracts', 'ScoreRange',
       'ln_loan_level_user_type', 'has_ever_been_overdue',
       'latest_granted_contract_overdue_flag',
       'ratio_closed_over_new_granted_cnt_24M',
       'ratio_risky_contracts_to_granted_contracts',
       'Short_and_Term_Loans_granted_contracts_cnt_24M',
       'flg_zero_non_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
       'CreditAvgCreditLimit', 'flg_zero_granted_ever', 'ca_cic_score']

dfd = transform_data(data, feature_column, a='ca_cic_score', modelDisplayName='Alpha-Cash-CIC-Model', tc='Trench 2', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3267538  2066a84f-b4ac-4864-b1b2-646c6385e557
# 1     3301965  c4b0626f-fd5a-48f3-8669-90592df208a5
# 2     2608966  dc279402-5cc0-48ac-b29c-2705c602d881
# 3     1812757  d85ec758-e0be-41f7-8ae5-29ec166b7111
# 4     2938375  d5184a84-ee86-4b7d-baa7-556e6b5fc5ac
#
#                       crifApplicationId  prediction  \
# 0  ae8ef945-60ed-42e0-8622-b4be20ef9f43    0.549529
# 1  26d26a7c-81a1-423b-89b8-4d9c49e28af5    0.373362
# 2  e7d5ae59-bf9d-4c4b-8922-b80f70f4ce61    0.615803
# 3  299e1fc8-14b4-4a32-87c0-fca7d83b48f3    0.596868
# 4  d51a8cf5-663d-47c9-b388-96b1ff58b79d    0.506186
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:04:50.466274  2026-01-16T19:04:50.466274
# 1  2026-01-16T19:04:50.466274  2026-01-16T19:04:50.466274
# 2  2026-01-16T19:04:50.469328  2026-01-16T19:04:50.469328
# 3  2026-01-16T19:04:50.469328  2026-01-16T19:04:50.469328
# 4  2026-01-16T19:04:50.469328  2026-01-16T19:04:50.469328
#
#        modelDisplayName modelVersionId  \
# 0  Alpha-Cash-CIC-Model             v1
# 1  Alpha-Cash-CIC-Model             v1
# 2  Alpha-Cash-CIC-Model             v1
# 3  Alpha-Cash-CIC-Model             v1
# 4  Alpha-Cash-CIC-Model             v1
#
#                                          calcFeature  \
# 0  {"max_age_all_contracts_snapshot": 1549.0, "ra...
# 1  {"max_age_all_contracts_snapshot": 5185.0, "ra...
# 2  {"max_age_all_contracts_snapshot": 563.0, "rat...
# 3  {"max_age_all_contracts_snapshot": 126.0, "rat...
# 4  {"max_age_all_contracts_snapshot": 500.0, "rat...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  9b740429-0beb-49b0-aeac-0776382d5236
# 1  Cash September 25 Models  cc12ebe4-e738-4bd6-93ec-d282f4922f30
# 2  Cash September 25 Models  7fa3c748-7cca-43c7-953f-019fc99400b6
# 3  Cash September 25 Models  06de1fcd-9472-4de1-bc0c-a77268be8dbd
# 4  Cash September 25 Models  9730ff3d-ed17-42b0-9121-a65277742dfb
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:04:50.466274         {}       Trench 2      ios
# 1  2026-01-16T19:04:50.466274         {}       Trench 2      ios
# 2  2026-01-16T19:04:50.469328         {}       Trench 2      ios
# 3  2026-01-16T19:04:50.469328         {}       Trench 2      ios
# 4  2026-01-16T19:04:50.469328         {}       Trench 2      ios
#
#   Data_selection Application_date
# 0       Dev_Test       2025-05-21
# 1       Dev_Test       2025-08-30
# 2      Dev_Train       2024-12-21
# 3       Dev_Test       2025-03-07
# 4      Dev_Train       2025-01-14

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       29036           2025-02-01
# 1      Dev_Train                       18740           2024-09-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=3bd42505-2bd3-4dbc-98dc-eeb2fdfe84b4>

# %% [markdown]
# ###### Trench 3

# %%
sq = """ 
select 
lmt.customerId customer_id,
r.digitalLoanAccountId,
r.ca_cic_score,
r.max_age_all_contracts_snapshot,
r.ratio_overdue_contracts_to_granted_contracts,
r.ScoreRange,
r.ln_loan_level_user_type,
r.has_ever_been_overdue,
r.latest_granted_contract_overdue_flag,
r.ratio_closed_over_new_granted_cnt_24M,
r.ratio_risky_contracts_to_granted_contracts,
r.Short_and_Term_Loans_granted_contracts_cnt_24M,
r.flg_zero_non_granted_ever,
r.Personal_Loans_granted_contracts_amt_24M,
r.CreditAvgCreditLimit,
r.flg_zero_granted_ever,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-09-01' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-09-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.cash_alpha_cic_all_applied_backscored_20240901_20250930 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where trench_category = 'Trench 3'
and r.ca_cic_score is not null 
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;
"""


data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 4093405d-3a5c-4804-851a-f3324b5c3a76 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (18967, 19)

# %%
feature_column = ['max_age_all_contracts_snapshot',
       'ratio_overdue_contracts_to_granted_contracts', 'ScoreRange',
       'ln_loan_level_user_type', 'has_ever_been_overdue',
       'latest_granted_contract_overdue_flag',
       'ratio_closed_over_new_granted_cnt_24M',
       'ratio_risky_contracts_to_granted_contracts',
       'Short_and_Term_Loans_granted_contracts_cnt_24M',
       'flg_zero_non_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
       'CreditAvgCreditLimit', 'flg_zero_granted_ever', 'ca_cic_score']

dfd = transform_data(data, feature_column, a='ca_cic_score', modelDisplayName='Alpha-Cash-CIC-Model', tc='Trench 3', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2635255  ffb0db54-7ea2-4166-895e-a860dc5c4616
# 1     2812695  583e21f1-0eb1-4c80-a68f-c458d511d303
# 2     2508417  3e1b71a6-3051-42e9-abdc-2b47c25fd5cb
# 3     2047584  ccafd585-6a3f-4ab4-92af-5ceaf70e282f
# 4     2688193  40433ac6-4872-4aa2-827b-112e63ccd0a3
#
#                       crifApplicationId  prediction  \
# 0  55c3483e-0de3-43be-b2bf-576c28576df4    0.469076
# 1  ffc79f35-59f8-4167-8f62-7a038f491ff0    0.365153
# 2  4f37e07f-a3af-4a74-b3fe-440d03ee3e2d    0.458994
# 3  72e18b0f-ac4d-452e-be6a-0e992d46e3f1    0.429049
# 4  8a240a62-39df-4998-9a06-af4bf8659002    0.449782
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:05:10.016126  2026-01-16T19:05:10.016126
# 1  2026-01-16T19:05:10.016126  2026-01-16T19:05:10.016126
# 2  2026-01-16T19:05:10.016126  2026-01-16T19:05:10.016126
# 3  2026-01-16T19:05:10.016126  2026-01-16T19:05:10.016126
# 4  2026-01-16T19:05:10.016126  2026-01-16T19:05:10.016126
#
#        modelDisplayName modelVersionId  \
# 0  Alpha-Cash-CIC-Model             v1
# 1  Alpha-Cash-CIC-Model             v1
# 2  Alpha-Cash-CIC-Model             v1
# 3  Alpha-Cash-CIC-Model             v1
# 4  Alpha-Cash-CIC-Model             v1
#
#                                          calcFeature  \
# 0  {"max_age_all_contracts_snapshot": 737.0, "rat...
# 1  {"max_age_all_contracts_snapshot": 1871.0, "ra...
# 2  {"max_age_all_contracts_snapshot": 348.0, "rat...
# 3  {"max_age_all_contracts_snapshot": 537.0, "rat...
# 4  {"max_age_all_contracts_snapshot": 251.0, "rat...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  c5b3bff3-d91a-49a3-b14f-a3d0c111bd6d
# 1  Cash September 25 Models  b8a321a6-504b-439d-904c-927000c46975
# 2  Cash September 25 Models  a274363f-8bd2-474e-90f1-579a1183f156
# 3  Cash September 25 Models  c0a3510e-0d04-4a70-b4e2-47901800d596
# 4  Cash September 25 Models  62fded36-863f-4ae8-a05a-e4c37bd4fd92
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:05:10.016126         {}       Trench 3  android
# 1  2026-01-16T19:05:10.016126         {}       Trench 3  android
# 2  2026-01-16T19:05:10.016126         {}       Trench 3  android
# 3  2026-01-16T19:05:10.016126         {}       Trench 3  android
# 4  2026-01-16T19:05:10.016126         {}       Trench 3      ios
#
#   Data_selection Application_date
# 0       Dev_Test       2025-06-18
# 1       Dev_Test       2025-09-03
# 2       Dev_Test       2025-06-29
# 3      Dev_Train       2024-10-29
# 4       Dev_Test       2025-04-03

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       12909           2025-02-01
# 1      Dev_Train                        6058           2024-09-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=1255bee0-324f-4b28-af4c-8401efe37fff>

# %% [markdown]
# ##### Beta-Cash-Demo-Model

# %% [markdown]
# ###### Trench 1

# %%
sq = """ 
select 
r.customerId customer_id,
r.digitalLoanAccountId,
r.c_demo_score Beta_Cash_Demo_Score,
r.ln_vas_opted_flag, 
r.ln_self_dec_income, 
r.ln_age,
r.ln_source_funds_new_bin, 
r.ln_loan_level_user_type,
r.ln_industry_new_cat_bin, 
r.ln_marital_status,
r.ln_doc_type_rolled, 
r.ln_education_level,
r.ln_ref2_type, 
r.ln_email_primary_domain, 
r.ln_province_bin,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-10-01' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-10-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.cash_beta_demo_all_applied_backscored_20241001_20250930 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where trench_category = 'Trench 1'
and r.c_demo_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;

"""

data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID cd96c3b3-b2de-43f0-807d-c7d83a7a5a8d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (318201, 18)

# %%
feature_column = ['ln_vas_opted_flag',
       'ln_self_dec_income', 'ln_age',
       'ln_source_funds_new_bin', 'ln_loan_level_user_type',
       'ln_industry_new_cat_bin',
       'ln_marital_status',
       'ln_doc_type_rolled',
       'ln_education_level',
       'ln_ref2_type', 'ln_email_primary_domain',
       'ln_province_bin','Beta_Cash_Demo_Score']

dfd = transform_data(data, feature_column, a='Beta_Cash_Demo_Score', modelDisplayName='Beta-Cash-Demo-Model', tc='Trench 1', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3649483  88374105-92a1-4555-b7e9-d1dadc5ce697
# 1     3660720  94cc0771-1100-42d6-a9da-659a72f3a13d
# 2     3270538  efbbae15-1e7b-4e0a-a4a3-0050b989710c
# 3     3024132  13aa699a-f346-446b-8297-29c3b2939141
# 4     3268280  1acfad4d-67b6-44ed-aa18-8f661da34be4
#
#                       crifApplicationId  prediction  \
# 0  df816ced-1299-4f5a-b272-af97f1621aab    0.620811
# 1  7c2f43ba-7b7b-4d0a-8d79-651dd6bf4308    0.600122
# 2  9e3e0de9-267d-4c81-b976-cd70ebbf9960    0.467917
# 3  93f6f122-ba21-488f-bdf8-a991f5706a49    0.622411
# 4  2e3d7eda-0afe-40b1-9d0b-b45059b3330e    0.433076
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:05:26.181751  2026-01-16T19:05:26.181751
# 1  2026-01-16T19:05:26.181751  2026-01-16T19:05:26.181751
# 2  2026-01-16T19:05:26.182290  2026-01-16T19:05:26.182290
# 3  2026-01-16T19:05:26.182290  2026-01-16T19:05:26.182290
# 4  2026-01-16T19:05:26.182290  2026-01-16T19:05:26.182290
#
#        modelDisplayName modelVersionId  \
# 0  Beta-Cash-Demo-Model             v1
# 1  Beta-Cash-Demo-Model             v1
# 2  Beta-Cash-Demo-Model             v1
# 3  Beta-Cash-Demo-Model             v1
# 4  Beta-Cash-Demo-Model             v1
#
#                                          calcFeature  \
# 0  {"ln_vas_opted_flag": "1", "ln_self_dec_income...
# 1  {"ln_vas_opted_flag": "1", "ln_self_dec_income...
# 2  {"ln_vas_opted_flag": "1", "ln_self_dec_income...
# 3  {"ln_vas_opted_flag": "1", "ln_self_dec_income...
# 4  {"ln_vas_opted_flag": "0", "ln_self_dec_income...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  6bd22a85-9e8c-4d8c-ac74-752ef7fdd6f3
# 1  Cash September 25 Models  b01ecf76-9302-4d5c-b4db-9ec158d4279b
# 2  Cash September 25 Models  eff8ead0-dabe-4f6e-a12d-c32b62c4372e
# 3  Cash September 25 Models  6ba3360c-ec78-4f66-9cc9-9642d5827fef
# 4  Cash September 25 Models  7a3724a9-c758-432e-91b8-f321ab4bf15f
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:05:26.181751         {}       Trench 1      ios
# 1  2026-01-16T19:05:26.181751         {}       Trench 1  android
# 2  2026-01-16T19:05:26.182290         {}       Trench 1  android
# 3  2026-01-16T19:05:26.182290         {}       Trench 1  android
# 4  2026-01-16T19:05:26.182290         {}       Trench 1  android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-08-29
# 1       Dev_Test       2025-09-04
# 2       Dev_Test       2025-02-19
# 3      Dev_Train       2024-11-14
# 4       Dev_Test       2025-02-22

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      191471           2025-02-01
# 1      Dev_Train                      126730           2024-10-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=be6aa399-1414-4e9d-9764-d74e9d8af22e>

# %% [markdown]
# ###### Trench 2

# %%
sq = """ 
select 
r.customerId customer_id,
r.digitalLoanAccountId,
r.c_demo_score Beta_Cash_Demo_Score,
r.ln_vas_opted_flag, 
r.ln_self_dec_income, 
r.ln_age,
r.ln_source_funds_new_bin, 
r.ln_loan_level_user_type,
r.ln_industry_new_cat_bin, 
r.ln_marital_status,
r.ln_doc_type_rolled, 
r.ln_education_level,
r.ln_ref2_type, 
r.ln_email_primary_domain, 
r.ln_province_bin,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-10-01' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-10-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.cash_beta_demo_all_applied_backscored_20241001_20250930 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where trench_category = 'Trench 2'
and r.c_demo_score is not null 
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;

"""

data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 7e81c8b5-e253-47ae-89c2-5e7905b29980 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (122498, 18)

# %%
feature_column = ['ln_vas_opted_flag',
       'ln_self_dec_income', 'ln_age',
       'ln_source_funds_new_bin', 'ln_loan_level_user_type',
       'ln_industry_new_cat_bin',
       'ln_marital_status',
       'ln_doc_type_rolled',
       'ln_education_level',
       'ln_ref2_type', 'ln_email_primary_domain',
       'ln_province_bin','Beta_Cash_Demo_Score']

dfd = transform_data(data, feature_column, a='Beta_Cash_Demo_Score', modelDisplayName='Beta-Cash-Demo-Model', tc='Trench 2', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3399442  4588304c-462e-46ba-abf9-e3c0fb4a869d
# 1     1135712  e29cca60-8010-460a-bb48-1e6a7079dcec
# 2     3329859  1b7a2878-9571-4436-a97e-6253d60504b2
# 3     3076453  315aa07d-1e6c-4298-bbf0-f85e9e0de45b
# 4     3227469  51766cd4-8281-4fb1-b2d7-c09c852bb1e2
#
#                       crifApplicationId  prediction  \
# 0  3f71a3f9-4ff6-4f9a-ba34-8fa307ca1afc    0.611906
# 1  ab2f3e33-501f-4bff-90e0-2f3db71b8d87    0.536509
# 2  e18db680-27b7-450d-8864-bfb3b0a93af3    0.582968
# 3  2226fd35-b87e-42d5-8d4e-065f33c0ecdb    0.446162
# 4  7052390d-ccc8-454a-9460-0c4d74706d8b    0.435020
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:07:18.577083  2026-01-16T19:07:18.577083
# 1  2026-01-16T19:07:18.577083  2026-01-16T19:07:18.577083
# 2  2026-01-16T19:07:18.577083  2026-01-16T19:07:18.577083
# 3  2026-01-16T19:07:18.577083  2026-01-16T19:07:18.577083
# 4  2026-01-16T19:07:18.577083  2026-01-16T19:07:18.577083
#
#        modelDisplayName modelVersionId  \
# 0  Beta-Cash-Demo-Model             v1
# 1  Beta-Cash-Demo-Model             v1
# 2  Beta-Cash-Demo-Model             v1
# 3  Beta-Cash-Demo-Model             v1
# 4  Beta-Cash-Demo-Model             v1
#
#                                          calcFeature  \
# 0  {"ln_vas_opted_flag": "1", "ln_self_dec_income...
# 1  {"ln_vas_opted_flag": "1", "ln_self_dec_income...
# 2  {"ln_vas_opted_flag": "1", "ln_self_dec_income...
# 3  {"ln_vas_opted_flag": "0", "ln_self_dec_income...
# 4  {"ln_vas_opted_flag": "0", "ln_self_dec_income...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  5013aeba-238a-49d2-86dd-e7c55eb00889
# 1  Cash September 25 Models  3bb63e7b-36f0-4502-9340-9aa59f00c390
# 2  Cash September 25 Models  dbfd43e9-d655-4acd-bdf7-82845102a147
# 3  Cash September 25 Models  0674176b-3bd8-4e3c-885d-fdeafea1fa30
# 4  Cash September 25 Models  bf612912-e60b-4ade-b1c7-5e747d19eef1
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:07:18.577083         {}       Trench 2      ios
# 1  2026-01-16T19:07:18.577083         {}       Trench 2  android
# 2  2026-01-16T19:07:18.577083         {}       Trench 2      ios
# 3  2026-01-16T19:07:18.577083         {}       Trench 2  android
# 4  2026-01-16T19:07:18.577083         {}       Trench 2  android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-07-26
# 1      Dev_Train       2024-10-18
# 2       Dev_Test       2025-06-28
# 3       Dev_Test       2025-04-20
# 4       Dev_Test       2025-05-16

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       84722           2025-02-01
# 1      Dev_Train                       37776           2024-10-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=13c7e3a8-537a-4817-a8c4-cbd951b4a932>

# %% [markdown]
# ###### Trench 3

# %%
sq = """ 
select 
r.customerId customer_id,
r.digitalLoanAccountId,
r.c_demo_score Beta_Cash_Demo_Score,
r.ln_vas_opted_flag, 
r.ln_self_dec_income, 
r.ln_age,
r.ln_source_funds_new_bin, 
r.ln_loan_level_user_type,
r.ln_industry_new_cat_bin, 
r.ln_marital_status,
r.ln_doc_type_rolled, 
r.ln_education_level,
r.ln_ref2_type, 
r.ln_email_primary_domain, 
r.ln_province_bin,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-10-01' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-10-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.cash_beta_demo_all_applied_backscored_20241001_20250930 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where trench_category = 'Trench 3'
and r.c_demo_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;

"""

data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 8106e83b-3870-436a-87a0-c01966a55549 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (41635, 18)

# %%
feature_column = ['ln_vas_opted_flag',
       'ln_self_dec_income', 'ln_age',
       'ln_source_funds_new_bin', 'ln_loan_level_user_type',
       'ln_industry_new_cat_bin',
       'ln_marital_status',
       'ln_doc_type_rolled',
       'ln_education_level',
       'ln_ref2_type', 'ln_email_primary_domain',
       'ln_province_bin','Beta_Cash_Demo_Score']

dfd = transform_data(data, feature_column, a='Beta_Cash_Demo_Score', modelDisplayName='Beta-Cash-Demo-Model', tc='Trench 3', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2546250  21310b39-34ef-4160-870b-00452ef106c3
# 1     2888924  954adec6-1e8b-4cac-bccc-7072534729e7
# 2     2894630  614c36aa-06aa-48c6-8c9f-270914d90916
# 3     2514498  65c464ae-5a8a-46cf-adea-e02a49e84928
# 4     1951771  1527ac51-8d37-43e1-a79a-b75410bfd13b
#
#                       crifApplicationId  prediction  \
# 0  df5ba0c6-9786-4504-984e-b1c4985d1c7c    0.343319
# 1  9fe85813-6a40-4914-a1d7-2ee5da7d9b07    0.422414
# 2  84586dcd-4d07-4e92-b7d1-ea50a7c4262a    0.485569
# 3  5aba2f9f-1546-44f5-af06-f287c4d33938    0.324677
# 4  1bc55b1f-aa89-40ae-b472-83aefa27ef65    0.301880
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:08:00.661840  2026-01-16T19:08:00.661840
# 1  2026-01-16T19:08:00.661840  2026-01-16T19:08:00.661840
# 2  2026-01-16T19:08:00.662855  2026-01-16T19:08:00.662855
# 3  2026-01-16T19:08:00.662855  2026-01-16T19:08:00.662855
# 4  2026-01-16T19:08:00.662855  2026-01-16T19:08:00.662855
#
#        modelDisplayName modelVersionId  \
# 0  Beta-Cash-Demo-Model             v1
# 1  Beta-Cash-Demo-Model             v1
# 2  Beta-Cash-Demo-Model             v1
# 3  Beta-Cash-Demo-Model             v1
# 4  Beta-Cash-Demo-Model             v1
#
#                                          calcFeature  \
# 0  {"ln_vas_opted_flag": "1", "ln_self_dec_income...
# 1  {"ln_vas_opted_flag": "0", "ln_self_dec_income...
# 2  {"ln_vas_opted_flag": "0", "ln_self_dec_income...
# 3  {"ln_vas_opted_flag": "0", "ln_self_dec_income...
# 4  {"ln_vas_opted_flag": "0", "ln_self_dec_income...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  4073c475-16a0-4eff-bb12-38ca6195ae44
# 1  Cash September 25 Models  103b54e7-7d48-479d-8c75-af27a680dc65
# 2  Cash September 25 Models  78b0147f-b847-4918-ad74-21b8a3359888
# 3  Cash September 25 Models  a3504589-86c5-46b4-8d38-d646a70a91da
# 4  Cash September 25 Models  b96f27f1-c33e-4271-80a3-18f63ca07d40
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:08:00.661840         {}       Trench 3  android
# 1  2026-01-16T19:08:00.661840         {}       Trench 3  android
# 2  2026-01-16T19:08:00.662855         {}       Trench 3  android
# 3  2026-01-16T19:08:00.662855         {}       Trench 3  android
# 4  2026-01-16T19:08:00.662855         {}       Trench 3  android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-03-03
# 1       Dev_Test       2025-04-03
# 2       Dev_Test       2025-03-29
# 3       Dev_Test       2025-07-19
# 4       Dev_Test       2025-06-12

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       30895           2025-02-01
# 1      Dev_Train                       10740           2024-10-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=10e5d41a-ebd4-4c1f-82b0-ec90ed9efa62>

# %% [markdown]
# ##### Beta-Cash-Stack-Model

# %%
sq = """ 
select r.customer_id,
r.digitalLoanAccountId,
r.demo_score,
r.apps_score,
r.credo_score,
r.stack_score Beta_cash_stack_score,
r.stack_score_norm,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-10-01' and '2025-02-28' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-10-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
 from worktable_data_analysis.cash_beta_trench1_applied_loans_backscored_20241001_20250930 r
 left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
 where r.stack_score is not null 
 and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID ecee70c3-9df8-445f-a199-652cb2a8c1a9 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (318108, 10)

# %%
feature_column = ['demo_score',
       'apps_score', 'credo_score',
       'stack_score', 'stack_score_norm']

dfd = transform_data(data, feature_column, a='Beta_cash_stack_score', modelDisplayName='Beta-Cash-Stack-Model', tc='Trench 1', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3423709  e1b69f85-c362-4aa2-a33b-271fa0a9d306
# 1     2948227  bbf9fe06-f0e2-4c69-a0cb-e43b1ccda708
# 2     3652857  af2e6ad1-42b6-4fd3-a9bf-460950ac8b93
# 3     3305416  ab7fe660-2c92-4dc6-a744-be115ac0195f
# 4     3587370  7624766d-3d2d-41a0-80af-62a68384fdbd
#
#                       crifApplicationId  prediction  \
# 0  4e8c2241-8bf4-44ae-a2fd-42f84c013dee    0.639406
# 1  d757f592-105c-4f67-b452-90ec7ebf1b02    0.557391
# 2  da13a4e0-c279-482e-bdc9-b31176385da6    0.534326
# 3  5fa23dfe-82a1-4a6d-9983-0fa17de474cf    0.660523
# 4  c400e8b8-84ad-402a-9bb3-e7c1fc9fc6b7    0.417116
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:08:23.191683  2026-01-16T19:08:23.191683
# 1  2026-01-16T19:08:23.191683  2026-01-16T19:08:23.191683
# 2  2026-01-16T19:08:23.191683  2026-01-16T19:08:23.191683
# 3  2026-01-16T19:08:23.191683  2026-01-16T19:08:23.191683
# 4  2026-01-16T19:08:23.191683  2026-01-16T19:08:23.191683
#
#         modelDisplayName modelVersionId  \
# 0  Beta-Cash-Stack-Model             v1
# 1  Beta-Cash-Stack-Model             v1
# 2  Beta-Cash-Stack-Model             v1
# 3  Beta-Cash-Stack-Model             v1
# 4  Beta-Cash-Stack-Model             v1
#
#                                          calcFeature  \
# 0  {"demo_score": 0.41346890602134695, "apps_scor...
# 1  {"demo_score": 0.598875329009884, "apps_score"...
# 2  {"demo_score": 0.49926035391431034, "apps_scor...
# 3  {"demo_score": 0.6146503742020991, "apps_score...
# 4  {"demo_score": 0.5464633738130923, "apps_score...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  b38f6339-e1ca-4fd2-846b-bad021f45279
# 1  Cash September 25 Models  db39bbfc-633c-48bd-9dc9-b7f2d99bc64d
# 2  Cash September 25 Models  bb32976f-5901-4167-b7a2-84be344a673c
# 3  Cash September 25 Models  60474e93-0b89-4b19-998b-7dc378ac9a5c
# 4  Cash September 25 Models  6b7dcf63-13f3-4885-8eeb-ebe40cae1709
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:08:23.191683         {}       Trench 1  android
# 1  2026-01-16T19:08:23.191683         {}       Trench 1  android
# 2  2026-01-16T19:08:23.191683         {}       Trench 1  android
# 3  2026-01-16T19:08:23.191683         {}       Trench 1  android
# 4  2026-01-16T19:08:23.191683         {}       Trench 1  android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-05-06
# 1      Dev_Train       2024-10-17
# 2       Dev_Test       2025-09-01
# 3       Dev_Test       2025-03-06
# 4       Dev_Test       2025-07-30

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      162675           2025-03-01
# 1      Dev_Train                      155433           2024-10-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=f394fffb-1588-4b5b-b0c4-f186f47288cd>

# %% [markdown]
# ###### Trench 2

# %%
sq = """ 
select r.customer_id,
r.digitalLoanAccountId,
r.demo_score,
r.apps_score,
r.credo_score,
r.stack_score Beta_cash_stack_score,
r.stack_score_norm,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-10-01' and '2025-02-28' then 'Dev_Train'
        when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-10-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
 from worktable_data_analysis.cash_beta_trench2_applied_loans_backscored_20241001_20250930 r
 left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
 where r.stack_score is not null
 and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID b7c79a6c-3f52-46ad-91b7-5e522ee05f38 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (119665, 10)

# %%
feature_column = ['demo_score',
       'apps_score', 'credo_score',
       'stack_score', 'stack_score_norm']

dfd = transform_data(data, feature_column, a='Beta_cash_stack_score', modelDisplayName='Beta-Cash-Stack-Model', tc='Trench 2', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3452485  e819e260-1353-4035-8194-4ab7f5b15e9b
# 1     1032618  95e6edfa-aeba-4a5b-b0fc-ddb18f36ba94
# 2     2823097  2c4140e1-f715-4277-9cf8-c89092aba034
# 3     2201684  f6ae7a7d-0404-4524-b737-29ec935eb446
# 4     3125864  6f245e30-b8dd-4a8b-8c8a-742a044e0f25
#
#                       crifApplicationId  prediction  \
# 0  64e50931-99d1-4dd3-86c4-208315eedfbf    0.809323
# 1  8478ef26-6d95-4ead-a97e-29abb648ac7e    0.636747
# 2  f2949d09-bede-40e6-a533-717155c7590d    0.638983
# 3  6135952e-d787-422e-b4ac-66fed3d374c1    0.935050
# 4  a3e4cc53-3a07-4c6c-ab5d-f309eae59ef8    0.866633
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:09:29.905752  2026-01-16T19:09:29.905752
# 1  2026-01-16T19:09:29.905752  2026-01-16T19:09:29.905752
# 2  2026-01-16T19:09:29.905752  2026-01-16T19:09:29.905752
# 3  2026-01-16T19:09:29.905752  2026-01-16T19:09:29.905752
# 4  2026-01-16T19:09:29.905752  2026-01-16T19:09:29.905752
#
#         modelDisplayName modelVersionId  \
# 0  Beta-Cash-Stack-Model             v1
# 1  Beta-Cash-Stack-Model             v1
# 2  Beta-Cash-Stack-Model             v1
# 3  Beta-Cash-Stack-Model             v1
# 4  Beta-Cash-Stack-Model             v1
#
#                                          calcFeature  \
# 0  {"demo_score": 0.5162030655521818, "apps_score...
# 1  {"demo_score": 0.46543677878024386, "apps_scor...
# 2  {"demo_score": 0.589520721349472, "apps_score"...
# 3  {"demo_score": 0.49498197667043714, "apps_scor...
# 4  {"demo_score": 0.5990094119899243, "apps_score...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  b5e927bb-ca81-4352-b7d1-bd8b33870755
# 1  Cash September 25 Models  44d73065-1457-492a-b99d-adf2a67ee08c
# 2  Cash September 25 Models  4b1d9280-fd05-4c73-8905-bff6265d64b9
# 3  Cash September 25 Models  eaadf67b-9047-422c-a876-cd5aaceeb6b4
# 4  Cash September 25 Models  bc6fd0e9-d989-409d-8904-216842ce8992
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:09:29.905752         {}       Trench 2  android
# 1  2026-01-16T19:09:29.905752         {}       Trench 2  android
# 2  2026-01-16T19:09:29.905752         {}       Trench 2  android
# 3  2026-01-16T19:09:29.905752         {}       Trench 2  android
# 4  2026-01-16T19:09:29.905752         {}       Trench 2  android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-06-27
# 1      Dev_Train       2024-11-12
# 2      Dev_Train       2024-11-10
# 3      Dev_Train       2024-10-24
# 4       Dev_Test       2025-04-25

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       72337           2025-03-01
# 1      Dev_Train                       47328           2024-10-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=fb469903-b1e6-4edd-ba97-f9943f49218f>

# %% [markdown]
# ###### Trench 3

# %%
sq = """ 
select r.customer_id,
r.digitalLoanAccountId,
r.demo_score,
r.apps_score,
r.credo_score,
r.stack_score Beta_cash_stack_score,
r.stack_score_norm,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-10-01' and '2025-02-28' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-10-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
 from worktable_data_analysis.cash_beta_trench3_applied_loans_backscored_20241001_20250930 r
 left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
 where r.stack_score is not null 
 and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'

"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 495968cb-79a2-40cf-a8f8-2bfb81da0928 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (41609, 10)

# %%
feature_column = ['demo_score',
       'apps_score', 'credo_score',
       'stack_score', 'stack_score_norm']

dfd = transform_data(data, feature_column, a='Beta_cash_stack_score', modelDisplayName='Beta-Cash-Stack-Model', tc='Trench 3', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2606551  a07e799a-721c-43ec-8cda-5be2a52d7815
# 1     3302428  714b1d63-f7f6-4d4b-829f-d069b446b8c0
# 2     2980389  d65f4d12-d433-423d-95e8-9dd6bed378c0
# 3     3413182  220e4cad-d94e-4b47-b86c-c744ed3ddd01
# 4     2314603  0575cda4-11ef-42cc-b5ee-2665a9fa19bf
#
#                       crifApplicationId  prediction  \
# 0  b8b7cd0d-3e6e-4820-8d81-4645e5617d83    0.265839
# 1  5f011dd1-63e0-4daf-892f-3318c74688ee    0.610899
# 2  1958be31-c9b9-49e8-944a-cadd7c3e2721    0.496895
# 3  4e7a4e8d-c2bc-4b0d-8d29-aee2e4a93cde    0.275250
# 4  5f17796a-ea4a-4ec5-8a89-8ed7eab3f7e0    0.648997
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:09:59.241077  2026-01-16T19:09:59.241077
# 1  2026-01-16T19:09:59.241599  2026-01-16T19:09:59.241599
# 2  2026-01-16T19:09:59.241599  2026-01-16T19:09:59.241599
# 3  2026-01-16T19:09:59.241599  2026-01-16T19:09:59.241599
# 4  2026-01-16T19:09:59.241599  2026-01-16T19:09:59.241599
#
#         modelDisplayName modelVersionId  \
# 0  Beta-Cash-Stack-Model             v1
# 1  Beta-Cash-Stack-Model             v1
# 2  Beta-Cash-Stack-Model             v1
# 3  Beta-Cash-Stack-Model             v1
# 4  Beta-Cash-Stack-Model             v1
#
#                                          calcFeature  \
# 0  {"demo_score": 0.3752460488638665, "apps_score...
# 1  {"demo_score": 0.4095834955430448, "apps_score...
# 2  {"demo_score": 0.4784989646697194, "apps_score...
# 3  {"demo_score": 0.2666855102891388, "apps_score...
# 4  {"demo_score": 0.4634881673242549, "apps_score...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  cf208b4f-7881-4308-ac4a-efd68f4f94e9
# 1  Cash September 25 Models  a7546734-a4d1-48b4-b690-7da2f37c6b18
# 2  Cash September 25 Models  a505ae80-63f0-4dee-a5de-febb3e20c3c0
# 3  Cash September 25 Models  cc5a5921-b8ce-4a3f-928d-2657f485a2e3
# 4  Cash September 25 Models  16ea47fe-37fa-43e2-bb56-bd148d5d8b2b
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:09:59.241077         {}       Trench 3  android
# 1  2026-01-16T19:09:59.241599         {}       Trench 3  android
# 2  2026-01-16T19:09:59.241599         {}       Trench 3  android
# 3  2026-01-16T19:09:59.241599         {}       Trench 3  android
# 4  2026-01-16T19:09:59.241599         {}       Trench 3  android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-08-15
# 1       Dev_Test       2025-05-19
# 2       Dev_Test       2025-07-24
# 3       Dev_Test       2025-09-07
# 4       Dev_Test       2025-06-05

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       27473           2025-03-01
# 1      Dev_Train                       14136           2024-10-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=170f129a-3eac-4b1d-8441-10999877dab7>

# %% [markdown]
# #####  Beta Cash AppScore Model

# %% [markdown]
# ###### Trench 1

# %%
## query to add the trench category trench 1 and trench 2

# create or replace table risk_mart.applied_quick_loan_new_applicants_20230101_20250930_app_scored_copy as 
# select * from risk_mart.applied_quick_loan_new_applicants_20230101_20250930_app_scored;



# ALTER TABLE risk_mart.applied_quick_loan_new_applicants_20230101_20250930_app_scored_copy
# ADD COLUMN trench_category STRING;

# MERGE risk_mart.applied_quick_loan_new_applicants_20230101_20250930_app_scored_copy AS target
# USING (
#   SELECT 
#     a.digitalLoanAccountId,
#     CASE 
#       WHEN b.ln_loan_level_user_type = '2_New Applicant'
#            AND DATE_DIFF(DATE(b.ln_appln_submit_datetime), DATE(b.onb_tsa_onboarding_datetime), DAY) <= 30 THEN 'Trench 1'
#       WHEN b.ln_loan_level_user_type = '2_New Applicant'
#            AND DATE_DIFF(DATE(b.ln_appln_submit_datetime), DATE(b.onb_tsa_onboarding_datetime), DAY) > 30 THEN 'Trench 2'
#       WHEN b.ln_loan_level_user_type = '1_Repeat Applicant' THEN 'Trench 3'
#       ELSE NULL
#     END AS trench_category,
#     ROW_NUMBER() OVER (PARTITION BY a.digitalLoanAccountId ORDER BY b.ln_appln_submit_datetime DESC) AS row_num
#   FROM risk_mart.applied_quick_loan_new_applicants_20230101_20250930_app_scored_copy a
#   LEFT JOIN prj-prod-dataplatform.risk_mart.applied_loans_20210701_20250930_trans b
#     ON a.digitalLoanAccountId = b.digitalLoanAccountId
# ) AS source
# ON target.digitalLoanAccountId = source.digitalLoanAccountId
# WHEN MATCHED AND source.row_num = 1 THEN
#   UPDATE SET target.trench_category = source.trench_category;

# %%
sq = """ 
select 
  r.customerId customer_id,
  r.digitalLoanAccountId,
  r.apps_score beta_cash_app_score,  
  r.app_cnt_health_and_fitness_ever app_cnt_health_and_fitness_ever, 
  r.app_cnt_shopping_ever app_cnt_shopping_ever,
  r.app_cnt_crypto_ever app_cnt_crypto_ever, 
  r.app_cnt_driver_ever app_cnt_driver_ever,
  r.app_cnt_payday_180d app_cnt_payday_180d, 
  r.app_cnt_gambling_180d app_cnt_gambling_180d,
  r.app_avg_time_bw_installed_mins_3d app_avg_time_bw_installed_mins_3d,
  r.app_median_time_bw_installed_mins_ever app_median_time_bw_installed_mins_3d,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
 date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-08-13' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-08-13' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from risk_mart.applied_quick_loan_new_applicants_20230101_20250930_app_scored_copy r 
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 1'
and r.apps_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 2a937cfe-ec06-4356-9230-b6c73f572ac9 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (382443, 14)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'beta_cash_app_score',
#        'app_cnt_health_and_fitness_ever', 'app_cnt_shopping_ever',
#        'app_cnt_crypto_ever', 'app_cnt_driver_ever', 'app_cnt_payday_180d',
#        'app_cnt_gambling_180d', 'app_avg_time_bw_installed_mins_3d',
#        'app_median_time_bw_installed_mins_3d', 'osType', 'application_date',
#        'Data_selection'],
#       dtype='object')

# %%
feature_column = ['beta_cash_app_score',
       'app_cnt_health_and_fitness_ever', 'app_cnt_shopping_ever',
       'app_cnt_crypto_ever', 'app_cnt_driver_ever', 'app_cnt_payday_180d',
       'app_cnt_gambling_180d', 'app_avg_time_bw_installed_mins_3d',
       'app_median_time_bw_installed_mins_3d']

dfd = transform_data(data, feature_column, a='beta_cash_app_score', modelDisplayName='Beta-Cash-AppScore-Model', tc='Trench 1', subscription_name = 'Cash September 25 Models') 
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382443 entries, 0 to 382442
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   customerId            382443 non-null  int64
#  1   digitalLoanAccountId  382443 non-null  object
#  2   crifApplicationId     382443 non-null  object
#  3   prediction            382443 non-null  float64
#  4   start_time            382443 non-null  object
#  5   end_time              382443 non-null  object
#  6   modelDisplayName      382443 non-null  object
#  7   modelVersionId        382443 non-null  object
#  8   calcFeature           382443 non-null  object
#  9   subscription_name     382443 non-null  object
#  10  message_id            382443 non-null  object
#  11  publish_time          382443 non-null  object
#  12  attributes            382443 non-null  object
#  13  trenchCategory        382443 non-null  object
#  14  deviceOs              382443 non-null  object
#  15  Data_selection        382443 non-null  object
#  16  Application_date      382443 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 49.6+ MB

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      125423           2025-02-01
# 1      Dev_Train                      141774           2024-08-13
# 2      Pre_Train                      115246           2024-01-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-01-31
# 2           2024-08-12

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=77790a92-c5bb-4645-9c2a-183b2c72c220>

# %% [markdown]
# ###### Trench 2

# %%
sq = """ 
select 
  r.customerId customer_id,
  r.digitalLoanAccountId,
  r.apps_score beta_cash_app_score,  
  r.app_cnt_health_and_fitness_ever app_cnt_health_and_fitness_ever, 
  r.app_cnt_shopping_ever app_cnt_shopping_ever,
  r.app_cnt_crypto_ever app_cnt_crypto_ever, 
  r.app_cnt_driver_ever app_cnt_driver_ever,
  r.app_cnt_payday_180d app_cnt_payday_180d, 
  r.app_cnt_gambling_180d app_cnt_gambling_180d,
  r.app_avg_time_bw_installed_mins_3d app_avg_time_bw_installed_mins_3d,
  r.app_median_time_bw_installed_mins_ever app_median_time_bw_installed_mins_3d,
    case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
 date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
 case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-08-13' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-08-13' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from risk_mart.applied_quick_loan_new_applicants_20230101_20250930_app_scored_copy r 
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 2'
and r.apps_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 1f2fe125-d3b8-4f4a-ade8-aa9586d425cd successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (121596, 14)

# %%
feature_column = ['beta_cash_app_score',
       'app_cnt_health_and_fitness_ever', 'app_cnt_shopping_ever',
       'app_cnt_crypto_ever', 'app_cnt_driver_ever', 'app_cnt_payday_180d',
       'app_cnt_gambling_180d', 'app_avg_time_bw_installed_mins_3d',
       'app_median_time_bw_installed_mins_3d']

dfd = transform_data(data, feature_column, a='beta_cash_app_score', modelDisplayName='Beta-Cash-AppScore-Model', tc='Trench 2', subscription_name = 'Cash September 25 Models') 
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121596 entries, 0 to 121595
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   customerId            121596 non-null  int64
#  1   digitalLoanAccountId  121596 non-null  object
#  2   crifApplicationId     121596 non-null  object
#  3   prediction            121596 non-null  float64
#  4   start_time            121596 non-null  object
#  5   end_time              121596 non-null  object
#  6   modelDisplayName      121596 non-null  object
#  7   modelVersionId        121596 non-null  object
#  8   calcFeature           121596 non-null  object
#  9   subscription_name     121596 non-null  object
#  10  message_id            121596 non-null  object
#  11  publish_time          121596 non-null  object
#  12  attributes            121596 non-null  object
#  13  trenchCategory        121596 non-null  object
#  14  deviceOs              121596 non-null  object
#  15  Data_selection        121596 non-null  object
#  16  Application_date      121596 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 15.8+ MB

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       54667           2025-02-01
# 1      Dev_Train                       36978           2024-08-13
# 2      Pre_Train                       29951           2024-01-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-01-31
# 2           2024-08-12

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=cf6d7eef-88eb-455a-acdf-fd5a7a046203>

# %% [markdown]
# ###### Trench 3

# %%
sq = """   
 select 
  r.customerId customer_id, 
  r.digitalLoanAccountId,
  r.apps_score beta_cash_app_score,
  r.app_cnt_health_and_fitness_ever_binned app_cnt_health_and_fitness_ever,
  r.app_cnt_productivity_ever_binned app_cnt_productivity_ever, 
  r.app_cnt_rated_for_18plus_ever_binned app_cnt_rated_for_18plus_ever,
  r.app_cnt_books_and_reference_ever_binned app_cnt_books_and_reference_ever, 
  r.app_cnt_gaming_180d_binned app_cnt_gaming_180d,
  r.app_cnt_absence_tag_365d_binned app_cnt_absence_tag_365d,
  r.app_last_payday_install_to_apply_days_binned app_last_payday_install_to_apply_days,
  r.app_cnt_absence_tag_365d_binned,
  r.app_cnt_gaming_180d_binned,
  r.app_cnt_productivity_ever_binned,
  r.app_cnt_rated_for_18plus_ever_binned,
  r.app_cnt_health_and_fitness_ever_binned,
  r.app_cnt_books_and_reference_ever_binned,
  r.app_last_payday_install_to_apply_days_binned,
  r.ln_user_type,
  case when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(lmt.osversion_v2, lmt.osVersion)) like '%os%' then 'ios'
    when lower(lmt.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
  date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
 case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-08-13' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-08-13' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from risk_mart.b_score_model_applied_loans_cash_20240101_20250930_app_scored r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.apps_score is not null 
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-09-24'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID d9ab600b-1209-45ad-a31a-9210c8b9ead0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (65874, 21)

# %%
feature_column = ['beta_cash_app_score',
       'app_cnt_health_and_fitness_ever', 'app_cnt_productivity_ever',
       'app_cnt_rated_for_18plus_ever', 'app_cnt_books_and_reference_ever',
       'app_cnt_gaming_180d', 'app_cnt_absence_tag_365d',
       'app_last_payday_install_to_apply_days',
       'app_cnt_absence_tag_365d_binned', 'app_cnt_gaming_180d_binned',
       'app_cnt_productivity_ever_binned',
       'app_cnt_rated_for_18plus_ever_binned',
       'app_cnt_health_and_fitness_ever_binned',
       'app_cnt_books_and_reference_ever_binned',
       'app_last_payday_install_to_apply_days_binned', 'ln_user_type']

dfd = transform_data(data, feature_column, a='beta_cash_app_score', modelDisplayName='Beta-Cash-AppScore-Model', tc='Trench 3', subscription_name = 'Cash September 25 Models') 
dfd.head()
# Out:
#   customerId                  digitalLoanAccountId  \
# 0    2303203  14cb13ff-3983-481d-b406-670e6b95b134
# 1    3110717  329d404f-d7f1-4920-8434-974d4b70ac50
# 2    2352356  e34d1858-30ac-4402-afc4-e9e77ed62e41
# 3    3281846  bf03844c-687d-4a05-a67e-41a8efcfd88d
# 4    2463395  7eb6284c-a7a3-4155-81de-eea1a3c36e05
#
#                       crifApplicationId  prediction  \
# 0  6ab8f34a-b7c0-47f5-8b56-f1f77e62e730    0.440576
# 1  0c5a69fc-1c65-4fed-8bce-f00a626c8186    0.551303
# 2  8031acb4-4504-4184-8639-4ebe5795b939    0.531319
# 3  2273e0d7-b473-44b7-be61-eba816de1f8c    0.554841
# 4  e1040a8d-dac2-449b-a118-eab9a8f8d472    0.547627
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:12:04.629971  2026-01-16T19:12:04.629971
# 1  2026-01-16T19:12:04.630748  2026-01-16T19:12:04.630748
# 2  2026-01-16T19:12:04.630748  2026-01-16T19:12:04.630748
# 3  2026-01-16T19:12:04.630748  2026-01-16T19:12:04.630748
# 4  2026-01-16T19:12:04.631445  2026-01-16T19:12:04.631445
#
#            modelDisplayName modelVersionId  \
# 0  Beta-Cash-AppScore-Model             v1
# 1  Beta-Cash-AppScore-Model             v1
# 2  Beta-Cash-AppScore-Model             v1
# 3  Beta-Cash-AppScore-Model             v1
# 4  Beta-Cash-AppScore-Model             v1
#
#                                          calcFeature  \
# 0  {"beta_cash_app_score": 0.4405763527299484, "a...
# 1  {"beta_cash_app_score": 0.551303368963618, "ap...
# 2  {"beta_cash_app_score": 0.5313186532291243, "a...
# 3  {"beta_cash_app_score": 0.5548406662124583, "a...
# 4  {"beta_cash_app_score": 0.5476268203634211, "a...
#
#           subscription_name                            message_id  \
# 0  Cash September 25 Models  5c2f514c-3c22-494e-b79a-b9f5050430d4
# 1  Cash September 25 Models  ecf9e9fb-3f48-4bd9-a674-8d87d4e4eb31
# 2  Cash September 25 Models  cd0a1ae4-4672-4b91-9411-80f89ddfe96d
# 3  Cash September 25 Models  0ea924bc-941d-4cb9-b0b5-f9f2903453cc
# 4  Cash September 25 Models  890cd79c-5397-478d-b9b2-30528929ad48
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:12:04.629971         {}       Trench 3  android
# 1  2026-01-16T19:12:04.630748         {}       Trench 3  android
# 2  2026-01-16T19:12:04.630748         {}       Trench 3  android
# 3  2026-01-16T19:12:04.630748         {}       Trench 3  android
# 4  2026-01-16T19:12:04.631445         {}       Trench 3  android
#
#   Data_selection Application_date
# 0      Pre_Train       2024-04-26
# 1       Dev_Test       2025-07-30
# 2      Dev_Train       2024-12-23
# 3       Dev_Test       2025-08-08
# 4      Dev_Train       2025-01-24

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       43321           2025-02-01
# 1      Dev_Train                       12362           2024-08-13
# 2      Pre_Train                       10191           2023-01-01
#
#   Application_date_max
# 0           2025-09-23
# 1           2025-01-31
# 2           2024-08-12

# %%
dfd.info()
dfd['customerId'] = pd.to_numeric(dfd['customerId'], errors='coerce')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65874 entries, 0 to 65873
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customerId            65874 non-null  object
#  1   digitalLoanAccountId  65874 non-null  object
#  2   crifApplicationId     65874 non-null  object
#  3   prediction            65874 non-null  float64
#  4   start_time            65874 non-null  object
#  5   end_time              65874 non-null  object
#  6   modelDisplayName      65874 non-null  object
#  7   modelVersionId        65874 non-null  object
#  8   calcFeature           65874 non-null  object
#  9   subscription_name     65874 non-null  object
#  10  message_id            65874 non-null  object
#  11  publish_time          65874 non-null  object
#  12  attributes            65874 non-null  object
#  13  trenchCategory        65874 non-null  object
#  14  deviceOs              65874 non-null  object
#  15  Data_selection        65874 non-null  object
#  16  Application_date      65874 non-null  object
# dtypes: float64(1), object(16)
# memory usage: 8.5+ MB

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=ca8370d5-be83-49fe-93cb-16497b0c998a>

# %% [markdown]
# # SIL V2

# %% [markdown]
# *   Sil-Alpha-CIC-SIL-Model: worktable_data_analysis.sil_alpha_cic_all_applied_backscored_20240901_20250930
# *   Sil-Alpha-StackingModel: worktable_data_analysis.sil_alpha_applied_loans_backscored_20240901_20251013_option3
# *   Sil-Beta-AppsScoreModel:
# *   New Applicants (T1, T2): risk_mart.applied_sil_trench1_trench2_loan_jan2024_30sep2025_app_scored, risk_mart.applied_sil_new_applicants_loan_oct0125_oct1325_app_scored
# *   Repeat Applicants (T3): risk_mart.b_score_model_applied_loans_sil_20240101_20250930_app_scored, risk_mart.applied_sil_repeat_applicants_loan_oct0125_oct1325_app_scored
# *   Sil-Beta-DemoScoreModel: worktable_data_analysis.sil_beta_demo_all_applied_backscored_20240801_20251015
# *   Sil-Beta-StackScoreModel: worktable_data_analysis.sil_beta_applied_loans_backscored_20240801_20251013_option3m

# %% [markdown]
# ##### 'Alpha - CIC-SIL-Model'

# %% [markdown]
# ##### Trench 1

# %%
sq = """ 
select 
r.customerId customer_id,
r.digitalLoanAccountId, 
r.c_cic_score ,
r.ScoreRange,
       ln_loan_level_user_type, flg_zero_non_granted_ever,
       flg_zero_granted_ever,
       Personal_Loans_granted_contracts_amt_24M,
       granted_contracts_cnt_6M, total_overdue_granted_contracts,
       has_ever_been_overdue, cnt_nongranted_contracts_3M,
       cnt_active_contracts, max_amt_granted_24M,
       tot_active_contracts_util, days_since_last_closed,
       vel_contract_nongranted_cnt_6on12,
       vel_contract_granted_amt_6on12,
       vel_contract_closed_amt_3on12,
case 
  when lower(r.ln_os_type) like '%andro%' then 'android'
  when lower(r.ln_os_type) like '%os%' then 'ios'
  else 'ios' end  osType,
 date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
 case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-09-01' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-09-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.sil_alpha_cic_all_applied_backscored_20240901_20250930 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 1'
and r.c_cic_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID ae2a6a5d-fb7f-4167-96ae-0f99a4f87647 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (224718, 22)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'c_cic_score', 'ScoreRange',
#        'ln_loan_level_user_type', 'flg_zero_non_granted_ever',
#        'flg_zero_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
#        'granted_contracts_cnt_6M', 'total_overdue_granted_contracts',
#        'has_ever_been_overdue', 'cnt_nongranted_contracts_3M',
#        'cnt_active_contracts', 'max_amt_granted_24M',
#        'tot_active_contracts_util', 'days_since_last_closed',
#        'vel_contract_nongranted_cnt_6on12', 'vel_contract_granted_amt_6on12',
#        'vel_contract_closed_amt_3on12', 'osType', 'application_date',
#        'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  c_cic_score ScoreRange  \
# 0      3195894  799a84c4-863b-47c0-81da-f3f3241f5008     0.482718         Ai
# 1      3550529  44276b9b-9313-4ecc-ba97-5a1228b110c8     0.343583         Bi
# 2      3624086  376622e1-2d1a-4f23-ac79-ce16787f763d     0.224131         Di
# 3      3296320  685f03ad-d40e-4f4e-9df9-480e2129bc9e     0.320591         Bi
# 4      3442497  2972225e-d8eb-434c-976e-8d1d40638ba0     0.309949      NH_Hi
#
#   ln_loan_level_user_type flg_zero_non_granted_ever flg_zero_granted_ever  \
# 0         2_New Applicant                         0                     0
# 1         2_New Applicant                         0                     0
# 2         2_New Applicant                         0                     0
# 3         2_New Applicant                         1                     0
# 4         2_New Applicant                         1                     0
#
#    Personal_Loans_granted_contracts_amt_24M  granted_contracts_cnt_6M  \
# 0                                    3999.0                       1.0
# 1                                    6148.0                       5.0
# 2                                   34044.0                       6.0
# 3                                   10670.0                       NaN
# 4                                    6556.0                       NaN
#
#    total_overdue_granted_contracts  has_ever_been_overdue  \
# 0                              5.0                    1.0
# 1                              7.0                    1.0
# 2                              6.0                    1.0
# 3                             13.0                    1.0
# 4                             12.0                    1.0
#
#    cnt_nongranted_contracts_3M  cnt_active_contracts  max_amt_granted_24M  \
# 0                          NaN                   1.0               3999.0
# 1                          2.0                   2.0              10000.0
# 2                          NaN                   2.0              10000.0
# 3                          NaN                   NaN              10670.0
# 4                          NaN                   NaN               2888.0
#
#    tot_active_contracts_util  days_since_last_closed  \
# 0                   1.272568                   277.0
# 1                   0.773333                     8.0
# 2                   1.134233                    11.0
# 3                        NaN                   161.0
# 4                        NaN                   529.0
#
#    vel_contract_nongranted_cnt_6on12  vel_contract_granted_amt_6on12  \
# 0                           2.012048                        1.000000
# 1                           1.334000                        2.232351
# 2                                NaN                        0.622222
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#    vel_contract_closed_amt_3on12   osType application_date Data_selection
# 0                            NaN  android       2025-01-17      Dev_Train
# 1                       3.285191  android       2025-07-11       Dev_Test
# 2                       2.060502  android       2025-08-16       Dev_Test
# 3                            NaN  android       2025-03-01       Dev_Test
# 4                            NaN  android       2025-05-17       Dev_Test

# %%
feature_column = ['ScoreRange',
       'ln_loan_level_user_type', 'flg_zero_non_granted_ever',
       'flg_zero_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
       'granted_contracts_cnt_6M', 'total_overdue_granted_contracts',
       'has_ever_been_overdue', 'cnt_nongranted_contracts_3M',
       'cnt_active_contracts', 'max_amt_granted_24M',
       'tot_active_contracts_util', 'days_since_last_closed',
       'vel_contract_nongranted_cnt_6on12', 'vel_contract_granted_amt_6on12',
       'vel_contract_closed_amt_3on12',]

dfd = transform_datav2(data, feature_column, a='c_cic_score', modelDisplayName='cic_model_sil', tc='Trench 1', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3195894  799a84c4-863b-47c0-81da-f3f3241f5008
# 1     3550529  44276b9b-9313-4ecc-ba97-5a1228b110c8
# 2     3624086  376622e1-2d1a-4f23-ac79-ce16787f763d
# 3     3296320  685f03ad-d40e-4f4e-9df9-480e2129bc9e
# 4     3442497  2972225e-d8eb-434c-976e-8d1d40638ba0
#
#                       crifApplicationId  prediction  \
# 0  6e73ee8b-63e6-4df3-8226-305cc4bbe6b2    0.482718
# 1  a5ed5ff9-f4bd-4b7a-b2b7-90e26209c660    0.343583
# 2  5954e08e-5b97-4bf2-b576-fcf1c587d1ee    0.224131
# 3  a1e85e1b-910d-4a8c-bf0e-460ba1d5d085    0.320591
# 4  2466d620-e327-42f6-b163-93cce2db9ee0    0.309949
#
#                    start_time                    end_time modelDisplayName  \
# 0  2026-01-16T19:12:23.883636  2026-01-16T19:12:23.883636    cic_model_sil
# 1  2026-01-16T19:12:23.883636  2026-01-16T19:12:23.883636    cic_model_sil
# 2  2026-01-16T19:12:23.883636  2026-01-16T19:12:23.883636    cic_model_sil
# 3  2026-01-16T19:12:23.884197  2026-01-16T19:12:23.884197    cic_model_sil
# 4  2026-01-16T19:12:23.884197  2026-01-16T19:12:23.884197    cic_model_sil
#
#   modelVersionId                                        calcFeature  \
# 0             v2  {"ScoreRange": "Ai", "ln_loan_level_user_type"...
# 1             v2  {"ScoreRange": "Bi", "ln_loan_level_user_type"...
# 2             v2  {"ScoreRange": "Di", "ln_loan_level_user_type"...
# 3             v2  {"ScoreRange": "Bi", "ln_loan_level_user_type"...
# 4             v2  {"ScoreRange": "NH_Hi", "ln_loan_level_user_ty...
#
#          subscription_name                            message_id  \
# 0  Cash November 25 Models  444a2a68-c303-47f5-be8a-bd8a77dec966
# 1  Cash November 25 Models  b47c15be-ce09-4424-98a7-0f9861389aad
# 2  Cash November 25 Models  74711d40-675c-42ce-862d-e70e0cdfe453
# 3  Cash November 25 Models  4e9674bf-2ea1-4f80-a8e3-182df647df67
# 4  Cash November 25 Models  d5bb676f-679c-41dc-b613-f7ab3f42bdca
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:12:23.883636         {}       Trench 1  android
# 1  2026-01-16T19:12:23.883636         {}       Trench 1  android
# 2  2026-01-16T19:12:23.883636         {}       Trench 1  android
# 3  2026-01-16T19:12:23.884197         {}       Trench 1  android
# 4  2026-01-16T19:12:23.884197         {}       Trench 1  android
#
#   Data_selection Application_date
# 0      Dev_Train       2025-01-17
# 1       Dev_Test       2025-07-11
# 2       Dev_Test       2025-08-16
# 3       Dev_Test       2025-03-01
# 4       Dev_Test       2025-05-17

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      130029           2025-02-01
# 1      Dev_Train                       94689           2024-09-01
#
#   Application_date_max
# 0           2025-11-15
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=43f030e0-07bc-4297-a617-0397551641c1>

# %% [markdown]
# ##### Trench 2

# %%
sq = """ 
select 
r.customerId customer_id,
r.digitalLoanAccountId, 
r.c_cic_score ,
r.ScoreRange,
       ln_loan_level_user_type, flg_zero_non_granted_ever,
       flg_zero_granted_ever,
       Personal_Loans_granted_contracts_amt_24M,
       granted_contracts_cnt_6M, total_overdue_granted_contracts,
       has_ever_been_overdue, cnt_nongranted_contracts_3M,
       cnt_active_contracts, max_amt_granted_24M,
       tot_active_contracts_util, days_since_last_closed,
       vel_contract_nongranted_cnt_6on12,
       vel_contract_granted_amt_6on12,
       vel_contract_closed_amt_3on12,
case 
  when lower(r.ln_os_type) like '%andro%' then 'android'
  when lower(r.ln_os_type) like '%os%' then 'ios'
  else 'ios' end  osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
 case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-09-01' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-09-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.sil_alpha_cic_all_applied_backscored_20240901_20250930 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 2'
and r.c_cic_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-11-17'
 ;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 8a6a376d-a8d5-44cf-993e-0b69143a92e2 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (10175, 22)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'c_cic_score', 'ScoreRange',
#        'ln_loan_level_user_type', 'flg_zero_non_granted_ever',
#        'flg_zero_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
#        'granted_contracts_cnt_6M', 'total_overdue_granted_contracts',
#        'has_ever_been_overdue', 'cnt_nongranted_contracts_3M',
#        'cnt_active_contracts', 'max_amt_granted_24M',
#        'tot_active_contracts_util', 'days_since_last_closed',
#        'vel_contract_nongranted_cnt_6on12', 'vel_contract_granted_amt_6on12',
#        'vel_contract_closed_amt_3on12', 'osType', 'application_date',
#        'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  c_cic_score ScoreRange  \
# 0      3022916  d1382548-aeb1-45bf-b89d-cfcbb9477f0a     0.384996    Missing
# 1      2705834  e105ebed-d92c-4ee7-8505-ff0af79ca52e     0.417764    Missing
# 2      2092600  fdc7321a-3fa8-4922-8694-09ab5eccaad3     0.379514    Missing
# 3      2101993  defcafdf-f102-4f65-94b9-bff5cac35060     0.289817         Bi
# 4      2041409  8f37f563-2baa-4892-a36b-3065e6611621     0.419148    Missing
#
#   ln_loan_level_user_type flg_zero_non_granted_ever flg_zero_granted_ever  \
# 0         2_New Applicant                         0                     0
# 1         2_New Applicant                         0                     0
# 2         2_New Applicant                         0                     0
# 3         2_New Applicant                         0                     0
# 4         2_New Applicant                         0                     0
#
#    Personal_Loans_granted_contracts_amt_24M  granted_contracts_cnt_6M  \
# 0                                     966.0                       NaN
# 1                                   22540.0                       NaN
# 2                                   22291.0                       NaN
# 3                                   15183.0                       1.0
# 4                                      65.0                       NaN
#
#    total_overdue_granted_contracts  has_ever_been_overdue  \
# 0                             14.0                    1.0
# 1                              9.0                    1.0
# 2                             11.0                    1.0
# 3                             16.0                    1.0
# 4                             22.0                    1.0
#
#    cnt_nongranted_contracts_3M  cnt_active_contracts  max_amt_granted_24M  \
# 0                          NaN                   1.0               9000.0
# 1                          NaN                   1.0              42141.0
# 2                          NaN                   1.0              17039.0
# 3                          NaN                   1.0              15183.0
# 4                          NaN                   1.0              19048.0
#
#    tot_active_contracts_util  days_since_last_closed  \
# 0                   0.000000                    49.0
# 1                   0.703306                   108.0
# 2                   0.000000                   132.0
# 3                   1.074096                   301.0
# 4                   0.753097                   106.0
#
#    vel_contract_nongranted_cnt_6on12  vel_contract_granted_amt_6on12  \
# 0                           2.012048                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                           1.994012                             1.0
# 4                                NaN                             NaN
#
#    vel_contract_closed_amt_3on12   osType application_date Data_selection
# 0                       2.144019  android       2025-09-02       Dev_Test
# 1                            NaN      ios       2025-06-01       Dev_Test
# 2                            NaN      ios       2025-03-13       Dev_Test
# 3                            NaN  android       2024-12-22      Dev_Train
# 4                            NaN  android       2025-06-05       Dev_Test

# %%
feature_column = ['ScoreRange',
       'ln_loan_level_user_type', 'flg_zero_non_granted_ever',
       'flg_zero_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
       'granted_contracts_cnt_6M', 'total_overdue_granted_contracts',
       'has_ever_been_overdue', 'cnt_nongranted_contracts_3M',
       'cnt_active_contracts', 'max_amt_granted_24M',
       'tot_active_contracts_util', 'days_since_last_closed',
       'vel_contract_nongranted_cnt_6on12', 'vel_contract_granted_amt_6on12',
       'vel_contract_closed_amt_3on12',]

dfd = transform_datav2(data, feature_column, a='c_cic_score', modelDisplayName='cic_model_sil', tc='Trench 2', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3022916  d1382548-aeb1-45bf-b89d-cfcbb9477f0a
# 1     2705834  e105ebed-d92c-4ee7-8505-ff0af79ca52e
# 2     2092600  fdc7321a-3fa8-4922-8694-09ab5eccaad3
# 3     2101993  defcafdf-f102-4f65-94b9-bff5cac35060
# 4     2041409  8f37f563-2baa-4892-a36b-3065e6611621
#
#                       crifApplicationId  prediction  \
# 0  03438d6f-10de-4c3e-9629-e24045f11d57    0.384996
# 1  336c8201-8741-46ee-abd8-fc9877359563    0.417764
# 2  98154147-af1b-4ad5-87da-994c594a4de0    0.379514
# 3  5bbabb34-16aa-4348-b4ac-39574ef8ca05    0.289817
# 4  16d9f09d-5cf2-435c-af5b-90cc992e1e91    0.419148
#
#                    start_time                    end_time modelDisplayName  \
# 0  2026-01-16T19:13:03.430941  2026-01-16T19:13:03.430941    cic_model_sil
# 1  2026-01-16T19:13:03.430941  2026-01-16T19:13:03.430941    cic_model_sil
# 2  2026-01-16T19:13:03.430941  2026-01-16T19:13:03.430941    cic_model_sil
# 3  2026-01-16T19:13:03.430941  2026-01-16T19:13:03.430941    cic_model_sil
# 4  2026-01-16T19:13:03.430941  2026-01-16T19:13:03.430941    cic_model_sil
#
#   modelVersionId                                        calcFeature  \
# 0             v2  {"ScoreRange": "Missing", "ln_loan_level_user_...
# 1             v2  {"ScoreRange": "Missing", "ln_loan_level_user_...
# 2             v2  {"ScoreRange": "Missing", "ln_loan_level_user_...
# 3             v2  {"ScoreRange": "Bi", "ln_loan_level_user_type"...
# 4             v2  {"ScoreRange": "Missing", "ln_loan_level_user_...
#
#          subscription_name                            message_id  \
# 0  Cash November 25 Models  ff75a22c-1e4d-4b2b-ae50-33343b684c43
# 1  Cash November 25 Models  836f0a84-b8a3-48e6-b9b6-c51ee4f49e9d
# 2  Cash November 25 Models  48ad1814-759e-46d7-b981-4deb87964baa
# 3  Cash November 25 Models  5f54c0f8-cedf-4f51-8b72-92bc07f590d0
# 4  Cash November 25 Models  79863e30-4071-4c80-8a54-e6e45cf7fde1
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:13:03.430941         {}       Trench 2  android
# 1  2026-01-16T19:13:03.430941         {}       Trench 2      ios
# 2  2026-01-16T19:13:03.430941         {}       Trench 2      ios
# 3  2026-01-16T19:13:03.430941         {}       Trench 2  android
# 4  2026-01-16T19:13:03.430941         {}       Trench 2  android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-09-02
# 1       Dev_Test       2025-06-01
# 2       Dev_Test       2025-03-13
# 3      Dev_Train       2024-12-22
# 4       Dev_Test       2025-06-05

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                        6943           2025-02-01
# 1      Dev_Train                        3232           2024-09-01
#
#   Application_date_max
# 0           2025-09-30
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=e1817af4-fddd-4520-8fd7-ef76fb97b18e>

# %% [markdown]
# ##### Trench 3

# %%
sq = """ 
select 
r.customerId customer_id,
r.digitalLoanAccountId, 
r.c_cic_score ,
r.ScoreRange,
       ln_loan_level_user_type, flg_zero_non_granted_ever,
       flg_zero_granted_ever,
       Personal_Loans_granted_contracts_amt_24M,
       granted_contracts_cnt_6M, total_overdue_granted_contracts,
       has_ever_been_overdue, cnt_nongranted_contracts_3M,
       cnt_active_contracts, max_amt_granted_24M,
       tot_active_contracts_util, days_since_last_closed,
       vel_contract_nongranted_cnt_6on12,
       vel_contract_granted_amt_6on12,
       vel_contract_closed_amt_3on12,
case 
  when lower(r.ln_os_type) like '%andro%' then 'android'
  when lower(r.ln_os_type) like '%os%' then 'ios'
  else 'ios' end  osType,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
 case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-09-01' and '2025-01-31' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-09-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection 
from worktable_data_analysis.sil_alpha_cic_all_applied_backscored_20240901_20250930 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 3'
and r.c_cic_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 259567ad-65d9-4988-95fb-02f29a5607b1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (11515, 22)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'c_cic_score', 'ScoreRange',
#        'ln_loan_level_user_type', 'flg_zero_non_granted_ever',
#        'flg_zero_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
#        'granted_contracts_cnt_6M', 'total_overdue_granted_contracts',
#        'has_ever_been_overdue', 'cnt_nongranted_contracts_3M',
#        'cnt_active_contracts', 'max_amt_granted_24M',
#        'tot_active_contracts_util', 'days_since_last_closed',
#        'vel_contract_nongranted_cnt_6on12', 'vel_contract_granted_amt_6on12',
#        'vel_contract_closed_amt_3on12', 'osType', 'application_date',
#        'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  c_cic_score ScoreRange  \
# 0      3213289  d4e72f5d-10bd-4f67-abf7-be40c360b33d     0.211146      NH_Ei
# 1      2339187  61769da3-9174-4bee-b091-819936c048f2     0.182873    Missing
# 2      2393831  ff553295-c468-4208-bdfb-25c9ee9dc176     0.085827         Ai
# 3      2716521  de15670f-bec3-4920-a76d-a4567bc61a10     0.151268         Ai
# 4      3280607  3214e007-ea81-4749-9d0f-9420b07f5135     0.151516      NH_Ii
#
#   ln_loan_level_user_type flg_zero_non_granted_ever flg_zero_granted_ever  \
# 0      1_Repeat Applicant                         0                     0
# 1      1_Repeat Applicant                         0                     0
# 2      1_Repeat Applicant                         0                     0
# 3      1_Repeat Applicant                         0                     0
# 4      1_Repeat Applicant                         1                     0
#
#    Personal_Loans_granted_contracts_amt_24M  granted_contracts_cnt_6M  \
# 0                                       NaN                       1.0
# 1                                       NaN                       NaN
# 2                                   53700.0                       NaN
# 3                                       NaN                       NaN
# 4                                       NaN                       1.0
#
#    total_overdue_granted_contracts  has_ever_been_overdue  \
# 0                              0.0                    0.0
# 1                              1.0                    1.0
# 2                              0.0                    0.0
# 3                              0.0                    0.0
# 4                              0.0                    0.0
#
#    cnt_nongranted_contracts_3M  cnt_active_contracts  max_amt_granted_24M  \
# 0                          NaN                   1.0               5000.0
# 1                          NaN                   2.0              57000.0
# 2                          NaN                   NaN              53700.0
# 3                          NaN                   1.0               8789.0
# 4                          NaN                   1.0              11782.0
#
#    tot_active_contracts_util  days_since_last_closed  \
# 0                   1.009600                     NaN
# 1                   0.094968                    35.0
# 2                        NaN                   127.0
# 3                   0.579929                     NaN
# 4                   1.009761                     NaN
#
#    vel_contract_nongranted_cnt_6on12  vel_contract_granted_amt_6on12  \
# 0                                NaN                             1.0
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             1.0
#
#    vel_contract_closed_amt_3on12   osType application_date Data_selection
# 0                            NaN  android       2025-06-18       Dev_Test
# 1                            1.0  android       2025-08-28       Dev_Test
# 2                            NaN  android       2025-03-22       Dev_Test
# 3                            NaN  android       2025-03-01       Dev_Test
# 4                            NaN  android       2025-08-21       Dev_Test

# %%
feature_column = ['ScoreRange',
       'ln_loan_level_user_type', 'flg_zero_non_granted_ever',
       'flg_zero_granted_ever', 'Personal_Loans_granted_contracts_amt_24M',
       'granted_contracts_cnt_6M', 'total_overdue_granted_contracts',
       'has_ever_been_overdue', 'cnt_nongranted_contracts_3M',
       'cnt_active_contracts', 'max_amt_granted_24M',
       'tot_active_contracts_util', 'days_since_last_closed',
       'vel_contract_nongranted_cnt_6on12', 'vel_contract_granted_amt_6on12',
       'vel_contract_closed_amt_3on12',]

dfd = transform_datav2(data, feature_column, a='c_cic_score', modelDisplayName='cic_model_sil', tc='Trench 3', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3213289  d4e72f5d-10bd-4f67-abf7-be40c360b33d
# 1     2339187  61769da3-9174-4bee-b091-819936c048f2
# 2     2393831  ff553295-c468-4208-bdfb-25c9ee9dc176
# 3     2716521  de15670f-bec3-4920-a76d-a4567bc61a10
# 4     3280607  3214e007-ea81-4749-9d0f-9420b07f5135
#
#                       crifApplicationId  prediction  \
# 0  aa6c7350-a30d-411a-9e13-b38565aa8615    0.211146
# 1  c9aebc48-b1e3-4844-9954-7910cd4319b5    0.182873
# 2  54987100-f143-47cd-8372-9df440a5eb76    0.085827
# 3  2a1e1bee-e505-4530-b5c7-e27b3ee36fdf    0.151268
# 4  f4cf0c98-dd27-4a67-b461-0fa02765fda6    0.151516
#
#                    start_time                    end_time modelDisplayName  \
# 0  2026-01-16T19:13:09.830811  2026-01-16T19:13:09.830811    cic_model_sil
# 1  2026-01-16T19:13:09.830811  2026-01-16T19:13:09.830811    cic_model_sil
# 2  2026-01-16T19:13:09.830811  2026-01-16T19:13:09.830811    cic_model_sil
# 3  2026-01-16T19:13:09.830811  2026-01-16T19:13:09.830811    cic_model_sil
# 4  2026-01-16T19:13:09.830811  2026-01-16T19:13:09.830811    cic_model_sil
#
#   modelVersionId                                        calcFeature  \
# 0             v2  {"ScoreRange": "NH_Ei", "ln_loan_level_user_ty...
# 1             v2  {"ScoreRange": "Missing", "ln_loan_level_user_...
# 2             v2  {"ScoreRange": "Ai", "ln_loan_level_user_type"...
# 3             v2  {"ScoreRange": "Ai", "ln_loan_level_user_type"...
# 4             v2  {"ScoreRange": "NH_Ii", "ln_loan_level_user_ty...
#
#          subscription_name                            message_id  \
# 0  Cash November 25 Models  e606092d-22bb-4dd0-90ad-dd748150fa7a
# 1  Cash November 25 Models  6cfe6252-b9e7-49ed-9d7d-a4551b2a3e08
# 2  Cash November 25 Models  65d1ea2f-f5f2-4cb0-8d64-29930429d33c
# 3  Cash November 25 Models  eb49ab9e-a0fc-4a38-bb40-4d267d55fb51
# 4  Cash November 25 Models  c6c92b57-97e0-4e41-834b-19ade2765d4e
#
#                  publish_time attributes trenchCategory deviceOs  \
# 0  2026-01-16T19:13:09.830811         {}       Trench 3  android
# 1  2026-01-16T19:13:09.830811         {}       Trench 3  android
# 2  2026-01-16T19:13:09.830811         {}       Trench 3  android
# 3  2026-01-16T19:13:09.830811         {}       Trench 3  android
# 4  2026-01-16T19:13:09.830811         {}       Trench 3  android
#
#   Data_selection Application_date
# 0       Dev_Test       2025-06-18
# 1       Dev_Test       2025-08-28
# 2       Dev_Test       2025-03-22
# 3       Dev_Test       2025-03-01
# 4       Dev_Test       2025-08-21

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                        7246           2025-02-01
# 1      Dev_Train                        4269           2024-09-01
#
#   Application_date_max
# 0           2025-09-30
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=ab5b71fe-3cf6-4717-92bd-3fa6455a52aa>

# %% [markdown]
# ##### Alpha Sil Stack Model

# %% [markdown]
# ##### Trench 1

# %%
sq = """ 
select 
lmt.customerId customer_id,
r.digitalLoanAccountId,  
r.sa_stack_score ,
r.sb_demo_score,
r.apps_score,
r.s_credo_score,
r.sa_cic_score,
case 
  when lower(r.ln_os_type) like '%andro%' then 'android'
  when lower(r.ln_os_type) like '%os%' then 'ios'
  else 'ios' end  osType,
ln_loan_type,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-09-01' and '2025-02-28' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-09-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from worktable_data_analysis.sil_alpha_applied_loans_backscored_20240901_20251013_option3 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 1'
and sa_stack_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID f2c343cd-10e2-4cf9-8279-a8aedc93a02d successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (232107, 11)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'sa_stack_score',
#        'sb_demo_score', 'apps_score', 's_credo_score', 'sa_cic_score',
#        'osType', 'ln_loan_type', 'application_date', 'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  sa_stack_score  \
# 0      3736951  43e8bac7-770e-47b1-bb02-575c10ffee01        0.632541
# 1      3304431  b6113c3b-b3a4-4b91-83b7-69e826b4113d        0.491930
# 2      3503641  0e1599c4-1e58-4b88-aa89-c12c6ed9ee76        0.067394
# 3      3449711  67b8a908-09dc-4431-93f4-e05391f091c2        0.242566
# 4      3620273  eb3d59c2-8e10-4175-92ca-b257225ae84b        0.579218
#
#    sb_demo_score  apps_score  s_credo_score  sa_cic_score   osType  \
# 0       0.631529    0.520775       0.098305      0.355412  android
# 1       0.444923         NaN       0.123621      0.359897      ios
# 2       0.322977    0.114667       0.027916      0.149299  android
# 3       0.248605    0.388681       0.089450      0.321306  android
# 4       0.578734    0.552404       0.192770      0.227156  android
#
#      ln_loan_type application_date Data_selection
# 0  SIL Competitor       2025-10-11       Dev_Test
# 1     SIL-Instore       2025-03-05       Dev_Test
# 2  SIL Competitor       2025-06-17       Dev_Test
# 3  SIL Competitor       2025-05-21       Dev_Test
# 4  SIL Competitor       2025-08-14       Dev_Test

# %%
feature_column = ['sb_demo_score', 'apps_score', 's_credo_score', 'sa_cic_score',]

dfd = transform_datav2(data, feature_column, a='sa_stack_score', modelDisplayName='alpha_stack_model_sil', tc='Trench 1', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3736951  43e8bac7-770e-47b1-bb02-575c10ffee01
# 1     3304431  b6113c3b-b3a4-4b91-83b7-69e826b4113d
# 2     3503641  0e1599c4-1e58-4b88-aa89-c12c6ed9ee76
# 3     3449711  67b8a908-09dc-4431-93f4-e05391f091c2
# 4     3620273  eb3d59c2-8e10-4175-92ca-b257225ae84b
#
#                       crifApplicationId  prediction  \
# 0  e7eed633-7e65-4744-aabd-90c753b6ad80    0.632541
# 1  cca9540c-89d7-493f-a296-ff18f0d8d9e0    0.491930
# 2  2f897494-a9dc-4eb5-a6b5-26a9450a7abb    0.067394
# 3  5eb8959a-6dd2-4a15-a7f5-56048cdf09ab    0.242566
# 4  a58f040f-8f2e-43e0-848a-fa93421bdcb5    0.579218
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:13:19.113352  2026-01-16T19:13:19.113352
# 1  2026-01-16T19:13:19.113352  2026-01-16T19:13:19.113352
# 2  2026-01-16T19:13:19.113352  2026-01-16T19:13:19.113352
# 3  2026-01-16T19:13:19.113352  2026-01-16T19:13:19.113352
# 4  2026-01-16T19:13:19.113352  2026-01-16T19:13:19.113352
#
#         modelDisplayName modelVersionId  \
# 0  alpha_stack_model_sil             v2
# 1  alpha_stack_model_sil             v2
# 2  alpha_stack_model_sil             v2
# 3  alpha_stack_model_sil             v2
# 4  alpha_stack_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"sb_demo_score": 0.6315289744907508, "apps_sc...  Cash November 25 Models
# 1  {"sb_demo_score": 0.4449231011845208, "s_credo...  Cash November 25 Models
# 2  {"sb_demo_score": 0.3229769141644266, "apps_sc...  Cash November 25 Models
# 3  {"sb_demo_score": 0.2486054811178959, "apps_sc...  Cash November 25 Models
# 4  {"sb_demo_score": 0.578733934945953, "apps_sco...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  41e72fb6-f8c4-4cdd-b8ed-4a17b5b20f43  2026-01-16T19:13:19.113352
# 1  1f8fb625-74c2-409a-af0f-5c481402e8bf  2026-01-16T19:13:19.113352
# 2  158193b4-add3-485a-ac9e-3e65cb2e36ef  2026-01-16T19:13:19.113352
# 3  af2284dc-5a5a-4a4f-b7fb-51ed0bba06a8  2026-01-16T19:13:19.113352
# 4  e8fa42a8-3e6b-4a6a-895e-c504ccab4f82  2026-01-16T19:13:19.113352
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 1  android       Dev_Test       2025-10-11
# 1         {}       Trench 1      ios       Dev_Test       2025-03-05
# 2         {}       Trench 1  android       Dev_Test       2025-06-17
# 3         {}       Trench 1  android       Dev_Test       2025-05-21
# 4         {}       Trench 1  android       Dev_Test       2025-08-14

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      124744           2025-03-01
# 1      Dev_Train                      107363           2024-09-01
#
#   Application_date_max
# 0           2025-11-15
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=919caff3-6818-45d6-814d-9d60e26d1391>

# %% [markdown]
# ##### Trench 2

# %%
sq = """ 
select 
lmt.customerId customer_id,
r.digitalLoanAccountId,  
r.sa_stack_score ,
r.sb_demo_score,
r.apps_score,
r.s_credo_score,
r.sa_cic_score,
case 
  when lower(r.ln_os_type) like '%andro%' then 'android'
  when lower(r.ln_os_type) like '%os%' then 'ios'
  else 'ios' end  osType,
ln_loan_type,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-09-01' and '2025-02-28' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-09-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from worktable_data_analysis.sil_alpha_applied_loans_backscored_20240901_20251013_option3 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 2'
and sa_stack_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 4c8ad6bf-0bf1-4d4b-97a9-f0f604666685 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (10592, 11)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'sa_stack_score',
#        'sb_demo_score', 'apps_score', 's_credo_score', 'sa_cic_score',
#        'osType', 'ln_loan_type', 'application_date', 'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  sa_stack_score  \
# 0      1706066  6f9b875d-f829-4aca-81a3-add1dd72d9bd        0.437056
# 1      2881477  a607568c-2bc9-480f-b9cb-508b5176a773        0.683400
# 2      3066850  2ba5d05a-cb37-4395-93ff-aa00e9bf3aca        0.843675
# 3      3063973  f7e7becb-e14f-494f-859b-e03b19064be3        0.265898
# 4      3226035  bbd0c072-ae38-4a31-b209-511bc1d420eb        0.197171
#
#    sb_demo_score  apps_score  s_credo_score  sa_cic_score   osType  \
# 0       0.393981         NaN       0.085152      0.325654      ios
# 1       0.592346    0.409713       0.103203      0.500461  android
# 2       0.718241    0.546141       0.292790      0.370947  android
# 3       0.414439    0.267552       0.067804      0.305599  android
# 4       0.458460    0.366575       0.052749      0.085191  android
#
#      ln_loan_type application_date Data_selection
# 0  SIL Competitor       2025-04-06       Dev_Test
# 1  SIL Competitor       2025-07-27       Dev_Test
# 2  SIL Competitor       2025-03-25       Dev_Test
# 3  SIL Competitor       2025-03-17       Dev_Test
# 4  SIL Competitor       2025-06-15       Dev_Test

# %%
feature_column = ['sb_demo_score', 'apps_score', 's_credo_score', 'sa_cic_score',]

dfd = transform_datav2(data, feature_column, a='sa_stack_score', modelDisplayName='alpha_stack_model_sil', tc='Trench 2', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     1706066  6f9b875d-f829-4aca-81a3-add1dd72d9bd
# 1     2881477  a607568c-2bc9-480f-b9cb-508b5176a773
# 2     3066850  2ba5d05a-cb37-4395-93ff-aa00e9bf3aca
# 3     3063973  f7e7becb-e14f-494f-859b-e03b19064be3
# 4     3226035  bbd0c072-ae38-4a31-b209-511bc1d420eb
#
#                       crifApplicationId  prediction  \
# 0  88dc4dee-95e2-4531-a2cc-917108275fd0    0.437056
# 1  9f0f3fcb-b612-4d33-a347-a6099bea7499    0.683400
# 2  bb8eb3d1-5e23-41e8-9317-49c9db0b4ccf    0.843675
# 3  f1d7949c-1bb1-4551-9f81-2f97664d403d    0.265898
# 4  613c4cd8-e861-41fe-8f4a-7f224bf75a6b    0.197171
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:13:52.379683  2026-01-16T19:13:52.379683
# 1  2026-01-16T19:13:52.379683  2026-01-16T19:13:52.379683
# 2  2026-01-16T19:13:52.379683  2026-01-16T19:13:52.379683
# 3  2026-01-16T19:13:52.379683  2026-01-16T19:13:52.379683
# 4  2026-01-16T19:13:52.379683  2026-01-16T19:13:52.379683
#
#         modelDisplayName modelVersionId  \
# 0  alpha_stack_model_sil             v2
# 1  alpha_stack_model_sil             v2
# 2  alpha_stack_model_sil             v2
# 3  alpha_stack_model_sil             v2
# 4  alpha_stack_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"sb_demo_score": 0.3939805975736532, "s_credo...  Cash November 25 Models
# 1  {"sb_demo_score": 0.5923459607500456, "apps_sc...  Cash November 25 Models
# 2  {"sb_demo_score": 0.7182411102757954, "apps_sc...  Cash November 25 Models
# 3  {"sb_demo_score": 0.41443871122959447, "apps_s...  Cash November 25 Models
# 4  {"sb_demo_score": 0.4584596087451035, "apps_sc...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  6dbbff05-5450-4ccb-b2c8-e96c6365bd11  2026-01-16T19:13:52.379683
# 1  0151155c-715c-4ba8-9dc9-4ef5f2d601a3  2026-01-16T19:13:52.379683
# 2  1399c398-8196-4fcb-b7a5-7452321503cf  2026-01-16T19:13:52.379683
# 3  e9a9d7b8-fe3a-427c-822b-c2ec06736835  2026-01-16T19:13:52.379683
# 4  17cf23d3-a691-4e5b-bbc7-fda91bf087f1  2026-01-16T19:13:52.379683
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 2      ios       Dev_Test       2025-04-06
# 1         {}       Trench 2  android       Dev_Test       2025-07-27
# 2         {}       Trench 2  android       Dev_Test       2025-03-25
# 3         {}       Trench 2  android       Dev_Test       2025-03-17
# 4         {}       Trench 2  android       Dev_Test       2025-06-15

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                        6825           2025-03-01
# 1      Dev_Train                        3767           2024-09-01
#
#   Application_date_max
# 0           2025-10-13
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=0207a7e0-0838-4f50-9704-54c3ca66187a>

# %% [markdown]
# ##### Trench 3

# %%
sq = """ 
select 
lmt.customerId customer_id,
r.digitalLoanAccountId,  
r.sa_stack_score ,
r.sb_demo_score,
r.apps_score,
r.s_credo_score,
r.sa_cic_score,
case 
  when lower(r.ln_os_type) like '%andro%' then 'android'
  when lower(r.ln_os_type) like '%os%' then 'ios'
  else 'ios' end  osType,
ln_loan_type,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-09-01' and '2025-02-28' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-09-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from worktable_data_analysis.sil_alpha_applied_loans_backscored_20240901_20251013_option3 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 3'
and sa_stack_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID ccaae7bc-8aff-4593-9e75-937e7af34014 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (11874, 11)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'sa_stack_score',
#        'sb_demo_score', 'apps_score', 's_credo_score', 'sa_cic_score',
#        'osType', 'ln_loan_type', 'application_date', 'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  sa_stack_score  \
# 0      3341806  659b3d49-a4f9-4cc7-8632-01d73b0c02ec        0.616288
# 1      2744135  02e4edb7-a5de-4415-a034-07b63370b61b        0.113657
# 2      2892628  594e3af2-add4-4b39-b976-afc547f7576c        0.570522
# 3      1635782  32b92b17-bbf8-4321-937f-7b6b43444414        0.493745
# 4      2361363  cd611d84-e556-4f1d-9502-24d170b7fd2d        0.287853
#
#    sb_demo_score  apps_score  s_credo_score  sa_cic_score   osType  \
# 0       0.292474    0.561706       0.160925      0.424917  android
# 1       0.259625    0.277129       0.069794      0.084362  android
# 2       0.305916    0.565756       0.400157      0.156382  android
# 3       0.331413    0.296944       0.144485      0.509808  android
# 4       0.272366         NaN       0.126082      0.160988      ios
#
#      ln_loan_type application_date Data_selection
# 0     SIL-Instore       2025-10-09       Dev_Test
# 1     SIL-Instore       2025-05-01       Dev_Test
# 2  SIL Competitor       2025-04-06       Dev_Test
# 3     SIL-Instore       2025-10-01       Dev_Test
# 4     SIL-Instore       2025-08-17       Dev_Test

# %%
feature_column = ['sb_demo_score', 'apps_score', 's_credo_score', 'sa_cic_score',]

dfd = transform_datav2(data, feature_column, a='sa_stack_score', modelDisplayName='alpha_stack_model_sil', tc='Trench 3', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3341806  659b3d49-a4f9-4cc7-8632-01d73b0c02ec
# 1     2744135  02e4edb7-a5de-4415-a034-07b63370b61b
# 2     2892628  594e3af2-add4-4b39-b976-afc547f7576c
# 3     1635782  32b92b17-bbf8-4321-937f-7b6b43444414
# 4     2361363  cd611d84-e556-4f1d-9502-24d170b7fd2d
#
#                       crifApplicationId  prediction  \
# 0  2d6005e1-244e-4532-a8bc-64320c2f0947    0.616288
# 1  80beb5c0-65d9-4862-8536-8b96043a2be8    0.113657
# 2  c9229657-4754-4246-99a3-b1160a03057d    0.570522
# 3  a184b562-de9b-43fb-a1b3-0f8382788346    0.493745
# 4  f292fbd9-4896-4f26-82b0-9d303c8dc1eb    0.287853
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:13:59.362845  2026-01-16T19:13:59.362845
# 1  2026-01-16T19:13:59.362845  2026-01-16T19:13:59.362845
# 2  2026-01-16T19:13:59.362845  2026-01-16T19:13:59.362845
# 3  2026-01-16T19:13:59.362845  2026-01-16T19:13:59.362845
# 4  2026-01-16T19:13:59.362845  2026-01-16T19:13:59.362845
#
#         modelDisplayName modelVersionId  \
# 0  alpha_stack_model_sil             v2
# 1  alpha_stack_model_sil             v2
# 2  alpha_stack_model_sil             v2
# 3  alpha_stack_model_sil             v2
# 4  alpha_stack_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"sb_demo_score": 0.29247418964989663, "apps_s...  Cash November 25 Models
# 1  {"sb_demo_score": 0.2596253005765629, "apps_sc...  Cash November 25 Models
# 2  {"sb_demo_score": 0.30591639031746076, "apps_s...  Cash November 25 Models
# 3  {"sb_demo_score": 0.33141313319742866, "apps_s...  Cash November 25 Models
# 4  {"sb_demo_score": 0.27236630907116643, "s_cred...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  6c0e5153-3bd3-4883-be95-631834fdab5f  2026-01-16T19:13:59.362845
# 1  26124102-dc9f-4b6c-9b28-8e6a751c5eaf  2026-01-16T19:13:59.362845
# 2  0d7cdf41-2b1f-48fb-961b-50a1d53d270a  2026-01-16T19:13:59.362845
# 3  75f0b9ae-66b8-4090-9365-d59240a243a2  2026-01-16T19:13:59.362845
# 4  3349bd6e-4921-4e2d-8496-8f06a87289e2  2026-01-16T19:13:59.362845
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 3  android       Dev_Test       2025-10-09
# 1         {}       Trench 3  android       Dev_Test       2025-05-01
# 2         {}       Trench 3  android       Dev_Test       2025-04-06
# 3         {}       Trench 3  android       Dev_Test       2025-10-01
# 4         {}       Trench 3      ios       Dev_Test       2025-08-17

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                        6833           2025-03-01
# 1      Dev_Train                        5041           2024-09-01
#
#   Application_date_max
# 0           2025-10-13
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=5dca3d10-14fa-485e-bd29-0e0a752ddf09>

# %% [markdown]
# ##### Beta SIL STACK Score Model

# %% [markdown]
# ##### Trench 1

# %%
sq = """ 
select 
lmt.customerId customer_id,
r.digitalLoanAccountId,  
r.sb_stack_score ,
r.sb_demo_score,
r.apps_score,
r.s_credo_score,
case 
  when lower(r.ln_os_type) like '%andro%' then 'android'
  when lower(r.ln_os_type) like '%os%' then 'ios'
  else 'ios' end  osType,
ln_loan_type,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-08-01' and '2025-02-28' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-08-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from prj-prod-dataplatform.worktable_data_analysis.sil_beta_applied_loans_backscored_20240801_20251013_option3 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 1'
and sb_stack_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 31de649b-422d-4cfd-b739-92ef399cd9ef successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (343968, 10)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'sb_stack_score',
#        'sb_demo_score', 'apps_score', 's_credo_score', 'osType',
#        'ln_loan_type', 'application_date', 'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  sb_stack_score  \
# 0      3742465  119ffc38-a362-43cc-9519-2aded0e8c245        0.189065
# 1      3555012  ff68645d-cefb-4778-9989-135b51f3cfe3        0.146709
# 2      3473255  1402bfc1-998e-411f-9dbc-711bbe9eee3d        0.262834
# 3      3643282  57e63be4-5a36-435e-8ed8-1598a5ddeecf        0.474806
# 4      3546641  6b348c01-993a-4dac-baf9-3decab0524bb        0.411039
#
#    sb_demo_score  apps_score  s_credo_score   osType    ln_loan_type  \
# 0       0.386711    0.183631       0.130050  android     SIL-Instore
# 1       0.199517    0.295672       0.101228  android     SIL-Instore
# 2       0.484231    0.271845       0.069499  android  SIL Competitor
# 3       0.542294    0.463375       0.084460  android     SIL-Instore
# 4       0.458586         NaN       0.072650      ios     SIL-Instore
#
#   application_date Data_selection
# 0       2025-10-13       Dev_Test
# 1       2025-07-13       Dev_Test
# 2       2025-06-02       Dev_Test
# 3       2025-08-25       Dev_Test
# 4       2025-07-09       Dev_Test

# %%
feature_column = ['sb_demo_score', 'apps_score', 's_credo_score']

dfd = transform_datav2(data, feature_column, a='sb_stack_score', modelDisplayName='beta_stack_model_sil', tc='Trench 1', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3742465  119ffc38-a362-43cc-9519-2aded0e8c245
# 1     3555012  ff68645d-cefb-4778-9989-135b51f3cfe3
# 2     3473255  1402bfc1-998e-411f-9dbc-711bbe9eee3d
# 3     3643282  57e63be4-5a36-435e-8ed8-1598a5ddeecf
# 4     3546641  6b348c01-993a-4dac-baf9-3decab0524bb
#
#                       crifApplicationId  prediction  \
# 0  b942c1a8-d3a5-4fc5-a712-8e595c01e38e    0.189065
# 1  3eef10d1-44eb-4089-94d8-b579339a9328    0.146709
# 2  1e8e76c7-86e4-4a36-9086-353b208de10a    0.262834
# 3  5eee6b58-8724-4059-80c0-472a3e40ce3e    0.474806
# 4  782b215f-92c3-4a74-9079-3488acaa73b7    0.411039
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:14:10.596451  2026-01-16T19:14:10.596451
# 1  2026-01-16T19:14:10.596451  2026-01-16T19:14:10.596451
# 2  2026-01-16T19:14:10.596451  2026-01-16T19:14:10.596451
# 3  2026-01-16T19:14:10.596451  2026-01-16T19:14:10.596451
# 4  2026-01-16T19:14:10.596451  2026-01-16T19:14:10.596451
#
#        modelDisplayName modelVersionId  \
# 0  beta_stack_model_sil             v2
# 1  beta_stack_model_sil             v2
# 2  beta_stack_model_sil             v2
# 3  beta_stack_model_sil             v2
# 4  beta_stack_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"sb_demo_score": 0.38671090314290235, "apps_s...  Cash November 25 Models
# 1  {"sb_demo_score": 0.19951719457009148, "apps_s...  Cash November 25 Models
# 2  {"sb_demo_score": 0.48423068408830183, "apps_s...  Cash November 25 Models
# 3  {"sb_demo_score": 0.5422941103330391, "apps_sc...  Cash November 25 Models
# 4  {"sb_demo_score": 0.4585859920361209, "s_credo...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  3479ad66-efe6-4fd8-9654-3db602491812  2026-01-16T19:14:10.596451
# 1  179023df-adae-4aa3-acc6-818f5b799cfd  2026-01-16T19:14:10.596451
# 2  63675234-5ae9-46aa-86aa-c47474a89572  2026-01-16T19:14:10.596451
# 3  4483132f-4f71-491e-82a5-ce457fb5aa5c  2026-01-16T19:14:10.596451
# 4  76be7fc7-7f40-4fb7-be95-4c93db1482e5  2026-01-16T19:14:10.596451
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 1  android       Dev_Test       2025-10-13
# 1         {}       Trench 1  android       Dev_Test       2025-07-13
# 2         {}       Trench 1  android       Dev_Test       2025-06-02
# 3         {}       Trench 1  android       Dev_Test       2025-08-25
# 4         {}       Trench 1      ios       Dev_Test       2025-07-09

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      165423           2025-03-01
# 1      Dev_Train                      178545           2024-08-01
#
#   Application_date_max
# 0           2025-11-15
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=34a20a75-605b-4ef8-ad33-ca7df1991d5b>

# %% [markdown]
# ##### Trench 2

# %%
sq = """ 
select 
lmt.customerId customer_id,
r.digitalLoanAccountId,  
r.sb_stack_score ,
r.sb_demo_score,
r.apps_score,
r.s_credo_score,
case 
  when lower(r.ln_os_type) like '%andro%' then 'android'
  when lower(r.ln_os_type) like '%os%' then 'ios'
  else 'ios' end  osType,
ln_loan_type,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-08-01' and '2025-02-28' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-08-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from prj-prod-dataplatform.worktable_data_analysis.sil_beta_applied_loans_backscored_20240801_20251013_option3 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 2'
and sb_stack_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 39eea9ec-1e18-4732-aec8-d2d0202cf77f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (13099, 10)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'sb_stack_score',
#        'sb_demo_score', 'apps_score', 's_credo_score', 'osType',
#        'ln_loan_type', 'application_date', 'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  sb_stack_score  \
# 0      3280189  f8adb417-86da-469b-a8a8-197410cf9776        0.462539
# 1      2215173  a31b0b1f-caa6-4741-8c34-c23341898e7c        0.582103
# 2      3115380  cc5b232a-ed90-4dec-9b07-cb6be5f90e0b        0.526366
# 3      2189425  bf400964-9a14-428e-81b1-14a1d827e992        0.309712
# 4      2880114  1a122e33-3f7c-4fad-9a08-8e4f3e0708ff        0.229878
#
#    sb_demo_score  apps_score  s_credo_score   osType ln_loan_type  \
# 0       0.503780    0.469983       0.097081  android     SIL ZERO
# 1       0.435959    0.653687       0.108681  android     SIL ZERO
# 2       0.594303    0.398850       0.159925  android     SIL ZERO
# 3       0.400669    0.362381       0.117657  android     SIL ZERO
# 4       0.299266    0.402037       0.053916  android  SIL-Instore
#
#   application_date Data_selection
# 0       2025-09-16       Dev_Test
# 1       2025-05-03       Dev_Test
# 2       2025-04-11       Dev_Test
# 3       2025-10-09       Dev_Test
# 4       2025-06-03       Dev_Test

# %%
feature_column = ['sb_demo_score', 'apps_score', 's_credo_score']

dfd = transform_datav2(data, feature_column, a='sb_stack_score', modelDisplayName='beta_stack_model_sil', tc='Trench 2', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3280189  f8adb417-86da-469b-a8a8-197410cf9776
# 1     2215173  a31b0b1f-caa6-4741-8c34-c23341898e7c
# 2     3115380  cc5b232a-ed90-4dec-9b07-cb6be5f90e0b
# 3     2189425  bf400964-9a14-428e-81b1-14a1d827e992
# 4     2880114  1a122e33-3f7c-4fad-9a08-8e4f3e0708ff
#
#                       crifApplicationId  prediction  \
# 0  3a640b27-bc08-4d82-a11e-84c92f3c2010    0.462539
# 1  103a7f3e-fe89-4794-8ee9-f5ed7b92c4fa    0.582103
# 2  e0d42646-0b52-4fdd-807a-f9fc35a6b364    0.526366
# 3  dbda7fd1-a54c-49c0-b96b-f895f1f78ed6    0.309712
# 4  914858f1-6838-48d6-84ad-ec2b12f36f2a    0.229878
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:14:51.274801  2026-01-16T19:14:51.274801
# 1  2026-01-16T19:14:51.274801  2026-01-16T19:14:51.274801
# 2  2026-01-16T19:14:51.274801  2026-01-16T19:14:51.274801
# 3  2026-01-16T19:14:51.274801  2026-01-16T19:14:51.274801
# 4  2026-01-16T19:14:51.274801  2026-01-16T19:14:51.274801
#
#        modelDisplayName modelVersionId  \
# 0  beta_stack_model_sil             v2
# 1  beta_stack_model_sil             v2
# 2  beta_stack_model_sil             v2
# 3  beta_stack_model_sil             v2
# 4  beta_stack_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"sb_demo_score": 0.5037803522853171, "apps_sc...  Cash November 25 Models
# 1  {"sb_demo_score": 0.4359585807282797, "apps_sc...  Cash November 25 Models
# 2  {"sb_demo_score": 0.5943026314634269, "apps_sc...  Cash November 25 Models
# 3  {"sb_demo_score": 0.40066927917656237, "apps_s...  Cash November 25 Models
# 4  {"sb_demo_score": 0.2992660611467991, "apps_sc...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  f0ff364d-2c59-4053-af8c-ea1006887b4c  2026-01-16T19:14:51.274801
# 1  327c0a1c-db5b-427f-b60e-e25ce4333f7a  2026-01-16T19:14:51.274801
# 2  01610e98-dd92-443b-a140-ae0528a65d99  2026-01-16T19:14:51.274801
# 3  b104a13b-77cd-4c99-9033-32d77df58d79  2026-01-16T19:14:51.274801
# 4  f3042257-bb2f-45ed-ab69-2b0b1bf87fda  2026-01-16T19:14:51.274801
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 2  android       Dev_Test       2025-09-16
# 1         {}       Trench 2  android       Dev_Test       2025-05-03
# 2         {}       Trench 2  android       Dev_Test       2025-04-11
# 3         {}       Trench 2  android       Dev_Test       2025-10-09
# 4         {}       Trench 2  android       Dev_Test       2025-06-03

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                        7599           2025-03-01
# 1      Dev_Train                        5500           2024-08-01
#
#   Application_date_max
# 0           2025-10-13
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=bbaab705-bec5-4959-834f-5a3c9f9d279b>

# %% [markdown]
# ##### Trench 3

# %%
sq = """ 
select 
lmt.customerId customer_id,
r.digitalLoanAccountId,  
r.sb_stack_score ,
r.sb_demo_score,
r.apps_score,
r.s_credo_score,
case 
  when lower(r.ln_os_type) like '%andro%' then 'android'
  when lower(r.ln_os_type) like '%os%' then 'ios'
  else 'ios' end  osType,
ln_loan_type,
date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime))
        between '2024-08-01' and '2025-02-28' then 'Dev_Train'
        when date(if(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2024-08-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from prj-prod-dataplatform.worktable_data_analysis.sil_beta_applied_loans_backscored_20240801_20251013_option3 r
left join `risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = r.digitalLoanAccountId
where r.trench_category = 'Trench 3'
and sb_stack_score is not null
and date(IF(lmt.new_loan_type = 'Flex-up', lmt.startApplyDateTime, lmt.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID eab6dc21-09ed-4055-ba95-dc401015b96c successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (13802, 10)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'sb_stack_score',
#        'sb_demo_score', 'apps_score', 's_credo_score', 'osType',
#        'ln_loan_type', 'application_date', 'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  sb_stack_score  \
# 0      2545858  9eb785e7-5567-4276-9cb8-7ad2a5bfb321        0.225571
# 1      2315681  e76a655f-2a13-4264-9609-2ff359438ce4        0.308010
# 2      2503045  3f47ce34-da32-4ca4-946a-db3c6cfbe889        0.369089
# 3      3309765  5c3fc7ba-0433-46f1-936c-a5e7c7287a77        0.452867
# 4      2341857  92298a10-1d55-4264-8d37-7157bf53c413        0.341828
#
#    sb_demo_score  apps_score  s_credo_score   osType    ln_loan_type  \
# 0       0.175574         NaN       0.081049      ios        SIL ZERO
# 1       0.304643    0.465938       0.095345  android        SIL ZERO
# 2       0.253630    0.582042       0.101363  android  SIL Competitor
# 3       0.285785    0.566070       0.187960  android     SIL-Instore
# 4       0.362918    0.480684       0.069894  android  SIL Competitor
#
#   application_date Data_selection
# 0       2025-04-20       Dev_Test
# 1       2025-03-06       Dev_Test
# 2       2025-04-04       Dev_Test
# 3       2025-08-09       Dev_Test
# 4       2025-05-06       Dev_Test

# %%
feature_column = ['sb_demo_score', 'apps_score', 's_credo_score']

dfd = transform_datav2(data, feature_column, a='sb_stack_score', modelDisplayName='beta_stack_model_sil', tc='Trench 3', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2545858  9eb785e7-5567-4276-9cb8-7ad2a5bfb321
# 1     2315681  e76a655f-2a13-4264-9609-2ff359438ce4
# 2     2503045  3f47ce34-da32-4ca4-946a-db3c6cfbe889
# 3     3309765  5c3fc7ba-0433-46f1-936c-a5e7c7287a77
# 4     2341857  92298a10-1d55-4264-8d37-7157bf53c413
#
#                       crifApplicationId  prediction  \
# 0  0734375a-b485-443f-a706-a027d88ca45e    0.225571
# 1  5b4c6a02-b80f-4180-b444-fb0240c9b20d    0.308010
# 2  22205394-87b4-4cb4-80bf-c13b2b871fb5    0.369089
# 3  abd47e40-b325-4454-b240-bf6077bc4dd2    0.452867
# 4  127c25f0-65ee-46e9-b73d-24a74c363ea6    0.341828
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:14:58.546279  2026-01-16T19:14:58.546279
# 1  2026-01-16T19:14:58.546279  2026-01-16T19:14:58.546279
# 2  2026-01-16T19:14:58.546279  2026-01-16T19:14:58.546279
# 3  2026-01-16T19:14:58.546279  2026-01-16T19:14:58.546279
# 4  2026-01-16T19:14:58.546279  2026-01-16T19:14:58.546279
#
#        modelDisplayName modelVersionId  \
# 0  beta_stack_model_sil             v2
# 1  beta_stack_model_sil             v2
# 2  beta_stack_model_sil             v2
# 3  beta_stack_model_sil             v2
# 4  beta_stack_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"sb_demo_score": 0.1755742572455905, "s_credo...  Cash November 25 Models
# 1  {"sb_demo_score": 0.3046433132639846, "apps_sc...  Cash November 25 Models
# 2  {"sb_demo_score": 0.25363013646064025, "apps_s...  Cash November 25 Models
# 3  {"sb_demo_score": 0.2857845839576205, "apps_sc...  Cash November 25 Models
# 4  {"sb_demo_score": 0.3629180003646723, "apps_sc...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  f0929bee-af10-40d9-b631-53656befc986  2026-01-16T19:14:58.546279
# 1  1b25c2c1-996d-4711-8d71-18babaed718a  2026-01-16T19:14:58.546279
# 2  33c2c901-be08-4609-a4f0-ef4243da8e44  2026-01-16T19:14:58.546279
# 3  72f8931e-1a30-413d-8b35-7855c9412ebd  2026-01-16T19:14:58.546279
# 4  45dc7c10-17ef-4571-bea4-beb80fd2d5b3  2026-01-16T19:14:58.546279
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 3      ios       Dev_Test       2025-04-20
# 1         {}       Trench 3  android       Dev_Test       2025-03-06
# 2         {}       Trench 3  android       Dev_Test       2025-04-04
# 3         {}       Trench 3  android       Dev_Test       2025-08-09
# 4         {}       Trench 3  android       Dev_Test       2025-05-06

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                        7383           2025-03-01
# 1      Dev_Train                        6419           2024-08-01
#
#   Application_date_max
# 0           2025-10-13
# 1           2025-02-28

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=4a42f5ec-de84-4a7b-a058-6b7847fc5308>

# %% [markdown]
# ##### Beta Sil App Score

# %% [markdown]
# ##### Trench 1

# %%
sq = """ 
select 
distinct 
loanmaster.customerId customer_id,
r.digitalLoanAccountId,
r.apps_score,
app_cnt_payday_ever,
app_cnt_finance_ever,
app_cnt_competitors_sil_ever,
app_cnt_competitors_ever,
app_cnt_finance_365d,
app_cnt_absence_tag_365d,
app_cnt_competitors_sil_365d,
app_cnt_finance_7d,
app_cnt_rated_for_3plus_ever,
app_cnt_payday_7d,
    case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
    when lower(loanmaster.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
        between '2024-08-01' and '2025-01-31' then 'Dev_Train'
        when date(if(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-08-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from  risk_mart.applied_sil_new_applicants_loan_20241001_20251124_app_scored r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where apps_score is not null
and trench_category = 'Trench 1'
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 0b2d60ed-0261-4300-80f4-70b823db0e86 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (289957, 16)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'apps_score',
#        'app_cnt_payday_ever', 'app_cnt_finance_ever',
#        'app_cnt_competitors_sil_ever', 'app_cnt_competitors_ever',
#        'app_cnt_finance_365d', 'app_cnt_absence_tag_365d',
#        'app_cnt_competitors_sil_365d', 'app_cnt_finance_7d',
#        'app_cnt_rated_for_3plus_ever', 'app_cnt_payday_7d', 'osType',
#        'application_date', 'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  apps_score  \
# 0      3655004  8e5fe550-a1dc-4141-8663-5e784853a663    0.137928
# 1      3635320  73a54de1-e56c-465f-9ed3-e54b72c9673c    0.404060
# 2      3365227  e19d2222-0f19-449c-bfcd-41e54c9d9ac3    0.326500
# 3      3381407  4e0f9db0-5e8e-4233-a7e9-59b4c8523bb3    0.576843
# 4      3400685  84059931-ce71-4d8b-b14f-ae44ea67c7d7    0.477944
#
#    app_cnt_payday_ever  app_cnt_finance_ever  app_cnt_competitors_sil_ever  \
# 0                    2                  19.0                             2
# 1                   10                  19.0                             5
# 2                    4                  14.0                             2
# 3                    4                  12.0                             4
# 4                    7                  15.0                             3
#
#    app_cnt_competitors_ever  app_cnt_finance_365d  app_cnt_absence_tag_365d  \
# 0                         5                   4.0                      18.0
# 1                        11                   9.0                      14.0
# 2                         7                  14.0                      18.0
# 3                         5                  12.0                      14.0
# 4                         7                  12.0                       5.0
#
#    app_cnt_competitors_sil_365d  app_cnt_finance_7d  \
# 0                           0.0                 0.0
# 1                           5.0                 0.0
# 2                           2.0                 0.0
# 3                           4.0                 4.0
# 4                           2.0                 0.0
#
#    app_cnt_rated_for_3plus_ever  app_cnt_payday_7d   osType application_date  \
# 0                          50.0                0.0  android       2025-08-31
# 1                          90.0                0.0  android       2025-08-21
# 2                          70.0                0.0  android       2025-04-07
# 3                          40.0                3.0  android       2025-04-15
# 4                          22.0                0.0  android       2025-04-25
#
#   Data_selection
# 0       Dev_Test
# 1       Dev_Test
# 2       Dev_Test
# 3       Dev_Test
# 4       Dev_Test

# %%
feature_column = ['app_cnt_payday_ever', 'app_cnt_finance_ever',
       'app_cnt_competitors_sil_ever', 'app_cnt_competitors_ever',
       'app_cnt_finance_365d', 'app_cnt_absence_tag_365d',
       'app_cnt_competitors_sil_365d', 'app_cnt_finance_7d',
       'app_cnt_rated_for_3plus_ever', 'app_cnt_payday_7d',]

dfd = transform_datav2(data, feature_column, a='apps_score', modelDisplayName='apps_score_model_sil', tc='Trench 1', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3655004  8e5fe550-a1dc-4141-8663-5e784853a663
# 1     3635320  73a54de1-e56c-465f-9ed3-e54b72c9673c
# 2     3365227  e19d2222-0f19-449c-bfcd-41e54c9d9ac3
# 3     3381407  4e0f9db0-5e8e-4233-a7e9-59b4c8523bb3
# 4     3400685  84059931-ce71-4d8b-b14f-ae44ea67c7d7
#
#                       crifApplicationId  prediction  \
# 0  177d24e7-0a9e-4c96-a302-4d98f795cffe    0.137928
# 1  841e2210-8933-430a-bdbb-97bafcf016c2    0.404060
# 2  2c294c67-c735-41a5-98b5-13554c89b53e    0.326500
# 3  369fc6a9-9461-40a8-9962-a2af44e41a3a    0.576843
# 4  513913b9-4db9-464e-905d-db2bcb5683b2    0.477944
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:15:08.008460  2026-01-16T19:15:08.008460
# 1  2026-01-16T19:15:08.008460  2026-01-16T19:15:08.008460
# 2  2026-01-16T19:15:08.008460  2026-01-16T19:15:08.008460
# 3  2026-01-16T19:15:08.008460  2026-01-16T19:15:08.008460
# 4  2026-01-16T19:15:08.008460  2026-01-16T19:15:08.008460
#
#        modelDisplayName modelVersionId  \
# 0  apps_score_model_sil             v2
# 1  apps_score_model_sil             v2
# 2  apps_score_model_sil             v2
# 3  apps_score_model_sil             v2
# 4  apps_score_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"app_cnt_payday_ever": 2, "app_cnt_finance_ev...  Cash November 25 Models
# 1  {"app_cnt_payday_ever": 10, "app_cnt_finance_e...  Cash November 25 Models
# 2  {"app_cnt_payday_ever": 4, "app_cnt_finance_ev...  Cash November 25 Models
# 3  {"app_cnt_payday_ever": 4, "app_cnt_finance_ev...  Cash November 25 Models
# 4  {"app_cnt_payday_ever": 7, "app_cnt_finance_ev...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  2db9134c-a47c-4486-9a4d-2693992c2d43  2026-01-16T19:15:08.008460
# 1  617b8b1a-d6a7-46d8-a051-8496f03a8fd1  2026-01-16T19:15:08.008460
# 2  74e3ab5c-4134-4def-b591-d760c174732e  2026-01-16T19:15:08.008460
# 3  2a4a6f82-67ba-462d-ae11-cd80b04d3237  2026-01-16T19:15:08.008460
# 4  dced5d72-bfbd-4762-b197-31a8945171b5  2026-01-16T19:15:08.008460
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 1  android       Dev_Test       2025-08-31
# 1         {}       Trench 1  android       Dev_Test       2025-08-21
# 2         {}       Trench 1  android       Dev_Test       2025-04-07
# 3         {}       Trench 1  android       Dev_Test       2025-04-15
# 4         {}       Trench 1  android       Dev_Test       2025-04-25

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      187810           2025-02-01
# 1      Dev_Train                      102147           2024-10-01
#
#   Application_date_max
# 0           2025-11-16
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=f4f960c1-02ce-4e53-b99c-853d933b0311>

# %% [markdown]
# ##### Trench 2

# %%
sq = """ 
select 
distinct 
loanmaster.customerId customer_id,
r.digitalLoanAccountId,
r.apps_score,
app_cnt_payday_ever,
app_cnt_finance_ever,
app_cnt_competitors_sil_ever,
app_cnt_competitors_ever,
app_cnt_finance_365d,
app_cnt_absence_tag_365d,
app_cnt_competitors_sil_365d,
app_cnt_finance_7d,
app_cnt_rated_for_3plus_ever,
app_cnt_payday_7d,
    case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
    when lower(loanmaster.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
        between '2024-08-01' and '2025-01-31' then 'Dev_Train'
        when date(if(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-08-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from  risk_mart.applied_sil_new_applicants_loan_20241001_20251124_app_scored r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where apps_score is not null
and trench_category = 'Trench 2'
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 79b530b9-2e24-4577-b122-4380cf831fdf successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (11680, 16)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'apps_score',
#        'app_cnt_payday_ever', 'app_cnt_finance_ever',
#        'app_cnt_competitors_sil_ever', 'app_cnt_competitors_ever',
#        'app_cnt_finance_365d', 'app_cnt_absence_tag_365d',
#        'app_cnt_competitors_sil_365d', 'app_cnt_finance_7d',
#        'app_cnt_rated_for_3plus_ever', 'app_cnt_payday_7d', 'osType',
#        'application_date', 'Data_selection'],
#       dtype='object')

# %%
data.head()
# Out:
#    customer_id                  digitalLoanAccountId  apps_score  \
# 0      2138075  1ddc22f5-026e-4150-9c2c-b64151154575    0.201415
# 1      2476027  2e05d89c-cd58-42f8-afce-eb0c437b9cfa    0.391375
# 2      3211173  c8524054-f1e7-44c3-a634-d3e7fb704a25    0.438699
# 3      2124531  15133f4e-4205-4ae3-b2a5-02e1163cd7c9    0.454678
# 4      3026188  4f058f3a-7e7b-4e40-9d50-0af3f084af8a    0.396767
#
#    app_cnt_payday_ever  app_cnt_finance_ever  app_cnt_competitors_sil_ever  \
# 0                    4                  19.0                             2
# 1                    7                  18.0                             4
# 2                   11                  22.0                             2
# 3                    2                  18.0                             2
# 4                   12                  21.0                             5
#
#    app_cnt_competitors_ever  app_cnt_finance_365d  app_cnt_absence_tag_365d  \
# 0                        10                  10.0                      11.0
# 1                        10                  15.0                       3.0
# 2                         8                  19.0                       7.0
# 3                         4                  18.0                       9.0
# 4                        13                  13.0                      10.0
#
#    app_cnt_competitors_sil_365d  app_cnt_finance_7d  \
# 0                           1.0                 1.0
# 1                           4.0                 1.0
# 2                           2.0                 3.0
# 3                           2.0                18.0
# 4                           3.0                 0.0
#
#    app_cnt_rated_for_3plus_ever  app_cnt_payday_7d   osType application_date  \
# 0                          59.0                1.0  android       2025-06-08
# 1                          46.0                1.0  android       2025-06-12
# 2                          54.0                2.0  android       2025-07-05
# 3                          31.0                2.0  android       2025-04-14
# 4                          74.0                0.0  android       2025-03-28
#
#   Data_selection
# 0       Dev_Test
# 1       Dev_Test
# 2       Dev_Test
# 3       Dev_Test
# 4       Dev_Test

# %%
feature_column = ['app_cnt_payday_ever', 'app_cnt_finance_ever',
       'app_cnt_competitors_sil_ever', 'app_cnt_competitors_ever',
       'app_cnt_finance_365d', 'app_cnt_absence_tag_365d',
       'app_cnt_competitors_sil_365d', 'app_cnt_finance_7d',
       'app_cnt_rated_for_3plus_ever', 'app_cnt_payday_7d',]

dfd = transform_datav2(data, feature_column, a='apps_score', modelDisplayName='apps_score_model_sil', tc='Trench 2', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2138075  1ddc22f5-026e-4150-9c2c-b64151154575
# 1     2476027  2e05d89c-cd58-42f8-afce-eb0c437b9cfa
# 2     3211173  c8524054-f1e7-44c3-a634-d3e7fb704a25
# 3     2124531  15133f4e-4205-4ae3-b2a5-02e1163cd7c9
# 4     3026188  4f058f3a-7e7b-4e40-9d50-0af3f084af8a
#
#                       crifApplicationId  prediction  \
# 0  6be38363-8e2e-4997-b133-8f8719e56bdc    0.201415
# 1  97c3fe99-fa1b-409e-921a-a53db36a53a7    0.391375
# 2  cfa0ae2f-322e-42ee-8eaa-e05a1654cf10    0.438699
# 3  54e2a8dc-97fe-433f-adde-07a31d5f6727    0.454678
# 4  e5fd092f-09ff-4829-8347-8527eb8134a0    0.396767
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:15:54.265915  2026-01-16T19:15:54.265915
# 1  2026-01-16T19:15:54.265915  2026-01-16T19:15:54.265915
# 2  2026-01-16T19:15:54.265915  2026-01-16T19:15:54.265915
# 3  2026-01-16T19:15:54.266451  2026-01-16T19:15:54.266451
# 4  2026-01-16T19:15:54.266451  2026-01-16T19:15:54.266451
#
#        modelDisplayName modelVersionId  \
# 0  apps_score_model_sil             v2
# 1  apps_score_model_sil             v2
# 2  apps_score_model_sil             v2
# 3  apps_score_model_sil             v2
# 4  apps_score_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"app_cnt_payday_ever": 4, "app_cnt_finance_ev...  Cash November 25 Models
# 1  {"app_cnt_payday_ever": 7, "app_cnt_finance_ev...  Cash November 25 Models
# 2  {"app_cnt_payday_ever": 11, "app_cnt_finance_e...  Cash November 25 Models
# 3  {"app_cnt_payday_ever": 2, "app_cnt_finance_ev...  Cash November 25 Models
# 4  {"app_cnt_payday_ever": 12, "app_cnt_finance_e...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  a1d25e83-3484-4a93-b359-0c40242751af  2026-01-16T19:15:54.265915
# 1  11a7eef2-db6c-45b6-a5ad-bfafdc5b7e85  2026-01-16T19:15:54.265915
# 2  4b8d8591-ea9d-4bda-b841-f37c46e23b55  2026-01-16T19:15:54.265915
# 3  efbc1b92-05af-4c35-8d91-96cbf219ab31  2026-01-16T19:15:54.266451
# 4  4e022fdd-fce4-4274-9d0f-1305f9ac5d3b  2026-01-16T19:15:54.266451
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 2  android       Dev_Test       2025-06-08
# 1         {}       Trench 2  android       Dev_Test       2025-06-12
# 2         {}       Trench 2  android       Dev_Test       2025-07-05
# 3         {}       Trench 2  android       Dev_Test       2025-04-14
# 4         {}       Trench 2  android       Dev_Test       2025-03-28

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                        8445           2025-02-01
# 1      Dev_Train                        3235           2024-10-01
#
#   Application_date_max
# 0           2025-11-16
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=d70c3a82-e94b-463d-8f4c-b0aa9ff85471>

# %% [markdown]
# ##### Trench 3

# %%
sq = """ 
select 
r.customerId customer_id,
r.digitalLoanAccountId,
r.apps_score,
app_cnt_productivity_ever,
app_cnt_rated_for_3plus_ever, 
app_cnt_books_and_reference_ever,
app_cnt_tools_ever, 
app_median_time_bw_installed_mins_3d,
app_median_time_bw_installed_mins_30d,
app_cnt_communication_ever, 
app_cnt_finance_90d,
app_cnt_absence_tag_180d, 
app_cnt_shopping_ever,
app_cnt_social_ever, 
app_cnt_driver_90d, 
app_cnt_payday_365d,
app_cnt_driver_365d, 
app_cnt_music_and_audio_ever,
app_cnt_finance_180d, 
app_cnt_art_and_design_ever,
app_cnt_gaming_90d, 
app_avg_time_bw_installed_mins_30d,
app_cnt_education_ever,
case when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%andro%' then 'android'
    when lower(coalesce(loanmaster.osversion_v2, loanmaster.osVersion)) like '%os%' then 'ios'
    when lower(loanmaster.deviceType) like '%andro%' then 'android'
    else 'ios' end osType,
date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
        between '2024-08-01' and '2025-01-31' then 'Dev_Train'
        when date(if(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-08-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from risk_mart.applied_sil_repeat_applicants_loan_20241001_20251124_app_scored r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where apps_score is not null
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 40e4db9d-8f3c-4260-9241-a51ec9fa97e1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (19768, 26)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 'apps_score',
#        'app_cnt_productivity_ever', 'app_cnt_rated_for_3plus_ever',
#        'app_cnt_books_and_reference_ever', 'app_cnt_tools_ever',
#        'app_median_time_bw_installed_mins_3d',
#        'app_median_time_bw_installed_mins_30d', 'app_cnt_communication_ever',
#        'app_cnt_finance_90d', 'app_cnt_absence_tag_180d',
#        'app_cnt_shopping_ever', 'app_cnt_social_ever', 'app_cnt_driver_90d',
#        'app_cnt_payday_365d', 'app_cnt_driver_365d',
#        'app_cnt_music_and_audio_ever', 'app_cnt_finance_180d',
#        'app_cnt_art_and_design_ever', 'app_cnt_gaming_90d',
#        'app_avg_time_bw_installed_mins_30d', 'app_cnt_education_ever',
#        'osType', 'application_date', 'Data_selection'],
#       dtype='object')

# %%
feature_column = ['app_cnt_productivity_ever', 'app_cnt_rated_for_3plus_ever',
       'app_cnt_books_and_reference_ever', 'app_cnt_tools_ever',
       'app_median_time_bw_installed_mins_3d',
       'app_median_time_bw_installed_mins_30d', 'app_cnt_communication_ever',
       'app_cnt_finance_90d', 'app_cnt_absence_tag_180d',
       'app_cnt_shopping_ever', 'app_cnt_social_ever', 'app_cnt_driver_90d',
       'app_cnt_payday_365d', 'app_cnt_driver_365d',
       'app_cnt_music_and_audio_ever', 'app_cnt_finance_180d',
       'app_cnt_art_and_design_ever', 'app_cnt_gaming_90d',
       'app_avg_time_bw_installed_mins_30d', 'app_cnt_education_ever',]

dfd = transform_datav2(data, feature_column, a='apps_score', modelDisplayName='apps_score_model_sil', tc='Trench 3', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#   customerId                  digitalLoanAccountId  \
# 0    2654586  7c66a1d9-c8c8-4758-8be4-1c8df0ed0fe9
# 1    2496300  bd9e7825-7ebb-4c2a-9fd0-3cc89a017e15
# 2    2708690  29b275ed-4938-4f6d-99ad-8cf47ef61339
# 3    2841934  5a27f398-61f8-4719-a497-626c04cfcd37
# 4    2476134  6a33e8be-263a-4190-ac73-d7a1629d63e6
#
#                       crifApplicationId  prediction  \
# 0  5a44d048-c16b-4503-8314-f302e97bd202    0.403125
# 1  4e6783de-ae91-43f3-abff-6954ad016c20    0.427483
# 2  778ed869-4943-4978-b005-3a90ec0e3e5d    0.261049
# 3  6f60378e-2f01-4663-bda2-bd526c7496f0    0.330189
# 4  c30baf3a-d1c8-4c93-8043-baee9ea5b4ad    0.369869
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:16:01.840840  2026-01-16T19:16:01.840840
# 1  2026-01-16T19:16:01.840840  2026-01-16T19:16:01.840840
# 2  2026-01-16T19:16:01.840840  2026-01-16T19:16:01.840840
# 3  2026-01-16T19:16:01.840840  2026-01-16T19:16:01.840840
# 4  2026-01-16T19:16:01.840840  2026-01-16T19:16:01.840840
#
#        modelDisplayName modelVersionId  \
# 0  apps_score_model_sil             v2
# 1  apps_score_model_sil             v2
# 2  apps_score_model_sil             v2
# 3  apps_score_model_sil             v2
# 4  apps_score_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"app_cnt_productivity_ever": 1.0, "app_cnt_ra...  Cash November 25 Models
# 1  {"app_cnt_productivity_ever": 0.0, "app_cnt_ra...  Cash November 25 Models
# 2  {"app_cnt_productivity_ever": 5.0, "app_cnt_ra...  Cash November 25 Models
# 3  {"app_cnt_productivity_ever": 5.0, "app_cnt_ra...  Cash November 25 Models
# 4  {"app_cnt_productivity_ever": 2.0, "app_cnt_ra...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  dc0531b4-9477-49b0-bcc3-698416e74117  2026-01-16T19:16:01.840840
# 1  8d2c4db1-bb0c-4041-870a-596bea621f6a  2026-01-16T19:16:01.840840
# 2  63fa487e-40f1-4021-9004-edbaf13e319a  2026-01-16T19:16:01.840840
# 3  35eaace9-53f7-4228-954d-8e5c43d27a8f  2026-01-16T19:16:01.840840
# 4  b0e34e85-4710-4186-85ca-a3e78c2a0336  2026-01-16T19:16:01.840840
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 3  android       Dev_Test       2025-04-12
# 1         {}       Trench 3  android      Dev_Train       2024-11-16
# 2         {}       Trench 3  android      Dev_Train       2024-11-19
# 3         {}       Trench 3  android      Dev_Train       2024-11-20
# 4         {}       Trench 3  android      Dev_Train       2024-11-28

# %%
dfd['customerId'] = pd.to_numeric(dfd['customerId'], errors='coerce')

# %%
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19768 entries, 0 to 19767
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customerId            19768 non-null  int64
#  1   digitalLoanAccountId  19768 non-null  object
#  2   crifApplicationId     19768 non-null  object
#  3   prediction            19768 non-null  float64
#  4   start_time            19768 non-null  object
#  5   end_time              19768 non-null  object
#  6   modelDisplayName      19768 non-null  object
#  7   modelVersionId        19768 non-null  object
#  8   calcFeature           19768 non-null  object
#  9   subscription_name     19768 non-null  object
#  10  message_id            19768 non-null  object
#  11  publish_time          19768 non-null  object
#  12  attributes            19768 non-null  object
#  13  trenchCategory        19768 non-null  object
#  14  deviceOs              19768 non-null  object
#  15  Data_selection        19768 non-null  object
#  16  Application_date      19768 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 2.6+ MB

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                       14581           2025-02-01
# 1      Dev_Train                        5187           2024-10-01
#
#   Application_date_max
# 0           2025-11-16
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=af6c71db-899d-4f14-9e44-dacbd61e622f>

# %% [markdown]
# ##### Beta SIL Demo Score

# %% [markdown]
# ##### Trench 1

# %%
sq = """select 
distinct 
loanmaster.customerId customer_id,
r.digitalLoanAccountId,
r.s_demo_score,
ln_vas_opted_flag,
ln_doc_type_rolled,
ln_industry_new_cat_bin,
ln_marital_status,
ln_age,
ln_education_level,
ln_cnt_dependents,
ln_ref2_type,
ln_loan_level_user_type,
ln_ref1_type,
ln_name_email_match_score,
ln_telconame,
ln_city_cat,
ln_brand_bin,
ln_apply_Is_Weekend,
r.ln_os_type osType,
date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
        between '2024-08-01' and '2025-01-31' then 'Dev_Train'
        when date(if(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-08-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from worktable_data_analysis.sil_beta_demo_all_applied_backscored_20240801_20251015 r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where s_demo_score is not null
and trench_category = 'Trench 1'
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID b6e9b29c-9da7-4ea4-b6d1-deaf6d957cf1 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (345905, 21)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 's_demo_score',
#        'ln_vas_opted_flag', 'ln_doc_type_rolled', 'ln_industry_new_cat_bin',
#        'ln_marital_status', 'ln_age', 'ln_education_level',
#        'ln_cnt_dependents', 'ln_ref2_type', 'ln_loan_level_user_type',
#        'ln_ref1_type', 'ln_name_email_match_score', 'ln_telconame',
#        'ln_city_cat', 'ln_brand_bin', 'ln_apply_Is_Weekend', 'osType',
#        'application_date', 'Data_selection'],
#       dtype='object')

# %%
feature_column = [ 'ln_vas_opted_flag', 'ln_doc_type_rolled', 'ln_industry_new_cat_bin',
       'ln_marital_status', 'ln_age', 'ln_education_level',
       'ln_cnt_dependents', 'ln_ref2_type', 'ln_loan_level_user_type',
       'ln_ref1_type', 'ln_name_email_match_score', 'ln_telconame',
       'ln_city_cat', 'ln_brand_bin', 'ln_apply_Is_Weekend', 'osType']

dfd = transform_datav2(data, feature_column, a='s_demo_score', modelDisplayName='beta_demo_model_sil', tc='Trench 1', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3574100  8d7a46db-9936-4267-81d4-9b0377e57299
# 1     3247541  905b4aae-8bfc-4ee3-9f10-65bfe51c5f5e
# 2     3298891  d281ff9b-2197-4e82-b612-44e7b4676338
# 3     3165295  3697a6c3-e3ac-4508-901e-0cc65cfa6e75
# 4     2766763  aed75b9d-c004-42db-bada-e523929d76b8
#
#                       crifApplicationId  prediction  \
# 0  95ff4875-107d-4e37-8a8b-9b441b50a439    0.391914
# 1  bdb4a4b6-5ae0-4cea-9950-9890b44ecdc1    0.246292
# 2  2553c833-0d9a-4fc7-b91a-ac5f10f19912    0.335671
# 3  b7ba2500-900c-491d-a380-67bc40cc84fa    0.324512
# 4  62af1736-dc9f-48d4-95cb-1b6947dd4e66    0.231494
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:16:16.744794  2026-01-16T19:16:16.744794
# 1  2026-01-16T19:16:16.744794  2026-01-16T19:16:16.744794
# 2  2026-01-16T19:16:16.744794  2026-01-16T19:16:16.744794
# 3  2026-01-16T19:16:16.745791  2026-01-16T19:16:16.745791
# 4  2026-01-16T19:16:16.745791  2026-01-16T19:16:16.745791
#
#       modelDisplayName modelVersionId  \
# 0  beta_demo_model_sil             v2
# 1  beta_demo_model_sil             v2
# 2  beta_demo_model_sil             v2
# 3  beta_demo_model_sil             v2
# 4  beta_demo_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"ln_vas_opted_flag": "0", "ln_doc_type_rolled...  Cash November 25 Models
# 1  {"ln_vas_opted_flag": "0", "ln_doc_type_rolled...  Cash November 25 Models
# 2  {"ln_vas_opted_flag": "0", "ln_doc_type_rolled...  Cash November 25 Models
# 3  {"ln_vas_opted_flag": "0", "ln_doc_type_rolled...  Cash November 25 Models
# 4  {"ln_vas_opted_flag": "0", "ln_doc_type_rolled...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  8fd092ba-a0f9-47ff-bcf9-d0690b755f99  2026-01-16T19:16:16.744794
# 1  3a2c34e1-2c3e-4980-bb9e-70c58bca633b  2026-01-16T19:16:16.744794
# 2  df99297e-7dd4-40e5-9f20-efbc50f999e7  2026-01-16T19:16:16.744794
# 3  9fe20da1-fb6a-4669-ae7a-e8b7a6cbf0ad  2026-01-16T19:16:16.745791
# 4  3d73f1c5-9703-4e87-98d6-01ae6e29743a  2026-01-16T19:16:16.745791
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 1  Android       Dev_Test       2025-07-23
# 1         {}       Trench 1  Android       Dev_Test       2025-02-09
# 2         {}       Trench 1  Android       Dev_Test       2025-03-02
# 3         {}       Trench 1  Android      Dev_Train       2025-01-04
# 4         {}       Trench 1  Android      Dev_Train       2024-08-18

# %%
dfd['customerId'] = pd.to_numeric(dfd['customerId'], errors='coerce')

# %%
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345905 entries, 0 to 345904
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   customerId            345905 non-null  int64
#  1   digitalLoanAccountId  345905 non-null  object
#  2   crifApplicationId     345905 non-null  object
#  3   prediction            345905 non-null  float64
#  4   start_time            345905 non-null  object
#  5   end_time              345905 non-null  object
#  6   modelDisplayName      345905 non-null  object
#  7   modelVersionId        345905 non-null  object
#  8   calcFeature           345905 non-null  object
#  9   subscription_name     345905 non-null  object
#  10  message_id            345905 non-null  object
#  11  publish_time          345905 non-null  object
#  12  attributes            345905 non-null  object
#  13  trenchCategory        345905 non-null  object
#  14  deviceOs              345905 non-null  object
#  15  Data_selection        345905 non-null  object
#  16  Application_date      345905 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 44.9+ MB

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                      185960           2025-02-01
# 1      Dev_Train                      159945           2024-08-01
#
#   Application_date_max
# 0           2025-11-15
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=9e785917-cf0d-4c66-a17d-43f391dbcf8f>

# %% [markdown]
# ##### Trench 2

# %%
sq = """select 
distinct 
loanmaster.customerId customer_id,
r.digitalLoanAccountId,
r.s_demo_score,
ln_vas_opted_flag,
ln_doc_type_rolled,
ln_industry_new_cat_bin,
ln_marital_status,
ln_age,
ln_education_level,
ln_cnt_dependents,
ln_ref2_type,
ln_loan_level_user_type,
ln_ref1_type,
ln_name_email_match_score,
ln_telconame,
ln_city_cat,
ln_brand_bin,
ln_apply_Is_Weekend,
r.ln_os_type osType,
date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
        between '2024-08-01' and '2025-01-31' then 'Dev_Train'
        when date(if(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-08-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from worktable_data_analysis.sil_beta_demo_all_applied_backscored_20240801_20251015 r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where s_demo_score is not null
and trench_category = 'Trench 2'
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-11-17'
;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 1c5d19f2-09b9-4f72-b418-ae85264dca5f successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (13192, 21)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 's_demo_score',
#        'ln_vas_opted_flag', 'ln_doc_type_rolled', 'ln_industry_new_cat_bin',
#        'ln_marital_status', 'ln_age', 'ln_education_level',
#        'ln_cnt_dependents', 'ln_ref2_type', 'ln_loan_level_user_type',
#        'ln_ref1_type', 'ln_name_email_match_score', 'ln_telconame',
#        'ln_city_cat', 'ln_brand_bin', 'ln_apply_Is_Weekend', 'osType',
#        'application_date', 'Data_selection'],
#       dtype='object')

# %%
feature_column = [ 'ln_vas_opted_flag', 'ln_doc_type_rolled', 'ln_industry_new_cat_bin',
       'ln_marital_status', 'ln_age', 'ln_education_level',
       'ln_cnt_dependents', 'ln_ref2_type', 'ln_loan_level_user_type',
       'ln_ref1_type', 'ln_name_email_match_score', 'ln_telconame',
       'ln_city_cat', 'ln_brand_bin', 'ln_apply_Is_Weekend', 'osType']

dfd = transform_datav2(data, feature_column, a='s_demo_score', modelDisplayName='beta_demo_model_sil', tc='Trench 2', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     3147455  7bd2018d-6fa9-4abb-ad87-2067dfcb0174
# 1     3224825  36b25813-702a-4326-9154-f067b19d49ea
# 2     3497052  6072249c-1e69-4e58-ad5f-779c96e2df7b
# 3     3083946  22e306b7-2b9e-4d80-82b9-9a938f91ef6c
# 4     2487157  685b73f4-7689-4b47-861c-b346a776b311
#
#                       crifApplicationId  prediction  \
# 0  c791505d-80a4-4630-b765-2a114a9fc91a    0.510103
# 1  9e92aa66-18f2-4991-ace6-388cd7a5e287    0.475738
# 2  a1d77add-4874-40bc-9c84-59e4e132c006    0.735441
# 3  c9d7429f-8c4b-46dd-aada-912317f5bc83    0.517193
# 4  3c71e4f2-85cc-4b0e-8de4-46d5d3fbcc3c    0.595762
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:17:39.466952  2026-01-16T19:17:39.466952
# 1  2026-01-16T19:17:39.467483  2026-01-16T19:17:39.467483
# 2  2026-01-16T19:17:39.467483  2026-01-16T19:17:39.467483
# 3  2026-01-16T19:17:39.468032  2026-01-16T19:17:39.468032
# 4  2026-01-16T19:17:39.468032  2026-01-16T19:17:39.468032
#
#       modelDisplayName modelVersionId  \
# 0  beta_demo_model_sil             v2
# 1  beta_demo_model_sil             v2
# 2  beta_demo_model_sil             v2
# 3  beta_demo_model_sil             v2
# 4  beta_demo_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"ln_vas_opted_flag": "1", "ln_doc_type_rolled...  Cash November 25 Models
# 1  {"ln_vas_opted_flag": "1", "ln_doc_type_rolled...  Cash November 25 Models
# 2  {"ln_vas_opted_flag": "1", "ln_doc_type_rolled...  Cash November 25 Models
# 3  {"ln_vas_opted_flag": "1", "ln_doc_type_rolled...  Cash November 25 Models
# 4  {"ln_vas_opted_flag": "1", "ln_doc_type_rolled...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  9e875040-07d0-4bb0-b479-c10255dd1b22  2026-01-16T19:17:39.466952
# 1  59f5ecbe-5930-4fc3-9871-b82536b996e8  2026-01-16T19:17:39.467483
# 2  ad564f49-668f-475a-a547-caa4a15ed111  2026-01-16T19:17:39.467483
# 3  87098952-668a-46a3-8f4d-9bb82bb139f4  2026-01-16T19:17:39.468032
# 4  ca9b8486-3382-474d-9383-1cefcf2d1543  2026-01-16T19:17:39.468032
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 2      iOS       Dev_Test       2025-10-05
# 1         {}       Trench 2  Android       Dev_Test       2025-07-13
# 2         {}       Trench 2  Android       Dev_Test       2025-10-02
# 3         {}       Trench 2      iOS       Dev_Test       2025-07-13
# 4         {}       Trench 2  Android      Dev_Train       2024-10-08

# %%
dfd['customerId'] = pd.to_numeric(dfd['customerId'], errors='coerce')

# %%
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13192 entries, 0 to 13191
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customerId            13192 non-null  int64
#  1   digitalLoanAccountId  13192 non-null  object
#  2   crifApplicationId     13192 non-null  object
#  3   prediction            13192 non-null  float64
#  4   start_time            13192 non-null  object
#  5   end_time              13192 non-null  object
#  6   modelDisplayName      13192 non-null  object
#  7   modelVersionId        13192 non-null  object
#  8   calcFeature           13192 non-null  object
#  9   subscription_name     13192 non-null  object
#  10  message_id            13192 non-null  object
#  11  publish_time          13192 non-null  object
#  12  attributes            13192 non-null  object
#  13  trenchCategory        13192 non-null  object
#  14  deviceOs              13192 non-null  object
#  15  Data_selection        13192 non-null  object
#  16  Application_date      13192 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 1.7+ MB

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                        8408           2025-02-01
# 1      Dev_Train                        4784           2024-08-01
#
#   Application_date_max
# 0           2025-10-15
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=c9aa10c9-9b85-46dd-a3a4-a1ad928257e0>

# %% [markdown]
# ##### Trench 3

# %%
sq = """select 
distinct 
loanmaster.customerId customer_id,
r.digitalLoanAccountId,
r.s_demo_score,
ln_vas_opted_flag,
ln_doc_type_rolled,
ln_industry_new_cat_bin,
ln_marital_status,
ln_age,
ln_education_level,
ln_cnt_dependents,
ln_ref2_type,
ln_loan_level_user_type,
ln_ref1_type,
ln_name_email_match_score,
ln_telconame,
ln_city_cat,
ln_brand_bin,
ln_apply_Is_Weekend,
r.ln_os_type osType,
date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) application_date,
case when date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime))
        between '2024-08-01' and '2025-01-31' then 'Dev_Train'
        when date(if(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2024-08-01' then 'Pre_Train'
                else 'Dev_Test' end as Data_selection
from worktable_data_analysis.sil_beta_demo_all_applied_backscored_20240801_20251015 r
left join risk_credit_mis.loan_master_table loanmaster
  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
where s_demo_score is not null
and trench_category = 'Trench 3'
and date(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime)) < '2025-11-17'
 ;
"""
data = client.query(sq).to_dataframe(progress_bar_type='tqdm')
print(f"The shape of the dataframe is:\t {data.shape}")
# Out:
# Job ID 0b0ca6f5-ac1d-444c-94e4-8b347f746b17 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# The shape of the dataframe is:	 (13866, 21)

# %%
data.columns
# Out:
# Index(['customer_id', 'digitalLoanAccountId', 's_demo_score',
#        'ln_vas_opted_flag', 'ln_doc_type_rolled', 'ln_industry_new_cat_bin',
#        'ln_marital_status', 'ln_age', 'ln_education_level',
#        'ln_cnt_dependents', 'ln_ref2_type', 'ln_loan_level_user_type',
#        'ln_ref1_type', 'ln_name_email_match_score', 'ln_telconame',
#        'ln_city_cat', 'ln_brand_bin', 'ln_apply_Is_Weekend', 'osType',
#        'application_date', 'Data_selection'],
#       dtype='object')

# %%
feature_column = [ 'ln_vas_opted_flag', 'ln_doc_type_rolled', 'ln_industry_new_cat_bin',
       'ln_marital_status', 'ln_age', 'ln_education_level',
       'ln_cnt_dependents', 'ln_ref2_type', 'ln_loan_level_user_type',
       'ln_ref1_type', 'ln_name_email_match_score', 'ln_telconame',
       'ln_city_cat', 'ln_brand_bin', 'ln_apply_Is_Weekend', 'osType']

dfd = transform_datav2(data, feature_column, a='s_demo_score', modelDisplayName='beta_demo_model_sil', tc='Trench 3', subscription_name = 'Cash November 25 Models') 
dfd.head()
# Out:
#    customerId                  digitalLoanAccountId  \
# 0     2603453  635ed803-deec-4b0b-8941-11b81674454b
# 1     2990791  5b09c15b-1ef0-4e15-af2b-7111a8584964
# 2     3334386  487a2bb8-03cc-4895-b561-4e81f519c19e
# 3     3131553  f3d34429-c090-4a35-8299-638a687b91d5
# 4     2496121  91d2b59b-6c4a-42c5-8208-f1f47e9a630e
#
#                       crifApplicationId  prediction  \
# 0  795376b9-ff31-4b84-a498-e37c6f6393eb    0.135418
# 1  78be01aa-efc7-40f9-9ac8-bcc5e5c81e48    0.100234
# 2  957678a7-18ab-4f59-9fa2-a27bb7c0d32e    0.206825
# 3  95792d62-1ef0-4077-96a9-e2c236130088    0.202157
# 4  189772d7-05ab-4570-9d4f-660658f0ce21    0.176284
#
#                    start_time                    end_time  \
# 0  2026-01-16T19:17:48.287394  2026-01-16T19:17:48.287394
# 1  2026-01-16T19:17:48.287394  2026-01-16T19:17:48.287394
# 2  2026-01-16T19:17:48.287394  2026-01-16T19:17:48.287394
# 3  2026-01-16T19:17:48.287394  2026-01-16T19:17:48.287394
# 4  2026-01-16T19:17:48.287394  2026-01-16T19:17:48.287394
#
#       modelDisplayName modelVersionId  \
# 0  beta_demo_model_sil             v2
# 1  beta_demo_model_sil             v2
# 2  beta_demo_model_sil             v2
# 3  beta_demo_model_sil             v2
# 4  beta_demo_model_sil             v2
#
#                                          calcFeature        subscription_name  \
# 0  {"ln_vas_opted_flag": "0", "ln_doc_type_rolled...  Cash November 25 Models
# 1  {"ln_vas_opted_flag": "0", "ln_doc_type_rolled...  Cash November 25 Models
# 2  {"ln_vas_opted_flag": "1", "ln_doc_type_rolled...  Cash November 25 Models
# 3  {"ln_vas_opted_flag": "1", "ln_doc_type_rolled...  Cash November 25 Models
# 4  {"ln_vas_opted_flag": "0", "ln_doc_type_rolled...  Cash November 25 Models
#
#                              message_id                publish_time  \
# 0  dec63272-e5e0-444c-9332-6eb75cbd28d9  2026-01-16T19:17:48.287394
# 1  b8d13c79-b498-4b4c-aac3-9ae057c42d0f  2026-01-16T19:17:48.287394
# 2  6f5b887a-8afc-4e48-a989-cf9f730dcfe4  2026-01-16T19:17:48.287394
# 3  c3629de9-c79a-4a93-8f9a-4b52e27ada21  2026-01-16T19:17:48.287394
# 4  675327e2-1e3a-4699-9243-4c85095a6c03  2026-01-16T19:17:48.287394
#
#   attributes trenchCategory deviceOs Data_selection Application_date
# 0         {}       Trench 3  Android      Dev_Train       2024-11-16
# 1         {}       Trench 3  Android       Dev_Test       2025-06-01
# 2         {}       Trench 3  Android       Dev_Test       2025-09-20
# 3         {}       Trench 3  Android       Dev_Test       2025-07-16
# 4         {}       Trench 3  Android      Dev_Train       2024-09-27

# %%
dfd['customerId'] = pd.to_numeric(dfd['customerId'], errors='coerce')

# %%
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13866 entries, 0 to 13865
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customerId            13866 non-null  int64
#  1   digitalLoanAccountId  13866 non-null  object
#  2   crifApplicationId     13866 non-null  object
#  3   prediction            13866 non-null  float64
#  4   start_time            13866 non-null  object
#  5   end_time              13866 non-null  object
#  6   modelDisplayName      13866 non-null  object
#  7   modelVersionId        13866 non-null  object
#  8   calcFeature           13866 non-null  object
#  9   subscription_name     13866 non-null  object
#  10  message_id            13866 non-null  object
#  11  publish_time          13866 non-null  object
#  12  attributes            13866 non-null  object
#  13  trenchCategory        13866 non-null  object
#  14  deviceOs              13866 non-null  object
#  15  Data_selection        13866 non-null  object
#  16  Application_date      13866 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 1.8+ MB

# %%
result = dfd.groupby('Data_selection').agg(
    digitalLoanAccountId_count=('digitalLoanAccountId', 'count'),
    Application_date_min=('Application_date', 'min'),
    Application_date_max=('Application_date', 'max')
).reset_index()

result
# Out:
#   Data_selection  digitalLoanAccountId_count Application_date_min  \
# 0       Dev_Test                        8346           2025-02-01
# 1      Dev_Train                        5520           2024-08-01
#
#   Application_date_max
# 0           2025-10-15
# 1           2025-01-31

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details_20260116"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dfd, table_id, job_config=job_config)
job.result()
# Out:
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=025db971-6e40-479a-a13a-79e7081b675c>

# %% [markdown]
# # End
