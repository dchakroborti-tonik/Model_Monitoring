# %% [markdown]
# # Define Library

# %%
# %% [markdown]
# # Jupyter Notebook Loading Header
#
# This is a custom loading header for Jupyter Notebooks in Visual Studio Code.
# It includes common imports and settings to get you started quickly.
# %% [markdown]
## Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery
from google.cloud import storage
import os
import tempfile
import time
from datetime import datetime
import uuid
import joblib
import uuid
from sklearn.metrics import roc_auc_score
from datetime import datetime, timedelta
import gcsfs
import duckdb as dd
import pickle
import joblib
from typing import Union
import io
path = r'C:\Users\Dwaipayan\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = path
client = bigquery.Client(project='prj-prod-dataplatform')
os.environ["GOOGLE_CLOUD_PROJECT"] = "prj-prod-dataplatform"

# %% [markdown]
## Configure Settings
# Set options or configurations as needed
pd.set_option('display.max_columns', None)
pd.set_option("Display.max_rows", 100)

# %% [markdown]
# # Function

# %% [markdown]
# ## calculate_gini

# %%
def calculate_gini(pd_scores, bad_indicators):
    """
    Calculate Gini coefficient from scores and binary indicators
    
    Parameters:
    pd_scores: array-like of scores/probabilities
    bad_indicators: array-like of binary outcomes (0/1)
    
    Returns:
    float: Gini coefficient
    """
    # Convert inputs to numpy arrays and ensure they're numeric
    pd_scores = np.array(pd_scores, dtype=float)
    bad_indicators = np.array(bad_indicators, dtype=int)
    
    # Check for valid input data
    if len(pd_scores) == 0 or len(bad_indicators) == 0:
        return np.nan
    
    # Check if we have both good and bad cases (needed for ROC AUC)
    if len(np.unique(bad_indicators)) < 2:
        return np.nan
    
    # Calculate AUC using sklearn
    try:
        auc = roc_auc_score(bad_indicators, pd_scores)
        # Calculate Gini from AUC
        gini = 2 * auc - 1
        return gini
    except ValueError:
        return np.nan

# %% [markdown]
# ## calculate_periodic_gini_prod_ver_trench

# %%
def calculate_periodic_gini_prod_ver_trench(df, score_column, label_column, namecolumn, 
                                        model_version_column=None, trench_column=None, 
                                        loan_type_column=None, loan_product_type_column=None):
    """
    Calculate periodic Gini coefficients at multiple levels:
    - Overall
    - By model version
    - By all combinations of model version, trench category, loan type, and loan product type
    
    Parameters:
    df: DataFrame with disbursement dates and score/label columns
    score_column: name of the score column
    label_column: name of the label column
    namecolumn: name for the bad rate label
    model_version_column: (optional) name of column for model version (e.g., 'modelVersionId')
    trench_column: (optional) name of column for trench category (e.g., 'trenchCategory')
    loan_type_column: (optional) name of loan type column (e.g., 'loan_type')
    loan_product_type_column: (optional) name of loan product type column (e.g., 'loan_product_type')
    """
    # Input validation
    required_columns = ['disbursementdate', score_column, label_column]
    if not all(col in df.columns for col in required_columns):
        raise ValueError(f"Missing required columns. Need: {required_columns}")
    
    optional_columns = {
        'model_version': model_version_column,
        'trench': trench_column,
        'loan_type': loan_type_column,
        'loan_product_type': loan_product_type_column
    }
    
    for col_name, col in optional_columns.items():
        if col and col not in df.columns:
            raise ValueError(f"{col_name.replace('_', ' ').title()} column '{col}' not found in dataframe")
    
    # Create a copy to avoid modifying original dataframe
    df = df.copy()
    
    # Ensure date is datetime type
    df['disbursementdate'] = pd.to_datetime(df['disbursementdate'])
    
    # Ensure score and label columns are numeric
    df[score_column] = pd.to_numeric(df[score_column], errors='coerce')
    df[label_column] = pd.to_numeric(df[label_column], errors='coerce')
    
    # Drop rows with invalid values
    df = df.dropna(subset=[score_column, label_column])
    
    # Define list of datasets to process
    datasets_to_process = [('Overall', df, {})]
    
    # Add model version level segmentation
    if model_version_column:
        for model_version in sorted(df[model_version_column].dropna().unique()):
            model_df = df[df[model_version_column] == model_version]
            metadata = {model_version_column: model_version}
            datasets_to_process.append((f'ModelVersion_{model_version}', model_df, metadata))
    
    # Add all combinations of model_version, trench, loan_type, loan_product_type
    segment_columns = []
    if model_version_column:
        segment_columns.append(('ModelVersion', model_version_column))
    if trench_column:
        segment_columns.append(('Trench', trench_column))
    if loan_type_column:
        segment_columns.append(('LoanType', loan_type_column))
    if loan_product_type_column:
        segment_columns.append(('ProductType', loan_product_type_column))
    
    # Generate all combinations (only if we have multiple segment columns)
    if len(segment_columns) > 1:
        # Create combinations by iterating through all segment dimensions
        def generate_combinations(df, segment_columns, index=0, current_filter=None, current_name=''):
            if current_filter is None:
                current_filter = {}
            
            if index >= len(segment_columns):
                # Apply all filters and create segment
                filtered_df = df
                for col, val in current_filter.items():
                    filtered_df = filtered_df[filtered_df[col] == val]
                
                if len(filtered_df) > 0:
                    yield (current_name.strip('_'), filtered_df, current_filter.copy())
                return
            
            seg_name, seg_col = segment_columns[index]
            for seg_value in sorted(df[seg_col].dropna().unique()):
                new_filter = current_filter.copy()
                new_filter[seg_col] = seg_value
                new_name = current_name + f'{seg_name}_{seg_value}_'
                
                yield from generate_combinations(df, segment_columns, index + 1, new_filter, new_name)
        
        for combo_name, combo_df, combo_metadata in generate_combinations(df, segment_columns):
            datasets_to_process.append((combo_name, combo_df, combo_metadata))
    
    all_results = []
    
    # Process each dataset
    for dataset_name, dataset_df, metadata in datasets_to_process:
        # Calculate weekly Gini
        dataset_df_copy = dataset_df.copy()
        dataset_df_copy['week'] = dataset_df_copy['disbursementdate'].dt.to_period('W')
        weekly_gini = dataset_df_copy.groupby('week').apply(
            lambda x: calculate_gini(x[score_column], x[label_column])
            if len(x) >= 10 else np.nan
        ).reset_index(name='gini')
        weekly_gini['period'] = 'Week'
        weekly_gini['start_date'] = weekly_gini['week'].apply(lambda x: x.to_timestamp())
        weekly_gini['end_date'] = weekly_gini['start_date'] + timedelta(days=6)
        weekly_gini = weekly_gini[['start_date', 'end_date', 'gini', 'period']]
        
        # Calculate monthly Gini
        dataset_df_copy = dataset_df.copy()
        dataset_df_copy['month'] = dataset_df_copy['disbursementdate'].dt.to_period('M')
        monthly_gini = dataset_df_copy.groupby('month').apply(
            lambda x: calculate_gini(x[score_column], x[label_column])
            if len(x) >= 20 else np.nan
        ).reset_index(name='gini')
        monthly_gini['period'] = 'Month'
        monthly_gini['start_date'] = monthly_gini['month'].apply(lambda x: x.to_timestamp())
        monthly_gini['end_date'] = monthly_gini['start_date'] + pd.DateOffset(months=1) - pd.Timedelta(days=1)
        monthly_gini = monthly_gini[['start_date', 'end_date', 'gini', 'period']]
        
        # Combine results for this dataset
        gini_results = pd.concat([weekly_gini, monthly_gini], ignore_index=True)
        gini_results = gini_results.sort_values(by='start_date').reset_index(drop=True)
        
        # Add metadata columns
        gini_results['Model_Name'] = score_column
        gini_results['bad_rate'] = namecolumn
        gini_results['segment_type'] = dataset_name
        
        # Add individual segment components
        if model_version_column and model_version_column in metadata:
            gini_results['model_version'] = metadata[model_version_column]
        else:
            gini_results['model_version'] = None
        
        if trench_column and trench_column in metadata:
            gini_results['trench_category'] = metadata[trench_column]
        else:
            gini_results['trench_category'] = None
        
        if loan_type_column and loan_type_column in metadata:
            gini_results['loan_type'] = metadata[loan_type_column]
        else:
            gini_results['loan_type'] = None
        
        if loan_product_type_column and loan_product_type_column in metadata:
            gini_results['loan_product_type'] = metadata[loan_product_type_column]
        else:
            gini_results['loan_product_type'] = None
        
        gini_results.rename(columns={'gini': f'{score_column}_{namecolumn}_gini'}, inplace=True)
        
        all_results.append(gini_results)
    
    # Combine all results
    final_results = pd.concat(all_results, ignore_index=True)
    
    return final_results


# Usage:
# gini_results = calculate_periodic_gini_prod_ver_trench(
#     df_concat, 
#     'Alpha_cic_sil_score', 
#     'deffpd0', 
#     'FPD0',
#     model_version_column='modelVersionId',
#     trench_column='trenchCategory',
#     loan_type_column='loan_type',
#     loan_product_type_column='loan_product_type'
# )

# %%
# def calculate_periodic_gini_prod_ver_trench_md(df, score_column, label_column, namecolumn, 
#                                         model_version_column=None, trench_column=None, 
#                                         loan_type_column=None, loan_product_type_column=None,
#                                         account_id_column=None):
#     """
#     Calculate periodic Gini coefficients at multiple levels:
#     - Overall
#     - By model version
#     - By all combinations of model version, trench category, loan type, and loan product type
    
#     Parameters:
#     df: DataFrame with disbursement dates and score/label columns
#     score_column: name of the score column
#     label_column: name of the label column
#     namecolumn: name for the bad rate label
#     model_version_column: (optional) name of column for model version (e.g., 'modelVersionId')
#     trench_column: (optional) name of column for trench category (e.g., 'trenchCategory')
#     loan_type_column: (optional) name of loan type column (e.g., 'loan_type')
#     loan_product_type_column: (optional) name of loan product type column (e.g., 'loan_product_type')
#     account_id_column: (optional) name of column for distinct account IDs (e.g., 'digitalLoanAccountId')
#     """
#     # Input validation
#     required_columns = ['disbursementdate', score_column, label_column]
#     if not all(col in df.columns for col in required_columns):
#         raise ValueError(f"Missing required columns. Need: {required_columns}")
    
#     optional_columns = {
#         'model_version': model_version_column,
#         'trench': trench_column,
#         'loan_type': loan_type_column,
#         'loan_product_type': loan_product_type_column,
#         'account_id': account_id_column
#     }
    
#     for col_name, col in optional_columns.items():
#         if col and col not in df.columns:
#             raise ValueError(f"{col_name.replace('_', ' ').title()} column '{col}' not found in dataframe")
    
#     # Create a copy to avoid modifying original dataframe
#     df = df.copy()
    
#     # Ensure date is datetime type
#     df['disbursementdate'] = pd.to_datetime(df['disbursementdate'])
    
#     # Ensure score and label columns are numeric
#     df[score_column] = pd.to_numeric(df[score_column], errors='coerce')
#     df[label_column] = pd.to_numeric(df[label_column], errors='coerce')
    
#     # Drop rows with invalid values
#     df = df.dropna(subset=[score_column, label_column])
    
#     # Define list of datasets to process
#     datasets_to_process = [('Overall', df, {})]
    
#     # Add model version level segmentation
#     if model_version_column:
#         for model_version in sorted(df[model_version_column].dropna().unique()):
#             model_df = df[df[model_version_column] == model_version]
#             metadata = {model_version_column: model_version}
#             datasets_to_process.append((f'ModelVersion_{model_version}', model_df, metadata))
    
#     # Add all combinations of model_version, trench, loan_type, loan_product_type
#     segment_columns = []
#     if model_version_column:
#         segment_columns.append(('ModelVersion', model_version_column))
#     if trench_column:
#         segment_columns.append(('Trench', trench_column))
#     if loan_type_column:
#         segment_columns.append(('LoanType', loan_type_column))
#     if loan_product_type_column:
#         segment_columns.append(('ProductType', loan_product_type_column))
    
#     # Generate all combinations (only if we have multiple segment columns)
#     if len(segment_columns) > 1:
#         # Create combinations by iterating through all segment dimensions
#         def generate_combinations(df, segment_columns, index=0, current_filter=None, current_name=''):
#             if current_filter is None:
#                 current_filter = {}
            
#             if index >= len(segment_columns):
#                 # Apply all filters and create segment
#                 filtered_df = df
#                 for col, val in current_filter.items():
#                     filtered_df = filtered_df[filtered_df[col] == val]
                
#                 if len(filtered_df) > 0:
#                     yield (current_name.strip('_'), filtered_df, current_filter.copy())
#                 return
            
#             seg_name, seg_col = segment_columns[index]
#             for seg_value in sorted(df[seg_col].dropna().unique()):
#                 new_filter = current_filter.copy()
#                 new_filter[seg_col] = seg_value
#                 new_name = current_name + f'{seg_name}_{seg_value}_'
                
#                 yield from generate_combinations(df, segment_columns, index + 1, new_filter, new_name)
        
#         for combo_name, combo_df, combo_metadata in generate_combinations(df, segment_columns):
#             datasets_to_process.append((combo_name, combo_df, combo_metadata))
    
#     all_results = []
    
#     # Process each dataset
#     for dataset_name, dataset_df, metadata in datasets_to_process:
#         # Calculate weekly Gini
#         dataset_df_copy = dataset_df.copy()
#         dataset_df_copy['week'] = dataset_df_copy['disbursementdate'].dt.to_period('W')
#         weekly_gini = dataset_df_copy.groupby('week').apply(
#             lambda x: calculate_gini(x[score_column], x[label_column])
#             if len(x) >= 10 else np.nan
#         ).reset_index(name='gini')
#         weekly_gini['period'] = 'Week'
#         weekly_gini['start_date'] = weekly_gini['week'].apply(lambda x: x.to_timestamp())
#         weekly_gini['end_date'] = weekly_gini['start_date'] + timedelta(days=6)
        
#         # Add distinct account count for weekly
#         if account_id_column:
#             weekly_gini['distinct_accounts'] = dataset_df_copy.groupby('week')[account_id_column].nunique().values
        
#         weekly_gini = weekly_gini[['start_date', 'end_date', 'gini', 'period']]
        
#         # Calculate monthly Gini
#         dataset_df_copy = dataset_df.copy()
#         dataset_df_copy['month'] = dataset_df_copy['disbursementdate'].dt.to_period('M')
#         monthly_gini = dataset_df_copy.groupby('month').apply(
#             lambda x: calculate_gini(x[score_column], x[label_column])
#             if len(x) >= 20 else np.nan
#         ).reset_index(name='gini')
#         monthly_gini['period'] = 'Month'
#         monthly_gini['start_date'] = monthly_gini['month'].apply(lambda x: x.to_timestamp())
#         monthly_gini['end_date'] = monthly_gini['start_date'] + pd.DateOffset(months=1) - pd.Timedelta(days=1)
        
#         # Add distinct account count for monthly
#         if account_id_column:
#             monthly_gini['distinct_accounts'] = dataset_df_copy.groupby('month')[account_id_column].nunique().values
        
#         monthly_gini = monthly_gini[['start_date', 'end_date', 'gini', 'period']]
        
#         # Combine results for this dataset
#         gini_results = pd.concat([weekly_gini, monthly_gini], ignore_index=True)
#         gini_results = gini_results.sort_values(by='start_date').reset_index(drop=True)
        
#         # Add metadata columns
#         gini_results['Model_Name'] = score_column
#         gini_results['bad_rate'] = namecolumn
#         gini_results['segment_type'] = dataset_name
        
#         # Add individual segment components
#         if model_version_column and model_version_column in metadata:
#             gini_results['model_version'] = metadata[model_version_column]
#         else:
#             gini_results['model_version'] = None
        
#         if trench_column and trench_column in metadata:
#             gini_results['trench_category'] = metadata[trench_column]
#         else:
#             gini_results['trench_category'] = None
        
#         if loan_type_column and loan_type_column in metadata:
#             gini_results['loan_type'] = metadata[loan_type_column]
#         else:
#             gini_results['loan_type'] = None
        
#         if loan_product_type_column and loan_product_type_column in metadata:
#             gini_results['loan_product_type'] = metadata[loan_product_type_column]
#         else:
#             gini_results['loan_product_type'] = None
        
#         gini_results.rename(columns={'gini': f'{score_column}_{namecolumn}_gini'}, inplace=True)
        
#         all_results.append(gini_results)
    
#     # Combine all results
#     final_results = pd.concat(all_results, ignore_index=True)
    
#     return final_results


# # Usage:
# # gini_results = calculate_periodic_gini_prod_ver_trench(
# #     df_concat, 
# #     'Alpha_cic_sil_score', 
# #     'deffpd0', 
# #     'FPD0',
# #     model_version_column='modelVersionId',
# #     trench_column='trenchCategory',
# #     loan_type_column='loan_type',
# #     loan_product_type_column='loan_product_type',
# #     account_id_column='digitalLoanAccountId'
# # )

# %%
# import pandas as pd
# import numpy as np
# from datetime import timedelta
# from itertools import combinations

# def calculate_gini(scores, labels):
#     """Calculate Gini coefficient"""
#     n = len(scores)
#     if n < 2:
#         return np.nan
    
#     sorted_indices = np.argsort(scores)
#     sorted_labels = labels.iloc[sorted_indices].values
#     cumsum_labels = np.cumsum(sorted_labels)
    
#     gini = 1 - 2 * np.sum(cumsum_labels) / (n * np.sum(sorted_labels))
#     return gini


# def calculate_periodic_gini_prod_ver_trench_md(df, score_column, label_column, namecolumn, 
#                                         model_version_column=None, trench_column=None, 
#                                         loan_type_column=None, loan_product_type_column=None,
#                                         account_id_column=None):
#     """
#     Calculate periodic Gini coefficients at multiple levels:
#     - Overall (entire dataset)
#     - By each individual segment (model version, trench, loan type, loan product type)
#     - By all possible combinations of segments
    
#     Parameters:
#     df: DataFrame with disbursement dates and score/label columns
#     score_column: name of the score column
#     label_column: name of the label column
#     namecolumn: name for the bad rate label
#     model_version_column: (optional) name of column for model version
#     trench_column: (optional) name of column for trench category
#     loan_type_column: (optional) name of loan type column
#     loan_product_type_column: (optional) name of loan product type column
#     account_id_column: (optional) name of column for distinct account IDs
#     """
#     # Input validation
#     required_columns = ['disbursementdate', score_column, label_column]
#     if not all(col in df.columns for col in required_columns):
#         raise ValueError(f"Missing required columns. Need: {required_columns}")
    
#     optional_columns = {
#         'model_version': model_version_column,
#         'trench': trench_column,
#         'loan_type': loan_type_column,
#         'loan_product_type': loan_product_type_column,
#         'account_id': account_id_column
#     }
    
#     for col_name, col in optional_columns.items():
#         if col and col not in df.columns:
#             raise ValueError(f"{col_name.replace('_', ' ').title()} column '{col}' not found in dataframe")
    
#     # Create a copy to avoid modifying original dataframe
#     df = df.copy()
    
#     # Ensure date is datetime type
#     df['disbursementdate'] = pd.to_datetime(df['disbursementdate'])
    
#     # Ensure score and label columns are numeric
#     df[score_column] = pd.to_numeric(df[score_column], errors='coerce')
#     df[label_column] = pd.to_numeric(df[label_column], errors='coerce')
    
#     # Drop rows with invalid values
#     df = df.dropna(subset=[score_column, label_column])
    
#     # Define list of datasets to process
#     datasets_to_process = [('Overall', df, {})]
    
#     # Create list of available segment columns
#     segment_columns = []
#     if model_version_column:
#         segment_columns.append(('ModelVersion', model_version_column))
#     if trench_column:
#         segment_columns.append(('Trench', trench_column))
#     if loan_type_column:
#         segment_columns.append(('LoanType', loan_type_column))
#     if loan_product_type_column:
#         segment_columns.append(('ProductType', loan_product_type_column))
    
#     # Generate all possible combinations of segment columns (from single to all)
#     for r in range(1, len(segment_columns) + 1):
#         for combo in combinations(segment_columns, r):
#             # Create combinations by iterating through all segment dimensions
#             def generate_combinations(df, segment_columns, index=0, current_filter=None, current_name=''):
#                 if current_filter is None:
#                     current_filter = {}
                
#                 if index >= len(segment_columns):
#                     # Apply all filters and create segment
#                     filtered_df = df
#                     for col, val in current_filter.items():
#                         filtered_df = filtered_df[filtered_df[col] == val]
                    
#                     if len(filtered_df) > 0:
#                         yield (current_name.strip('_'), filtered_df, current_filter.copy())
#                     return
                
#                 seg_name, seg_col = segment_columns[index]
#                 for seg_value in sorted(df[seg_col].dropna().unique()):
#                     new_filter = current_filter.copy()
#                     new_filter[seg_col] = seg_value
#                     new_name = current_name + f'{seg_name}_{seg_value}_'
                    
#                     yield from generate_combinations(df, segment_columns, index + 1, new_filter, new_name)
            
#             for combo_name, combo_df, combo_metadata in generate_combinations(df, list(combo)):
#                 datasets_to_process.append((combo_name, combo_df, combo_metadata))
    
#     all_results = []
    
#     # Process each dataset
#     for dataset_name, dataset_df, metadata in datasets_to_process:
#         # Calculate weekly Gini
#         dataset_df_copy = dataset_df.copy()
#         dataset_df_copy['week'] = dataset_df_copy['disbursementdate'].dt.to_period('W')
#         weekly_gini = dataset_df_copy.groupby('week').apply(
#             lambda x: calculate_gini(x[score_column], x[label_column])
#             if len(x) >= 10 else np.nan
#         ).reset_index(name='gini')
#         weekly_gini['period'] = 'Week'
#         weekly_gini['start_date'] = weekly_gini['week'].apply(lambda x: x.to_timestamp())
#         weekly_gini['end_date'] = weekly_gini['start_date'] + timedelta(days=6)
        
#         # Add distinct account count for weekly
#         if account_id_column:
#             weekly_account_counts = dataset_df_copy.groupby('week')[account_id_column].nunique().reset_index()
#             weekly_account_counts.columns = ['week', 'distinct_accounts']
#             weekly_gini = weekly_gini.merge(weekly_account_counts, on='week', how='left')
        
#         weekly_gini = weekly_gini[['start_date', 'end_date', 'gini', 'period'] + (['distinct_accounts'] if account_id_column else [])]
        
#         # Calculate monthly Gini
#         dataset_df_copy = dataset_df.copy()
#         dataset_df_copy['month'] = dataset_df_copy['disbursementdate'].dt.to_period('M')
#         monthly_gini = dataset_df_copy.groupby('month').apply(
#             lambda x: calculate_gini(x[score_column], x[label_column])
#             if len(x) >= 20 else np.nan
#         ).reset_index(name='gini')
#         monthly_gini['period'] = 'Month'
#         monthly_gini['start_date'] = monthly_gini['month'].apply(lambda x: x.to_timestamp())
#         monthly_gini['end_date'] = monthly_gini['start_date'] + pd.DateOffset(months=1) - pd.Timedelta(days=1)
        
#         # Add distinct account count for monthly
#         if account_id_column:
#             monthly_account_counts = dataset_df_copy.groupby('month')[account_id_column].nunique().reset_index()
#             monthly_account_counts.columns = ['month', 'distinct_accounts']
#             monthly_gini = monthly_gini.merge(monthly_account_counts, on='month', how='left')
        
#         monthly_gini = monthly_gini[['start_date', 'end_date', 'gini', 'period'] + (['distinct_accounts'] if account_id_column else [])]
        
#         # Combine results for this dataset
#         gini_results = pd.concat([weekly_gini, monthly_gini], ignore_index=True)
#         gini_results = gini_results.sort_values(by='start_date').reset_index(drop=True)
        
#         # Add metadata columns
#         gini_results['Model_Name'] = score_column
#         gini_results['bad_rate'] = namecolumn
#         gini_results['segment_type'] = dataset_name
        
#         # Add individual segment components
#         if model_version_column and model_version_column in metadata:
#             gini_results['model_version'] = metadata[model_version_column]
#         else:
#             gini_results['model_version'] = None
        
#         if trench_column and trench_column in metadata:
#             gini_results['trench_category'] = metadata[trench_column]
#         else:
#             gini_results['trench_category'] = None
        
#         if loan_type_column and loan_type_column in metadata:
#             gini_results['loan_type'] = metadata[loan_type_column]
#         else:
#             gini_results['loan_type'] = None
        
#         if loan_product_type_column and loan_product_type_column in metadata:
#             gini_results['loan_product_type'] = metadata[loan_product_type_column]
#         else:
#             gini_results['loan_product_type'] = None
        
#         gini_results.rename(columns={'gini': f'{score_column}_{namecolumn}_gini'}, inplace=True)
        
#         all_results.append(gini_results)
    
#     # Combine all results
#     final_results = pd.concat(all_results, ignore_index=True)
    
#     return final_results


# # Usage:
# # gini_results = calculate_periodic_gini_prod_ver_trench_md(
# #     df_concat, 
# #     'Alpha_cic_sil_score', 
# #     'deffpd0', 
# #     'FPD0',
# #     model_version_column='modelVersionId',
# #     trench_column='trenchCategory',
# #     loan_type_column='loan_type',
# #     loan_product_type_column='loan_product_type',
# #     account_id_column='digitalLoanAccountId'
# # )

# %%
# import pandas as pd
# import numpy as np
# from datetime import timedelta
# from itertools import combinations

# def calculate_gini(scores, labels):
#     """Calculate Gini coefficient"""
#     n = len(scores)
#     if n < 2:
#         return np.nan
    
#     sorted_indices = np.argsort(scores)
#     sorted_labels = labels.iloc[sorted_indices].values
#     cumsum_labels = np.cumsum(sorted_labels)
    
#     gini = 1 - 2 * np.sum(cumsum_labels) / (n * np.sum(sorted_labels))
#     return gini


# def calculate_periodic_gini_prod_ver_trench_md_col(df, score_column, label_column, namecolumn, 
#                                         model_version_column=None, trench_column=None, 
#                                         loan_type_column=None, loan_product_type_column=None,
#                                         account_id_column=None):
#     """
#     Calculate periodic Gini coefficients at multiple levels (wide format):
#     - Overall (entire dataset)
#     - By each individual segment (model version, trench, loan type, loan product type)
#     - By all possible combinations of segments
    
#     Returns wide format with one row per period and separate columns for each segment_type's Gini.
    
#     Parameters:
#     df: DataFrame with disbursement dates and score/label columns
#     score_column: name of the score column
#     label_column: name of the label column
#     namecolumn: name for the bad rate label
#     model_version_column: (optional) name of column for model version
#     trench_column: (optional) name of column for trench category
#     loan_type_column: (optional) name of loan type column
#     loan_product_type_column: (optional) name of loan product type column
#     account_id_column: (optional) name of column for distinct account IDs
#     """
#     # Input validation
#     required_columns = ['disbursementdate', score_column, label_column]
#     if not all(col in df.columns for col in required_columns):
#         raise ValueError(f"Missing required columns. Need: {required_columns}")
    
#     optional_columns = {
#         'model_version': model_version_column,
#         'trench': trench_column,
#         'loan_type': loan_type_column,
#         'loan_product_type': loan_product_type_column,
#         'account_id': account_id_column
#     }
    
#     for col_name, col in optional_columns.items():
#         if col and col not in df.columns:
#             raise ValueError(f"{col_name.replace('_', ' ').title()} column '{col}' not found in dataframe")
    
#     # Create a copy to avoid modifying original dataframe
#     df = df.copy()
    
#     # Ensure date is datetime type
#     df['disbursementdate'] = pd.to_datetime(df['disbursementdate'])
    
#     # Ensure score and label columns are numeric
#     df[score_column] = pd.to_numeric(df[score_column], errors='coerce')
#     df[label_column] = pd.to_numeric(df[label_column], errors='coerce')
    
#     # Drop rows with invalid values
#     df = df.dropna(subset=[score_column, label_column])
    
#     # Define list of datasets to process
#     datasets_to_process = [('Overall', df, {})]
    
#     # Create list of available segment columns
#     segment_columns = []
#     if model_version_column:
#         segment_columns.append(('ModelVersion', model_version_column))
#     if trench_column:
#         segment_columns.append(('Trench', trench_column))
#     if loan_type_column:
#         segment_columns.append(('LoanType', loan_type_column))
#     if loan_product_type_column:
#         segment_columns.append(('ProductType', loan_product_type_column))
    
#     # Generate all possible combinations of segment columns (from single to all)
#     for r in range(1, len(segment_columns) + 1):
#         for combo in combinations(segment_columns, r):
#             # Create combinations by iterating through all segment dimensions
#             def generate_combinations(df, segment_columns, index=0, current_filter=None, current_name=''):
#                 if current_filter is None:
#                     current_filter = {}
                
#                 if index >= len(segment_columns):
#                     # Apply all filters and create segment
#                     filtered_df = df
#                     for col, val in current_filter.items():
#                         filtered_df = filtered_df[filtered_df[col] == val]
                    
#                     if len(filtered_df) > 0:
#                         yield (current_name.strip('_'), filtered_df, current_filter.copy())
#                     return
                
#                 seg_name, seg_col = segment_columns[index]
#                 for seg_value in sorted(df[seg_col].dropna().unique()):
#                     new_filter = current_filter.copy()
#                     new_filter[seg_col] = seg_value
#                     new_name = current_name + f'{seg_name}_{seg_value}_'
                    
#                     yield from generate_combinations(df, segment_columns, index + 1, new_filter, new_name)
            
#             for combo_name, combo_df, combo_metadata in generate_combinations(df, list(combo)):
#                 datasets_to_process.append((combo_name, combo_df, combo_metadata))
    
#     all_results = []
    
#     # Process each dataset
#     for dataset_name, dataset_df, metadata in datasets_to_process:
#         # Calculate weekly Gini
#         dataset_df_copy = dataset_df.copy()
#         dataset_df_copy['week'] = dataset_df_copy['disbursementdate'].dt.to_period('W')
#         weekly_gini = dataset_df_copy.groupby('week').apply(
#             lambda x: calculate_gini(x[score_column], x[label_column])
#             if len(x) >= 10 else np.nan
#         ).reset_index(name='gini')
#         weekly_gini['period'] = 'Week'
#         weekly_gini['start_date'] = weekly_gini['week'].apply(lambda x: x.to_timestamp())
#         weekly_gini['end_date'] = weekly_gini['start_date'] + timedelta(days=6)
#         weekly_gini = weekly_gini[['start_date', 'end_date', 'gini', 'period']]
        
#         # Calculate monthly Gini
#         dataset_df_copy = dataset_df.copy()
#         dataset_df_copy['month'] = dataset_df_copy['disbursementdate'].dt.to_period('M')
#         monthly_gini = dataset_df_copy.groupby('month').apply(
#             lambda x: calculate_gini(x[score_column], x[label_column])
#             if len(x) >= 20 else np.nan
#         ).reset_index(name='gini')
#         monthly_gini['period'] = 'Month'
#         monthly_gini['start_date'] = monthly_gini['month'].apply(lambda x: x.to_timestamp())
#         monthly_gini['end_date'] = monthly_gini['start_date'] + pd.DateOffset(months=1) - pd.Timedelta(days=1)
#         monthly_gini = monthly_gini[['start_date', 'end_date', 'gini', 'period']]
        
#         # Combine results for this dataset
#         gini_results = pd.concat([weekly_gini, monthly_gini], ignore_index=True)
#         gini_results = gini_results.sort_values(by='start_date').reset_index(drop=True)
        
#         # Create column name for this segment's Gini
#         gini_column_name = f'{score_column}_{namecolumn}_gini_{dataset_name}'
#         gini_results[gini_column_name] = gini_results['gini']
#         gini_results = gini_results.drop('gini', axis=1)
        
#         all_results.append(gini_results)
    
#     # Merge all results on start_date, end_date, and period
#     final_results = all_results[0]
#     for result_df in all_results[1:]:
#         final_results = final_results.merge(
#             result_df,
#             on=['start_date', 'end_date', 'period'],
#             how='outer'
#         )
    
#     # Add metadata columns (these will be the same for each row)
#     final_results['Model_Name'] = score_column
#     final_results['bad_rate'] = namecolumn
    
#     if model_version_column:
#         final_results['model_version'] = None
#     else:
#         final_results['model_version'] = None
    
#     if trench_column:
#         final_results['trench_category'] = None
#     else:
#         final_results['trench_category'] = None
    
#     if loan_type_column:
#         final_results['loan_type'] = None
#     else:
#         final_results['loan_type'] = None
    
#     if loan_product_type_column:
#         final_results['loan_product_type'] = None
#     else:
#         final_results['loan_product_type'] = None
    
#     # Reorder columns: metadata first, then all Gini columns
#     metadata_cols = ['start_date', 'end_date', 'period', 'Model_Name', 'bad_rate', 
#                      'model_version', 'trench_category', 'loan_type', 'loan_product_type']
#     gini_cols = [col for col in final_results.columns if col.startswith(f'{score_column}_{namecolumn}_gini_')]
    
#     final_results = final_results[metadata_cols + gini_cols]
    
#     return final_results


# # Usage:
# # gini_results = calculate_periodic_gini_prod_ver_trench_md(
# #     df_concat, 
# #     'Alpha_cic_sil_score', 
# #     'deffpd0', 
# #     'FPD0',
# #     model_version_column='modelVersionId',
# #     trench_column='trenchCategory',
# #     loan_type_column='loan_type',
# #     loan_product_type_column='loan_product_type',
# #     account_id_column='digitalLoanAccountId'
# # )

# %%
# import pandas as pd
# import numpy as np
# from datetime import timedelta
# from itertools import combinations

# def calculate_gini(scores, labels):
#     """
#     Calculate Gini coefficient with proper handling of edge cases
    
#     Returns np.nan when:
#     - Fewer than 2 observations
#     - No positive labels (sum of labels = 0)
#     """
#     n = len(scores)
#     if n < 2:
#         return np.nan
    
#     label_sum = np.sum(labels)
    
#     # Handle case where no positive labels exist (all zeros)
#     # This prevents division by zero warning
#     if label_sum == 0:
#         return np.nan
    
#     sorted_indices = np.argsort(scores)
#     sorted_labels = labels.iloc[sorted_indices].values
#     cumsum_labels = np.cumsum(sorted_labels)
    
#     gini = 1 - 2 * np.sum(cumsum_labels) / (n * label_sum)
#     return gini


# def calculate_periodic_gini_prod_ver_trench_dimfact(df, score_column, label_column, namecolumn, 
#                                         model_version_column=None, trench_column=None, 
#                                         loan_type_column=None, loan_product_type_column=None,
#                                         account_id_column=None):
#     """
#     Calculate periodic Gini coefficients and return Power BI-friendly long format
#     with fact and dimension tables.
    
#     Returns:
#     - fact_table: Long format with one row per segment per period
#     - dimension_table: Unique segment combinations for filtering
    
#     Parameters:
#     df: DataFrame with disbursement dates and score/label columns
#     score_column: name of the score column
#     label_column: name of the label column
#     namecolumn: name for the bad rate label
#     model_version_column: (optional) name of column for model version
#     trench_column: (optional) name of column for trench category
#     loan_type_column: (optional) name of loan type column
#     loan_product_type_column: (optional) name of loan product type column
#     account_id_column: (optional) name of column for distinct account IDs
#     """
#     # Input validation
#     required_columns = ['disbursementdate', score_column, label_column]
#     if not all(col in df.columns for col in required_columns):
#         raise ValueError(f"Missing required columns. Need: {required_columns}")
    
#     optional_columns = {
#         'model_version': model_version_column,
#         'trench': trench_column,
#         'loan_type': loan_type_column,
#         'loan_product_type': loan_product_type_column,
#         'account_id': account_id_column
#     }
    
#     for col_name, col in optional_columns.items():
#         if col and col not in df.columns:
#             raise ValueError(f"{col_name.replace('_', ' ').title()} column '{col}' not found in dataframe")
    
#     # Create a copy to avoid modifying original dataframe
#     df = df.copy()
    
#     # Ensure date is datetime type
#     df['disbursementdate'] = pd.to_datetime(df['disbursementdate'])
    
#     # Ensure score and label columns are numeric
#     df[score_column] = pd.to_numeric(df[score_column], errors='coerce')
#     df[label_column] = pd.to_numeric(df[label_column], errors='coerce')
    
#     # Drop rows with invalid values
#     df = df.dropna(subset=[score_column, label_column])
    
#     # Define list of datasets to process
#     datasets_to_process = [('Overall', df, {})]
    
#     # Create list of available segment columns
#     segment_columns = []
#     if model_version_column:
#         segment_columns.append(('ModelVersion', model_version_column))
#     if trench_column:
#         segment_columns.append(('Trench', trench_column))
#     if loan_type_column:
#         segment_columns.append(('LoanType', loan_type_column))
#     if loan_product_type_column:
#         segment_columns.append(('ProductType', loan_product_type_column))
    
#     # Generate all possible combinations of segment columns
#     for r in range(1, len(segment_columns) + 1):
#         for combo in combinations(segment_columns, r):
#             def generate_combinations(df, segment_columns, index=0, current_filter=None, current_name=''):
#                 if current_filter is None:
#                     current_filter = {}
                
#                 if index >= len(segment_columns):
#                     filtered_df = df
#                     for col, val in current_filter.items():
#                         filtered_df = filtered_df[filtered_df[col] == val]
                    
#                     if len(filtered_df) > 0:
#                         yield (current_name.strip('_'), filtered_df, current_filter.copy())
#                     return
                
#                 seg_name, seg_col = segment_columns[index]
#                 for seg_value in sorted(df[seg_col].dropna().unique()):
#                     new_filter = current_filter.copy()
#                     new_filter[seg_col] = seg_value
#                     new_name = current_name + f'{seg_name}_{seg_value}_'
                    
#                     yield from generate_combinations(df, segment_columns, index + 1, new_filter, new_name)
            
#             for combo_name, combo_df, combo_metadata in generate_combinations(df, list(combo)):
#                 datasets_to_process.append((combo_name, combo_df, combo_metadata))
    
#     all_results = []
    
#     # Process each dataset
#     for dataset_name, dataset_df, metadata in datasets_to_process:
#         # Calculate weekly Gini
#         dataset_df_copy = dataset_df.copy()
#         dataset_df_copy['week'] = dataset_df_copy['disbursementdate'].dt.to_period('W')
#         weekly_gini = dataset_df_copy.groupby('week').apply(
#             lambda x: calculate_gini(x[score_column], x[label_column])
#             if len(x) >= 10 else np.nan
#         ).reset_index(name='gini_value')
#         weekly_gini['period'] = 'Week'
#         weekly_gini['start_date'] = weekly_gini['week'].apply(lambda x: x.to_timestamp())
#         weekly_gini['end_date'] = weekly_gini['start_date'] + timedelta(days=6)
        
#         # Add distinct account count for weekly
#         if account_id_column:
#             weekly_account_counts = dataset_df_copy.groupby('week')[account_id_column].nunique().reset_index()
#             weekly_account_counts.columns = ['week', 'distinct_accounts']
#             weekly_gini = weekly_gini.merge(weekly_account_counts, on='week', how='left')
#         else:
#             weekly_gini['distinct_accounts'] = None
        
#         weekly_gini = weekly_gini[['start_date', 'end_date', 'gini_value', 'period', 'distinct_accounts']]
        
#         # Calculate monthly Gini
#         dataset_df_copy = dataset_df.copy()
#         dataset_df_copy['month'] = dataset_df_copy['disbursementdate'].dt.to_period('M')
#         monthly_gini = dataset_df_copy.groupby('month').apply(
#             lambda x: calculate_gini(x[score_column], x[label_column])
#             if len(x) >= 20 else np.nan
#         ).reset_index(name='gini_value')
#         monthly_gini['period'] = 'Month'
#         monthly_gini['start_date'] = monthly_gini['month'].apply(lambda x: x.to_timestamp())
#         monthly_gini['end_date'] = monthly_gini['start_date'] + pd.DateOffset(months=1) - pd.Timedelta(days=1)
        
#         # Add distinct account count for monthly
#         if account_id_column:
#             monthly_account_counts = dataset_df_copy.groupby('month')[account_id_column].nunique().reset_index()
#             monthly_account_counts.columns = ['month', 'distinct_accounts']
#             monthly_gini = monthly_gini.merge(monthly_account_counts, on='month', how='left')
#         else:
#             monthly_gini['distinct_accounts'] = None
        
#         monthly_gini = monthly_gini[['start_date', 'end_date', 'gini_value', 'period', 'distinct_accounts']]
        
#         # Combine results for this dataset
#         gini_results = pd.concat([weekly_gini, monthly_gini], ignore_index=True)
#         gini_results = gini_results.sort_values(by='start_date').reset_index(drop=True)
        
#         # Add metadata columns
#         gini_results['Model_Name'] = score_column
#         gini_results['bad_rate'] = namecolumn
#         gini_results['segment_type'] = dataset_name
        
#         # Add individual segment components
#         gini_results['model_version'] = metadata.get(model_version_column, None) if model_version_column else None
#         gini_results['trench_category'] = metadata.get(trench_column, None) if trench_column else None
#         gini_results['loan_type'] = metadata.get(loan_type_column, None) if loan_type_column else None
#         gini_results['loan_product_type'] = metadata.get(loan_product_type_column, None) if loan_product_type_column else None
        
#         all_results.append(gini_results)
    
#     # Combine all results
#     fact_table = pd.concat(all_results, ignore_index=True)
    
#     # Create dimension table (unique segment combinations for filtering)
#     dimension_table = fact_table[['Model_Name', 'bad_rate', 'segment_type', 'model_version', 
#                                    'trench_category', 'loan_type', 'loan_product_type']].drop_duplicates().reset_index(drop=True)
#     dimension_table['segment_id'] = range(len(dimension_table))
    
#     # Add segment_id to fact table
#     fact_table = fact_table.merge(dimension_table[['segment_id', 'Model_Name', 'bad_rate', 'segment_type', 
#                                                      'model_version', 'trench_category', 'loan_type', 'loan_product_type']], 
#                                   on=['Model_Name', 'bad_rate', 'segment_type', 'model_version', 
#                                       'trench_category', 'loan_type', 'loan_product_type'], 
#                                   how='left')
    
#     # Reorder columns in fact table
#     fact_table = fact_table[['segment_id', 'start_date', 'end_date', 'period', 'gini_value', 'distinct_accounts',
#                              'Model_Name', 'bad_rate', 'segment_type', 'model_version', 'trench_category', 
#                              'loan_type', 'loan_product_type']]
    
#     return fact_table, dimension_table


# # Usage:
# # fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
# #     df_concat, 
# #     'Alpha_cic_sil_score', 
# #     'deffpd0', 
# #     'FPD0',
# #     model_version_column='modelVersionId',
# #     trench_column='trenchCategory',
# #     loan_type_column='loan_type',
# #     loan_product_type_column='loan_product_type',
# #     account_id_column='digitalLoanAccountId'
# # )
# # 
# # # In Power BI:
# # # 1. Import fact_table and dimension_table
# # # 2. Create relationship: dimension_table[segment_id] -> fact_table[segment_id]
# # # 3. Use dimension table columns as filters
# # # 4. Create DAX measures:
# # #    - Gini Measure = AVERAGE(fact_table[gini_value])
# # #    - Account Count = SUM(fact_table[distinct_accounts])
# # # 5. Use start_date, end_date, period for time-based analysis

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
from itertools import combinations

def calculate_gini(scores, labels):
    """
    Calculate Gini coefficient with proper handling of edge cases
    
    Returns np.nan when:
    - Fewer than 2 observations
    - No positive labels (sum of labels = 0)
    """
    n = len(scores)
    if n < 2:
        return np.nan
    
    label_sum = np.sum(labels)
    
    # Handle case where no positive labels exist (all zeros)
    # This prevents division by zero warning
    if label_sum == 0:
        return np.nan
    
    sorted_indices = np.argsort(scores)
    sorted_labels = labels.iloc[sorted_indices].values
    cumsum_labels = np.cumsum(sorted_labels)
    
    gini = 1 - 2 * np.sum(cumsum_labels) / (n * label_sum)
    return gini


def calculate_periodic_gini_prod_ver_trench_dimfact(df, score_column, label_column, namecolumn, 
                                        data_selection_column=None,
                                        model_version_column=None, trench_column=None, 
                                        loan_type_column=None, loan_product_type_column=None,
                                        account_id_column=None):
    """
    Calculate periodic Gini coefficients and return Power BI-friendly long format
    with fact and dimension tables.
    
    Returns:
    - fact_table: Long format with one row per segment per period
    - dimension_table: Unique segment combinations for filtering
    
    Parameters:
    df: DataFrame with disbursement dates and score/label columns
    score_column: name of the score column
    label_column: name of the label column
    namecolumn: name for the bad rate label
    data_selection_column: (optional) name of column for data selection (Test/Train)
    model_version_column: (optional) name of column for model version
    trench_column: (optional) name of column for trench category
    loan_type_column: (optional) name of loan type column
    loan_product_type_column: (optional) name of loan product type column
    account_id_column: (optional) name of column for distinct account IDs
    """
    # Input validation
    required_columns = ['disbursementdate', score_column, label_column]
    if not all(col in df.columns for col in required_columns):
        raise ValueError(f"Missing required columns. Need: {required_columns}")
    
    optional_columns = {
        'data_selection': data_selection_column,
        'model_version': model_version_column,
        'trench': trench_column,
        'loan_type': loan_type_column,
        'loan_product_type': loan_product_type_column,
        'account_id': account_id_column
    }
    
    for col_name, col in optional_columns.items():
        if col and col not in df.columns:
            raise ValueError(f"{col_name.replace('_', ' ').title()} column '{col}' not found in dataframe")
    
    # Create a copy to avoid modifying original dataframe
    df = df.copy()
    
    # Ensure date is datetime type
    df['disbursementdate'] = pd.to_datetime(df['disbursementdate'])
    
    # Ensure score and label columns are numeric
    df[score_column] = pd.to_numeric(df[score_column], errors='coerce')
    df[label_column] = pd.to_numeric(df[label_column], errors='coerce')
    
    # Drop rows with invalid values
    df = df.dropna(subset=[score_column, label_column])
    
    # Define list of datasets to process
    datasets_to_process = [('Overall', df, {})]
    
    # Create list of available segment columns
    segment_columns = []
    if data_selection_column:
        segment_columns.append(('DataSelection', data_selection_column))
    if model_version_column:
        segment_columns.append(('ModelVersion', model_version_column))
    if trench_column:
        segment_columns.append(('Trench', trench_column))
    if loan_type_column:
        segment_columns.append(('LoanType', loan_type_column))
    if loan_product_type_column:
        segment_columns.append(('ProductType', loan_product_type_column))
    
    # Generate all possible combinations of segment columns
    for r in range(1, len(segment_columns) + 1):
        for combo in combinations(segment_columns, r):
            def generate_combinations(df, segment_columns, index=0, current_filter=None, current_name=''):
                if current_filter is None:
                    current_filter = {}
                
                if index >= len(segment_columns):
                    filtered_df = df
                    for col, val in current_filter.items():
                        filtered_df = filtered_df[filtered_df[col] == val]
                    
                    if len(filtered_df) > 0:
                        yield (current_name.strip('_'), filtered_df, current_filter.copy())
                    return
                
                seg_name, seg_col = segment_columns[index]
                for seg_value in sorted(df[seg_col].dropna().unique()):
                    new_filter = current_filter.copy()
                    new_filter[seg_col] = seg_value
                    new_name = current_name + f'{seg_name}_{seg_value}_'
                    
                    yield from generate_combinations(df, segment_columns, index + 1, new_filter, new_name)
            
            for combo_name, combo_df, combo_metadata in generate_combinations(df, list(combo)):
                datasets_to_process.append((combo_name, combo_df, combo_metadata))
    
    all_results = []
    
    # Process each dataset
    for dataset_name, dataset_df, metadata in datasets_to_process:
        # Calculate weekly Gini
        dataset_df_copy = dataset_df.copy()
        dataset_df_copy['week'] = dataset_df_copy['disbursementdate'].dt.to_period('W')
        weekly_gini = dataset_df_copy.groupby('week').apply(
            lambda x: calculate_gini(x[score_column], x[label_column])
            if len(x) >= 10 else np.nan
        ).reset_index(name='gini_value')
        weekly_gini['period'] = 'Week'
        weekly_gini['start_date'] = weekly_gini['week'].apply(lambda x: x.to_timestamp())
        weekly_gini['end_date'] = weekly_gini['start_date'] + timedelta(days=6)
        
        # Add distinct account count for weekly
        if account_id_column:
            weekly_account_counts = dataset_df_copy.groupby('week')[account_id_column].nunique().reset_index()
            weekly_account_counts.columns = ['week', 'distinct_accounts']
            weekly_gini = weekly_gini.merge(weekly_account_counts, on='week', how='left')
        else:
            weekly_gini['distinct_accounts'] = None
        
        weekly_gini = weekly_gini[['start_date', 'end_date', 'gini_value', 'period', 'distinct_accounts']]
        
        # Calculate monthly Gini
        dataset_df_copy = dataset_df.copy()
        dataset_df_copy['month'] = dataset_df_copy['disbursementdate'].dt.to_period('M')
        monthly_gini = dataset_df_copy.groupby('month').apply(
            lambda x: calculate_gini(x[score_column], x[label_column])
            if len(x) >= 20 else np.nan
        ).reset_index(name='gini_value')
        monthly_gini['period'] = 'Month'
        monthly_gini['start_date'] = monthly_gini['month'].apply(lambda x: x.to_timestamp())
        monthly_gini['end_date'] = monthly_gini['start_date'] + pd.DateOffset(months=1) - pd.Timedelta(days=1)
        
        # Add distinct account count for monthly
        if account_id_column:
            monthly_account_counts = dataset_df_copy.groupby('month')[account_id_column].nunique().reset_index()
            monthly_account_counts.columns = ['month', 'distinct_accounts']
            monthly_gini = monthly_gini.merge(monthly_account_counts, on='month', how='left')
        else:
            monthly_gini['distinct_accounts'] = None
        
        monthly_gini = monthly_gini[['start_date', 'end_date', 'gini_value', 'period', 'distinct_accounts']]
        
        # Combine results for this dataset
        gini_results = pd.concat([weekly_gini, monthly_gini], ignore_index=True)
        gini_results = gini_results.sort_values(by='start_date').reset_index(drop=True)
        
        # Add metadata columns
        gini_results['Model_Name'] = score_column
        gini_results['bad_rate'] = namecolumn
        gini_results['segment_type'] = dataset_name
        
        # Add individual segment components
        gini_results['data_selection'] = metadata.get(data_selection_column, None) if data_selection_column else None
        gini_results['model_version'] = metadata.get(model_version_column, None) if model_version_column else None
        gini_results['trench_category'] = metadata.get(trench_column, None) if trench_column else None
        gini_results['loan_type'] = metadata.get(loan_type_column, None) if loan_type_column else None
        gini_results['loan_product_type'] = metadata.get(loan_product_type_column, None) if loan_product_type_column else None
        
        all_results.append(gini_results)
    
    # Combine all results
    fact_table = pd.concat(all_results, ignore_index=True)
    
    # Create dimension table (unique segment combinations for filtering)
    dimension_table = fact_table[['Model_Name', 'bad_rate', 'segment_type', 'data_selection', 'model_version', 
                                   'trench_category', 'loan_type', 'loan_product_type']].drop_duplicates().reset_index(drop=True)
    dimension_table['segment_id'] = range(len(dimension_table))
    
    # Add segment_id to fact table
    fact_table = fact_table.merge(dimension_table[['segment_id', 'Model_Name', 'bad_rate', 'segment_type', 
                                                     'data_selection', 'model_version', 'trench_category', 'loan_type', 'loan_product_type']], 
                                  on=['Model_Name', 'bad_rate', 'segment_type', 'data_selection', 'model_version', 
                                      'trench_category', 'loan_type', 'loan_product_type'], 
                                  how='left')
    
    # Reorder columns in fact table
    fact_table = fact_table[['segment_id', 'start_date', 'end_date', 'period', 'gini_value', 'distinct_accounts',
                             'Model_Name', 'bad_rate', 'segment_type', 'data_selection', 'model_version', 'trench_category', 
                             'loan_type', 'loan_product_type']]
    
    # Reorder columns in dimension table
    dimension_table = dimension_table[['segment_id', 'Model_Name', 'bad_rate', 'segment_type', 'data_selection', 
                                        'model_version', 'trench_category', 'loan_type', 'loan_product_type']]
    
    return fact_table, dimension_table


# Usage:
# fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
#     df_concat, 
#     'Alpha_cic_sil_score', 
#     'deffpd0', 
#     'FPD0',
#     data_selection_column='Data_selection',
#     model_version_column='modelVersionId',
#     trench_column='trenchCategory',
#     loan_type_column='loan_type',
#     loan_product_type_column='loan_product_type',
#     account_id_column='digitalLoanAccountId'
# )
# 
# # In Power BI:
# # 1. Import fact_table and dimension_table
# # 2. Create relationship: dimension_table[segment_id] -> fact_table[segment_id]
# # 3. Use dimension table columns as filters
# # 4. Create DAX measures:
# #    - Gini Measure = AVERAGE(fact_table[gini_value])
# #    - Account Count = SUM(fact_table[distinct_accounts])
# # 5. Use start_date, end_date, period for time-based analysis

# %% [markdown]
# # update_tables

# %%
def update_tables(fact_table: pd.DataFrame, dimension_table: pd.DataFrame, model_name: str, product: str) -> tuple:
    """
    Updates fact_table and dimension_table:
    - Sets 'Model_display_name' to the given model_name
    - Replaces NaN values in specified columns with 'Overall'
    
    Returns:
        Updated fact_table and dimension_table as a tuple
    """
    # Columns where missing values should be replaced
    cols_to_replace = ['model_version', 'trench_category', 'loan_type', 'loan_product_type']
    
    # Update fact_table
    fact_table['Model_display_name'] = model_name
    fact_table['Product_Category'] = product
    fact_table[cols_to_replace] = fact_table[cols_to_replace].fillna('Overall')
    
    # Update dimension_table
    dimension_table['Model_display_name'] = model_name
    dimension_table['Product_Category'] = product
    dimension_table[cols_to_replace] = dimension_table[cols_to_replace].fillna('Overall')
    
    return fact_table, dimension_table

# %% [markdown]
# # SIL

# %% [markdown]
# ## cic_model_sil

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  (SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (66790, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3509194  0007aa60-32b3-4af2-9818-76887a7d96bf    60835091940014
# 1    3446061  01f5b185-ca94-4b7e-9055-d1e49d791922    60834460610014
# 2    3702724  02e92229-4593-4dfa-a009-d240f25d07da    60837027240012
# 3    3562240  0346961c-19dc-4a5a-93c4-86747df5d3bf    60835622400015
# 4    3557171  045aa047-ad38-4bd0-81ed-1c312ea8a6e8    60835571710014
#
#   modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0    cic_model_sil  0.12554077753482806   2025-06-20 14:06:11
# 1    cic_model_sil  0.18535425813462234   2025-05-19 15:14:32
# 2    cic_model_sil  0.18713858978281955   2025-09-24 15:11:08
# 3    cic_model_sil  0.06691871265945662   2025-07-17 14:43:09
# 4    cic_model_sil  0.06768672347008829   2025-07-14 18:47:27
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-06-20           2025-06           Test        0                1
# 1       2025-05-19           2025-05           Test        0                1
# 2       2025-09-24           2025-09           Test        0                1
# 3       2025-07-17           2025-07           Test        0                1
# 4       2025-07-14           2025-07           Test        1                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0  SIL Competitor             v1       Trench 2              Mall
# 1     SIL-Instore             v1       Trench 2         Appliance
# 2     SIL-Instore             v1       Trench 2         Appliance
# 3  SIL Competitor             v1       Trench 2         Appliance
# 4  SIL Competitor             v1       Trench 2         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (
   SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (279393, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 1     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 2     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2848196  00007493-6d52-4c64-b767-ff598a3447d8    60828481960013
#
#         modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0          cic_model_sil             0.470123   2025-05-03 11:51:03
# 1          cic_model_sil             0.299147   2025-02-25 10:39:01
# 2  Alpha - CIC-SIL-Model             0.085583   2024-10-12 15:53:50
# 3          cic_model_sil             0.244526   2024-10-12 15:53:50
# 4  Alpha - CIC-SIL-Model             0.126759   2024-09-15 15:24:45
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-05-03           2025-05          Train        0                1
# 1       2025-02-25           2025-02          Train        0                1
# 2       2024-10-12           2024-10          Train        0                1
# 3       2024-10-12           2024-10          Train        0                1
# 4       2024-09-15           2024-09          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0   SIL-Instore             v2       Trench 1         Appliance
# 1   SIL-Instore             v2       Trench 1         Appliance
# 2   SIL-Instore             v1       Trench 2            Mobile
# 3   SIL-Instore             v2       Trench 1            Mobile
# 4   SIL-Instore             v1       Trench 2         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (309468, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3791286  129c2930-f350-41e3-aa6f-623b67636045    60837912860012
# 1    3877353  16c53a30-48fb-4fce-8535-772cc572dd95    60838773530016
# 2    3733166  19963bee-941a-4b5e-8afe-ae0ebda8791b    60837331660013
# 3    3881814  1f34b2d7-3cf9-435a-b2ac-2dfe61550447    60838818140015
# 4    3745429  22f77aec-28bc-42d4-b736-fbb279082cc2    60837454290011
#
#   modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0    cic_model_sil  0.10276763916461164   2025-11-04 16:20:30
# 1    cic_model_sil   0.4178799480699215   2025-12-09 13:48:24
# 2    cic_model_sil   0.0745045284081565   2025-10-09 13:17:56
# 3    cic_model_sil  0.04486298128724436   2025-12-10 16:44:14
# 4    cic_model_sil  0.12314882724944955   2025-10-15 11:01:43
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-11-04           2025-11           Test        0                1
# 1       2025-12-09           2025-12           Test        0                1
# 2       2025-10-09           2025-10           Test        0                1
# 3       2025-12-10           2025-12           Test        0                1
# 4       2025-10-15           2025-10           Test        0                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0     SIL-Instore             v1       Trench 2              Mall
# 1  SIL Competitor             v2       Trench 1         Appliance
# 2     SIL-Instore             v1       Trench 2         Appliance
# 3  SIL Competitor             v1       Trench 2         Appliance
# 4  SIL Competitor             v1       Trench 2         Appliance

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309468 entries, 0 to 309467
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   customerId             309468 non-null  object
#  1   digitalLoanAccountId   309468 non-null  object
#  2   loanAccountNumber      309468 non-null  object
#  3   modelDisplayName       309468 non-null  object
#  4   Alpha_cic_sil_score    309468 non-null  object
#  5   appln_submit_datetime  309468 non-null  datetime64[us]
#  6   disbursementdate       309468 non-null  dbdate
#  7   Application_month      309468 non-null  object
#  8   Data_selection         309468 non-null  object
#  9   deffpd0                309468 non-null  Int64
#  10  flg_mature_fpd0        309468 non-null  Int64
#  11  new_loan_type          309468 non-null  object
#  12  modelVersionId         309468 non-null  object
#  13  trenchCategory         309468 non-null  object
#  14  loan_product_type      309468 non-null  object
# dtypes: Int64(2), datetime64[us](1), dbdate(1), object(11)
# memory usage: 36.0+ MB

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance             8447
#                                                 Mall                  3039
#                                 v2              Appliance              339
#                                                 Mall                   123
#                 SIL ZERO        v1              Appliance              932
#                                 v2              Appliance               32
#                 SIL-Instore     v1              Appliance            13492
#                                                 Mall                  3016
#                                 v2              Appliance              547
#                                                 Mall                   108
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            27940
#                                                 Mall                  8153
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             9275
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            90985
#                                                 Mall                 12853
#                                                 Mobile                9559
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['new_loan_type'].unique()
# Out:
# array(['SIL-Instore', 'SIL Competitor', 'SIL ZERO', 'SIL Repeat'],
#       dtype=object)

# %%
df_concat['Alpha_cic_sil_score'] = pd.to_numeric(df_concat['Alpha_cic_sil_score'], errors='coerce')

# %%
# df_concat.to_csv(r"D:\OneDrive - Tonik Financial Pte Ltd\MyStuff\Data Engineering\Model_Monitoring\Gini Monitoring\New_Gini_Monitoring_2025-11-25\Future\sample.csv", index = False)

# %%
# fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
#     df_concat, 
#     'Alpha_cic_sil_score', 
#     'deffpd0', 
#     'FPD0',
#     model_version_column='modelVersionId',
#     trench_column='trenchCategory',
#     loan_type_column='new_loan_type',
#     loan_product_type_column='loan_product_type',
#     account_id_column='digitalLoanAccountId'
# )

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Alpha_cic_sil_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table =update_tables(fact_table, dimension_table, 'cic_model_sil', 'SIL')

# %%
# print(fact_table.columns)
# fact_table['segment_type'].value_counts(dropna=False)
# fact_table['Model_display_name'] = 'cic_model_sil'

# %%
# # Columns where missing values should be replaced
# cols_to_replace = ['model_version', 'trench_category', 'loan_type', 'loan_product_type']

# # Replace NaN values with 'Overall'
# fact_table[cols_to_replace] = fact_table[cols_to_replace].fillna('Overall')

# fact_table.head()

# %%
# dimension_table['Model_display_name'] = 'cic_model_sil'

# %%
# # Columns where missing values should be replaced
# cols_to_replace = ['model_version', 'trench_category', 'loan_type', 'loan_product_type']

# # Replace NaN values with 'Overall'
# dimension_table[cols_to_replace] = dimension_table[cols_to_replace].fillna('Overall')

# dimension_table.head()

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_TRUNCATE",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=2f8e97a7-6b12-4f03-9b38-9706b5c737b3>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_TRUNCATE",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=6d6e43e1-1917-483a-b4f0-3b4c7516fe53>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  (SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (60642, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3483974  0055929c-c763-46eb-8166-34d7e6ba3b70    60834839740014
# 1    3045243  00c388ac-c413-465a-9bfd-a566ebf0a7af    60830452430028
# 2    3606047  00faae6c-0df1-4a3c-9b78-a8ebd5d915d0    60836060470018
# 3    3693376  0114a24c-3222-48d4-b302-819745d69d86    60836933760015
# 4    3573975  01db8c1c-3932-4fca-bda5-6a60e65b1582    60835739750016
#
#   modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0    cic_model_sil   0.0957734398268965   2025-06-07 19:36:22
# 1    cic_model_sil   0.1336356538188955   2025-06-11 16:15:54
# 2    cic_model_sil  0.07406220436244897   2025-08-07 19:13:02
# 3    cic_model_sil  0.15498883274383277   2025-09-19 19:18:10
# 4    cic_model_sil  0.15619911136760414   2025-07-23 15:59:47
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-06-07           2025-06           Test         0
# 1       2025-06-11           2025-06           Test         0
# 2       2025-08-07           2025-08           Test         0
# 3       2025-09-19           2025-09           Test         0
# 4       2025-07-23           2025-07           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 3
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (279393, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2173899  09ea0df2-7c99-4590-b7ed-06bec81ed1e8    60821738990011
# 1     2209358  1291d117-2876-41d4-82db-d783b3b03442    60822093580011
# 2     2255457  14e910da-e153-4631-90a2-16b4b502b687    60822554570012
# 3     2285691  17905dfc-f412-48cc-988f-09627b0ea4c3    60822856910015
# 4     2051498  1caaf6d9-5c86-445e-a6a6-2d14e08a50c4    60820514980013
#
#         modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0  Alpha - CIC-SIL-Model             0.089422   2023-08-05 12:36:17
# 1  Alpha - CIC-SIL-Model             0.125541   2023-08-27 11:57:52
# 2  Alpha - CIC-SIL-Model             0.063073   2023-10-01 16:42:29
# 3  Alpha - CIC-SIL-Model             0.125189   2023-10-27 12:39:39
# 4  Alpha - CIC-SIL-Model             0.043351   2023-05-19 11:56:33
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2023-08-05           2023-08          Train         0
# 1       2023-08-27           2023-08          Train         0
# 2       2023-10-01           2023-10          Train         0
# 3       2023-10-27           2023-10          Train         0
# 4       2023-05-19           2023-05          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 3
# 1                 1   SIL-Instore             v1       Trench 2
# 2                 1   SIL-Instore             v1       Trench 3
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (303320, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3731759  0393a476-985d-4c66-8e78-ac5b802ac11e    60837317590014
# 1    3832970  08ac0efb-2060-4002-a193-25e08122bc4d    60838329700015
# 2    3790997  1474568f-539d-4638-bf41-c5fb33374995    60837909970012
# 3    3735333  14962541-0b23-4db0-8c8c-3f72720fe650    60837353330018
# 4    3735808  1c5a2dfa-d27d-4837-867b-8e1cbb61856f    60837358080012
#
#   modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0    cic_model_sil  0.10026580073649688   2025-10-22 09:22:41
# 1    cic_model_sil  0.11708619300229363   2025-11-24 16:40:16
# 2    cic_model_sil   0.1269794190835551   2025-11-04 14:39:19
# 3    cic_model_sil   0.1073312934438125   2025-10-10 15:37:17
# 4    cic_model_sil  0.12251979271045058   2025-10-10 18:55:50
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-22           2025-10           Test         0
# 1       2025-11-24           2025-11           Test         0
# 2       2025-11-04           2025-11           Test         0
# 3       2025-10-10           2025-10           Test         0
# 4       2025-10-10           2025-10           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1  SIL Competitor             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance             6830
#                                                 Mall                  2448
#                                 v2              Appliance              166
#                                                 Mall                    58
#                 SIL ZERO        v1              Appliance              757
#                                 v2              Appliance               11
#                 SIL-Instore     v1              Appliance            10902
#                                                 Mall                  2403
#                                 v2              Appliance              290
#                                                 Mall                    62
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            27940
#                                                 Mall                  8153
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             9275
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            90985
#                                                 Mall                 12853
#                                                 Mobile                9559
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['Alpha_cic_sil_score'] = pd.to_numeric(df_concat['Alpha_cic_sil_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
     df_concat, 
    'Alpha_cic_sil_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
# fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
#     df_concat, 
#     'Alpha_cic_sil_score', 
#     'deffpd10', 
#     'FPD10',
#     model_version_column='modelVersionId',
#     trench_column='trenchCategory',
#     loan_type_column='new_loan_type',
#     loan_product_type_column='loan_product_type',
#     account_id_column='digitalLoanAccountId'
# )

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='cic_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=9800bb73-d7f6-4173-8702-6c5578a70d44>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=bd14bb13-eba5-4fad-aa38-7ba643add9b6>

# %%
#

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  (SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (50746, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3647868  0050e7df-814a-4916-9f5c-8201470045e8    60836478680011
# 1    3663344  058e337a-131c-4cfa-b382-327217df2371    60836633440012
# 2    3575769  06c4e36a-2534-4446-937e-e82bd69f01eb    60835757690011
# 3    2901059  082942c3-1059-4bad-aa7c-f00a7ea14b18    60829010590021
# 4    3797247  08473b12-9d34-4d6e-822d-5ad784e10422    60837972470019
#
#   modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0    cic_model_sil   0.1580065599627478   2025-08-28 13:46:35
# 1    cic_model_sil   0.0602374033138849   2025-09-04 12:34:42
# 2    cic_model_sil  0.13663241943619653   2025-07-24 15:50:46
# 3    cic_model_sil  0.12078474340120787   2025-06-10 17:01:03
# 4    cic_model_sil  0.11839531916995005   2025-11-07 15:01:06
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-08-28           2025-08           Test         0
# 1       2025-09-04           2025-09           Test         0
# 2       2025-07-24           2025-07           Test         0
# 3       2025-06-10           2025-06           Test         0
# 4       2025-11-07           2025-11           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1        SIL ZERO             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 3
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
     case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (279393, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 1     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 2     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2848196  00007493-6d52-4c64-b767-ff598a3447d8    60828481960013
#
#         modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0          cic_model_sil             0.470123   2025-05-03 11:51:03
# 1          cic_model_sil             0.299147   2025-02-25 10:39:01
# 2  Alpha - CIC-SIL-Model             0.085583   2024-10-12 15:53:50
# 3          cic_model_sil             0.244526   2024-10-12 15:53:50
# 4  Alpha - CIC-SIL-Model             0.126759   2024-09-15 15:24:45
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-05-03           2025-05          Train         0
# 1       2025-02-25           2025-02          Train         0
# 2       2024-10-12           2024-10          Train         0
# 3       2024-10-12           2024-10          Train         0
# 4       2024-09-15           2024-09          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v2       Trench 1
# 1                 1   SIL-Instore             v2       Trench 1
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v2       Trench 1
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2            Mobile
# 3            Mobile
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (293424, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3797247  08473b12-9d34-4d6e-822d-5ad784e10422    60837972470019
# 1    3797080  68855c82-5dd0-49dd-bc8d-27b1f8490800    60837970800014
# 2    3730940  71818fa9-976b-46b6-87f5-42cacc9ed4f7    60837309400015
# 3    2904391  7b9a7912-3931-4109-8dd0-e1c099bb51be    60829043910022
# 4    3798529  875adcb8-7d5d-49ad-9807-8a5ca3862735    60837985290011
#
#   modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0    cic_model_sil  0.11839531916995005   2025-11-07 15:01:06
# 1    cic_model_sil   0.1607635557107178   2025-11-07 13:59:22
# 2    cic_model_sil  0.04518450549160146   2025-10-08 11:05:52
# 3    cic_model_sil  0.08729489817297227   2025-10-09 10:26:37
# 4    cic_model_sil  0.10045040917353999   2025-11-08 10:12:29
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-11-07           2025-11           Test         0
# 1       2025-11-07           2025-11           Test         0
# 2       2025-10-08           2025-10           Test         0
# 3       2025-10-09           2025-10           Test         0
# 4       2025-11-08           2025-11           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1  SIL Competitor             v1       Trench 3
# 4                 1        SIL ZERO             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1              Mall
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance             4363
#                                                 Mall                  1464
#                 SIL ZERO        v1              Appliance              441
#                 SIL-Instore     v1              Appliance             6356
#                                                 Mall                  1407
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            27940
#                                                 Mall                  8153
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             9275
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            90985
#                                                 Mall                 12853
#                                                 Mobile                9559
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['Alpha_cic_sil_score'] = pd.to_numeric(df_concat['Alpha_cic_sil_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Alpha_cic_sil_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
# fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
#     df_concat, 
#     'Alpha_cic_sil_score', 
#     'deffpd30', 
#     'FPD30',
#     model_version_column='modelVersionId',
#     trench_column='trenchCategory',
#     loan_type_column='new_loan_type',
#     loan_product_type_column='loan_product_type',
#     account_id_column='digitalLoanAccountId'
# )

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='cic_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=f7b06658-a73c-40fa-ac08-75802cd77d3e>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=0a52a300-91b7-4bee-a7b0-56ba44c481a5>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  (SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (39418, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3438685  029f88c6-68d7-4b3c-af36-5320ed5363c6    60834386850013
# 1    3349476  053b2b43-c49b-4ee0-b314-24b2da9cf72f    60833494760019
# 2    3501488  119768ee-2d21-4f30-9c59-3dff73c58a2b    60835014880013
# 3    3487106  2002bf79-3ba7-4d73-a84e-d00da53f5cf2    60834871060014
# 4    3645280  20c33588-59d2-4abe-a5b8-bec93055fdd0    60836452800011
#
#   modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0    cic_model_sil  0.08400039892771376   2025-05-15 16:44:18
# 1    cic_model_sil  0.14222682922918106   2025-03-30 15:58:40
# 2    cic_model_sil   0.1798707408314363   2025-06-16 16:30:09
# 3    cic_model_sil  0.11085895923469906   2025-06-09 12:52:59
# 4    cic_model_sil   0.1217991504907045   2025-08-26 19:37:37
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-05-15           2025-05           Test          1
# 1       2025-03-30           2025-03           Test          0
# 2       2025-06-16           2025-06           Test          0
# 3       2025-06-09           2025-06           Test          0
# 4       2025-08-26           2025-08           Test          0
#
#    flg_mature_fspd_30   new_loan_type modelVersionId trenchCategory  \
# 0                   1     SIL-Instore             v1       Trench 2
# 1                   1     SIL-Instore             v1       Trench 2
# 2                   1     SIL-Instore             v1       Trench 2
# 3                   1     SIL-Instore             v1       Trench 2
# 4                   1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4              Mall

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (279391, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 1     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 2     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2848196  00007493-6d52-4c64-b767-ff598a3447d8    60828481960013
#
#         modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0          cic_model_sil             0.470123   2025-05-03 11:51:03
# 1          cic_model_sil             0.299147   2025-02-25 10:39:01
# 2  Alpha - CIC-SIL-Model             0.085583   2024-10-12 15:53:50
# 3          cic_model_sil             0.244526   2024-10-12 15:53:50
# 4  Alpha - CIC-SIL-Model             0.126759   2024-09-15 15:24:45
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-05-03           2025-05          Train          0
# 1       2025-02-25           2025-02          Train          0
# 2       2024-10-12           2024-10          Train          1
# 3       2024-10-12           2024-10          Train          1
# 4       2024-09-15           2024-09          Train          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v2       Trench 1
# 1                   1   SIL-Instore             v2       Trench 1
# 2                   1   SIL-Instore             v1       Trench 2
# 3                   1   SIL-Instore             v2       Trench 1
# 4                   1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2            Mobile
# 3            Mobile
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (282095, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3730977  489a5743-34d5-4c2c-8bea-522d3b46fe8a    60837309770018
# 1    3735703  4d4dedec-0d36-4872-84cf-be52ea9f8739    60837357030014
# 2    3732091  82e10b78-b58c-4d4f-aac3-f0d780ecd822    60837320910017
# 3    3522127  aaad9770-8e24-48fa-8c9f-7968c4d27983    60835221270023
# 4    3731766  d5358aee-7af0-426b-a80d-cf8636338b3f    60837317660013
#
#   modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0    cic_model_sil  0.11464120518562637   2025-10-08 11:29:05
# 1    cic_model_sil  0.07022896646756703   2025-10-10 18:02:31
# 2    cic_model_sil  0.15042156889236674   2025-10-08 18:54:01
# 3    cic_model_sil  0.08691576307270292   2025-10-12 15:47:12
# 4    cic_model_sil  0.11136085020144332   2025-10-08 16:39:21
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-08           2025-10           Test          0
# 1       2025-10-10           2025-10           Test          0
# 2       2025-10-08           2025-10           Test          0
# 3       2025-10-12           2025-10           Test          0
# 4       2025-10-08           2025-10           Test          0
#
#    flg_mature_fspd_30   new_loan_type modelVersionId trenchCategory  \
# 0                   1     SIL-Instore             v1       Trench 2
# 1                   1  SIL Competitor             v1       Trench 2
# 2                   1  SIL Competitor             v1       Trench 2
# 3                   1     SIL-Instore             v1       Trench 3
# 4                   1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance              839
#                                                 Mall                   266
#                 SIL ZERO        v1              Appliance               84
#                 SIL-Instore     v1              Appliance             1231
#                                                 Mall                   284
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            27940
#                                                 Mall                  8153
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             9275
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            90984
#                                                 Mall                 12852
#                                                 Mobile                9559
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['Alpha_cic_sil_score'] = pd.to_numeric(df_concat['Alpha_cic_sil_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Alpha_cic_sil_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='cic_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=d3892791-9dbc-435b-ae7e-4a52e9d8383e>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=512c5664-94ac-4ddb-917f-aa04ad1308a0>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  (SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (30164, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3236615  10d5fd3c-57e1-4707-922e-0276e95f714e    60832366150027
# 1    3675626  1d4b4e28-67fd-43b8-9358-5f54a6de96d8    60836756260012
# 2    3477608  215a9f95-42c6-4976-b9b3-e04e6f8830ee    60834776080016
# 3    3674311  2df3b76b-9d2a-413e-9765-921a14984334    60836743110012
# 4    3422440  2fe88d34-b4a8-40e9-a4a9-a7ec8c97c03a    60834224400015
#
#   modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0    cic_model_sil  0.06772058969150656   2025-04-19 16:03:50
# 1    cic_model_sil  0.16098505439561694   2025-09-10 11:07:15
# 2    cic_model_sil   0.1255901246223767   2025-06-04 15:23:11
# 3    cic_model_sil  0.08655348026864867   2025-09-09 15:00:33
# 4    cic_model_sil  0.09949246293769576   2025-05-06 10:47:26
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-04-19           2025-04           Test           0
# 1       2025-09-10           2025-09           Test           0
# 2       2025-06-04           2025-06           Test           0
# 3       2025-09-09           2025-09           Test           0
# 4       2025-05-06           2025-05           Test           1
#
#    flg_mature_fstpd_30   new_loan_type modelVersionId trenchCategory  \
# 0                    1     SIL-Instore             v1       Trench 3
# 1                    1        SIL ZERO             v1       Trench 2
# 2                    1     SIL-Instore             v1       Trench 2
# 3                    1  SIL Competitor             v1       Trench 2
# 4                    1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3              Mall
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Alpha_cic_sil_score,start_time,end_time,modelDisplayName,modelVersionId, 
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha - CIC-SIL-Model', 'cic_model_sil', 'Sil-Alpha-CIC-SIL-Model')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Alpha_cic_sil_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Alpha_cic_sil_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (271493, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 1     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 2     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2848196  00007493-6d52-4c64-b767-ff598a3447d8    60828481960013
#
#         modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0          cic_model_sil             0.470123   2025-05-03 11:51:03
# 1          cic_model_sil             0.299147   2025-02-25 10:39:01
# 2  Alpha - CIC-SIL-Model             0.085583   2024-10-12 15:53:50
# 3          cic_model_sil             0.244526   2024-10-12 15:53:50
# 4  Alpha - CIC-SIL-Model             0.126759   2024-09-15 15:24:45
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-05-03           2025-05          Train           0
# 1       2025-02-25           2025-02          Train           0
# 2       2024-10-12           2024-10          Train           1
# 3       2024-10-12           2024-10          Train           1
# 4       2024-09-15           2024-09          Train           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v2       Trench 1
# 1                    1   SIL-Instore             v2       Trench 1
# 2                    1   SIL-Instore             v1       Trench 2
# 3                    1   SIL-Instore             v2       Trench 1
# 4                    1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2            Mobile
# 3            Mobile
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (271495, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3071132  b73e11f2-2886-45d8-b911-4208f166f6fc    60830711320013
# 1    3482558  e875982d-ea4b-492e-a5ef-a5304b679d4e    60834825580018
# 2    3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 3    3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 4    2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
#
#         modelDisplayName  Alpha_cic_sil_score appln_submit_datetime  \
# 0          cic_model_sil  0.12648804051571458   2025-03-28 15:32:24
# 1          cic_model_sil  0.12352030274275619   2025-06-07 09:20:45
# 2          cic_model_sil             0.470123   2025-05-03 11:51:03
# 3          cic_model_sil             0.299147   2025-02-25 10:39:01
# 4  Alpha - CIC-SIL-Model             0.085583   2024-10-12 15:53:50
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-03-29           2025-03           Test           0
# 1       2025-06-11           2025-06           Test           1
# 2       2025-05-03           2025-05          Train           0
# 3       2025-02-25           2025-02          Train           0
# 4       2024-10-12           2024-10          Train           1
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 3
# 1                    1   SIL-Instore             v1       Trench 2
# 2                    1   SIL-Instore             v2       Trench 1
# 3                    1   SIL-Instore             v2       Trench 1
# 4                    1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4            Mobile

# %%
df_concat['Alpha_cic_sil_score'] = pd.to_numeric(df_concat['Alpha_cic_sil_score'], errors='coerce')

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL-Instore     v1              Appliance                2
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            25513
#                                                 Mall                  7342
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             8965
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            87398
#                                                 Mall                 12088
#                                                 Mobile                9559
# Name: digitalLoanAccountId, dtype: int64

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Alpha_cic_sil_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='cic_model_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (21008, 16)
# The shape of the dimension table is:	 (376, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=c9571f33-719f-4e7e-8810-a483ce5d7dd2>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=f9f29435-9cad-4e6a-8a3e-24dc5330fd03>

# %% [markdown]
# ## alpha_stack_model_sil

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (66790, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3504923  005fc562-33b4-47aa-baef-885b2bba5179    60835049230013
# 1    3587721  00a88e0d-df64-4aa7-a3f1-bde24e2d4043    60835877210017
# 2    3523320  01306cc5-2b66-49fd-9129-ec47d119070a    60835233200018
# 3    3674886  0281510b-1c64-4d64-bf2c-8996183408b8    60836748860016
# 4    3518925  02cbcc9d-8c25-44d4-9709-a6537a6d2561    60835189250016
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil   0.03038953712945081   2025-06-18 12:04:25
# 1  alpha_stack_model_sil    0.1631780761362553   2025-07-30 12:24:07
# 2  alpha_stack_model_sil  0.020564725726620624   2025-06-27 16:17:57
# 3  alpha_stack_model_sil   0.03910319142200721   2025-09-09 18:43:41
# 4  alpha_stack_model_sil  0.060191083018726395   2025-06-25 12:17:29
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-06-18           2025-06           Test        0                1
# 1       2025-07-30           2025-07           Test        1                1
# 2       2025-06-27           2025-06           Test        0                1
# 3       2025-09-09           2025-09           Test        1                1
# 4       2025-06-25           2025-06           Test        0                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0        SIL ZERO             v1       Trench 2         Appliance
# 1     SIL-Instore             v1       Trench 2         Appliance
# 2        SIL ZERO             v1       Trench 2         Appliance
# 3     SIL-Instore             v1       Trench 2         Appliance
# 4  SIL Competitor             v1       Trench 2              Mall

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (284380, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 1     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 2     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2848196  00007493-6d52-4c64-b767-ff598a3447d8    60828481960013
#
#         modelDisplayName  Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil               0.626735   2025-05-03 11:51:03
# 1  alpha_stack_model_sil               0.615562   2025-02-25 10:39:01
# 2  Alpha - StackingModel               0.155134   2024-10-12 15:53:50
# 3  alpha_stack_model_sil               0.528763   2024-10-12 15:53:50
# 4  Alpha - StackingModel               0.029253   2024-09-15 15:24:45
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-05-03           2025-05          Train        0                1
# 1       2025-02-25           2025-02          Train        0                1
# 2       2024-10-12           2024-10          Train        0                1
# 3       2024-10-12           2024-10          Train        0                1
# 4       2024-09-15           2024-09          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0   SIL-Instore             v2       Trench 1         Appliance
# 1   SIL-Instore             v2       Trench 1         Appliance
# 2   SIL-Instore             v1       Trench 2            Mobile
# 3   SIL-Instore             v2       Trench 1            Mobile
# 4   SIL-Instore             v1       Trench 2         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()

# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (310128, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3758512  22e1a6bc-5aeb-4c23-b741-2ac948811b6e    60837585120011
# 1    3756253  3acfb79d-ebed-4a24-b344-690fe6af1c77    60837562530013
# 2    3744469  3d4ccdf4-0bb5-4d69-b2c9-e219af207cc6    60837444690014
# 3    3018662  42a4ed16-5734-4fb9-ba26-ca274bdb00e9    60830186620038
# 4    3800966  47b73622-871c-49ed-ae9c-e651051f3242    60838009660016
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil   0.04525205919214831   2025-10-21 13:19:02
# 1  alpha_stack_model_sil    0.0389271921303172   2025-10-20 12:43:55
# 2  alpha_stack_model_sil  0.026666143395252435   2025-10-14 18:05:12
# 3  alpha_stack_model_sil   0.12637329370968797   2025-12-09 12:01:58
# 4  alpha_stack_model_sil   0.14556855436029667   2025-11-09 13:25:53
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-21           2025-10           Test        0                1
# 1       2025-10-20           2025-10           Test        0                1
# 2       2025-10-14           2025-10           Test        0                1
# 3       2025-12-09           2025-12           Test        0                1
# 4       2025-11-09           2025-11           Test        0                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0     SIL-Instore             v1       Trench 2         Appliance
# 1  SIL Competitor             v1       Trench 2              Mall
# 2  SIL Competitor             v1       Trench 3         Appliance
# 3     SIL-Instore             v1       Trench 3         Appliance
# 4     SIL-Instore             v1       Trench 2              Mall

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310128 entries, 0 to 310127
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   customerId             310128 non-null  object
#  1   digitalLoanAccountId   310128 non-null  object
#  2   loanAccountNumber      310128 non-null  object
#  3   modelDisplayName       310128 non-null  object
#  4   Sil_Alpha_Stack_score  310128 non-null  object
#  5   appln_submit_datetime  310128 non-null  datetime64[us]
#  6   disbursementdate       310128 non-null  dbdate
#  7   Application_month      310128 non-null  object
#  8   Data_selection         310128 non-null  object
#  9   deffpd0                310128 non-null  Int64
#  10  flg_mature_fpd0        310128 non-null  Int64
#  11  new_loan_type          310128 non-null  object
#  12  modelVersionId         310128 non-null  object
#  13  trenchCategory         310128 non-null  object
#  14  loan_product_type      310128 non-null  object
# dtypes: Int64(2), datetime64[us](1), dbdate(1), object(11)
# memory usage: 36.1+ MB

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance             7045
#                                                 Mall                  2602
#                                 v2              Appliance              339
#                                                 Mall                   123
#                 SIL ZERO        v1              Appliance              790
#                                 v2              Appliance               32
#                 SIL-Instore     v1              Appliance            11588
#                                                 Mall                  2574
#                                 v2              Appliance              547
#                                                 Mall                   108
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            29562
#                                                 Mall                  8641
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             9442
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            93318
#                                                 Mall                 13361
#                                                 Mobile                9428
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['new_loan_type'].unique()
# Out:
# array(['SIL-Instore', 'SIL Competitor', 'SIL ZERO', 'SIL Repeat'],
#       dtype=object)

# %%
df_concat['Sil_Alpha_Stack_score'] = pd.to_numeric(df_concat['Sil_Alpha_Stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Sil_Alpha_Stack_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (24968, 16)
# The shape of the dimension table is:	 (473, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=8b73f16e-cb6a-4e2c-9646-df2bf0414a18>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=6b837cbb-ff41-4a55-b0a1-1536fa574c9a>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  ( SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (60642, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3584955  00c46f0f-8944-43e3-962f-96803514cb5f    60835849550011
# 1    3713126  04ad1343-b0c5-48e8-a4ce-1975cc61fb2f    60837131260015
# 2    3503113  058ceb58-5c2b-4c67-b1e9-5dfa262ec187    60835031130013
# 3    3647570  073104cd-98ad-47a3-80c2-2f69dacc8308    60836475700016
# 4    3544896  0928b8d2-7b3b-4cf7-bbf1-4ebb22797853    60835448960017
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil   0.13793187392723313   2025-07-28 19:49:36
# 1  alpha_stack_model_sil   0.04195985259419062   2025-09-29 16:13:58
# 2  alpha_stack_model_sil   0.13875327154200942   2025-06-17 13:55:10
# 3  alpha_stack_model_sil   0.10629234197305036   2025-08-28 11:53:39
# 4  alpha_stack_model_sil    0.0856189154541487   2025-07-08 10:58:01
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-07-28           2025-07           Test         0
# 1       2025-09-29           2025-09           Test         0
# 2       2025-06-17           2025-06           Test         1
# 3       2025-08-28           2025-08           Test         0
# 4       2025-07-08           2025-07           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1  SIL Competitor             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4              Mall

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (284380, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 1     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 2     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2848196  00007493-6d52-4c64-b767-ff598a3447d8    60828481960013
#
#         modelDisplayName  Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil               0.626735   2025-05-03 11:51:03
# 1  alpha_stack_model_sil               0.615562   2025-02-25 10:39:01
# 2  Alpha - StackingModel               0.155134   2024-10-12 15:53:50
# 3  alpha_stack_model_sil               0.528763   2024-10-12 15:53:50
# 4  Alpha - StackingModel               0.029253   2024-09-15 15:24:45
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-05-03           2025-05          Train         0
# 1       2025-02-25           2025-02          Train         0
# 2       2024-10-12           2024-10          Train         0
# 3       2024-10-12           2024-10          Train         0
# 4       2024-09-15           2024-09          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v2       Trench 1
# 1                 1   SIL-Instore             v2       Trench 1
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v2       Trench 1
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2            Mobile
# 3            Mobile
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (303980, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3713962  125813e8-5f06-494b-86d8-7120004b05d9    60837139620013
# 1    3376334  13977d62-4383-4d44-a213-d4064d8e8e6a    60833763340027
# 2    3743611  29993045-3c09-4898-81da-2808d63f4cb6    60837436110018
# 3    3791576  382ccfd6-fc6d-4586-953e-a77ae32240ea    60837915760019
# 4    3746721  3da5b3aa-86ac-493b-b304-61462a4223c3    60837467210015
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil   0.04909202823866796   2025-09-30 11:38:58
# 1  alpha_stack_model_sil   0.04813838727395227   2025-10-22 13:57:51
# 2  alpha_stack_model_sil   0.06739085198841656   2025-10-14 12:55:18
# 3  alpha_stack_model_sil    0.0295580815227921   2025-11-04 18:07:55
# 4  alpha_stack_model_sil   0.07459766657056904   2025-10-15 19:22:08
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-09-30           2025-09           Test         0
# 1       2025-10-22           2025-10           Test         0
# 2       2025-10-14           2025-10           Test         0
# 3       2025-11-04           2025-11           Test         0
# 4       2025-10-15           2025-10           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 3
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance             5428
#                                                 Mall                  2011
#                                 v2              Appliance              166
#                                                 Mall                    58
#                 SIL ZERO        v1              Appliance              615
#                                 v2              Appliance               11
#                 SIL-Instore     v1              Appliance             8998
#                                                 Mall                  1961
#                                 v2              Appliance              290
#                                                 Mall                    62
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            29562
#                                                 Mall                  8641
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             9442
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            93318
#                                                 Mall                 13361
#                                                 Mobile                9428
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['Sil_Alpha_Stack_score'] = pd.to_numeric(df_concat['Sil_Alpha_Stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Sil_Alpha_Stack_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=d2c3d6e9-1bfd-434f-98a9-9316f409d079>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=de37f9d7-bf19-4822-b9dc-e3b176097f02>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  (SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (50746, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3545388  0404e352-d131-43f9-9365-cb7a91ee7a31    60835453880016
# 1    3801276  055e1fae-d512-42a3-b1dc-479e5dfeeb8e    60838012760011
# 2    3575357  059e2da7-d058-489a-bdfe-eda394cc35c0    60835753570014
# 3    3706250  07e694ee-67cc-4c81-b279-85c533c2964a    60837062500015
# 4    3701995  087b8f0d-be71-41e0-93dd-1cfd3d2afa41    60837019950019
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil   0.04545437775055467   2025-07-08 14:43:50
# 1  alpha_stack_model_sil   0.19487303828856306   2025-11-09 15:28:07
# 2  alpha_stack_model_sil   0.03138540344542647   2025-07-24 12:55:39
# 3  alpha_stack_model_sil   0.12396036744297124   2025-09-26 16:08:07
# 4  alpha_stack_model_sil    0.1349223070638321   2025-09-24 09:43:46
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-07-08           2025-07           Test         0
# 1       2025-11-09           2025-11           Test         1
# 2       2025-07-24           2025-07           Test         0
# 3       2025-09-26           2025-09           Test         0
# 4       2025-09-24           2025-09           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 3
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (284380, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 1     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 2     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2848196  00007493-6d52-4c64-b767-ff598a3447d8    60828481960013
#
#         modelDisplayName  Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil               0.626735   2025-05-03 11:51:03
# 1  alpha_stack_model_sil               0.615562   2025-02-25 10:39:01
# 2  Alpha - StackingModel               0.155134   2024-10-12 15:53:50
# 3  alpha_stack_model_sil               0.528763   2024-10-12 15:53:50
# 4  Alpha - StackingModel               0.029253   2024-09-15 15:24:45
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-05-03           2025-05          Train         0
# 1       2025-02-25           2025-02          Train         0
# 2       2024-10-12           2024-10          Train         0
# 3       2024-10-12           2024-10          Train         0
# 4       2024-09-15           2024-09          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v2       Trench 1
# 1                 1   SIL-Instore             v2       Trench 1
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v2       Trench 1
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2            Mobile
# 3            Mobile
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (294084, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3801276  055e1fae-d512-42a3-b1dc-479e5dfeeb8e    60838012760011
# 1    3794845  180ca406-65e7-4cd5-98ce-8838a55c11ad    60837948450013
# 2    3800790  209b2bf5-3f58-4322-ab3b-b0334028d5a5    60838007900011
# 3    3797028  286a4291-fba7-4cc2-9a6c-1ed97d7184b3    60837970280011
# 4    3803273  57fbde41-8c9c-4e3c-98bd-dd6421acf84b    60838032730016
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil   0.19487303828856306   2025-11-09 15:28:07
# 1  alpha_stack_model_sil   0.07664459287591574   2025-11-06 14:12:18
# 2  alpha_stack_model_sil   0.14621269423478253   2025-11-09 12:04:10
# 3  alpha_stack_model_sil  0.039016456404297815   2025-11-07 13:43:56
# 4  alpha_stack_model_sil   0.09085715773937536   2025-11-10 17:11:39
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-11-09           2025-11           Test         1
# 1       2025-11-06           2025-11           Test         0
# 2       2025-11-09           2025-11           Test         0
# 3       2025-11-07           2025-11           Test         0
# 4       2025-11-10           2025-11           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1  SIL Competitor             v1       Trench 2
# 4                 1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance             2961
#                                                 Mall                  1027
#                 SIL ZERO        v1              Appliance              299
#                 SIL-Instore     v1              Appliance             4452
#                                                 Mall                   965
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            29562
#                                                 Mall                  8641
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             9442
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            93318
#                                                 Mall                 13361
#                                                 Mobile                9428
# Name: digitalLoanAccountId, dtype: int64

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Sil_Alpha_Stack_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=490611b3-1d62-4e7a-bcf1-12ebd64ab315>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=542ec8ff-af79-40fc-a58a-4bfc44f4232a>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (39418, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3739722  0dba9de5-6344-45ae-b8ec-0f923b5a4543    60837397220013
# 1    3728031  14038a05-6519-4077-accd-dc0e08ddd774    60837280310014
# 2    3440738  1f5270a3-0c53-4b74-813c-4bf7d2eda7b2    60834407380012
# 3    3420042  2e10fd8c-99e2-47e6-91fd-2cdbafe1aa9f    60834200420017
# 4    3490367  340fbc98-f63e-4b0f-8b96-a2670b0ac262    60834903670011
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil   0.03898079411352201   2025-10-12 15:33:17
# 1  alpha_stack_model_sil   0.02718682004373387   2025-10-06 19:06:16
# 2  alpha_stack_model_sil   0.13293446747634324   2025-05-16 17:55:06
# 3  alpha_stack_model_sil   0.13528735800370342   2025-05-04 19:36:59
# 4  alpha_stack_model_sil    0.1499438017598421   2025-06-11 10:06:12
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-12           2025-10           Test          0
# 1       2025-10-06           2025-10           Test          0
# 2       2025-05-16           2025-05           Test          0
# 3       2025-05-04           2025-05           Test          0
# 4       2025-06-11           2025-06           Test          0
#
#    flg_mature_fspd_30   new_loan_type modelVersionId trenchCategory  \
# 0                   1  SIL Competitor             v1       Trench 2
# 1                   1     SIL-Instore             v1       Trench 2
# 2                   1     SIL-Instore             v1       Trench 2
# 3                   1     SIL-Instore             v1       Trench 2
# 4                   1     SIL-Instore             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3              Mall
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (282381, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2230985  0f7fa0cf-0ff5-4296-815c-ecb5cd105a5d    60822309850011
# 1     2225948  131f4167-b798-453b-8787-e41a5bd14032    60822259480011
# 2     2258289  1841d865-eea7-437a-bc2e-a311756a345a    60822582890016
# 3     2207083  19e29bfe-b266-4334-be97-3d2704a288e1    60822070830015
# 4     1883432  2b8d3b4f-620f-40b0-8e73-8608449dc285    60818834320027
#
#         modelDisplayName  Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  Alpha - StackingModel               0.185284   2023-09-12 15:44:43
# 1  Alpha - StackingModel               0.270018   2023-09-08 17:44:02
# 2  Alpha - StackingModel               0.123347   2023-10-03 15:59:07
# 3  Alpha - StackingModel               0.046391   2023-08-25 17:35:42
# 4  Alpha - StackingModel               0.034272   2023-09-28 10:19:17
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2023-09-12           2023-09          Train          0
# 1       2023-09-08           2023-09          Train          0
# 2       2023-10-03           2023-10          Train          0
# 3       2023-08-25           2023-08          Train          0
# 4       2023-09-28           2023-09          Train          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 3
# 1                   1   SIL-Instore             v1       Trench 2
# 2                   1   SIL-Instore             v1       Trench 2
# 3                   1   SIL-Instore             v1       Trench 2
# 4                   1   SIL-Instore             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (282423, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3358816  b22207e8-7643-41e8-a199-9842bde1ae8d    60833588160011
# 1    3725781  fc44ad44-5f44-45af-bced-3160c83bac86    60837257810013
# 2    3482558  e875982d-ea4b-492e-a5ef-a5304b679d4e    60834825580018
# 3    3071132  b73e11f2-2886-45d8-b911-4208f166f6fc    60830711320013
# 4    3634235  6d640f14-ffd2-43a3-b1e4-62ec3e82b5d9    60836342350017
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil  0.010246952080656055   2025-04-04 12:31:28
# 1  alpha_stack_model_sil   0.06257457840568006   2025-10-06 13:54:36
# 2  alpha_stack_model_sil    0.1377673123601746   2025-06-07 09:20:45
# 3  alpha_stack_model_sil  0.010246952080656055   2025-03-28 15:32:24
# 4  alpha_stack_model_sil   0.03224989422262025   2025-08-26 16:43:52
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-04-04           2025-04           Test          0
# 1       2025-10-06           2025-10           Test          0
# 2       2025-06-11           2025-06           Test          1
# 3       2025-03-29           2025-03           Test          0
# 4       2025-08-26           2025-08           Test          1
#
#    flg_mature_fspd_30   new_loan_type modelVersionId trenchCategory  \
# 0                   1     SIL-Instore             v1       Trench 2
# 1                   1     SIL-Instore             v1       Trench 2
# 2                   1     SIL-Instore             v1       Trench 2
# 3                   1     SIL-Instore             v1       Trench 3
# 4                   1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4              Mall

# %%
df_concat['Sil_Alpha_Stack_score'] = pd.to_numeric(df_concat['Sil_Alpha_Stack_score'], errors='coerce')

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance                5
#                                                 Mall                     4
#                 SIL ZERO        v1              Appliance                1
#                 SIL-Instore     v1              Appliance               25
#                                                 Mall                     7
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            28913
#                                                 Mall                  8450
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             9373
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            92422
#                                                 Mall                 13167
#                                                 Mobile                9428
# Name: digitalLoanAccountId, dtype: int64

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Sil_Alpha_Stack_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=61acd910-8fbc-4d59-a643-b5cebd068293>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=736a9c00-3d03-4905-a691-87b493e3ad31>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (30164, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3439963  02666af7-fa62-4989-8556-7fed9b3d58ee    60834399630011
# 1    3395173  02ff55e1-27f0-4409-a593-34b82c47ff1b    60833951730016
# 2    3412179  05650869-5aa4-4d02-ad3f-c8c40d7f796c    60834121790016
# 3    3468045  1fee5891-cf9f-4100-97d2-daf861f890d2    60834680450012
# 4    3673845  216c545f-7719-4194-a7b9-2b95e622abf8    60836738450013
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil   0.18514623485615198   2025-05-16 12:37:24
# 1  alpha_stack_model_sil   0.10401607692701598   2025-04-22 14:29:36
# 2  alpha_stack_model_sil   0.15236328402601024   2025-05-01 09:14:37
# 3  alpha_stack_model_sil   0.03463695247596067   2025-05-30 17:31:36
# 4  alpha_stack_model_sil   0.02871793395107937   2025-09-09 11:33:48
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-05-16           2025-05           Test           1
# 1       2025-04-22           2025-04           Test           0
# 2       2025-05-01           2025-05           Test           0
# 3       2025-05-30           2025-05           Test           0
# 4       2025-09-09           2025-09           Test           0
#
#    flg_mature_fstpd_30   new_loan_type modelVersionId trenchCategory  \
# 0                    1     SIL-Instore             v1       Trench 2
# 1                    1     SIL-Instore             v1       Trench 2
# 2                    1     SIL-Instore             v1       Trench 2
# 3                    1     SIL-Instore             v1       Trench 2
# 4                    1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
  with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction Sil_Alpha_Stack_score,start_time,end_time,modelDisplayName,modelVersionId, 
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Sil_Alpha_Stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Sil_Alpha_Stack_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (271230, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     1860512  01bd2618-8960-4e02-bfe0-b8057a518ba3    60818605120016
# 1     2252951  044bc2c0-b611-4f99-95ec-fd1db936306d    60822529510019
# 2     2252184  0a12e990-4266-4b5a-92f5-d57135cb5ff0    60822521840014
# 3     2226744  0e584998-6830-43ab-bfcb-416c46b6da42    60822267440015
# 4     2082583  0f004f65-bcdf-47d0-b578-5a275427bbd2    60820825830018
#
#         modelDisplayName  Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  Alpha - StackingModel               0.079859   2023-01-13 16:52:05
# 1  Alpha - StackingModel               0.079949   2023-09-29 19:55:22
# 2  Alpha - StackingModel               0.146786   2023-09-29 10:32:51
# 3  Alpha - StackingModel               0.028241   2023-09-09 13:20:41
# 4  Alpha - StackingModel               0.036544   2023-06-07 19:25:39
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2023-01-13           2023-01          Train           0
# 1       2023-09-29           2023-09          Train           0
# 2       2023-09-29           2023-09          Train           0
# 3       2023-09-09           2023-09          Train           0
# 4       2023-06-07           2023-06          Train           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 3
# 1                    1   SIL-Instore             v1       Trench 2
# 2                    1   SIL-Instore             v1       Trench 2
# 3                    1   SIL-Instore             v1       Trench 2
# 4                    1   SIL-Instore             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (271253, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3358816  b22207e8-7643-41e8-a199-9842bde1ae8d    60833588160011
# 1    3669444  3de74d78-bcde-4b83-8883-506a8a431be4    60836694440019
# 2    3431236  3b19bc86-07f3-4f35-839d-ebd5c9c9f7f0    60834312360014
# 3    3071132  b73e11f2-2886-45d8-b911-4208f166f6fc    60830711320013
# 4    3678502  166f3c24-3db7-4002-a777-354308e02eab    60836785020013
#
#         modelDisplayName Sil_Alpha_Stack_score appln_submit_datetime  \
# 0  alpha_stack_model_sil  0.010246952080656055   2025-04-04 12:31:28
# 1  alpha_stack_model_sil   0.04024485686734662   2025-09-10 09:24:41
# 2  alpha_stack_model_sil   0.14732277538919222   2025-05-11 13:56:41
# 3  alpha_stack_model_sil  0.010246952080656055   2025-03-28 15:32:24
# 4  alpha_stack_model_sil    0.0893281068689788   2025-09-12 16:38:55
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-04-04           2025-04           Test           0
# 1       2025-09-10           2025-09           Test           0
# 2       2025-05-11           2025-05           Test           1
# 3       2025-03-29           2025-03           Test           0
# 4       2025-09-12           2025-09           Test           1
#
#    flg_mature_fstpd_30   new_loan_type modelVersionId trenchCategory  \
# 0                    1     SIL-Instore             v1       Trench 2
# 1                    1     SIL-Instore             v1       Trench 2
# 2                    1     SIL-Instore             v1       Trench 2
# 3                    1     SIL-Instore             v1       Trench 3
# 4                    1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4              Mall

# %%
df_concat['Sil_Alpha_Stack_score'] = pd.to_numeric(df_concat['Sil_Alpha_Stack_score'], errors='coerce')

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance                2
#                                                 Mall                     2
#                 SIL ZERO        v1              Appliance                1
#                 SIL-Instore     v1              Appliance               14
#                                                 Mall                     4
# Train           SIL Competitor  v1              Appliance             2938
#                                                 Mall                   526
#                                                 Mobile                  40
#                                 v2              Appliance            25509
#                                                 Mall                  7339
#                                                 Mobile                  45
#                 SIL Repeat      v1              Appliance             1224
#                                                 Mall                   129
#                 SIL ZERO        v1              Appliance             4735
#                                                 Mobile                 924
#                                 v2              Appliance             8956
#                                                 Mobile                 544
#                 SIL-Instore     v1              Appliance            88978
#                                                 Mall                  4463
#                                                 Mobile               16082
#                                 v2              Appliance            87296
#                                                 Mall                 12074
#                                                 Mobile                9428
# Name: digitalLoanAccountId, dtype: int64

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Sil_Alpha_Stack_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',  # Add this
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (21536, 16)
# The shape of the dimension table is:	 (404, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=66e2256b-410e-48e2-b761-3c7b7eabb116>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=b49be1b5-dc17-4865-90f6-99b0d07973d5>

# %% [markdown]
# ## Beta SIL STACK Score Model

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
    ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (99180, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3807263  005c2fad-2177-4370-b0a7-8d946757e3e6    60838072630011
# 1    3493407  017f3ba9-b852-4f7b-8d2b-a782e0c085af    60834934070013
# 2    3573569  01c7e7db-2aee-4dc0-9fff-f333fd7095a7    60835735690016
# 3    3758878  029b1cc2-4e53-4230-810c-e1bce17e045a    60837588780018
# 4    3656857  02a283b8-45b3-43a1-9b2e-b1aadc6b2496    60836568570019
#
#        modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil  0.023325894381765012   2025-11-12 19:25:24
# 1  beta_stack_model_sil   0.10400775968702891   2025-06-12 17:45:42
# 2  beta_stack_model_sil  0.015238373176670717   2025-07-23 13:31:34
# 3  beta_stack_model_sil   0.09684014183490508   2025-10-21 15:46:09
# 4  beta_stack_model_sil    0.1283407472455959   2025-09-01 13:19:34
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-11-12           2025-11           Test        0                1
# 1       2025-06-12           2025-06           Test        1                1
# 2       2025-07-23           2025-07           Test        0                1
# 3       2025-10-21           2025-10           Test        1                1
# 4       2025-09-01           2025-09           Test        0                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0     SIL-Instore             v1       Trench 2              Mall
# 1     SIL-Instore             v1       Trench 2         Appliance
# 2  SIL Competitor             v1       Trench 2              Mall
# 3     SIL-Instore             v1       Trench 2              Mall
# 4  SIL Competitor             v1       Trench 2         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (414893, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     1983591  066a259b-ebb4-453e-812d-f92281b303e5    60819835910019
# 1     2042140  0b044a9d-ccd6-4fda-a2e9-1c76f97a7d01    60820421400015
# 2     1979374  0ec4d43a-9225-4227-8a8d-158ffd47834a    60819793740011
# 3     1869168  0eeb477b-c12f-4cc9-bf56-c1bc93b37db8    60818691680016
# 4     2096795  0f489a2f-398e-4842-8e86-6a9c8ef4054c    60820967950019
#
#          modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  Beta - StackScoreModel              0.027298   2023-04-08 11:39:25
# 1  Beta - StackScoreModel              0.040414   2023-05-13 11:16:00
# 2  Beta - StackScoreModel              0.406757   2023-04-05 14:38:56
# 3  Beta - StackScoreModel              0.082627   2023-01-21 16:16:07
# 4  Beta - StackScoreModel              0.122191   2023-06-17 10:21:42
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2023-04-08           2023-04          Train        0                1
# 1       2023-05-13           2023-05          Train        0                1
# 2       2023-04-05           2023-04          Train        0                1
# 3       2023-01-21           2023-01          Train        0                1
# 4       2023-06-17           2023-06          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0   SIL-Instore             v1       Trench 2         Appliance
# 1   SIL-Instore             v1       Trench 2         Appliance
# 2   SIL-Instore             v1       Trench 3         Appliance
# 3   SIL-Instore             v1       Trench 3         Appliance
# 4   SIL-Instore             v1       Trench 3         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()

# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (451722, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3807263  005c2fad-2177-4370-b0a7-8d946757e3e6    60838072630011
# 1    3758878  029b1cc2-4e53-4230-810c-e1bce17e045a    60837588780018
# 2    2923173  05a0f714-9f28-4262-8ed1-3d7f6006b746    60829231730012
# 3    3806293  0676258b-6331-4ee4-8fbc-05b2f847f08c    60838062930012
# 4    3807300  0aecc2a5-cf66-4c46-b071-aed5f86dbf03    60838073000018
#
#        modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil  0.023325894381765012   2025-11-12 19:25:24
# 1  beta_stack_model_sil   0.09684014183490508   2025-10-21 15:46:09
# 2  beta_stack_model_sil   0.19386326217486463   2025-11-04 11:45:57
# 3  beta_stack_model_sil   0.11457175797608034   2025-11-12 11:34:34
# 4  beta_stack_model_sil   0.12404160059613875   2025-11-12 19:54:09
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-11-12           2025-11           Test        0                1
# 1       2025-10-21           2025-10           Test        1                1
# 2       2025-11-04           2025-11           Test        0                1
# 3       2025-11-12           2025-11           Test        0                1
# 4       2025-11-12           2025-11           Test        1                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0   SIL-Instore             v1       Trench 2              Mall
# 1   SIL-Instore             v1       Trench 2              Mall
# 2   SIL-Instore             v1       Trench 2         Appliance
# 3   SIL-Instore             v1       Trench 2         Appliance
# 4   SIL-Instore             v1       Trench 2         Appliance

# %%
df_concat.columns
# Out:
# Index(['customerId', 'digitalLoanAccountId', 'loanAccountNumber',
#        'modelDisplayName', 'sil_beta_stack_score', 'appln_submit_datetime',
#        'disbursementdate', 'Application_month', 'Data_selection', 'deffpd0',
#        'flg_mature_fpd0', 'new_loan_type', 'modelVersionId', 'trenchCategory',
#        'loan_product_type'],
#       dtype='object')

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance              9174
#                                                 Mall                   3136
#                                 v2              Appliance               428
#                                                 Mall                    144
#                 SIL ZERO        v1              Appliance              1148
#                                 v2              Appliance                44
#                 SIL-Instore     v1              Appliance             18226
#                                                 Mall                   3578
#                                 v2              Appliance               803
#                                                 Mall                    148
# Train           SIL Competitor  v1              Appliance              3342
#                                                 Mall                    592
#                                                 Mobile                   47
#                                 v2              Appliance             33525
#                                                 Mall                   9633
#                                                 Mobile                   52
#                 SIL Repeat      v1              Appliance              1281
#                                                 Mall                    140
#                 SIL ZERO        v1              Appliance              5875
#                                                 Mobile                 1081
#                                 v2              Appliance             11877
#                                                 Mobile                 1081
#                 SIL-Instore     v1              Appliance            149786
#                                                 Mall                   5520
#                                                 Mobile                21591
#                                 v2              Appliance            136523
#                                                 Mall                  16670
#                                                 Mobile                16277
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['new_loan_type'].unique()
# Out:
# array(['SIL-Instore', 'SIL Competitor', 'SIL ZERO', 'SIL Repeat'],
#       dtype=object)

# %%
df_concat['sil_beta_stack_score'] = pd.to_numeric(df_concat['sil_beta_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_stack_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (25652, 16)
# The shape of the dimension table is:	 (473, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=0e19939a-bddb-4416-a5f1-9c5035b814ad>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=a8b484d1-16b3-4b47-87e4-59c200db035b>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
   SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (90512, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3649357  005cb5ff-911d-4f65-ba82-7ab53ad36703    60836493570011
# 1    3451681  00ffd415-5f04-4b86-a85e-c985e5765075    60834516810011
# 2    3409131  01f6ae55-993d-4293-bdf3-e9adc0b9c639    60834091310013
# 3    3547034  029ed357-9c8b-461c-bef1-6943a8ed57c4    60835470340011
# 4    3851593  02dae76f-85ce-49dd-95ac-1c87f34a47bb    60838515930016
#
#        modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil   0.08211752146774699   2025-08-29 11:23:19
# 1  beta_stack_model_sil   0.05964062594970977   2025-05-22 15:58:05
# 2  beta_stack_model_sil    0.0864419359503892   2025-04-29 16:12:02
# 3  beta_stack_model_sil   0.06007297882861165   2025-07-09 14:25:39
# 4  beta_stack_model_sil  0.026543585858968852   2025-12-01 15:14:43
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-08-29           2025-08           Test         0
# 1       2025-05-22           2025-05           Test         0
# 2       2025-04-29           2025-04           Test         0
# 3       2025-07-09           2025-07           Test         0
# 4       2025-12-01           2025-12           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1  SIL Competitor             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 3
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4              Mall

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (414893, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2046953  04ac32a4-4f80-4ebb-bdac-f90a4893ef95    60820469530011
# 1     1904514  094e391d-abb3-48cb-9539-bd2c81f8da31    60819045140011
# 2     1966039  13933f48-4d7a-4713-a3a5-30d6b8a89ef5    60819660390012
# 3     2161806  13edd272-142d-4612-9456-2ecfdbde1270    60821618060016
# 4     1950606  19c30a92-2c4e-4a4b-96b9-3211d57f7eee    60819506060012
#
#          modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  Beta - StackScoreModel              0.105514   2023-05-16 13:46:39
# 1  Beta - StackScoreModel              0.041926   2023-02-17 12:37:24
# 2  Beta - StackScoreModel              0.230481   2023-06-10 12:07:15
# 3  Beta - StackScoreModel              0.102190   2023-07-29 13:21:18
# 4  Beta - StackScoreModel              0.166112   2023-03-19 19:21:05
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2023-05-16           2023-05          Train         0
# 1       2023-02-17           2023-02          Train         0
# 2       2023-06-10           2023-06          Train         0
# 3       2023-07-29           2023-07          Train         0
# 4       2023-03-19           2023-03          Train         1
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 3
# 1                 1   SIL-Instore             v1       Trench 2
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()

# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (443054, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3851593  02dae76f-85ce-49dd-95ac-1c87f34a47bb    60838515930016
# 1    3759060  0711de83-99b5-4f31-8ab8-50b407bc0f1d    60837590600018
# 2    3801122  075e0971-4cc7-4e79-b75e-5d5a49828e5b    60838011220014
# 3    3831888  19b0ae63-071a-4977-89a0-e193f178346b    60838318880018
# 4    3800649  1a29f1a4-d63e-463d-9062-1cce9e512371    60838006490016
#
#        modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil  0.026543585858968852   2025-12-01 15:14:43
# 1  beta_stack_model_sil  0.024838320276442352   2025-10-21 16:30:18
# 2  beta_stack_model_sil   0.06050476897202524   2025-11-09 14:30:36
# 3  beta_stack_model_sil   0.07069520920914223   2025-11-24 09:50:09
# 4  beta_stack_model_sil   0.05658814915575612   2025-11-09 11:07:24
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-12-01           2025-12           Test         0
# 1       2025-10-21           2025-10           Test         0
# 2       2025-11-09           2025-11           Test         0
# 3       2025-11-24           2025-11           Test         0
# 4       2025-11-09           2025-11           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1  SIL Competitor             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance              7077
#                                                 Mall                   2438
#                                 v2              Appliance               206
#                                                 Mall                     71
#                 SIL ZERO        v1              Appliance               891
#                                 v2              Appliance                17
#                 SIL-Instore     v1              Appliance             14249
#                                                 Mall                   2732
#                                 v2              Appliance               399
#                                                 Mall                     81
# Train           SIL Competitor  v1              Appliance              3342
#                                                 Mall                    592
#                                                 Mobile                   47
#                                 v2              Appliance             33525
#                                                 Mall                   9633
#                                                 Mobile                   52
#                 SIL Repeat      v1              Appliance              1281
#                                                 Mall                    140
#                 SIL ZERO        v1              Appliance              5875
#                                                 Mobile                 1081
#                                 v2              Appliance             11877
#                                                 Mobile                 1081
#                 SIL-Instore     v1              Appliance            149786
#                                                 Mall                   5520
#                                                 Mobile                21591
#                                 v2              Appliance            136523
#                                                 Mall                  16670
#                                                 Mobile                16277
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['sil_beta_stack_score'] = pd.to_numeric(df_concat['sil_beta_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_stack_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection', 
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=42b289b9-bfdb-44d7-8066-a366c5bb0713>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=482b4513-0402-4b8e-9e06-891da4118fa4>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
   SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (76472, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3483974  0055929c-c763-46eb-8166-34d7e6ba3b70    60834839740014
# 1    3045243  00c388ac-c413-465a-9bfd-a566ebf0a7af    60830452430028
# 2    3573975  01db8c1c-3932-4fca-bda5-6a60e65b1582    60835739750016
# 3    3676303  044508eb-5e12-438c-b1ef-86a21ced7d1e    60836763030011
# 4    3571839  0448c841-e19e-4f1d-80ca-7f21eec70049    60835718390011
#
#        modelDisplayName sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil  0.09514746057069046   2025-06-07 19:36:22
# 1  beta_stack_model_sil  0.04235627944288622   2025-06-11 16:15:54
# 2  beta_stack_model_sil  0.05510655487374319   2025-07-23 15:59:47
# 3  beta_stack_model_sil  0.12246273822300245   2025-09-10 16:41:44
# 4  beta_stack_model_sil  0.05095491124850971   2025-07-22 14:09:15
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-06-07           2025-06           Test         0
# 1       2025-06-11           2025-06           Test         0
# 2       2025-07-23           2025-07           Test         0
# 3       2025-09-10           2025-09           Test         0
# 4       2025-07-22           2025-07           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 3
# 2                 1  SIL Competitor             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3              Mall
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (414893, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2122333  01e266e4-fc43-47a5-84a3-d2119df7e6ef    60821223330018
# 1     2051732  04f1b256-0efe-40b5-a9c9-0054b04b52fe    60820517320014
# 2     1991253  05fe853f-917a-44d7-85d6-1d87b2e74104    60819912530011
# 3     2152935  08298315-5597-4d20-baae-d73c63623c53    60821529350013
# 4     2012964  0cdd312a-4356-41c1-ae67-08f287a01210    60820129640012
#
#          modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  Beta - StackScoreModel              0.016626   2023-07-06 17:36:47
# 1  Beta - StackScoreModel              0.088427   2023-05-19 14:51:59
# 2  Beta - StackScoreModel              0.029993   2023-04-14 14:23:46
# 3  Beta - StackScoreModel              0.180076   2023-07-24 11:40:30
# 4  Beta - StackScoreModel              0.085320   2023-04-25 11:17:34
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2023-07-06           2023-07          Train         0
# 1       2023-05-19           2023-05          Train         0
# 2       2023-04-14           2023-04          Train         0
# 3       2023-07-24           2023-07          Train         0
# 4       2023-04-25           2023-04          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 3
# 1                 1   SIL-Instore             v1       Trench 3
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (429014, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3806787  1d1168a3-d63d-4408-9a45-03a7b3747e89    60838067870019
# 1    3744333  1f223cb6-465a-46fa-b0f4-199735be0bbe    60837443330019
# 2    3801017  3a4d1d49-a3dd-4a85-8aff-0eaf1842b2b5    60838010170014
# 3    3796971  3bad2ca1-9669-4b1f-b63b-43fbf75975f8    60837969710016
# 4    3797085  4f9c78a9-e8cf-45dc-8217-beaf921aebe0    60837970850019
#
#        modelDisplayName sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil  0.08241743720418807   2025-11-12 15:39:41
# 1  beta_stack_model_sil  0.06873544023553475   2025-10-14 17:02:34
# 2  beta_stack_model_sil  0.06678935445834075   2025-11-09 13:56:03
# 3  beta_stack_model_sil  0.04268646642840672   2025-11-07 13:31:57
# 4  beta_stack_model_sil  0.11120401671803315   2025-11-07 14:04:28
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-11-12           2025-11           Test         0
# 1       2025-10-14           2025-10           Test         0
# 2       2025-11-09           2025-11           Test         0
# 3       2025-11-07           2025-11           Test         0
# 4       2025-11-07           2025-11           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type   modelVersionId  loan_product_type
# Test            SIL Competitor  v1              Appliance              3856
#                                                 Mall                   1252
#                 SIL ZERO        v1              Appliance               459
#                 SIL-Instore     v1              Appliance              7196
#                                                 Mall                   1358
# Train           SIL Competitor  v1              Appliance              3342
#                                                 Mall                    592
#                                                 Mobile                   47
#                                 v2              Appliance             33525
#                                                 Mall                   9633
#                                                 Mobile                   52
#                 SIL Repeat      v1              Appliance              1281
#                                                 Mall                    140
#                 SIL ZERO        v1              Appliance              5875
#                                                 Mobile                 1081
#                                 v2              Appliance             11877
#                                                 Mobile                 1081
#                 SIL-Instore     v1              Appliance            149786
#                                                 Mall                   5520
#                                                 Mobile                21591
#                                 v2              Appliance            136523
#                                                 Mall                  16670
#                                                 Mobile                16277
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['sil_beta_stack_score'] = pd.to_numeric(df_concat['sil_beta_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_stack_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',  
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=3baeb51f-3706-4e13-9660-f82314b4f8f1>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=e3691a95-e833-4a6e-83a5-25156f1a7e8b>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
   SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (60000, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3446061  01f5b185-ca94-4b7e-9055-d1e49d791922    60834460610014
# 1    3353776  05925c55-d88e-474e-89c5-4b2768ae096b    60833537760019
# 2    3575207  0a00f0a4-ba8b-4041-a7f1-fea63f4fae1d    60835752070011
# 3    3646551  1201b41a-aabd-45e9-a2eb-12ea041cbeac    60836465510019
# 4    3727358  26b72f79-5daf-42a8-b409-90a59252c995    60837273580011
#
#        modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil   0.18954753278386646   2025-05-19 15:14:32
# 1  beta_stack_model_sil   0.06914301832641337   2025-04-01 17:21:51
# 2  beta_stack_model_sil   0.08493784228740325   2025-07-24 11:31:22
# 3  beta_stack_model_sil    0.0724647723870292   2025-08-27 16:50:11
# 4  beta_stack_model_sil  0.045498394394953345   2025-10-06 14:46:06
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-05-19           2025-05           Test          0
# 1       2025-04-01           2025-04           Test          0
# 2       2025-07-24           2025-07           Test          0
# 3       2025-08-27           2025-08           Test          0
# 4       2025-10-06           2025-10           Test          0
#
#    flg_mature_fspd_30   new_loan_type modelVersionId trenchCategory  \
# 0                   1     SIL-Instore             v1       Trench 2
# 1                   1     SIL-Instore             v1       Trench 2
# 2                   1     SIL-Instore             v1       Trench 2
# 3                   1  SIL Competitor             v1       Trench 2
# 4                   1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (412476, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     1909369  01a9a992-e86f-4a37-b111-5165f3c46661    60819093690019
# 1     1738012  07024b71-68ef-43fe-adb2-2f0afe580474    60817380120012
# 2     2067235  07d76a82-c37e-45ba-8370-f6cfd550f3c6    60820672350011
# 3     1985970  142d872a-836c-474b-a7bd-bb56ed0b9fbd    60819859700014
# 4     2141228  147c0e23-74ef-4913-baf9-666b509085b7    60821412280014
#
#          modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  Beta - StackScoreModel              0.083235   2023-02-20 18:02:24
# 1  Beta - StackScoreModel              0.170928   2023-02-17 11:38:39
# 2  Beta - StackScoreModel              0.032655   2023-05-29 16:05:45
# 3  Beta - StackScoreModel              0.048627   2023-04-09 19:43:53
# 4  Beta - StackScoreModel              0.051656   2023-07-17 11:30:50
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2023-02-20           2023-02          Train          0
# 1       2023-02-17           2023-02          Train          0
# 2       2023-05-29           2023-05          Train          0
# 3       2023-04-09           2023-04          Train          0
# 4       2023-07-17           2023-07          Train          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 2
# 1                   1   SIL-Instore             v1       Trench 3
# 2                   1   SIL-Instore             v1       Trench 2
# 3                   1   SIL-Instore             v1       Trench 2
# 4                   1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (412542, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3431236  3b19bc86-07f3-4f35-839d-ebd5c9c9f7f0    60834312360014
# 1    3725781  fc44ad44-5f44-45af-bced-3160c83bac86    60837257810013
# 2    3358816  b22207e8-7643-41e8-a199-9842bde1ae8d    60833588160011
# 3    2449123  4c59bdbc-c1dc-4828-bb05-bf278d295cf0    60824491230032
# 4    3343551  fd3767af-fd32-42d6-b702-0253dd90e03d    60833435510019
#
#        modelDisplayName sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil  0.22512422805411256   2025-05-11 13:56:41
# 1  beta_stack_model_sil  0.03299695489269644   2025-10-06 13:54:36
# 2  beta_stack_model_sil  0.17224088331771564   2025-04-04 12:31:28
# 3  beta_stack_model_sil   0.3854082304186329   2025-10-06 14:35:56
# 4  beta_stack_model_sil  0.21828598206605487   2025-03-27 16:08:12
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-05-11           2025-05           Test          0
# 1       2025-10-06           2025-10           Test          0
# 2       2025-04-04           2025-04           Test          0
# 3       2025-10-06           2025-10           Test          0
# 4       2025-03-27           2025-03           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 2
# 1                   1   SIL-Instore             v1       Trench 2
# 2                   1   SIL-Instore             v1       Trench 2
# 3                   1   SIL-Instore             v1       Trench 3
# 4                   1   SIL-Instore             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df_concat['sil_beta_stack_score'] = pd.to_numeric(df_concat['sil_beta_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_stack_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection', 
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=83096ead-258d-4756-ab85-074687fe5770>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=6939de50-72b1-4ec0-adf0-a6c03a323b99>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
   SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (46290, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3679992  03b9188d-3d29-4b17-ad77-0a238177a952    60836799920017
# 1    3391797  060789ef-6dd3-4c38-bb40-17c53429617a    60833917970016
# 2    3428249  124eaf99-5349-4262-bcab-e7c25a28b3b1    60834282490012
# 3    3405404  1891ece0-ae42-4a9b-b9f2-fae4eab7eb15    60834054040013
# 4    3443934  2799b2d1-b269-400a-a854-6e808b0421e3    60834439340016
#
#        modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil   0.04631642208912308   2025-09-12 17:16:41
# 1  beta_stack_model_sil   0.03169264267453934   2025-04-20 18:54:37
# 2  beta_stack_model_sil   0.07390739279431702   2025-05-09 17:32:16
# 3  beta_stack_model_sil  0.019718325493811216   2025-04-27 15:38:25
# 4  beta_stack_model_sil   0.16094297512006492   2025-05-18 14:39:19
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-09-12           2025-09           Test           0
# 1       2025-04-20           2025-04           Test           0
# 2       2025-05-09           2025-05           Test           0
# 3       2025-04-27           2025-04           Test           0
# 4       2025-05-18           2025-05           Test           1
#
#    flg_mature_fstpd_30   new_loan_type modelVersionId trenchCategory  \
# 0                    1  SIL Competitor             v1       Trench 2
# 1                    1     SIL-Instore             v1       Trench 2
# 2                    1     SIL-Instore             v1       Trench 2
# 3                    1     SIL-Instore             v1       Trench 2
# 4                    1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature
   FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_stack_score,
  modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_stack_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (398796, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2042626  04560413-0770-4f4d-a0d6-3c6787d2ebf1    60820426260012
# 1     1924419  0b37ece3-9c36-4985-bed2-c905801617aa    60819244190012
# 2     1885104  0b9a2dbc-dfb3-4aec-a063-a663bca54d3b    60818851040014
# 3     1863629  0cf5965c-c7ba-4832-a82d-9c78483cb3bd    60818636290011
# 4     2041294  132f72ff-9202-4a55-b388-2134c3050290    60820412940018
#
#          modelDisplayName  sil_beta_stack_score appln_submit_datetime  \
# 0  Beta - StackScoreModel              0.090253   2023-05-13 16:38:05
# 1  Beta - StackScoreModel              0.106519   2023-03-02 13:14:08
# 2  Beta - StackScoreModel              0.041948   2023-02-03 18:30:19
# 3  Beta - StackScoreModel              0.060769   2023-01-16 15:30:44
# 4  Beta - StackScoreModel              0.581451   2023-05-12 18:08:44
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2023-05-13           2023-05          Train           0
# 1       2023-03-02           2023-03          Train           0
# 2       2023-02-03           2023-02          Train           0
# 3       2023-01-16           2023-01          Train           1
# 4       2023-05-12           2023-05          Train           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1   SIL-Instore             v1       Trench 3
# 2                    1   SIL-Instore             v1       Trench 2
# 3                    1   SIL-Instore             v1       Trench 2
# 4                    1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (398832, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3678282  a587b4a4-689b-4ec1-b603-9580e42e34e0    60836782820011
# 1    3678502  166f3c24-3db7-4002-a777-354308e02eab    60836785020013
# 2    3431236  3b19bc86-07f3-4f35-839d-ebd5c9c9f7f0    60834312360014
# 3    3435452  c9080f44-1a0b-4e44-aeb4-0853679519fc    60834354520016
# 4    3358816  b22207e8-7643-41e8-a199-9842bde1ae8d    60833588160011
#
#        modelDisplayName sil_beta_stack_score appln_submit_datetime  \
# 0  beta_stack_model_sil    0.120935115019117   2025-09-12 11:59:37
# 1  beta_stack_model_sil  0.05483038379504281   2025-09-12 16:38:55
# 2  beta_stack_model_sil  0.22512422805411256   2025-05-11 13:56:41
# 3  beta_stack_model_sil  0.09171499469759378   2025-05-13 17:54:17
# 4  beta_stack_model_sil  0.17224088331771564   2025-04-04 12:31:28
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-09-12           2025-09           Test           0
# 1       2025-09-12           2025-09           Test           1
# 2       2025-05-11           2025-05           Test           1
# 3       2025-05-13           2025-05           Test           1
# 4       2025-04-04           2025-04           Test           0
#
#    flg_mature_fstpd_30   new_loan_type modelVersionId trenchCategory  \
# 0                    1     SIL-Instore             v1       Trench 2
# 1                    1  SIL Competitor             v1       Trench 2
# 2                    1     SIL-Instore             v1       Trench 2
# 3                    1     SIL-Instore             v1       Trench 2
# 4                    1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df_concat['sil_beta_stack_score'] = pd.to_numeric(df_concat['sil_beta_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_stack_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection', 
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (22214, 16)
# The shape of the dimension table is:	 (404, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=c33c155e-4ac9-41dd-87ce-e3338ee69c74>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=79876ab1-941e-41dc-974a-eda61b608d88>

# %% [markdown]
# ## Beta Sil App Score

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
    SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
   ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64) as sil_beta_app_score,
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (85981, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3455268  002783ec-23b9-43aa-ac3f-f69970e81592    60834552680026
# 1    3492876  0033913d-a3ee-4c44-a380-e515884473bc    60834928760014
# 2    3587779  0037583a-8065-4c80-80e9-77738f113f97    60835877790015
# 3    3605641  004480d7-9b88-4413-85c3-7195fd7dcdfa    60836056410016
# 4    3517429  006ba085-0fac-48d2-b9d3-28f7b6ea26e4    60835174290011
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.573117   2025-10-23 16:43:02
# 1  apps_score_model_sil            0.549573   2025-06-12 14:38:19
# 2  apps_score_model_sil            0.535034   2025-07-30 13:04:11
# 3  apps_score_model_sil            0.325259   2025-08-07 16:40:13
# 4  apps_score_model_sil            0.400904   2025-06-24 14:10:08
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-23           2025-10           Test        0                1
# 1       2025-06-12           2025-06           Test        0                1
# 2       2025-07-30           2025-07           Test        0                1
# 3       2025-08-07           2025-08           Test        0                1
# 4       2025-06-24           2025-06           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0   SIL-Instore             v1       Trench 3         Appliance
# 1   SIL-Instore             v1       Trench 3         Appliance
# 2   SIL-Instore             v1       Trench 2              Mall
# 3   SIL-Instore             v1       Trench 2              Mall
# 4   SIL-Instore             v1       Trench 2              Mall

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(cast(prediction as string), "'", '"'), "None", "null") AS prediction_clean
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
    ),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  coalesce(prediction, safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64)) as sil_beta_app_score, 
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (268618, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2126826  14ccf453-4a33-4497-8b46-84972a6c1228    60821268260011
# 1     2021503  1ba15f06-c366-4d67-abec-afb51304821b    60820215030018
# 2     2091390  20119ec3-b638-4ab7-978e-3ddb786b6655    60820913900012
# 3     2110037  2733222b-aab3-4f63-ac91-f18c6a789da4    60821100370011
# 4     1955428  290168c5-cff9-4fcd-8c5d-06de4781aaa6    60819554280012
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.553199   2023-07-09 13:19:32
# 1  apps_score_model_sil            0.660693   2023-05-01 11:13:07
# 2  apps_score_model_sil            0.424602   2023-06-13 17:38:45
# 3  apps_score_model_sil            0.424127   2023-06-27 18:38:53
# 4  apps_score_model_sil            0.398144   2023-03-22 17:45:06
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2023-07-09           2023-07          Train        1                1
# 1       2023-05-01           2023-05          Train        0                1
# 2       2023-06-14           2023-06          Train        0                1
# 3       2023-06-27           2023-06          Train        0                1
# 4       2023-03-22           2023-03          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0   SIL-Instore             v1       Trench 2         Appliance
# 1   SIL-Instore             v1       Trench 3         Appliance
# 2   SIL-Instore             v1       Trench 3         Appliance
# 3   SIL-Instore             v1       Trench 2         Appliance
# 4   SIL-Instore             v1       Trench 2         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (278074, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3873586  0651f328-9cfe-4c52-8fea-a5eea74370b1    60838735860015
# 1    3874623  099de10d-a377-46b1-913c-71f7e2f0be83    60838746230017
# 2    3877865  372ecfc1-46bb-4cb5-ae55-0da56b3059f0    60838778650015
# 3    3876865  3ed4a84b-8f8d-4858-9784-a55a65d0575f    60838768650011
# 4    3874187  464d9d81-9bc5-42a4-b01f-75955066de68    60838741870018
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.529397   2025-12-08 13:57:34
# 1  apps_score_model_sil            0.523929   2025-12-08 16:57:18
# 2  apps_score_model_sil            0.565984   2025-12-09 15:23:39
# 3  apps_score_model_sil            0.553327   2025-12-09 12:33:34
# 4  apps_score_model_sil            0.620859   2025-12-08 15:42:29
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-12-08           2025-12           Test        1                1
# 1       2025-12-08           2025-12           Test        0                1
# 2       2025-12-09           2025-12           Test        0                1
# 3       2025-12-09           2025-12           Test        0                1
# 4       2025-12-08           2025-12           Test        0                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0  SIL Competitor             v1       Trench 2         Appliance
# 1  SIL Competitor             v1       Trench 2         Appliance
# 2     SIL-Instore             v1       Trench 2         Appliance
# 3     SIL-Instore             v1       Trench 2         Appliance
# 4     SIL-Instore             v1       Trench 2         Appliance

# %%
df_concat['sil_beta_app_score'] = pd.to_numeric(df_concat['sil_beta_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_app_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection', 
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_model_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (22631, 16)
# The shape of the dimension table is:	 (391, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=a48725e2-4d82-4160-ba01-47e4c1c2857d>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=7b55f379-9e25-4455-ae8f-cad62ae69791>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
    SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
   ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64) as sil_beta_app_score,
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (79013, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3831997  0185e7ab-833e-4cdd-8fa2-7d77d53d8c4f    60838319970012
# 1    3692284  01bff3df-1eb3-4080-9a09-5e14aa180060    60836922840018
# 2    3650434  03d64a9f-e906-46ba-ab98-b32c3a31cdfe    60836504340016
# 3    3558748  04238e6f-d269-4ba3-bd8b-5444c0987770    60835587480017
# 4    3648563  044d31d6-bab9-4103-a0e6-196d45540cf4    60836485630011
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.571778   2025-11-24 10:51:42
# 1  apps_score_model_sil            0.448565   2025-09-19 11:18:33
# 2  apps_score_model_sil            0.497392   2025-08-29 18:33:29
# 3  apps_score_model_sil            0.561450   2025-07-15 17:01:14
# 4  apps_score_model_sil            0.598534   2025-08-28 19:08:20
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-11-24           2025-11           Test         0
# 1       2025-09-19           2025-09           Test         0
# 2       2025-08-29           2025-08           Test         0
# 3       2025-07-15           2025-07           Test         0
# 4       2025-08-28           2025-08           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1  SIL Competitor             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1  SIL Competitor             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(cast(prediction as string), "'", '"'), "None", "null") AS prediction_clean
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
    ),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  coalesce(prediction, safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64)) as sil_beta_app_score, 
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (268614, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     1852353  04971638-0a78-46df-af3d-5201a131fa22    60818523530012
# 1     1960393  0fd679f1-02fe-4649-8f25-b45b1b2686be    60819603930013
# 2     2010194  19f2b715-3458-4237-898c-59adb4906ffb    60820101940016
# 3     2085202  1d4e04f8-e4e9-4545-bb04-f2823e9a4f49    60820852020014
# 4     1957204  222f5d74-1149-4ded-90d4-637494cdf92b    60819572040016
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.534637   2023-01-06 13:16:36
# 1  apps_score_model_sil            0.549224   2023-03-25 19:03:31
# 2  apps_score_model_sil            0.600402   2023-04-23 14:36:45
# 3  apps_score_model_sil            0.469234   2023-06-09 15:56:40
# 4  apps_score_model_sil            0.411507   2023-03-23 19:27:21
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2023-01-06           2023-01          Train         0
# 1       2023-03-25           2023-03          Train         0
# 2       2023-04-23           2023-04          Train         0
# 3       2023-06-09           2023-06          Train         0
# 4       2023-03-23           2023-03          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 3
# 1                 1   SIL-Instore             v1       Trench 2
# 2                 1   SIL-Instore             v1       Trench 3
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (271106, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3358816  b22207e8-7643-41e8-a199-9842bde1ae8d    60833588160011
# 1    3431236  3b19bc86-07f3-4f35-839d-ebd5c9c9f7f0    60834312360014
# 2    3851828  304fd049-6f12-45c6-8e02-8885282626f1    60838518280016
# 3    3616945  e74cf719-4136-4b34-afad-56a493da4229    60836169450018
# 4    3851611  eb457983-e00c-4135-9e40-ac1e37e23da0    60838516110011
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.673509   2025-04-04 12:31:28
# 1  apps_score_model_sil            0.607208   2025-05-11 13:56:41
# 2  apps_score_model_sil            0.518171   2025-12-01 16:05:44
# 3  apps_score_model_sil            0.505684   2025-08-13 13:32:22
# 4  apps_score_model_sil            0.583990   2025-12-01 16:06:09
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-04-04           2025-04           Test         0
# 1       2025-05-11           2025-05           Test         0
# 2       2025-12-01           2025-12           Test         0
# 3       2025-08-13           2025-08           Test         0
# 4       2025-12-01           2025-12           Test         1
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1  SIL Competitor             v1       Trench 2
# 3                 1  SIL Competitor             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4              Mall

# %%
df_concat['sil_beta_app_score'] = pd.to_numeric(df_concat['sil_beta_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_app_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=fbf04cc6-215b-44ad-afa3-ac0936ce961c>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=be9b21c3-ad9e-4fa1-a6aa-c15bb3a073fc>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
    SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
   ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64) as sil_beta_app_score,
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (67380, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3482830  01581f2b-bef6-46b8-b395-d007da13a99a    60834828300015
# 1    3407427  0435e1f7-0e4a-44e6-96ea-34ffdd0a6b59    60834074270018
# 2    3633011  04b128e3-b372-4263-b01f-4278e3759676    60836330110019
# 3    3690417  07b50802-52c4-4ad2-b99e-56372f49c54b    60836904170015
# 4    3442454  08388dc4-7343-4d69-aa53-2072b7745bbb    60834424540011
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.612420   2025-06-07 11:41:23
# 1  apps_score_model_sil            0.534789   2025-04-28 17:00:20
# 2  apps_score_model_sil            0.547001   2025-08-20 18:47:59
# 3  apps_score_model_sil            0.578306   2025-09-18 10:14:10
# 4  apps_score_model_sil            0.377591   2025-05-17 17:35:36
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-06-07           2025-06           Test         0
# 1       2025-04-28           2025-04           Test         0
# 2       2025-08-20           2025-08           Test         0
# 3       2025-09-18           2025-09           Test         0
# 4       2025-05-17           2025-05           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1  SIL Competitor             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(cast(prediction as string), "'", '"'), "None", "null") AS prediction_clean
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
    ),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  coalesce(prediction, safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64)) as sil_beta_app_score, 
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (258385, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2077104  04936c5e-068b-4c47-a0c3-88bd50395abe    60820771040016
# 1     1876102  04db5a5d-6925-40dc-9c1e-62ce25564f10    60818761020011
# 2     2061921  0f1f0c4b-e188-4105-aa2a-e56e10b31711    60820619210012
# 3     2088064  0f372dba-b9ca-4f89-9547-8e2622709a42    60820880640014
# 4     1949764  21db8a5d-3b8c-4b9e-a241-086eeef139c3    60819497640016
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.540868   2023-06-04 14:26:32
# 1  apps_score_model_sil            0.484696   2023-01-27 18:09:18
# 2  apps_score_model_sil            0.541620   2023-05-26 12:54:30
# 3  apps_score_model_sil            0.416153   2023-06-11 18:00:01
# 4  apps_score_model_sil            0.269918   2023-03-19 10:13:37
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2023-06-04           2023-06          Train         0
# 1       2023-01-27           2023-01          Train         0
# 2       2023-05-26           2023-05          Train         0
# 3       2023-06-11           2023-06          Train         0
# 4       2023-03-19           2023-03          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 3
# 1                 1   SIL-Instore             v1       Trench 2
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (258496, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3634235  6d640f14-ffd2-43a3-b1e4-62ec3e82b5d9    60836342350017
# 1    3594002  7048a31a-1b5e-455a-8823-bb0c63dfea8d    60835940020016
# 2    3343551  fd3767af-fd32-42d6-b702-0253dd90e03d    60833435510019
# 3    3515791  64ea9b1e-fdb6-4559-bbe9-f38484573035    60835157910018
# 4    3731013  1f97ffc6-be84-4f57-9cfd-5fa486b3e277    60837310130019
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.375066   2025-08-26 16:43:52
# 1  apps_score_model_sil            0.466332   2025-09-03 16:30:10
# 2  apps_score_model_sil            0.607208   2025-03-27 16:08:12
# 3  apps_score_model_sil            0.473617   2025-06-23 15:34:51
# 4  apps_score_model_sil            0.401666   2025-10-09 09:49:13
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-08-26           2025-08           Test         1
# 1       2025-09-03           2025-09           Test         0
# 2       2025-03-27           2025-03           Test         0
# 3       2025-06-23           2025-06           Test         0
# 4       2025-10-09           2025-10           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1  SIL Competitor             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 3
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df_concat['sil_beta_app_score'] = pd.to_numeric(df_concat['sil_beta_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_app_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=6d4309f5-0954-44e5-9099-8f2b409b77c4>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=b371f53e-e00f-4bd0-9ee8-0ef7e1ef5679>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
    SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
   ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64) as sil_beta_app_score,
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (52836, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3731820  0163bbad-02f7-4148-930c-9f90c3d19555    60837318200012
# 1    3444648  02d4d655-3fdd-4b54-9bee-c87b59d6e928    60834446480017
# 2    3733572  0500f341-ceda-43f7-a8ac-a34d58a120db    60837335720013
# 3    3469472  1042a713-5cfe-4741-a5d6-893098b1f479    60834694720011
# 4    3739899  175ce377-b0ed-4095-82e5-50ab3663dd7b    60837398990017
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.539612   2025-10-08 17:00:50
# 1  apps_score_model_sil            0.474912   2025-05-18 18:15:12
# 2  apps_score_model_sil            0.584482   2025-10-09 15:57:01
# 3  apps_score_model_sil            0.587749   2025-05-31 13:44:29
# 4  apps_score_model_sil            0.599750   2025-10-12 16:17:49
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-08           2025-10           Test          0
# 1       2025-05-18           2025-05           Test          0
# 2       2025-10-09           2025-10           Test          0
# 3       2025-05-31           2025-05           Test          0
# 4       2025-10-12           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 2
# 1                   1   SIL-Instore             v1       Trench 2
# 2                   1   SIL-Instore             v1       Trench 2
# 3                   1   SIL-Instore             v1       Trench 2
# 4                   1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(cast(prediction as string), "'", '"'), "None", "null") AS prediction_clean
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
    ),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  coalesce(prediction, safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64)) as sil_beta_app_score, 
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (242872, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2474900  00000ad2-697b-49a4-9f16-b177eb3b5f39    60824749000018
# 1     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 2     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 3     2928450  0000598b-5876-42d6-b8fe-0c3d2c321763    60829284500022
# 4     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.701965   2024-04-21 13:49:41
# 1  apps_score_model_sil            0.428914   2025-05-03 11:51:03
# 2  apps_score_model_sil            0.649693   2025-02-25 10:39:01
# 3  apps_score_model_sil            0.255350   2025-06-27 16:48:11
# 4  apps_score_model_sil            0.434053   2024-10-12 15:53:50
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2024-04-21           2024-04          Train          0
# 1       2025-05-03           2025-05          Train          0
# 2       2025-02-25           2025-02          Train          0
# 3       2025-06-27           2025-06          Train          0
# 4       2024-10-12           2024-10          Train          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 2
# 1                   1   SIL-Instore             v2       Trench 1
# 2                   1   SIL-Instore             v2       Trench 1
# 3                   1    SIL Repeat             v2       Trench 3
# 4                   1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4            Mobile

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (242943, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3431236  3b19bc86-07f3-4f35-839d-ebd5c9c9f7f0    60834312360014
# 1    3435452  c9080f44-1a0b-4e44-aeb4-0853679519fc    60834354520016
# 2    3634235  6d640f14-ffd2-43a3-b1e4-62ec3e82b5d9    60836342350017
# 3    2449123  4c59bdbc-c1dc-4828-bb05-bf278d295cf0    60824491230032
# 4    3343551  fd3767af-fd32-42d6-b702-0253dd90e03d    60833435510019
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.607208   2025-05-11 13:56:41
# 1  apps_score_model_sil            0.607208   2025-05-13 17:54:17
# 2  apps_score_model_sil            0.375066   2025-08-26 16:43:52
# 3  apps_score_model_sil            0.616544   2025-10-06 14:35:56
# 4  apps_score_model_sil            0.607208   2025-03-27 16:08:12
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-05-11           2025-05           Test          0
# 1       2025-05-13           2025-05           Test          0
# 2       2025-08-26           2025-08           Test          1
# 3       2025-10-06           2025-10           Test          0
# 4       2025-03-27           2025-03           Test          0
#
#    flg_mature_fspd_30   new_loan_type modelVersionId trenchCategory  \
# 0                   1     SIL-Instore             v1       Trench 2
# 1                   1     SIL-Instore             v1       Trench 2
# 2                   1  SIL Competitor             v1       Trench 2
# 3                   1     SIL-Instore             v1       Trench 3
# 4                   1     SIL-Instore             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
df_concat['sil_beta_app_score'] = pd.to_numeric(df_concat['sil_beta_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_app_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=df45c6e9-32e6-4dc0-8928-77e678a52717>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=1536dbd2-bc32-413f-9d9d-6df3b768a952>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
    SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
   FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
   ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64) as sil_beta_app_score,
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (40675, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3405059  0613ed6a-52ff-4908-a4c0-30233a74fe09    60834050590016
# 1    3672838  191c0072-c09f-4631-b379-a1b032f40a53    60836728380011
# 2    3679572  327e822b-d83b-4f8e-8afa-f3b38a18cfd2    60836795720011
# 3    3674932  39766ecf-3467-4da2-8f15-bf1245715e44    60836749320015
# 4    3420790  4174b945-bb58-43ec-a272-6e464b03ba6a    60834207900016
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.521665   2025-04-27 13:51:27
# 1  apps_score_model_sil            0.518952   2025-09-08 17:47:13
# 2  apps_score_model_sil            0.546923   2025-09-12 14:14:39
# 3  apps_score_model_sil            0.394333   2025-09-09 19:20:16
# 4  apps_score_model_sil            0.583378   2025-05-05 12:02:52
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-04-27           2025-04           Test           0
# 1       2025-09-08           2025-09           Test           0
# 2       2025-09-12           2025-09           Test           0
# 3       2025-09-09           2025-09           Test           0
# 4       2025-05-05           2025-05           Test           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1   SIL-Instore             v1       Trench 2
# 2                    1   SIL-Instore             v1       Trench 2
# 3                    1   SIL-Instore             v1       Trench 2
# 4                    1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3              Mall
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    REPLACE(REPLACE(cast(prediction as string), "'", '"'), "None", "null") AS prediction_clean
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - AppsScoreModel', 'apps_score_model_sil')
    ),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  coalesce(prediction, safe_cast(JSON_VALUE(prediction_clean, "$.combined_score") AS float64)) as sil_beta_app_score, 
  case when modelDisplayName = 'Beta - AppsScoreModel' then 'apps_score_model_sil'
       else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_app_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (229641, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2474900  00000ad2-697b-49a4-9f16-b177eb3b5f39    60824749000018
# 1     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 2     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 3     2928450  0000598b-5876-42d6-b8fe-0c3d2c321763    60829284500022
# 4     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.701965   2024-04-21 13:49:41
# 1  apps_score_model_sil            0.428914   2025-05-03 11:51:03
# 2  apps_score_model_sil            0.649693   2025-02-25 10:39:01
# 3  apps_score_model_sil            0.255350   2025-06-27 16:48:11
# 4  apps_score_model_sil            0.434053   2024-10-12 15:53:50
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-04-21           2024-04          Train           1
# 1       2025-05-03           2025-05          Train           0
# 2       2025-02-25           2025-02          Train           0
# 3       2025-06-27           2025-06          Train           0
# 4       2024-10-12           2024-10          Train           1
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1   SIL-Instore             v2       Trench 1
# 2                    1   SIL-Instore             v2       Trench 1
# 3                    1    SIL Repeat             v2       Trench 3
# 4                    1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4            Mobile

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (229681, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3358816  b22207e8-7643-41e8-a199-9842bde1ae8d    60833588160011
# 1    3669444  3de74d78-bcde-4b83-8883-506a8a431be4    60836694440019
# 2    3678282  a587b4a4-689b-4ec1-b603-9580e42e34e0    60836782820011
# 3    3343551  fd3767af-fd32-42d6-b702-0253dd90e03d    60833435510019
# 4    3435452  c9080f44-1a0b-4e44-aeb4-0853679519fc    60834354520016
#
#        modelDisplayName  sil_beta_app_score appln_submit_datetime  \
# 0  apps_score_model_sil            0.673509   2025-04-04 12:31:28
# 1  apps_score_model_sil            0.506825   2025-09-10 09:24:41
# 2  apps_score_model_sil            0.542384   2025-09-12 11:59:37
# 3  apps_score_model_sil            0.607208   2025-03-27 16:08:12
# 4  apps_score_model_sil            0.607208   2025-05-13 17:54:17
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-04-04           2025-04           Test           0
# 1       2025-09-10           2025-09           Test           0
# 2       2025-09-12           2025-09           Test           0
# 3       2025-03-27           2025-03           Test           0
# 4       2025-05-13           2025-05           Test           1
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1   SIL-Instore             v1       Trench 2
# 2                    1   SIL-Instore             v1       Trench 2
# 3                    1   SIL-Instore             v1       Trench 3
# 4                    1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
df_concat['sil_beta_app_score'] = pd.to_numeric(df_concat['sil_beta_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_app_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_model_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (18832, 16)
# The shape of the dimension table is:	 (370, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=31065bca-4f41-4a3e-b3aa-c11955630acf>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=898f7bf4-1d6c-4741-90e2-abcb73c05aad>

# %% [markdown]
# ## Beta SIL Demo Score

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
    SELECT
  mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details` mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (99180, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3648385  00d778c1-695c-41b5-9c77-bfb732596991    60836483850011
# 1    3831839  0119ea64-6303-423c-ba87-b5bdbb57f385    60838318390019
# 2    3546070  01c2c1f7-5451-4040-9f9d-588b954ed520    60835460700011
# 3    3643317  024c7b89-a95d-407e-a1a6-78c400748888    60836433170019
# 4    3575319  031ae8c8-e0aa-4fe0-83b8-e96abde9bc03    60835753190018
#
#       modelDisplayName sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil        0.0423553589   2025-08-28 17:28:02
# 1  beta_demo_model_sil         0.050745067   2025-11-24 08:59:53
# 2  beta_demo_model_sil        0.0774971391   2025-12-10 13:21:31
# 3  beta_demo_model_sil        0.0212952282   2025-08-25 17:33:02
# 4  beta_demo_model_sil        0.0968575817   2025-07-24 12:41:42
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-08-28           2025-08           Test        0                1
# 1       2025-11-24           2025-11           Test        0                1
# 2       2025-12-10           2025-12           Test        0                1
# 3       2025-08-25           2025-08           Test        0                1
# 4       2025-07-24           2025-07           Test        0                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0     SIL-Instore             v1       Trench 2         Appliance
# 1     SIL-Instore             v1       Trench 2         Appliance
# 2     SIL-Instore             v1       Trench 2         Appliance
# 3  SIL Competitor             v1       Trench 2              Mall
# 4     SIL-Instore             v1       Trench 2              Mall

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
    SELECT
  mmrd.customerId, mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  case when modelDisplayName = 'Beta - DemoScoreModel' then 'beta_demo_model_sil' else modelDisplayName end as modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (416110, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     1928157  0455b0e5-3195-4909-814b-ab7f888c9079    60819281570015
# 1     1739400  0ab59830-7c02-4311-849b-82262953b412    60817394000014
# 2     1848860  1170703d-d5a4-47f8-b651-d6638e055636    60818488600023
# 3     1937284  12567ae1-ffde-4393-93cc-379cd1356939    60819372840012
# 4     1909004  1313c20e-fe00-4044-8ddf-366510a688dc    60819090040013
#
#       modelDisplayName  sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil             0.056042   2023-03-04 18:49:29
# 1  beta_demo_model_sil             0.204139   2023-05-02 14:29:33
# 2  beta_demo_model_sil             0.214802   2023-04-22 18:39:11
# 3  beta_demo_model_sil             0.126978   2023-03-10 14:32:32
# 4  beta_demo_model_sil             0.062717   2023-02-20 14:29:15
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2023-03-04           2023-03          Train        0                1
# 1       2023-05-02           2023-05          Train        0                1
# 2       2023-04-22           2023-04          Train        0                1
# 3       2023-03-10           2023-03          Train        0                1
# 4       2023-02-20           2023-02          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0   SIL-Instore             v1       Trench 2         Appliance
# 1   SIL-Instore             v1       Trench 3         Appliance
# 2   SIL-Instore             v1       Trench 3         Appliance
# 3   SIL-Instore             v1       Trench 2         Appliance
# 4   SIL-Instore             v1       Trench 3         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (452094, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3831839  0119ea64-6303-423c-ba87-b5bdbb57f385    60838318390019
# 1    3546070  01c2c1f7-5451-4040-9f9d-588b954ed520    60835460700011
# 2    3760045  05f27935-15c2-4725-8e12-ed88d0a9c148    60837600450018
# 3    3791029  061f969b-1f10-4d7e-b0b1-c53d7ae002b8    60837910290017
# 4    3762571  0e0d490b-3d35-4e5c-9226-fd672ae91e49    60837625710013
#
#       modelDisplayName sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil         0.050745067   2025-11-24 08:59:53
# 1  beta_demo_model_sil        0.0774971391   2025-12-10 13:21:31
# 2  beta_demo_model_sil        0.0381586431   2025-10-22 09:48:52
# 3  beta_demo_model_sil        0.1245893342   2025-11-04 14:52:24
# 4  beta_demo_model_sil        0.0165425188   2025-10-23 12:24:04
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-11-24           2025-11           Test        0                1
# 1       2025-12-10           2025-12           Test        0                1
# 2       2025-10-22           2025-10           Test        0                1
# 3       2025-11-04           2025-11           Test        0                1
# 4       2025-10-23           2025-10           Test        0                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0     SIL-Instore             v1       Trench 2         Appliance
# 1     SIL-Instore             v1       Trench 2         Appliance
# 2     SIL-Instore             v1       Trench 2         Appliance
# 3  SIL Competitor             v1       Trench 2              Mall
# 4     SIL-Instore             v1       Trench 2         Appliance

# %%
df_concat['sil_beta_demo_score'] = pd.to_numeric(df_concat['sil_beta_demo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_demo_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (24709, 16)
# The shape of the dimension table is:	 (473, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=3224e117-ac95-4280-85d6-cf3c35db8cb2>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=5b8c075c-7f87-49af-bee8-53f0fa674881>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
     SELECT
  mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details` mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (90512, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3531887  0005471e-bc26-44ff-9321-bef640c21db8    60835318870019
# 1    3719494  016b7cdd-0857-4725-88c1-f75efc097d40    60837194940011
# 2    3763309  017438f7-e4ec-4330-9258-db1482354d4a    60837633090015
# 3    3692479  019ef78a-eb15-43f4-a6d6-3175873aec5c    60836924790017
# 4    3680867  01bc6d39-0518-4812-bede-1ac1a7a0d36b    60836808670012
#
#       modelDisplayName sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil        0.0732822878   2025-07-01 15:27:20
# 1  beta_demo_model_sil        0.0492604296   2025-10-02 19:24:16
# 2  beta_demo_model_sil        0.0850597885   2025-10-23 16:00:20
# 3  beta_demo_model_sil        0.0459348553   2025-09-19 13:02:08
# 4  beta_demo_model_sil        0.0658705752   2025-09-13 11:00:33
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-07-01           2025-07           Test         0
# 1       2025-10-02           2025-10           Test         0
# 2       2025-10-23           2025-10           Test         0
# 3       2025-09-19           2025-09           Test         0
# 4       2025-09-13           2025-09           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
    SELECT
  mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  case when modelDisplayName = 'Beta - DemoScoreModel' then 'beta_demo_model_sil' else modelDisplayName end as modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (416110, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2122333  01e266e4-fc43-47a5-84a3-d2119df7e6ef    60821223330018
# 1     2051732  04f1b256-0efe-40b5-a9c9-0054b04b52fe    60820517320014
# 2     1991253  05fe853f-917a-44d7-85d6-1d87b2e74104    60819912530011
# 3     2152935  08298315-5597-4d20-baae-d73c63623c53    60821529350013
# 4     2012964  0cdd312a-4356-41c1-ae67-08f287a01210    60820129640012
#
#       modelDisplayName  sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil             0.059688   2023-07-06 17:36:47
# 1  beta_demo_model_sil             0.120532   2023-05-19 14:51:59
# 2  beta_demo_model_sil             0.110817   2023-04-14 14:23:46
# 3  beta_demo_model_sil             0.098513   2023-07-24 11:40:30
# 4  beta_demo_model_sil             0.122696   2023-04-25 11:17:34
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2023-07-06           2023-07          Train         0
# 1       2023-05-19           2023-05          Train         0
# 2       2023-04-14           2023-04          Train         0
# 3       2023-07-24           2023-07          Train         0
# 4       2023-04-25           2023-04          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 3
# 1                 1   SIL-Instore             v1       Trench 3
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (443426, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3763309  017438f7-e4ec-4330-9258-db1482354d4a    60837633090015
# 1    3851530  08fc4c45-f23c-41b5-b3e0-46da549e6380    60838515300011
# 2    3832003  0bc3ceaf-e380-4833-ae9f-9b65284ba172    60838320030025
# 3    3760724  0e2cab09-8813-433d-854c-6d3d1c69f37b    60837607240014
# 4    3790835  114cb617-8084-4439-a8d5-914265041fe3    60837908350015
#
#       modelDisplayName sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil        0.0850597885   2025-10-23 16:00:20
# 1  beta_demo_model_sil        0.0573140515   2025-12-01 14:56:37
# 2  beta_demo_model_sil        0.0658525993   2025-11-24 14:43:29
# 3  beta_demo_model_sil        0.0749405435   2025-10-22 14:48:13
# 4  beta_demo_model_sil         0.110650098   2025-11-04 13:33:29
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-23           2025-10           Test         0
# 1       2025-12-01           2025-12           Test         0
# 2       2025-11-24           2025-11           Test         1
# 3       2025-10-22           2025-10           Test         0
# 4       2025-11-04           2025-11           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 2
# 1                 1   SIL-Instore             v1       Trench 2
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df_concat['sil_beta_demo_score'] = pd.to_numeric(df_concat['sil_beta_demo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_demo_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=27b32122-b26e-4ba3-bb5c-3cb197b4fd46>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=fd452e21-07ae-4c3c-a071-689ef10b4b12>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
 SELECT
  mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details` mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (76472, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3397661  053f86c8-f700-410e-bd9c-da959c66a0b1    60833976610015
# 1    3702612  05487bcd-0dff-411b-a10f-c491abc8fb89    60837026120015
# 2    3490953  05f0ca95-f76d-4e56-bae3-4cafc1217f6e    60834909530012
# 3    3674237  0751adbc-4a66-4178-9695-1491edc3676a    60836742370019
# 4    3347055  0b04b110-4c7d-48e4-825c-d00e1736ab52    60833470550014
#
#       modelDisplayName sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil        0.0454950859   2025-04-23 16:48:45
# 1  beta_demo_model_sil        0.0554708527   2025-09-24 14:42:09
# 2  beta_demo_model_sil        0.0433316516   2025-06-11 14:38:48
# 3  beta_demo_model_sil        0.0239419968   2025-09-09 14:25:07
# 4  beta_demo_model_sil        0.0272240238   2025-03-29 14:58:28
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-04-23           2025-04           Test         0
# 1       2025-09-24           2025-09           Test         0
# 2       2025-06-11           2025-06           Test         0
# 3       2025-09-09           2025-09           Test         0
# 4       2025-03-29           2025-03           Test         1
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1        SIL ZERO             v1       Trench 3
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 3
# 3                 1  SIL Competitor             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
    SELECT
  mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
   case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  case when modelDisplayName = 'Beta - DemoScoreModel' then 'beta_demo_model_sil' else modelDisplayName end as modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (416110, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2138481  019c0e96-d529-4c86-bf71-240b9f045856    60821384810018
# 1     2123614  032920fd-d499-4d70-ace9-88fca5600b9c    60821236140018
# 2     2120659  065b5161-0246-4da2-abf7-4b2dd21dc03d    60821206590019
# 3     2115171  0d999748-19c0-4b58-ba79-6d70c9c149fb    60821151710015
# 4     1869151  18eb9d4d-c04e-442e-a84f-42d80e218b93    60818691510017
#
#       modelDisplayName  sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil             0.094912   2023-07-15 15:18:38
# 1  beta_demo_model_sil             0.200733   2023-07-07 14:16:44
# 2  beta_demo_model_sil             0.096518   2023-07-05 17:19:01
# 3  beta_demo_model_sil             0.100895   2023-07-01 15:44:00
# 4  beta_demo_model_sil             0.104392   2023-01-21 15:57:09
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2023-07-15           2023-07          Train         0
# 1       2023-07-07           2023-07          Train         0
# 2       2023-07-05           2023-07          Train         0
# 3       2023-07-01           2023-07          Train         1
# 4       2023-01-23           2023-01          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 2
# 1                 1   SIL-Instore             v1       Trench 3
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (429386, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3799006  18a0c53a-cf4d-4ac6-9f94-e3eb0501fb92    60837990060012
# 1    3803479  1ee32157-8085-4236-88ef-242ea629748b    60838034790018
# 2    3800993  20eb8523-8d21-4bb1-9665-a8a1112dcffc    60838009930019
# 3    3806223  5228ef0b-a91a-4ce9-ae51-6b4a2c12aca6    60838062230018
# 4    3807129  577a942d-e0db-4269-a38b-464d7d19c8f0    60838071290015
#
#       modelDisplayName sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil        0.1184247623   2025-11-08 13:11:34
# 1  beta_demo_model_sil        0.0449691536   2025-11-10 18:07:10
# 2  beta_demo_model_sil        0.0521659699   2025-11-09 13:39:49
# 3  beta_demo_model_sil        0.0615768944   2025-11-12 11:07:13
# 4  beta_demo_model_sil        0.0267036182   2025-11-12 18:08:52
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-11-08           2025-11           Test         0
# 1       2025-11-10           2025-11           Test         0
# 2       2025-11-09           2025-11           Test         0
# 3       2025-11-12           2025-11           Test         0
# 4       2025-11-12           2025-11           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
df_concat['sil_beta_demo_score'] = pd.to_numeric(df_concat['sil_beta_demo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_demo_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=3dbf79ee-4861-4f4c-bbfb-6348d73b658a>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=b8f69b07-4516-4d1d-affd-2260891ad863>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
     SELECT
  mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details` mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (60000, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3644286  01e222fd-14a4-4781-ad64-3c0fc991ee98    60836442860013
# 1    3727140  1155601e-2177-4e86-9f6f-3778eed81bd1    60837271400014
# 2    3727212  1209ccd5-0493-47ea-a8c2-88400860837d    60837272120013
# 3    2802023  154e79e2-3945-46d1-b4df-89176090ab5d    60828020230027
# 4    3144771  20fea0e1-e2c4-4e94-b7d4-ff41b19165d2    60831447710011
#
#       modelDisplayName sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil        0.0235984179   2025-08-26 11:11:54
# 1  beta_demo_model_sil        0.0446735532   2025-10-06 13:37:32
# 2  beta_demo_model_sil        0.0713353751   2025-10-06 14:05:07
# 3  beta_demo_model_sil        0.1506033094   2025-08-26 17:19:38
# 4  beta_demo_model_sil        0.0941866419   2025-08-26 20:03:26
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-08-26           2025-08           Test          0
# 1       2025-10-06           2025-10           Test          0
# 2       2025-10-06           2025-10           Test          0
# 3       2025-08-26           2025-08           Test          0
# 4       2025-08-26           2025-08           Test          0
#
#    flg_mature_fspd_30   new_loan_type modelVersionId trenchCategory  \
# 0                   1  SIL Competitor             v1       Trench 2
# 1                   1  SIL Competitor             v1       Trench 2
# 2                   1     SIL-Instore             v1       Trench 2
# 3                   1  SIL Competitor             v1       Trench 3
# 4                   1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
    SELECT
  mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
    case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  case when modelDisplayName = 'Beta - DemoScoreModel' then 'beta_demo_model_sil' else modelDisplayName end as modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (412914, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2474900  00000ad2-697b-49a4-9f16-b177eb3b5f39    60824749000018
# 1     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 2     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
#
#       modelDisplayName  sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil             0.095036   2024-04-21 13:49:41
# 1  beta_demo_model_sil             0.555774   2025-05-03 11:51:03
# 2  beta_demo_model_sil             0.341274   2025-02-25 10:39:01
# 3  beta_demo_model_sil             0.128286   2024-10-12 15:53:50
# 4  beta_demo_model_sil             0.606946   2024-10-12 15:53:50
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2024-04-21           2024-04          Train          0
# 1       2025-05-03           2025-05          Train          0
# 2       2025-02-25           2025-02          Train          0
# 3       2024-10-12           2024-10          Train          1
# 4       2024-10-12           2024-10          Train          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 2
# 1                   1   SIL-Instore             v2       Trench 1
# 2                   1   SIL-Instore             v2       Trench 1
# 3                   1   SIL-Instore             v1       Trench 2
# 4                   1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3            Mobile
# 4            Mobile

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()

# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (412914, 15)
# C:\Users\Dwaipayan\AppData\Local\Temp\ipykernel_49316\436855073.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2474900  00000ad2-697b-49a4-9f16-b177eb3b5f39    60824749000018
# 1     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 2     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
#
#       modelDisplayName  sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil             0.095036   2024-04-21 13:49:41
# 1  beta_demo_model_sil             0.555774   2025-05-03 11:51:03
# 2  beta_demo_model_sil             0.341274   2025-02-25 10:39:01
# 3  beta_demo_model_sil             0.128286   2024-10-12 15:53:50
# 4  beta_demo_model_sil             0.606946   2024-10-12 15:53:50
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2024-04-21           2024-04          Train          0
# 1       2025-05-03           2025-05          Train          0
# 2       2025-02-25           2025-02          Train          0
# 3       2024-10-12           2024-10          Train          1
# 4       2024-10-12           2024-10          Train          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 2
# 1                   1   SIL-Instore             v2       Trench 1
# 2                   1   SIL-Instore             v2       Trench 1
# 3                   1   SIL-Instore             v1       Trench 2
# 4                   1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3            Mobile
# 4            Mobile

# %%
df_concat['sil_beta_demo_score'] = pd.to_numeric(df_concat['sil_beta_demo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_demo_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_sil', product='SIL')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=a96bfa24-7c22-4625-9a07-800b3a686f40>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=6fe7aa1b-f5a5-4aee-9c7a-fca86f6081e4>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH cleaned AS (
SELECT
  mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details` mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (46290, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3679992  03b9188d-3d29-4b17-ad77-0a238177a952    60836799920017
# 1    3391797  060789ef-6dd3-4c38-bb40-17c53429617a    60833917970016
# 2    3428249  124eaf99-5349-4262-bcab-e7c25a28b3b1    60834282490012
# 3    3405404  1891ece0-ae42-4a9b-b9f2-fae4eab7eb15    60834054040013
# 4    3443934  2799b2d1-b269-400a-a854-6e808b0421e3    60834439340016
#
#       modelDisplayName sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil        0.0473237493   2025-09-12 17:16:41
# 1  beta_demo_model_sil        0.0653057251   2025-04-20 18:54:37
# 2  beta_demo_model_sil        0.0553066583   2025-05-09 17:32:16
# 3  beta_demo_model_sil        0.0685245153   2025-04-27 15:38:25
# 4  beta_demo_model_sil        0.1257699341   2025-05-18 14:39:19
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-09-12           2025-09           Test           0
# 1       2025-04-20           2025-04           Test           0
# 2       2025-05-09           2025-05           Test           0
# 3       2025-04-27           2025-04           Test           0
# 4       2025-05-18           2025-05           Test           1
#
#    flg_mature_fstpd_30   new_loan_type modelVersionId trenchCategory  \
# 0                    1  SIL Competitor             v1       Trench 2
# 1                    1     SIL-Instore             v1       Trench 2
# 2                    1     SIL-Instore             v1       Trench 2
# 3                    1     SIL-Instore             v1       Trench 2
# 4                    1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1              Mall
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH cleaned AS (
  SELECT
  mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId,
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature_cleaned
  FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
    left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - DemoScoreModel', 'beta_demo_model_sil')
  ), 
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction sil_beta_demo_score,
  case when modelDisplayName = 'Beta - DemoScoreModel' then 'beta_demo_model_sil' else modelDisplayName end as modelDisplayName,
  modelVersionId, trenchCategory,
  from cleaned
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.sil_beta_demo_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.sil_beta_demo_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (399196, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2474900  00000ad2-697b-49a4-9f16-b177eb3b5f39    60824749000018
# 1     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 2     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
#
#       modelDisplayName  sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil             0.095036   2024-04-21 13:49:41
# 1  beta_demo_model_sil             0.555774   2025-05-03 11:51:03
# 2  beta_demo_model_sil             0.341274   2025-02-25 10:39:01
# 3  beta_demo_model_sil             0.128286   2024-10-12 15:53:50
# 4  beta_demo_model_sil             0.606946   2024-10-12 15:53:50
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-04-21           2024-04          Train           1
# 1       2025-05-03           2025-05          Train           0
# 2       2025-02-25           2025-02          Train           0
# 3       2024-10-12           2024-10          Train           1
# 4       2024-10-12           2024-10          Train           1
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1   SIL-Instore             v2       Trench 1
# 2                    1   SIL-Instore             v2       Trench 1
# 3                    1   SIL-Instore             v1       Trench 2
# 4                    1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3            Mobile
# 4            Mobile

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()

# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (399196, 15)
# C:\Users\Dwaipayan\AppData\Local\Temp\ipykernel_49316\436855073.py:19: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2474900  00000ad2-697b-49a4-9f16-b177eb3b5f39    60824749000018
# 1     3416713  0000292e-4628-4120-be9c-cd8a64094384    60834167130012
# 2     3286380  0000361b-31f7-45ef-8bb4-7f7962e1a381    60832863800014
# 3     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
# 4     2933855  0000725a-1bdb-4e5e-a464-888cf53f3dbb    60829338550016
#
#       modelDisplayName  sil_beta_demo_score appln_submit_datetime  \
# 0  beta_demo_model_sil             0.095036   2024-04-21 13:49:41
# 1  beta_demo_model_sil             0.555774   2025-05-03 11:51:03
# 2  beta_demo_model_sil             0.341274   2025-02-25 10:39:01
# 3  beta_demo_model_sil             0.128286   2024-10-12 15:53:50
# 4  beta_demo_model_sil             0.606946   2024-10-12 15:53:50
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-04-21           2024-04          Train           1
# 1       2025-05-03           2025-05          Train           0
# 2       2025-02-25           2025-02          Train           0
# 3       2024-10-12           2024-10          Train           1
# 4       2024-10-12           2024-10          Train           1
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1   SIL-Instore             v2       Trench 1
# 2                    1   SIL-Instore             v2       Trench 1
# 3                    1   SIL-Instore             v1       Trench 2
# 4                    1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3            Mobile
# 4            Mobile

# %%
df_concat['sil_beta_demo_score'] = pd.to_numeric(df_concat['sil_beta_demo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'sil_beta_demo_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (21422, 16)
# The shape of the dimension table is:	 (352, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=3c983017-200b-489a-b9a2-ca30921874d0>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=ef7817bf-4809-46d6-b048-b5f90613f363>

# %% [markdown]
# # alpha_stack_model_sil_credo_score

# %% [markdown]
# ## FPD0

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (65827, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3509194  0007aa60-32b3-4af2-9818-76887a7d96bf    60835091940014
# 1    3446061  01f5b185-ca94-4b7e-9055-d1e49d791922    60834460610014
# 2    3702724  02e92229-4593-4dfa-a009-d240f25d07da    60837027240012
# 3    3562240  0346961c-19dc-4a5a-93c4-86747df5d3bf    60835622400015
# 4    3557171  045aa047-ad38-4bd0-81ed-1c312ea8a6e8    60835571710014
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.0621
# 1  alpha_stack_model_sil       0.1253
# 2  alpha_stack_model_sil       0.1217
# 3  alpha_stack_model_sil       0.0963
# 4  alpha_stack_model_sil       0.0479
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.0912772388, "s_cic_score":...   2025-06-20 14:06:11
# 1  {"sb_demo_score": 0.1466409212, "s_cic_score":...   2025-05-19 15:14:32
# 2  {"sb_demo_score": 0.0439277901, "s_cic_score":...   2025-09-24 15:11:08
# 3  {"sb_demo_score": 0.1581778635, "s_cic_score":...   2025-07-17 14:43:09
# 4  {"sb_demo_score": 0.0263165942, "s_cic_score":...   2025-07-14 18:47:27
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-06-20           2025-06           Test        0                1
# 1       2025-05-19           2025-05           Test        0                1
# 2       2025-09-24           2025-09           Test        0                1
# 3       2025-07-17           2025-07           Test        0                1
# 4       2025-07-14           2025-07           Test        1                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0  SIL Competitor             v1       Trench 2              Mall
# 1     SIL-Instore             v1       Trench 2         Appliance
# 2     SIL-Instore             v1       Trench 2         Appliance
# 3  SIL Competitor             v1       Trench 2         Appliance
# 4  SIL Competitor             v1       Trench 2         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (283527, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2248548  03e62c01-681f-4add-8e56-ab76371b8e99    60822485480011
# 1     2042626  04560413-0770-4f4d-a0d6-3c6787d2ebf1    60820426260012
# 2     2248930  05c0ac88-1d86-4574-88c2-d70378238bf2    60822489300013
# 3     2229579  0f589322-710e-4bb6-b819-a3d584dc8372    60822295790012
# 4     2182816  1affa353-00cc-4b40-bd5b-21d2d37931b7    60821828160012
#
#         modelDisplayName  credo_score  \
# 0  Alpha - StackingModel     0.092363
# 1  Alpha - StackingModel     0.172322
# 2  Alpha - StackingModel     0.073723
# 3  Alpha - StackingModel     0.099906
# 4  Alpha - StackingModel     0.098554
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.19990418101635965, "s_cic_...   2023-09-26 09:56:48
# 1  {"sb_demo_score": 0.07418245976383668, "s_cic_...   2023-05-13 16:38:05
# 2  {"sb_demo_score": 0.07112799599395424, "s_cic_...   2023-09-26 14:25:31
# 3  {"sb_demo_score": 0.05769897469537977, "s_cic_...   2023-09-11 14:43:43
# 4  {"sb_demo_score": 0.07338665226627737, "s_cic_...   2024-02-01 11:49:12
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2023-09-26           2023-09          Train        0                1
# 1       2023-05-13           2023-05          Train        0                1
# 2       2023-09-26           2023-09          Train        0                1
# 3       2023-09-11           2023-09          Train        0                1
# 4       2024-02-01           2024-02          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0   SIL-Instore             v1       Trench 3         Appliance
# 1   SIL-Instore             v1       Trench 2         Appliance
# 2   SIL-Instore             v1       Trench 2         Appliance
# 3   SIL-Instore             v1       Trench 2         Appliance
# 4   SIL-Instore             v1       Trench 2         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (308762, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3791286  129c2930-f350-41e3-aa6f-623b67636045    60837912860012
# 1    3877353  16c53a30-48fb-4fce-8535-772cc572dd95    60838773530016
# 2    3881814  1f34b2d7-3cf9-435a-b2ac-2dfe61550447    60838818140015
# 3    3745429  22f77aec-28bc-42d4-b736-fbb279082cc2    60837454290011
# 4    3791219  24d4ecc3-eac6-46bd-b866-bb534f841339    60837912190011
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.1211
# 1  alpha_stack_model_sil       0.0711
# 2  alpha_stack_model_sil       0.0790
# 3  alpha_stack_model_sil       0.1131
# 4  alpha_stack_model_sil       0.1143
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.0447030965, "s_cic_score":...   2025-11-04 16:20:30
# 1  {"sb_demo_score": 0.5828270026, "apps_score": ...   2025-12-09 13:48:24
# 2  {"sb_demo_score": 0.0632904105, "s_cic_score":...   2025-12-10 16:44:14
# 3  {"sb_demo_score": 0.0286716927, "s_cic_score":...   2025-10-15 11:01:43
# 4  {"sb_demo_score": 0.081871201, "s_cic_score": ...   2025-11-04 16:00:54
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-11-04           2025-11           Test        0                1
# 1       2025-12-09           2025-12           Test        0                1
# 2       2025-12-10           2025-12           Test        0                1
# 3       2025-10-15           2025-10           Test        0                1
# 4       2025-11-04           2025-11           Test        0                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0     SIL-Instore             v1       Trench 2              Mall
# 1  SIL Competitor             v2       Trench 1         Appliance
# 2  SIL Competitor             v1       Trench 2         Appliance
# 3  SIL Competitor             v1       Trench 2         Appliance
# 4     SIL-Instore             v1       Trench 2         Appliance

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (25456, 16)
# The shape of the dimension table is:	 (473, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=c5ba2a4f-f8d4-4992-b3cf-1c9080d3066b>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=1788515c-dea7-4c14-acf0-582e1cea7973>

# %% [markdown]
# ## FPD10

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd10 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (59700, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3446061  01f5b185-ca94-4b7e-9055-d1e49d791922    60834460610014
# 1    3702724  02e92229-4593-4dfa-a009-d240f25d07da    60837027240012
# 2    3562240  0346961c-19dc-4a5a-93c4-86747df5d3bf    60835622400015
# 3    3557171  045aa047-ad38-4bd0-81ed-1c312ea8a6e8    60835571710014
# 4    1050919  047365c4-86c7-4045-88a6-796d67680b6a    60810509190038
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.1253
# 1  alpha_stack_model_sil       0.1217
# 2  alpha_stack_model_sil       0.0963
# 3  alpha_stack_model_sil       0.0479
# 4  alpha_stack_model_sil       0.1031
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.1466409212, "s_cic_score":...   2025-05-19 15:14:32
# 1  {"sb_demo_score": 0.0439277901, "s_cic_score":...   2025-09-24 15:11:08
# 2  {"sb_demo_score": 0.1581778635, "s_cic_score":...   2025-07-17 14:43:09
# 3  {"sb_demo_score": 0.0263165942, "s_cic_score":...   2025-07-14 18:47:27
# 4  {"sb_demo_score": 0.1402829508, "s_cic_score":...   2025-06-07 18:11:02
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-05-19           2025-05           Test         0
# 1       2025-09-24           2025-09           Test         0
# 2       2025-07-17           2025-07           Test         0
# 3       2025-07-14           2025-07           Test         0
# 4       2025-06-07           2025-06           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1  SIL Competitor             v1       Trench 2
# 3                 1  SIL Competitor             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd10 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (283527, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     1863854  03482e86-3d11-43b6-9a2d-bcb814e8e1a9    60818638540017
# 1     2263827  06faffc9-8769-4bf3-bd4c-67993947439f    60822638270015
# 2     1974084  071f2bc6-dbf5-4fd8-ac0d-b8c8c560e149    60819740840014
# 3     2182831  078d81e0-b73d-4e2f-9660-f053e2492e40    60821828310011
# 4     2390602  07f9ca1e-e2e4-4301-a3e9-b4902976d345    60823906020019
#
#         modelDisplayName  credo_score  \
# 0  Alpha - StackingModel     0.130932
# 1  Alpha - StackingModel     0.066249
# 2  Alpha - StackingModel     0.093220
# 3  Alpha - StackingModel     0.109841
# 4  Alpha - StackingModel     0.107901
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.04992837448369349, "s_cic_...   2023-01-16 18:33:36
# 1  {"sb_demo_score": 0.11682525669318071, "s_cic_...   2023-10-07 17:38:19
# 2  {"sb_demo_score": 0.09043354801601024, "s_cic_...   2023-04-02 15:05:25
# 3  {"sb_demo_score": 0.09889921670622359, "s_cic_...   2023-08-10 17:14:17
# 4  {"sb_demo_score": 0.027181182671235215, "s_cic...   2024-02-05 12:17:08
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2023-01-16           2023-01          Train         0
# 1       2023-10-07           2023-10          Train         0
# 2       2023-04-02           2023-04          Train         0
# 3       2023-08-10           2023-08          Train         0
# 4       2024-02-05           2024-02          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 2
# 1                 1   SIL-Instore             v1       Trench 3
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v1       Trench 3
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (302635, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3791286  129c2930-f350-41e3-aa6f-623b67636045    60837912860012
# 1    3745429  22f77aec-28bc-42d4-b736-fbb279082cc2    60837454290011
# 2    3791219  24d4ecc3-eac6-46bd-b866-bb534f841339    60837912190011
# 3    2772233  27eb77b5-58f2-4618-8cd9-b1c9771edec1    60827722330016
# 4    3752056  2dc49ff5-8b85-4425-84c6-fe476bac2a47    60837520560014
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.1211
# 1  alpha_stack_model_sil       0.1131
# 2  alpha_stack_model_sil       0.1143
# 3  alpha_stack_model_sil       0.1735
# 4  alpha_stack_model_sil       0.1912
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.0447030965, "s_cic_score":...   2025-11-04 16:20:30
# 1  {"sb_demo_score": 0.0286716927, "s_cic_score":...   2025-10-15 11:01:43
# 2  {"sb_demo_score": 0.081871201, "s_cic_score": ...   2025-11-04 16:00:54
# 3  {"sb_demo_score": 0.2819415944, "s_cic_score":...   2025-11-24 18:05:05
# 4  {"sb_demo_score": 0.0858799139, "s_cic_score":...   2025-10-18 13:26:14
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-11-04           2025-11           Test         0
# 1       2025-10-15           2025-10           Test         0
# 2       2025-11-04           2025-11           Test         0
# 3       2025-11-24           2025-11           Test         0
# 4       2025-10-21           2025-10           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (24994, 16)
# The shape of the dimension table is:	 (449, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=858ad0be-5b72-4cde-87ef-01fd35c5ee23>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=30e7cf69-24f9-47f8-a20f-2fea688c6b39>

# %% [markdown]
# ## FPD30

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (50385, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3675949  02772349-b50e-4d16-832e-0365c0365562    60836759490018
# 1    2744135  02e4edb7-a5de-4415-a034-07b63370b61b    60827441350026
# 2    3570620  07a1aef6-63ac-4867-a6eb-96ecb16e1fba    60835706200011
# 3    3575389  07d47139-17ae-4686-8c24-319427f09db3    60835753890012
# 4    3672742  0bf1fe4f-4c80-4b9e-a92e-e2b686b60dba    60836727420013
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.1844
# 1  alpha_stack_model_sil       0.0720
# 2  alpha_stack_model_sil       0.1629
# 3  alpha_stack_model_sil       0.1440
# 4  alpha_stack_model_sil       0.0932
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.1058501955, "s_cic_score":...   2025-09-10 13:59:11
# 1  {"sb_demo_score": 0.0785887604, "s_cic_score":...   2025-05-01 18:50:22
# 2  {"sb_demo_score": 0.0370756776, "s_cic_score":...   2025-07-21 18:11:57
# 3  {"sb_demo_score": 0.0815393236, "s_cic_score":...   2025-07-24 13:07:05
# 4  {"sb_demo_score": 0.0312653529, "s_cic_score":...   2025-09-08 16:58:48
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-09-10           2025-09           Test         0
# 1       2025-05-01           2025-05           Test         0
# 2       2025-07-21           2025-07           Test         0
# 3       2025-07-24           2025-07           Test         0
# 4       2025-09-08           2025-09           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1  SIL Competitor             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 3
# 2                 1     SIL-Instore             v1       Trench 2
# 3                 1  SIL Competitor             v1       Trench 2
# 4                 1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (283527, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     1991253  05fe853f-917a-44d7-85d6-1d87b2e74104    60819912530011
# 1     2287851  0604b33f-e4e4-4091-b7e9-8f342b7d2d7e    60822878510011
# 2     2403997  06a63ed8-b9eb-45e0-b6f4-abb48e30e016    60824039970014
# 3     2255274  077402d8-5f36-4124-b27e-c29f5db6109f    60822552740017
# 4     2242526  0de2e00c-fc20-40f0-bf40-73446c6cd868    60822425260011
#
#         modelDisplayName  credo_score  \
# 0  Alpha - StackingModel     0.047408
# 1  Alpha - StackingModel     0.031724
# 2  Alpha - StackingModel     0.131511
# 3  Alpha - StackingModel     0.141645
# 4  Alpha - StackingModel     0.082546
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.11081709976276412, "s_cic_...   2023-04-14 14:23:46
# 1  {"sb_demo_score": 0.034860144000904966, "s_cic...   2023-10-29 15:46:47
# 2  {"sb_demo_score": 0.01768959022459569, "s_cic_...   2024-02-18 15:29:09
# 3  {"sb_demo_score": 0.10251491493633785, "s_cic_...   2023-10-01 15:01:27
# 4  {"sb_demo_score": 0.13313585196692213, "s_cic_...   2023-09-21 18:12:03
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2023-04-14           2023-04          Train         0
# 1       2023-10-29           2023-10          Train         0
# 2       2024-02-18           2024-02          Train         0
# 3       2023-10-01           2023-10          Train         0
# 4       2023-09-21           2023-09          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 2
# 1                 1   SIL-Instore             v1       Trench 2
# 2                 1   SIL-Instore             v1       Trench 3
# 3                 1   SIL-Instore             v1       Trench 3
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (293320, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3797541  16f14f67-84d9-45e8-98d6-4e2fe438bcd9    60837975410012
# 1    3797009  3507542e-d87e-4bca-9e79-0baba0ac1013    60837970090017
# 2    3669444  3de74d78-bcde-4b83-8883-506a8a431be4    60836694440019
# 3    3799344  46020507-09eb-4f4a-8d51-3c7d8e76d132    60837993440017
# 4    3796701  4c45a018-94b3-466d-a1d2-5e7b0f25d187    60837967010016
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.0945
# 1  alpha_stack_model_sil       0.0871
# 2  alpha_stack_model_sil       0.1196
# 3  alpha_stack_model_sil       0.1178
# 4  alpha_stack_model_sil       0.0758
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.0274933493, "s_cic_score":...   2025-11-07 16:52:56
# 1  {"sb_demo_score": 0.0576639469, "s_cic_score":...   2025-11-07 13:41:07
# 2  {"sb_demo_score": 0.0313161313, "s_cic_score":...   2025-09-10 09:24:41
# 3  {"sb_demo_score": 0.0200763813, "s_cic_score":...   2025-11-08 15:16:37
# 4  {"sb_demo_score": 0.0492581319, "s_cic_score":...   2025-11-07 11:32:33
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-11-07           2025-11           Test         0
# 1       2025-11-07           2025-11           Test         0
# 2       2025-09-10           2025-09           Test         0
# 3       2025-11-08           2025-11           Test         1
# 4       2025-11-07           2025-11           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v1       Trench 2
# 1                 1   SIL-Instore             v1       Trench 2
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (24286, 16)
# The shape of the dimension table is:	 (418, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=1e4071b1-c7d5-4806-b2c1-aa7ba53256a2>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=2cbfbb04-a709-4403-a366-d69dc614dc44>

# %% [markdown]
# ## FSPD30

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (39083, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3452054  11e6c192-18f4-4ad2-8f39-6798658ba7b9    60834520540014
# 1    3726727  170ad676-6550-49f0-b0f4-980061ff7a4d    60837267270011
# 2    3439784  1f4eaabc-7aee-4310-a66b-e2699f5f26a9    60834397840019
# 3    3473559  2a9041a8-3f69-42ab-b5c0-a063695e641d    60834735590018
# 4    3489382  2fb14747-3efb-4008-a440-a8cae99e4de2    60834893820011
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.1490
# 1  alpha_stack_model_sil       0.1277
# 2  alpha_stack_model_sil       0.0940
# 3  alpha_stack_model_sil       0.2196
# 4  alpha_stack_model_sil       0.1211
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.0754420875, "s_cic_score":...   2025-05-22 18:38:25
# 1  {"sb_demo_score": 0.0531725118, "s_cic_score":...   2025-10-06 10:33:01
# 2  {"sb_demo_score": 0.1254590839, "s_cic_score":...   2025-05-16 11:29:41
# 3  {"sb_demo_score": 0.0785209903, "s_cic_score":...   2025-06-02 11:55:04
# 4  {"sb_demo_score": 0.1577316789, "s_cic_score":...   2025-06-10 16:36:02
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-05-22           2025-05           Test          0
# 1       2025-10-06           2025-10           Test          0
# 2       2025-05-16           2025-05           Test          0
# 3       2025-06-02           2025-06           Test          0
# 4       2025-06-10           2025-06           Test          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 2
# 1                   1   SIL-Instore             v1       Trench 2
# 2                   1   SIL-Instore             v1       Trench 2
# 3                   1   SIL-Instore             v1       Trench 2
# 4                   1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (281532, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2265300  0526e272-e59f-484d-be29-182580b319da    60822653000017
# 1     2244892  15bffd55-4d59-4272-afe9-446f4d01d930    60822448920018
# 2     2287510  17f434de-0e39-4286-89ee-4565178c259b    60822875100013
# 3     2229639  19125680-6e52-4a38-abfb-9b5821101681    60822296390017
# 4     1897781  1951c658-15ec-4d3f-b74f-a60b85ebf1a1    60818977810018
#
#         modelDisplayName  credo_score  \
# 0  Alpha - StackingModel     0.052045
# 1  Alpha - StackingModel     0.050220
# 2  Alpha - StackingModel     0.110372
# 3  Alpha - StackingModel     0.036110
# 4  Alpha - StackingModel     0.048004
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.16944168218538933, "s_cic_...   2023-10-08 18:42:32
# 1  {"sb_demo_score": 0.06266923525360679, "s_cic_...   2023-09-23 16:19:06
# 2  {"sb_demo_score": 0.03704306318914643, "s_cic_...   2023-10-29 12:00:38
# 3  {"sb_demo_score": 0.07193539478957828, "s_cic_...   2023-09-11 15:17:21
# 4  {"sb_demo_score": 0.07078117798822067, "s_cic_...   2023-02-12 17:27:38
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2023-10-08           2023-10          Train          0
# 1       2023-09-23           2023-09          Train          0
# 2       2023-10-29           2023-10          Train          0
# 3       2023-09-11           2023-09          Train          0
# 4       2023-02-12           2023-02          Train          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 2
# 1                   1   SIL-Instore             v1       Trench 2
# 2                   1   SIL-Instore             v1       Trench 3
# 3                   1   SIL-Instore             v1       Trench 2
# 4                   1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (281680, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3739454  55d50e9c-d1e4-45dd-a70e-694be70ebcc3    60837394540012
# 1    3431236  3b19bc86-07f3-4f35-839d-ebd5c9c9f7f0    60834312360014
# 2    3469691  0cb97fa9-8568-4eb2-a0d2-74840fdee48d    60834696910011
# 3    3402653  b9e1b8fc-d825-4cde-a06a-38dd07634b1c    60834026530016
# 4    3482558  e875982d-ea4b-492e-a5ef-a5304b679d4e    60834825580018
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.1892
# 1  alpha_stack_model_sil       0.1564
# 2  alpha_stack_model_sil       0.0878
# 3  alpha_stack_model_sil       0.1474
# 4  alpha_stack_model_sil       0.0964
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.1135077882, "s_cic_score":...   2025-10-12 14:31:27
# 1  {"sb_demo_score": 0.1476247707, "s_cic_score":...   2025-05-11 13:56:41
# 2  {"sb_demo_score": 0.0261010805, "s_cic_score":...   2025-05-31 15:11:26
# 3  {"sb_demo_score": 0.079366751, "s_cic_score": ...   2025-04-26 10:38:59
# 4  {"sb_demo_score": 0.1491641468, "s_cic_score":...   2025-06-07 09:20:45
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-12           2025-10           Test          0
# 1       2025-05-11           2025-05           Test          0
# 2       2025-05-31           2025-05           Test          0
# 3       2025-04-26           2025-04           Test          1
# 4       2025-06-11           2025-06           Test          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v1       Trench 2
# 1                   1   SIL-Instore             v1       Trench 2
# 2                   1   SIL-Instore             v1       Trench 2
# 3                   1   SIL-Instore             v1       Trench 2
# 4                   1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4         Appliance

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (23276, 16)
# The shape of the dimension table is:	 (414, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=4e378acc-293a-41dd-94b6-2b74f2a9d51f>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=4bec4b04-2122-4b76-9c06-f0adff4115e7>

# %% [markdown]
# ## FSTPD30

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (29848, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3675949  02772349-b50e-4d16-832e-0365c0365562    60836759490018
# 1    2744135  02e4edb7-a5de-4415-a034-07b63370b61b    60827441350026
# 2    3672742  0bf1fe4f-4c80-4b9e-a92e-e2b686b60dba    60836727420013
# 3    3472051  0f123bcd-4a6e-41fd-8d06-6e0b902b7b57    60834720510011
# 4    3391343  213ac559-d6c0-41c6-854c-80ecf9bb3aaf    60833913430011
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.1844
# 1  alpha_stack_model_sil       0.0720
# 2  alpha_stack_model_sil       0.0932
# 3  alpha_stack_model_sil       0.0556
# 4  alpha_stack_model_sil       0.1293
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.1058501955, "s_cic_score":...   2025-09-10 13:59:11
# 1  {"sb_demo_score": 0.0785887604, "s_cic_score":...   2025-05-01 18:50:22
# 2  {"sb_demo_score": 0.0312653529, "s_cic_score":...   2025-09-08 16:58:48
# 3  {"sb_demo_score": 0.018935209, "s_cic_score": ...   2025-06-01 16:01:23
# 4  {"sb_demo_score": 0.0655131675, "s_cic_score":...   2025-04-20 16:35:07
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-09-10           2025-09           Test           1
# 1       2025-05-01           2025-05           Test           0
# 2       2025-09-08           2025-09           Test           0
# 3       2025-06-01           2025-06           Test           0
# 4       2025-04-20           2025-04           Test           0
#
#    flg_mature_fstpd_30   new_loan_type modelVersionId trenchCategory  \
# 0                    1  SIL Competitor             v1       Trench 2
# 1                    1     SIL-Instore             v1       Trench 3
# 2                    1  SIL Competitor             v1       Trench 2
# 3                    1     SIL-Instore             v1       Trench 2
# 4                    1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in  ('Alpha - StackingModel', 'alpha_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (270419, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2244892  15bffd55-4d59-4272-afe9-446f4d01d930    60822448920018
# 1     2229639  19125680-6e52-4a38-abfb-9b5821101681    60822296390017
# 2     1897781  1951c658-15ec-4d3f-b74f-a60b85ebf1a1    60818977810018
# 3     1930822  223d00ea-bf73-4456-b409-e96b01eb68eb    60819308220018
# 4     2252755  2855ed9c-bbde-48b9-bc8b-646e2c3274ed    60822527550017
#
#         modelDisplayName  credo_score  \
# 0  Alpha - StackingModel     0.050220
# 1  Alpha - StackingModel     0.036110
# 2  Alpha - StackingModel     0.048004
# 3  Alpha - StackingModel     0.090865
# 4  Alpha - StackingModel     0.274759
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.06266923525360679, "s_cic_...   2023-09-23 16:19:06
# 1  {"sb_demo_score": 0.07193539478957828, "s_cic_...   2023-09-11 15:17:21
# 2  {"sb_demo_score": 0.07078117798822067, "s_cic_...   2023-02-12 17:27:38
# 3  {"sb_demo_score": 0.14635225127748874, "s_cic_...   2023-03-07 12:39:19
# 4  {"sb_demo_score": 0.12925431826166336, "s_cic_...   2023-09-29 17:18:11
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2023-09-23           2023-09          Train           0
# 1       2023-09-11           2023-09          Train           0
# 2       2023-02-12           2023-02          Train           0
# 3       2023-03-07           2023-03          Train           0
# 4       2023-09-29           2023-09          Train           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1   SIL-Instore             v1       Trench 2
# 2                    1   SIL-Instore             v1       Trench 2
# 3                    1   SIL-Instore             v1       Trench 2
# 4                    1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (270530, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3669444  3de74d78-bcde-4b83-8883-506a8a431be4    60836694440019
# 1    3431236  3b19bc86-07f3-4f35-839d-ebd5c9c9f7f0    60834312360014
# 2    3680036  43b98177-16b5-42fe-a32c-4d41d4bee8c0    60836800360011
# 3    3677238  a6335710-7186-4737-b465-3c80e465526b    60836772380012
# 4    3469691  0cb97fa9-8568-4eb2-a0d2-74840fdee48d    60834696910011
#
#         modelDisplayName  credo_score  \
# 0  alpha_stack_model_sil       0.1196
# 1  alpha_stack_model_sil       0.1564
# 2  alpha_stack_model_sil       0.2163
# 3  alpha_stack_model_sil       0.1709
# 4  alpha_stack_model_sil       0.0878
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.0313161313, "s_cic_score":...   2025-09-10 09:24:41
# 1  {"sb_demo_score": 0.1476247707, "s_cic_score":...   2025-05-11 13:56:41
# 2  {"sb_demo_score": 0.0464718562, "s_cic_score":...   2025-09-12 17:45:09
# 3  {"sb_demo_score": 0.0910699961, "s_cic_score":...   2025-09-11 08:56:31
# 4  {"sb_demo_score": 0.0261010805, "s_cic_score":...   2025-05-31 15:11:26
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-09-10           2025-09           Test           0
# 1       2025-05-11           2025-05           Test           1
# 2       2025-09-12           2025-09           Test           0
# 3       2025-09-11           2025-09           Test           0
# 4       2025-05-31           2025-05           Test           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1   SIL-Instore             v1       Trench 2
# 2                    1   SIL-Instore             v1       Trench 2
# 3                    1   SIL-Instore             v1       Trench 2
# 4                    1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4              Mall

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (22100, 16)
# The shape of the dimension table is:	 (414, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=47c785f7-369d-416b-95af-87526242c083>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=250fdd46-598e-407b-89e3-4ff59441dd56>

# %% [markdown]
# # beta_stack_model_sil_credo_score

# %% [markdown]
# ## FPD0

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (97406, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3590700  00a486a4-7133-4108-901e-5ceb74799a2e    60835907000019
# 1    3385630  013bb1fa-ec81-464d-a864-e76bb8bd8061    60833856300015
# 2    3632558  017185eb-1680-46b1-a7a0-10fe0510d549    60836325580015
# 3    3413263  024b9418-70cf-47a2-90cf-723633b6d363    60834132630015
# 4    3648580  02518255-60bb-4130-b3ed-07ca1eaa76d8    60836485800012
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.1146
# 1  beta_stack_model_sil       0.0920
# 2  beta_stack_model_sil       0.1273
# 3  beta_stack_model_sil       0.1656
# 4  beta_stack_model_sil       0.1484
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": null, "s_credo_score": 0.1146...   2025-07-31 18:30:30
# 1  {"s_apps_score": null, "s_credo_score": 0.092,...   2025-04-17 15:07:30
# 2  {"s_apps_score": 0.4311063391573552, "s_credo_...   2025-08-20 15:51:01
# 3  {"s_apps_score": 0.47652826302076545, "s_credo...   2025-05-01 16:03:17
# 4  {"s_apps_score": 0.6684231248096719, "s_credo_...   2025-08-28 19:26:07
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-07-31           2025-07           Test        0                1
# 1       2025-04-17           2025-04           Test        0                1
# 2       2025-08-20           2025-08           Test        0                1
# 3       2025-05-01           2025-05           Test        0                1
# 4       2025-08-28           2025-08           Test        1                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0  SIL Competitor             v1       Trench 2         Appliance
# 1     SIL-Instore             v1       Trench 2              Mall
# 2     SIL-Instore             v1       Trench 2         Appliance
# 3     SIL-Instore             v1       Trench 2         Appliance
# 4     SIL-Instore             v1       Trench 2         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (225063, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3206286  6b2d3c9c-efd4-4d62-a4d3-db28826ffd7a    60832062860017
# 1     2791337  019689bc-457a-408b-a7f6-13a282008292    60827913370019
# 2     2795178  01bd2af8-79b7-4533-9d4b-cf82fdc45b8e    60827951780018
# 3     2765504  0206a674-4b03-4b6d-b031-350e36dfd01d    60827655040017
# 4     2808735  03ac85f4-dcde-4e44-97ba-8393455f6f14    60828087350018
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil     0.050984
# 1  beta_stack_model_sil     0.091806
# 2  beta_stack_model_sil     0.094722
# 3  beta_stack_model_sil     0.071408
# 4  beta_stack_model_sil     0.079232
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.49638812817771, "apps_scor...   2025-11-15 10:23:43
# 1  {"sb_demo_score": 0.2283575893945324, "apps_sc...   2024-08-25 16:37:49
# 2  {"sb_demo_score": 0.4113826174608042, "apps_sc...   2024-08-26 17:34:14
# 3  {"sb_demo_score": 0.5047256587387133, "apps_sc...   2024-08-18 10:16:49
# 4  {"sb_demo_score": 0.465444018629917, "apps_sco...   2024-08-30 20:00:52
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-01-21           2025-11          Train        0                1
# 1       2024-08-25           2024-08          Train        0                1
# 2       2024-08-26           2024-08          Train        0                1
# 3       2024-08-18           2024-08          Train        1                1
# 4       2024-08-30           2024-08          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0   SIL-Instore             v2       Trench 1         Appliance
# 1   SIL-Instore             v2       Trench 1            Mobile
# 2   SIL-Instore             v2       Trench 1         Appliance
# 3   SIL-Instore             v2       Trench 1         Appliance
# 4   SIL-Instore             v2       Trench 1         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (260407, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3763498  0335ab0d-6777-4f1c-a174-267e770c5a6d    60837634980015
# 1    3877523  0a4e2d03-b420-4757-aec4-10e9055be972    60838775230016
# 2    3885011  0f4e5bdb-1074-41a4-ad8d-4637ce5ee68e    60838850110014
# 3    3777933  151528b9-0652-4136-9f31-503aca8a1318    60837779330014
# 4    3340281  15d3ed8f-b633-4c0e-8c50-b023e2eb2dc1    60833402810014
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.1178
# 1  beta_stack_model_sil       0.2313
# 2  beta_stack_model_sil       0.1241
# 3  beta_stack_model_sil       0.1098
# 4  beta_stack_model_sil       0.0772
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": 0.39847597241304444, "s_credo...   2025-10-23 18:44:56
# 1  {"s_apps_score": 0.5691634372387653, "s_credo_...   2025-12-09 14:18:52
# 2  {"s_apps_score": 0.5890236409058494, "s_credo_...   2025-12-11 15:41:14
# 3  {"s_apps_score": 0.28146199126117843, "s_credo...   2025-10-29 17:11:57
# 4  {"s_apps_score": 0.49629243564635767, "s_credo...   2025-12-08 12:25:29
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-23           2025-10           Test        0                1
# 1       2025-12-09           2025-12           Test        0                1
# 2       2025-12-11           2025-12           Test        1                1
# 3       2025-10-29           2025-10           Test        0                1
# 4       2025-12-08           2025-12           Test        0                1
#
#     new_loan_type modelVersionId trenchCategory loan_product_type
# 0  SIL Competitor             v1       Trench 2              Mall
# 1  SIL Competitor             v1       Trench 2         Appliance
# 2     SIL-Instore             v1       Trench 2         Appliance
# 3  SIL Competitor             v1       Trench 2              Mall
# 4     SIL-Instore             v1       Trench 2         Appliance

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (17490, 16)
# The shape of the dimension table is:	 (335, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=10b4d3ce-515b-4d8b-ba9e-ba6866f7d6df>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=7d1ed143-509a-4e55-865c-f8c906e5249f>

# %% [markdown]
# ## FPD10

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd10 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (89549, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3628931  00196a92-5854-4281-8082-1f530cf1eb1b    60836289310015
# 1    3606715  00c26b6c-32c7-4607-805e-aa767c83be44    60836067150011
# 2    3832186  02cab0e3-11d3-46d2-8ec3-89af8fcb7a79    60838321860019
# 3    3605939  04820c11-97ae-41a6-ba38-69570698de96    60836059390011
# 4    3397661  053f86c8-f700-410e-bd9c-da959c66a0b1    60833976610015
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.0517
# 1  beta_stack_model_sil       0.1468
# 2  beta_stack_model_sil       0.1248
# 3  beta_stack_model_sil       0.1305
# 4  beta_stack_model_sil       0.0612
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": 0.46899389505067457, "s_credo...   2025-08-18 15:52:28
# 1  {"s_apps_score": 0.4692659808017438, "s_credo_...   2025-08-08 09:48:03
# 2  {"s_apps_score": 0.5175689985502268, "s_credo_...   2025-11-24 12:01:09
# 3  {"s_apps_score": 0.5415183590433545, "s_credo_...   2025-08-07 18:34:38
# 4  {"s_apps_score": 0.5192211251125649, "s_credo_...   2025-04-23 16:48:45
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-08-18           2025-08           Test         0
# 1       2025-08-08           2025-08           Test         0
# 2       2025-11-24           2025-11           Test         0
# 3       2025-08-07           2025-08           Test         1
# 4       2025-04-23           2025-04           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1     SIL-Instore             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1  SIL Competitor             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1        SIL ZERO             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (225063, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3206286  6b2d3c9c-efd4-4d62-a4d3-db28826ffd7a    60832062860017
# 1     2716957  0378d6a1-3b53-45db-9bef-ea509753c4db    60827169570011
# 2     2742275  03c2651a-eec5-49eb-a060-091caf2986b4    60827422750011
# 3     2774351  0520a3ac-820c-44f7-9eb9-97d7cf8b932f    60827743510019
# 4     2800521  057ecf75-685b-4774-9a88-334ade6fdcc1    60828005210014
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil     0.050984
# 1  beta_stack_model_sil     0.108462
# 2  beta_stack_model_sil     0.129031
# 3  beta_stack_model_sil     0.320719
# 4  beta_stack_model_sil     0.059445
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.49638812817771, "apps_scor...   2025-11-15 10:23:43
# 1  {"sb_demo_score": 0.49533220885561763, "apps_s...   2024-08-03 12:03:26
# 2  {"sb_demo_score": 0.6329315932686127, "apps_sc...   2024-08-11 10:43:03
# 3  {"sb_demo_score": 0.658543000325295, "apps_sco...   2024-08-20 17:28:13
# 4  {"sb_demo_score": 0.586119355251616, "apps_sco...   2024-08-29 17:02:48
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-01-21           2025-11          Train         0
# 1       2024-08-03           2024-08          Train         0
# 2       2024-08-11           2024-08          Train         1
# 3       2024-08-20           2024-08          Train         0
# 4       2024-08-29           2024-08          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v2       Trench 1
# 1                 1   SIL-Instore             v2       Trench 1
# 2                 1   SIL-Instore             v2       Trench 1
# 3                 1   SIL-Instore             v2       Trench 1
# 4                 1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (252550, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3832186  02cab0e3-11d3-46d2-8ec3-89af8fcb7a79    60838321860019
# 1    3760227  2202d625-361b-4d5f-83c3-d064730f90e7    60837602270012
# 2    3833220  220fd2e6-8b16-4d95-9656-3b492566d899    60838332200018
# 3    3760836  25e8544a-a061-4f64-b3a9-7e7fb1b6ef32    60837608360011
# 4    3746466  2dc8fa53-906d-4f7b-ae01-2af3272ec247    60837464660019
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.1248
# 1  beta_stack_model_sil       0.0762
# 2  beta_stack_model_sil       0.0878
# 3  beta_stack_model_sil       0.1116
# 4  beta_stack_model_sil       0.1343
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": 0.5175689985502268, "s_credo_...   2025-11-24 12:01:09
# 1  {"s_apps_score": 0.6101346883999135, "s_credo_...   2025-10-22 11:20:30
# 2  {"s_apps_score": 0.4736469294941462, "s_credo_...   2025-11-24 18:18:21
# 3  {"s_apps_score": 0.5818728654228236, "s_credo_...   2025-10-22 16:09:37
# 4  {"s_apps_score": 0.5443231465756113, "s_credo_...   2025-10-15 17:32:54
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-11-24           2025-11           Test         0
# 1       2025-10-22           2025-10           Test         0
# 2       2025-11-24           2025-11           Test         0
# 3       2025-10-22           2025-10           Test         0
# 4       2025-10-15           2025-10           Test         0
#
#    flg_mature_fpd10   new_loan_type modelVersionId trenchCategory  \
# 0                 1  SIL Competitor             v1       Trench 2
# 1                 1     SIL-Instore             v1       Trench 2
# 2                 1  SIL Competitor             v1       Trench 2
# 3                 1     SIL-Instore             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (17318, 16)
# The shape of the dimension table is:	 (335, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=d4f1b07c-d63d-4cbd-945d-7901bd221d02>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=c7b259ca-6e5d-450d-a719-82f1138eb159>

# %% [markdown]
# ## FPD30

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (76308, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3471673  03771cdb-bedb-460b-8d75-c7d2233bbad6    60834716730011
# 1    3703307  0384b54a-af03-4adb-a148-a492ced09538    60837033070013
# 2    3476312  043ede40-2c7c-4306-8b8c-1878de5e1d0f    60834763120019
# 3    3678266  04d94cc8-8ea2-4d7e-b9de-569605eef4e5    60836782660011
# 4    3678162  073432f7-72d1-4b70-8008-bbd86fabc7eb    60836781620013
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.1158
# 1  beta_stack_model_sil       0.0765
# 2  beta_stack_model_sil       0.0979
# 3  beta_stack_model_sil       0.1898
# 4  beta_stack_model_sil       0.0920
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": 0.4100498779896969, "s_credo_...   2025-11-06 10:47:52
# 1  {"s_apps_score": 0.31647399442184926, "s_credo...   2025-09-24 19:57:48
# 2  {"s_apps_score": null, "s_credo_score": 0.0979...   2025-06-03 19:27:28
# 3  {"s_apps_score": 0.5785271841965371, "s_credo_...   2025-09-11 17:34:57
# 4  {"s_apps_score": null, "s_credo_score": 0.092,...   2025-09-11 16:48:26
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-11-06           2025-11           Test         0
# 1       2025-09-24           2025-09           Test         0
# 2       2025-06-03           2025-06           Test         0
# 3       2025-09-11           2025-09           Test         0
# 4       2025-09-11           2025-09           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1      SIL ZERO             v1       Trench 2
# 1                 1   SIL-Instore             v1       Trench 2
# 2                 1   SIL-Instore             v1       Trench 2
# 3                 1   SIL-Instore             v1       Trench 2
# 4                 1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2              Mall
# 3         Appliance
# 4              Mall

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (225063, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3206286  6b2d3c9c-efd4-4d62-a4d3-db28826ffd7a    60832062860017
# 1     2780702  01e46c89-ad9e-465c-ad47-d3bd7ca4ba6d    60827807020011
# 2     2812098  02cc1963-b548-4450-8bf0-4554e76b5360    60828120980013
# 3     2733784  05379dcb-60fd-4e4a-9099-f4ad712b6711    60827337840016
# 4     2734174  05ea11e1-a02c-4542-997c-4b60394da90a    60827341740011
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil     0.050984
# 1  beta_stack_model_sil     0.337235
# 2  beta_stack_model_sil     0.170681
# 3  beta_stack_model_sil     0.056647
# 4  beta_stack_model_sil     0.084763
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.49638812817771, "apps_scor...   2025-11-15 10:23:43
# 1  {"sb_demo_score": 0.6364841230702901, "apps_sc...   2024-08-22 15:30:43
# 2  {"sb_demo_score": 0.43435580283011976, "apps_s...   2024-08-31 19:31:11
# 3  {"sb_demo_score": 0.7024369032959416, "apps_sc...   2024-08-08 15:28:36
# 4  {"sb_demo_score": 0.6580834999612222, "apps_sc...   2024-08-08 16:51:20
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-01-21           2025-11          Train         0
# 1       2024-08-22           2024-08          Train         0
# 2       2024-08-31           2024-08          Train         0
# 3       2024-08-08           2024-08          Train         0
# 4       2024-08-08           2024-08          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1   SIL-Instore             v2       Trench 1
# 1                 1   SIL-Instore             v2       Trench 1
# 2                 1      SIL ZERO             v2       Trench 1
# 3                 1   SIL-Instore             v2       Trench 1
# 4                 1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2            Mobile
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (239309, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3471673  03771cdb-bedb-460b-8d75-c7d2233bbad6    60834716730011
# 1    3799394  201f0daa-2085-4264-8125-292e97b5be8b    60837993940017
# 2    3743544  6256a355-a593-40ca-b0ff-49038114f0ca    60837435440014
# 3    3801517  89792117-b89e-444e-a501-8b3806aa087a    60838015170019
# 4    3796945  9e19e5d8-51a9-423d-a538-fbd9f9d649d1    60837969450014
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.1158
# 1  beta_stack_model_sil       0.0710
# 2  beta_stack_model_sil       0.0734
# 3  beta_stack_model_sil       0.1031
# 4  beta_stack_model_sil       0.1279
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": 0.4100498779896969, "s_credo_...   2025-11-06 10:47:52
# 1  {"s_apps_score": 0.31461386837984484, "s_credo...   2025-11-08 15:34:00
# 2  {"s_apps_score": 0.41731484612531533, "s_credo...   2025-10-14 12:31:59
# 3  {"s_apps_score": null, "s_credo_score": 0.1031...   2025-11-09 17:51:27
# 4  {"s_apps_score": 0.41806770740795596, "s_credo...   2025-11-07 13:07:07
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-11-06           2025-11           Test         0
# 1       2025-11-08           2025-11           Test         0
# 2       2025-10-14           2025-10           Test         0
# 3       2025-11-09           2025-11           Test         0
# 4       2025-11-07           2025-11           Test         0
#
#    flg_mature_fpd30   new_loan_type modelVersionId trenchCategory  \
# 0                 1        SIL ZERO             v1       Trench 2
# 1                 1  SIL Competitor             v1       Trench 2
# 2                 1  SIL Competitor             v1       Trench 2
# 3                 1  SIL Competitor             v1       Trench 2
# 4                 1     SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3              Mall
# 4         Appliance

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (16830, 16)
# The shape of the dimension table is:	 (335, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=6ca40861-41fe-4cf7-aff0-871ca66ce164>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=8bc821c7-372b-4948-b8a5-ca9d7dfd7124>

# %% [markdown]
# ## FSPD30

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (59866, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3737468  093d0b8a-414e-4e9a-934c-675a28b435b4    60837374680011
# 1    3342818  0e03b5b7-7201-4baf-ba27-b5df2844e574    60833428180013
# 2    3343929  0e5734ee-e78c-47a7-a64d-59733acb0f94    60833439290013
# 3    3442464  1ca6834d-beff-428c-a64c-d1e82c0f8490    60834424640013
# 4    3726737  2697dec4-0ada-40ec-bcdc-847c5f1be8d4    60837267370013
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.1323
# 1  beta_stack_model_sil       0.1621
# 2  beta_stack_model_sil       0.1097
# 3  beta_stack_model_sil       0.0613
# 4  beta_stack_model_sil       0.0575
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": 0.41535426151504373, "s_credo...   2025-10-11 16:23:33
# 1  {"s_apps_score": 0.5295068542680688, "s_credo_...   2025-03-27 10:17:59
# 2  {"s_apps_score": 0.43519932194402616, "s_credo...   2025-03-27 18:58:16
# 3  {"s_apps_score": 0.32020202955086563, "s_credo...   2025-05-17 17:34:40
# 4  {"s_apps_score": 0.5256776744925511, "s_credo_...   2025-10-06 10:35:35
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-11           2025-10           Test          0
# 1       2025-03-27           2025-03           Test          1
# 2       2025-03-27           2025-03           Test          1
# 3       2025-05-17           2025-05           Test          0
# 4       2025-10-06           2025-10           Test          1
#
#    flg_mature_fspd_30   new_loan_type modelVersionId trenchCategory  \
# 0                   1  SIL Competitor             v1       Trench 2
# 1                   1     SIL-Instore             v1       Trench 2
# 2                   1     SIL-Instore             v1       Trench 2
# 3                   1     SIL-Instore             v1       Trench 2
# 4                   1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3              Mall
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  deffspd30,
  flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fspd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (222648, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3206286  6b2d3c9c-efd4-4d62-a4d3-db28826ffd7a    60832062860017
# 1     2774348  00088f0d-7e27-4d9b-8c78-6436716bb0b1    60827743480014
# 2     2723071  04658d92-943d-4520-bc93-ff22edc05be9    60827230710015
# 3     2776255  0656c802-4401-4b10-86f0-fa207e56d143    60827762550018
# 4     2742991  0c7ec8fa-c950-43b3-94e5-ea3715769dcb    60827429910012
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil     0.050984
# 1  beta_stack_model_sil     0.267250
# 2  beta_stack_model_sil     0.182500
# 3  beta_stack_model_sil     0.131199
# 4  beta_stack_model_sil     0.067059
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.49638812817771, "apps_scor...   2025-11-15 10:23:43
# 1  {"sb_demo_score": 0.5280204024224252, "apps_sc...   2024-08-20 17:22:05
# 2  {"sb_demo_score": 0.5036080179473589, "apps_sc...   2024-08-05 10:29:44
# 3  {"sb_demo_score": 0.32108938888792904, "apps_s...   2024-08-21 11:36:30
# 4  {"sb_demo_score": 0.33723953216036584, "apps_s...   2024-08-11 13:00:36
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-01-21           2025-11          Train          0
# 1       2024-08-20           2024-08          Train          0
# 2       2024-08-05           2024-08          Train          0
# 3       2024-08-21           2024-08          Train          0
# 4       2024-08-11           2024-08          Train          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1   SIL-Instore             v2       Trench 1
# 1                   1   SIL-Instore             v2       Trench 1
# 2                   1   SIL-Instore             v2       Trench 1
# 3                   1   SIL-Instore             v2       Trench 1
# 4                   1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (222860, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3644353  dd8b0a2f-d956-43f9-abaa-8127f9382ed3    60836443530017
# 1    3732868  f4c65a03-7c2f-4766-b5d5-189805e10b28    60837328680012
# 2    2449123  4c59bdbc-c1dc-4828-bb05-bf278d295cf0    60824491230032
# 3    3343551  fd3767af-fd32-42d6-b702-0253dd90e03d    60833435510019
# 4    3634235  6d640f14-ffd2-43a3-b1e4-62ec3e82b5d9    60836342350017
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.1371
# 1  beta_stack_model_sil       0.1094
# 2  beta_stack_model_sil       0.2121
# 3  beta_stack_model_sil       0.1834
# 4  beta_stack_model_sil       0.0889
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": 0.6528019583726831, "s_credo_...   2025-08-26 11:52:39
# 1  {"s_apps_score": 0.494830135942931, "s_credo_s...   2025-10-09 10:56:02
# 2  {"s_apps_score": 0.6165444237586986, "s_credo_...   2025-10-06 14:35:56
# 3  {"s_apps_score": 0.6072078321205403, "s_credo_...   2025-03-27 16:08:12
# 4  {"s_apps_score": 0.37506613452655846, "s_credo...   2025-08-26 16:43:52
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-08-26           2025-08           Test          0
# 1       2025-10-09           2025-10           Test          0
# 2       2025-10-06           2025-10           Test          0
# 3       2025-03-27           2025-03           Test          0
# 4       2025-08-26           2025-08           Test          1
#
#    flg_mature_fspd_30   new_loan_type modelVersionId trenchCategory  \
# 0                   1  SIL Competitor             v1       Trench 2
# 1                   1     SIL-Instore             v1       Trench 2
# 2                   1     SIL-Instore             v1       Trench 3
# 3                   1     SIL-Instore             v1       Trench 3
# 4                   1  SIL Competitor             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4              Mall

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (15826, 16)
# The shape of the dimension table is:	 (326, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=ae56176d-2716-465d-a35b-a8eb73eabc4f>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=0946c561-a0b2-4b29-8ae0-1686a6f9b44b>

# %% [markdown]
# ## FSTPD30

# %% [markdown]
# ## Test

# %%
sq = f"""with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (46184, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3419962  065efdfa-7a4c-4870-8cf2-c03c557c6b08    60834199620019
# 1    3392650  1159e4d0-2153-4f01-ba86-53d98fa8cbab    60833926500012
# 2    3403017  199bb07e-8970-4772-8c75-13433472bb60    60834030170018
# 3    3016948  23c8eadc-4005-4cdb-a198-f6f97c492fd3    60830169480023
# 4    3676580  24d42ea9-75cf-4167-9f5e-70b9de89437e    60836765800019
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.0794
# 1  beta_stack_model_sil       0.1361
# 2  beta_stack_model_sil       0.0967
# 3  beta_stack_model_sil       0.1274
# 4  beta_stack_model_sil       0.1427
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": null, "s_credo_score": 0.0794...   2025-05-04 18:42:12
# 1  {"s_apps_score": 0.5729889022820043, "s_credo_...   2025-04-21 10:59:14
# 2  {"s_apps_score": 0.48598021975900707, "s_credo...   2025-04-26 12:58:19
# 3  {"s_apps_score": 0.5516549687895667, "s_credo_...   2025-08-27 15:38:32
# 4  {"s_apps_score": 0.5588063393602705, "s_credo_...   2025-09-10 18:11:36
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-05-04           2025-05           Test           0
# 1       2025-04-21           2025-04           Test           0
# 2       2025-04-26           2025-04           Test           1
# 3       2025-08-27           2025-08           Test           0
# 4       2025-09-10           2025-09           Test           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1      SIL ZERO             v1       Trench 2
# 2                    1   SIL-Instore             v1       Trench 2
# 3                    1   SIL-Instore             v1       Trench 2
# 4                    1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0         Appliance
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta - StackScoreModel', 'beta_stack_model_sil')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.s_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  deffstpd30,
  flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fstpd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (208995, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     3206286  6b2d3c9c-efd4-4d62-a4d3-db28826ffd7a    60832062860017
# 1     2720308  03012c83-91f0-49df-afc0-fc5e49860ce2    60827203080015
# 2     2791717  04b65c43-30e1-4590-bf4c-f2f27a6253df    60827917170017
# 3     2742290  058cad3f-25b7-4613-b70a-78fcfb4bcbc1    60827422900011
# 4     2725282  07b298ce-10c3-43ba-bc6f-e3d7bc6b08a2    60827252820012
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil     0.050984
# 1  beta_stack_model_sil     0.032000
# 2  beta_stack_model_sil     0.091783
# 3  beta_stack_model_sil     0.046652
# 4  beta_stack_model_sil     0.153652
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"sb_demo_score": 0.49638812817771, "apps_scor...   2025-11-15 10:23:43
# 1  {"sb_demo_score": 0.5927256040800529, "apps_sc...   2024-08-04 12:13:03
# 2  {"sb_demo_score": 0.4598340258620217, "apps_sc...   2024-08-25 17:53:31
# 3  {"sb_demo_score": 0.3984067763160565, "apps_sc...   2024-08-11 10:37:44
# 4  {"sb_demo_score": 0.3793771336025608, "apps_sc...   2024-08-05 20:00:59
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-01-21           2025-11          Train           0
# 1       2024-08-04           2024-08          Train           0
# 2       2024-08-25           2024-08          Train           0
# 3       2024-08-11           2024-08          Train           0
# 4       2024-08-05           2024-08          Train           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v2       Trench 1
# 1                    1   SIL-Instore             v2       Trench 1
# 2                    1   SIL-Instore             v2       Trench 1
# 3                    1   SIL-Instore             v2       Trench 1
# 4                    1   SIL-Instore             v2       Trench 1
#
#   loan_product_type
# 0         Appliance
# 1            Mobile
# 2            Mobile
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (209150, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3469691  0cb97fa9-8568-4eb2-a0d2-74840fdee48d    60834696910011
# 1    3676572  d44f840c-13a9-4935-85cf-1c5df8150bef    60836765720019
# 2    3677238  a6335710-7186-4737-b465-3c80e465526b    60836772380012
# 3    3358816  b22207e8-7643-41e8-a199-9842bde1ae8d    60833588160011
# 4    3339905  ca1cdce8-a27f-497a-8032-726079179be6    60833399050014
#
#        modelDisplayName  credo_score  \
# 0  beta_stack_model_sil       0.0878
# 1  beta_stack_model_sil       0.1115
# 2  beta_stack_model_sil       0.1709
# 3  beta_stack_model_sil       0.1504
# 4  beta_stack_model_sil       0.1348
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"s_apps_score": 0.339067994826413, "s_credo_s...   2025-05-31 15:11:26
# 1  {"s_apps_score": 0.5415123964298683, "s_credo_...   2025-09-10 18:16:57
# 2  {"s_apps_score": null, "s_credo_score": 0.1709...   2025-09-11 08:56:31
# 3  {"s_apps_score": 0.6735094506962598, "s_credo_...   2025-04-04 12:31:28
# 4  {"s_apps_score": 0.5180843963444356, "s_credo_...   2025-03-25 14:59:59
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-05-31           2025-05           Test           0
# 1       2025-09-10           2025-09           Test           0
# 2       2025-09-11           2025-09           Test           0
# 3       2025-04-04           2025-04           Test           0
# 4       2025-03-28           2025-03           Test           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1   SIL-Instore             v1       Trench 2
# 1                    1   SIL-Instore             v1       Trench 2
# 2                    1   SIL-Instore             v1       Trench 2
# 3                    1   SIL-Instore             v1       Trench 2
# 4                    1   SIL-Instore             v1       Trench 2
#
#   loan_product_type
# 0              Mall
# 1         Appliance
# 2         Appliance
# 3         Appliance
# 4         Appliance

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_sil', product='SIL')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (14632, 16)
# The shape of the dimension table is:	 (326, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=dd267ce6-5a23-4586-b436-c5a02aa8e22d>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=98d5f112-f5af-47d2-89b7-811f92a48a76>

# %% [markdown]
# # CASH

# %% [markdown]
# ## Alpha-Cash-CIC-Model

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = r"""
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
--REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aCicScore,
  case when p.modelDisplayName like 'Alpha%' then 'cic_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (11878, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3705891  ec2bf9f2-ee68-44de-9f2e-9690f53ec824    60837058910018
# 1    3450487  3f85a529-ed37-4e8e-a494-487058987b51    60834504870025
# 2    2161307  b09215e1-3284-479d-8f99-349b292fcd61    60821613070021
# 3    2335443  855135e0-dce2-4a34-aef9-8d5a798c1bb5    60823354430038
# 4    3177894  940a265b-e43b-4985-905f-675f8ea3787b    60831778940018
#
#   modelDisplayName            aCicScore appln_submit_datetime  \
# 0   cic_model_cash    0.444046831474933   2025-09-26 14:01:57
# 1   cic_model_cash  0.32168739553136344   2025-09-30 11:23:16
# 2   cic_model_cash   0.3702853189649125   2025-10-06 09:25:01
# 3   cic_model_cash   0.3753610723983421   2025-09-30 15:21:22
# 4   cic_model_cash   0.4908542455071541   2025-10-01 18:05:45
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-02           2025-09           Test        1                1
# 1       2025-10-01           2025-09           Test        1                1
# 2       2025-10-06           2025-10           Test        0                1
# 3       2025-10-01           2025-09           Test        0                1
# 4       2025-10-03           2025-10           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 1    not applicable
# 1         Quick             v1       Trench 3    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
and modelVersionId = 'v1'
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aCicScore,
  case when modelDisplayName like 'Alpha%' then 'cic_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (40128, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#   modelDisplayName  aCicScore appln_submit_datetime disbursementdate  \
# 0   cic_model_cash   0.433590   2024-10-21 22:41:59       2024-10-24
# 1   cic_model_cash   0.452064   2024-12-27 16:40:09       2024-12-27
# 2   cic_model_cash   0.568505   2025-05-19 07:45:14       2025-05-20
# 3   cic_model_cash   0.325981   2025-08-02 09:46:51       2025-08-02
# 4   cic_model_cash   0.677052   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffpd0  flg_mature_fpd0 new_loan_type  \
# 0           2024-10          Train        0                1         Quick
# 1           2024-12          Train        0                1         Quick
# 2           2025-05          Train        0                1         Quick
# 3           2025-08          Train        0                1         Quick
# 4           2025-01          Train        0                1         Quick
#
#   modelVersionId trenchCategory loan_product_type
# 0             v1       Trench 2    not applicable
# 1             v1       Trench 1    not applicable
# 2             v1       Trench 3    not applicable
# 3             v1       Trench 3    not applicable
# 4             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()

# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (51971, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    2161307  b09215e1-3284-479d-8f99-349b292fcd61    60821613070021
# 1    3177894  940a265b-e43b-4985-905f-675f8ea3787b    60831778940018
# 2    3716231  64b86ec3-a037-4e33-bf27-c0f2603ab1b8    60837162310017
# 3    2832430  89aa711e-cc9b-466e-a14f-7b1073fa1ce2    60828324300031
# 4    3883167  afffda14-36fb-4a39-bd29-62fc651e9aed    60838831670015
#
#   modelDisplayName            aCicScore appln_submit_datetime  \
# 0   cic_model_cash   0.3702853189649125   2025-10-06 09:25:01
# 1   cic_model_cash   0.4908542455071541   2025-10-01 18:05:45
# 2   cic_model_cash    0.557901400349205   2025-10-01 10:49:31
# 3   cic_model_cash    0.461063857225889   2025-10-06 13:24:58
# 4   cic_model_cash  0.43242675555609117   2025-12-11 04:23:31
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-06           2025-10           Test        0                1
# 1       2025-10-03           2025-10           Test        0                1
# 2       2025-10-01           2025-10           Test        0                1
# 3       2025-10-06           2025-10           Test        1                1
# 4       2025-12-11           2025-12           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 3    not applicable
# 1         Quick             v1       Trench 2    not applicable
# 2         Quick             v1       Trench 1    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 1    not applicable

# %%
df_concat['aCicScore'] = pd.to_numeric(df_concat['aCicScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aCicScore', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='cic_model_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (5656, 16)
# The shape of the dimension table is:	 (96, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=6a3966cd-097c-4d7e-a651-7378c2787279>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=1fa14fd9-1565-4474-a667-580fc2ad7891>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = r"""
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
--REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aCicScore,
  case when p.modelDisplayName like 'Alpha%' then 'cic_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (9836, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3569649  53a8cef3-7e62-4726-850f-d616880df6e2    60835696490014
# 1    3410305  88751b76-493f-4a5d-bdbd-bc1b3280af3b    60834103050032
# 2    3479077  628bb8f9-78bd-4a36-bd17-80d4f85852d9    60834790770019
# 3    3852680  f22cefcb-3684-45ab-bfe7-403c4b013c80    60838526800018
# 4    3727978  fb1ae638-3fd0-42e0-9c44-81a2e88d188e    60837279780012
#
#   modelDisplayName            aCicScore appln_submit_datetime  \
# 0   cic_model_cash   0.5484060562268933   2025-09-29 21:25:24
# 1   cic_model_cash   0.6704806506598259   2025-10-05 21:31:55
# 2   cic_model_cash  0.43088414033831307   2025-10-03 19:44:09
# 3   cic_model_cash   0.3756889144409566   2025-12-01 20:55:36
# 4   cic_model_cash  0.42906818063926705   2025-10-06 18:44:36
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-09-30           2025-09           Test         1
# 1       2025-10-06           2025-10           Test         0
# 2       2025-10-03           2025-10           Test         0
# 3       2025-12-02           2025-12           Test         0
# 4       2025-10-06           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 2
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
and modelVersionId = 'v1'
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aCicScore,
  case when modelDisplayName like 'Alpha%' then 'cic_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (40128, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#   modelDisplayName  aCicScore appln_submit_datetime disbursementdate  \
# 0   cic_model_cash   0.433590   2024-10-21 22:41:59       2024-10-24
# 1   cic_model_cash   0.452064   2024-12-27 16:40:09       2024-12-27
# 2   cic_model_cash   0.568505   2025-05-19 07:45:14       2025-05-20
# 3   cic_model_cash   0.325981   2025-08-02 09:46:51       2025-08-02
# 4   cic_model_cash   0.677052   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffpd10  flg_mature_fpd10 new_loan_type  \
# 0           2024-10          Train         0                 1         Quick
# 1           2024-12          Train         0                 1         Quick
# 2           2025-05          Train         0                 1         Quick
# 3           2025-08          Train         0                 1         Quick
# 4           2025-01          Train         0                 1         Quick
#
#   modelVersionId trenchCategory loan_product_type
# 0             v1       Trench 2    not applicable
# 1             v1       Trench 1    not applicable
# 2             v1       Trench 3    not applicable
# 3             v1       Trench 3    not applicable
# 4             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()

# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (49929, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3410305  88751b76-493f-4a5d-bdbd-bc1b3280af3b    60834103050032
# 1    3479077  628bb8f9-78bd-4a36-bd17-80d4f85852d9    60834790770019
# 2    3852680  f22cefcb-3684-45ab-bfe7-403c4b013c80    60838526800018
# 3    3727978  fb1ae638-3fd0-42e0-9c44-81a2e88d188e    60837279780012
# 4    3338490  9da8823e-ac4c-4d0f-890a-05788b02b3a5    60833384900026
#
#   modelDisplayName            aCicScore appln_submit_datetime  \
# 0   cic_model_cash   0.6704806506598259   2025-10-05 21:31:55
# 1   cic_model_cash  0.43088414033831307   2025-10-03 19:44:09
# 2   cic_model_cash   0.3756889144409566   2025-12-01 20:55:36
# 3   cic_model_cash  0.42906818063926705   2025-10-06 18:44:36
# 4   cic_model_cash   0.4199278976748951   2025-10-04 23:10:38
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-06           2025-10           Test         0
# 1       2025-10-03           2025-10           Test         0
# 2       2025-12-02           2025-12           Test         0
# 3       2025-10-06           2025-10           Test         0
# 4       2025-10-05           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 3
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['aCicScore'] = pd.to_numeric(df_concat['aCicScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aCicScore', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='cic_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=3d4cfa21-6748-4e61-8ea2-123a7a140c17>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=e0182a98-147f-438a-86f7-f60f763e5218>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = r"""
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
--REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aCicScore,
  case when p.modelDisplayName like 'Alpha%' then 'cic_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (4393, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    1939255  189e94f7-4587-444e-9be9-39ab39f5ab4c    60819392550023
# 1    3792646  13a56d04-6419-4e86-9649-3d952e17d5b3    60837926460011
# 2    3719610  4625afe9-909b-49fb-b373-307600575bc0    60837196100016
# 3    3569649  53a8cef3-7e62-4726-850f-d616880df6e2    60835696490014
# 4    3410305  88751b76-493f-4a5d-bdbd-bc1b3280af3b    60834103050032
#
#   modelDisplayName           aCicScore appln_submit_datetime disbursementdate  \
# 0   cic_model_cash  0.4116475124739584   2025-10-06 04:14:34       2025-10-06
# 1   cic_model_cash  0.4655481314401537   2025-11-06 18:12:43       2025-11-15
# 2   cic_model_cash  0.5500553489622988   2025-10-02 20:43:28       2025-10-07
# 3   cic_model_cash  0.5484060562268933   2025-09-29 21:25:24       2025-09-30
# 4   cic_model_cash  0.6704806506598259   2025-10-05 21:31:55       2025-10-06
#
#   Application_month Data_selection  deffpd30  flg_mature_fpd30 new_loan_type  \
# 0           2025-10           Test         1                 1         Quick
# 1           2025-11           Test         0                 1         Quick
# 2           2025-10           Test         1                 1         Quick
# 3           2025-09           Test         1                 1         Quick
# 4           2025-10           Test         0                 1         Quick
#
#   modelVersionId trenchCategory loan_product_type
# 0             v1       Trench 3    not applicable
# 1             v1       Trench 1    not applicable
# 2             v1       Trench 1    not applicable
# 3             v1       Trench 2    not applicable
# 4             v1       Trench 2    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
and modelVersionId = 'v1'
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aCicScore,
  case when modelDisplayName like 'Alpha%' then 'cic_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (40128, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#   modelDisplayName  aCicScore appln_submit_datetime disbursementdate  \
# 0   cic_model_cash   0.433590   2024-10-21 22:41:59       2024-10-24
# 1   cic_model_cash   0.452064   2024-12-27 16:40:09       2024-12-27
# 2   cic_model_cash   0.568505   2025-05-19 07:45:14       2025-05-20
# 3   cic_model_cash   0.325981   2025-08-02 09:46:51       2025-08-02
# 4   cic_model_cash   0.677052   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffpd30  flg_mature_fpd30 new_loan_type  \
# 0           2024-10          Train         0                 1         Quick
# 1           2024-12          Train         0                 1         Quick
# 2           2025-05          Train         0                 1         Quick
# 3           2025-08          Train         0                 1         Quick
# 4           2025-01          Train         0                 1         Quick
#
#   modelVersionId trenchCategory loan_product_type
# 0             v1       Trench 2    not applicable
# 1             v1       Trench 1    not applicable
# 2             v1       Trench 3    not applicable
# 3             v1       Trench 3    not applicable
# 4             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (44486, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    1939255  189e94f7-4587-444e-9be9-39ab39f5ab4c    60819392550023
# 1    3792646  13a56d04-6419-4e86-9649-3d952e17d5b3    60837926460011
# 2    3719610  4625afe9-909b-49fb-b373-307600575bc0    60837196100016
# 3    3410305  88751b76-493f-4a5d-bdbd-bc1b3280af3b    60834103050032
# 4    3718881  7c1dead3-748f-4299-a825-7e76c7d10c81    60837188810013
#
#   modelDisplayName           aCicScore appln_submit_datetime disbursementdate  \
# 0   cic_model_cash  0.4116475124739584   2025-10-06 04:14:34       2025-10-06
# 1   cic_model_cash  0.4655481314401537   2025-11-06 18:12:43       2025-11-15
# 2   cic_model_cash  0.5500553489622988   2025-10-02 20:43:28       2025-10-07
# 3   cic_model_cash  0.6704806506598259   2025-10-05 21:31:55       2025-10-06
# 4   cic_model_cash   0.411287055313931   2025-10-02 15:31:34       2025-10-02
#
#   Application_month Data_selection  deffpd30  flg_mature_fpd30 new_loan_type  \
# 0           2025-10           Test         1                 1         Quick
# 1           2025-11           Test         0                 1         Quick
# 2           2025-10           Test         1                 1         Quick
# 3           2025-10           Test         0                 1         Quick
# 4           2025-10           Test         0                 1         Quick
#
#   modelVersionId trenchCategory loan_product_type
# 0             v1       Trench 3    not applicable
# 1             v1       Trench 1    not applicable
# 2             v1       Trench 1    not applicable
# 3             v1       Trench 2    not applicable
# 4             v1       Trench 1    not applicable

# %%
df_concat['aCicScore'] = pd.to_numeric(df_concat['aCicScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aCicScore', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='cic_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=c8ced1b7-167d-4539-8199-5b7091c94f6b>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=8fee3a60-a232-4db9-90b4-36936c457523>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = r"""
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
--REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aCicScore,
  case when p.modelDisplayName like 'Alpha%' then 'cic_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (187, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3732985  a51a6129-a36f-43b2-9b56-f5897824a443    60837329850016
# 1    3518670  2de40cde-a5eb-49b7-bc5a-7e6e64f2091a    60835186700012
# 2    3718881  7c1dead3-748f-4299-a825-7e76c7d10c81    60837188810013
# 3    2652688  879f37b7-c5e9-4fc5-a91e-14cb39917af4    60826526880025
# 4    3714868  bdda830c-3985-463e-b8bf-a4d02bd00a03    60837148680011
#
#   modelDisplayName            aCicScore appln_submit_datetime  \
# 0   cic_model_cash   0.4738796108271763   2025-10-09 11:56:58
# 1   cic_model_cash   0.5506469586307943   2025-10-12 21:54:18
# 2   cic_model_cash    0.411287055313931   2025-10-02 15:31:34
# 3   cic_model_cash  0.41593301606911565   2025-09-25 10:12:16
# 4   cic_model_cash  0.42478178955732115   2025-09-30 15:32:10
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-09           2025-10           Test          0
# 1       2025-10-13           2025-10           Test          1
# 2       2025-10-02           2025-10           Test          0
# 3       2025-09-25           2025-09           Test          0
# 4       2025-10-02           2025-09           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 1
# 1                   1         Quick             v1       Trench 2
# 2                   1         Quick             v1       Trench 1
# 3                   1         Quick             v1       Trench 3
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
and modelVersionId = 'v1'
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aCicScore,
  case when modelDisplayName like 'Alpha%' then 'cic_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (40108, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#   modelDisplayName  aCicScore appln_submit_datetime disbursementdate  \
# 0   cic_model_cash   0.433590   2024-10-21 22:41:59       2024-10-24
# 1   cic_model_cash   0.452064   2024-12-27 16:40:09       2024-12-27
# 2   cic_model_cash   0.568505   2025-05-19 07:45:14       2025-05-20
# 3   cic_model_cash   0.325981   2025-08-02 09:46:51       2025-08-02
# 4   cic_model_cash   0.677052   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffspd30  flg_mature_fspd_30  \
# 0           2024-10          Train          0                   1
# 1           2024-12          Train          0                   1
# 2           2025-05          Train          0                   1
# 3           2025-08          Train          0                   1
# 4           2025-01          Train          1                   1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (40260, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3732985  a51a6129-a36f-43b2-9b56-f5897824a443    60837329850016
# 1    3518670  2de40cde-a5eb-49b7-bc5a-7e6e64f2091a    60835186700012
# 2    3718881  7c1dead3-748f-4299-a825-7e76c7d10c81    60837188810013
# 3    3361625  dabfe415-23b2-4157-add2-168d3a4248bf    60833616250012
# 4    3728357  2504c2f4-7db8-46aa-a4aa-0d3545429cc1    60837283570013
#
#   modelDisplayName            aCicScore appln_submit_datetime  \
# 0   cic_model_cash   0.4738796108271763   2025-10-09 11:56:58
# 1   cic_model_cash   0.5506469586307943   2025-10-12 21:54:18
# 2   cic_model_cash    0.411287055313931   2025-10-02 15:31:34
# 3   cic_model_cash  0.39569066772495076   2025-10-09 18:22:13
# 4   cic_model_cash   0.5025248326896119   2025-10-06 23:35:25
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-09           2025-10           Test          0
# 1       2025-10-13           2025-10           Test          1
# 2       2025-10-02           2025-10           Test          0
# 3       2025-10-10           2025-10           Test          0
# 4       2025-10-07           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 1
# 1                   1         Quick             v1       Trench 2
# 2                   1         Quick             v1       Trench 1
# 3                   1         Quick             v1       Trench 2
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat.groupby(['Data_selection','new_loan_type', 'modelVersionId', 'loan_product_type'])['digitalLoanAccountId'].nunique()
# Out:
# Data_selection  new_loan_type  modelVersionId  loan_product_type
# Test            Quick          v1              not applicable         152
# Train           Quick          v1              not applicable       40108
# Name: digitalLoanAccountId, dtype: int64

# %%
df_concat['aCicScore'] = pd.to_numeric(df_concat['aCicScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aCicScore', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='cic_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=4c5e16bc-e48b-48cb-9601-3ab739a2e3b4>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=5aea4402-9e62-4778-85a1-cf6d56a40c3c>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = r"""
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
--REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aCicScore,
  case when p.modelDisplayName like 'Alpha%' then 'cic_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (0, 15)
# Empty DataFrame
# Columns: [customerId, digitalLoanAccountId, loanAccountNumber, modelDisplayName, aCicScore, appln_submit_datetime, disbursementdate, Application_month, Data_selection, deffstpd30, flg_mature_fstpd_30, new_loan_type, modelVersionId, trenchCategory, loan_product_type]
# Index: []

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-CIC-Model','Alpha Cash CIC Model','cic_model_cash')
and modelVersionId = 'v1'
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aCicScore,
  case when modelDisplayName like 'Alpha%' then 'cic_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aCicScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aCicScore is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (37949, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#   modelDisplayName  aCicScore appln_submit_datetime disbursementdate  \
# 0   cic_model_cash   0.433590   2024-10-21 22:41:59       2024-10-24
# 1   cic_model_cash   0.452064   2024-12-27 16:40:09       2024-12-27
# 2   cic_model_cash   0.568505   2025-05-19 07:45:14       2025-05-20
# 3   cic_model_cash   0.325981   2025-08-02 09:46:51       2025-08-02
# 4   cic_model_cash   0.677052   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffstpd30  flg_mature_fstpd_30  \
# 0           2024-10          Train           0                    1
# 1           2024-12          Train           0                    1
# 2           2025-05          Train           0                    1
# 3           2025-08          Train           1                    1
# 4           2025-01          Train           1                    1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (37949, 15)
# C:\Users\Dwaipayan\AppData\Local\Temp\ipykernel_49316\2946223290.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#   modelDisplayName  aCicScore appln_submit_datetime disbursementdate  \
# 0   cic_model_cash   0.433590   2024-10-21 22:41:59       2024-10-24
# 1   cic_model_cash   0.452064   2024-12-27 16:40:09       2024-12-27
# 2   cic_model_cash   0.568505   2025-05-19 07:45:14       2025-05-20
# 3   cic_model_cash   0.325981   2025-08-02 09:46:51       2025-08-02
# 4   cic_model_cash   0.677052   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffstpd30  flg_mature_fstpd_30  \
# 0           2024-10          Train           0                    1
# 1           2024-12          Train           0                    1
# 2           2025-05          Train           0                    1
# 3           2025-08          Train           1                    1
# 4           2025-01          Train           1                    1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df_concat['aCicScore'] = pd.to_numeric(df_concat['aCicScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aCicScore', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='cic_model_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (4352, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=d19df5a5-f96c-4064-8db4-b5c124e346d1>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=4b1990c9-50f0-4eca-b470-4728e8c436be>

# %% [markdown]
# ## Alpha-Cash-Stack-Model

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = r""" 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (11878, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    1939255  189e94f7-4587-444e-9be9-39ab39f5ab4c    60819392550023
# 1    3066495  75da5a84-b7b6-4c21-9775-4d01a16a903c    60830664950038
# 2    3174284  006766c8-3f5f-4d30-8257-52f9bfc3a110    60831742840016
# 3    3818341  bbc81aba-7d73-496e-9dcc-1324bb732884    60838183410016
# 4    2863259  78fce405-fd35-4832-ab50-eb15cbf54b89    60828632590029
#
#          modelDisplayName          aStackScore appln_submit_datetime  \
# 0  alpha_stack_model_cash   0.5352197236516072   2025-10-06 04:14:34
# 1  alpha_stack_model_cash   0.5206735494497335   2025-09-30 18:59:01
# 2  alpha_stack_model_cash   0.5128559983638348   2025-09-29 17:57:23
# 3  alpha_stack_model_cash   0.5275226832344673   2025-11-23 16:02:01
# 4  alpha_stack_model_cash  0.48548160881352503   2025-10-02 10:17:03
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-06           2025-10           Test        1                1
# 1       2025-10-01           2025-09           Test        0                1
# 2       2025-09-30           2025-09           Test        1                1
# 3       2025-12-23           2025-11           Test        0                1
# 4       2025-10-02           2025-10           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 3    not applicable
# 1         Quick             v1       Trench 3    not applicable
# 2         Quick             v1       Trench 2    not applicable
# 3         Quick             v1       Trench 1    not applicable
# 4         Quick             v1       Trench 3    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  trenchCategory
  from parsed p
  ) ,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (36491, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#          modelDisplayName  aStackScore appln_submit_datetime disbursementdate  \
# 0  alpha_stack_model_cash     0.297889   2024-10-21 22:41:59       2024-10-24
# 1  alpha_stack_model_cash     0.561060   2024-12-27 16:40:09       2024-12-27
# 2  alpha_stack_model_cash     0.704138   2025-05-19 07:45:14       2025-05-20
# 3  alpha_stack_model_cash     0.326280   2025-08-02 09:46:51       2025-08-02
# 4  alpha_stack_model_cash     0.817580   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffpd0  flg_mature_fpd0 new_loan_type  \
# 0           2024-10          Train        0                1         Quick
# 1           2024-12          Train        0                1         Quick
# 2           2025-05          Train        0                1         Quick
# 3           2025-08          Train        0                1         Quick
# 4           2025-01          Train        0                1         Quick
#
#   modelVersionId trenchCategory loan_product_type
# 0             v1       Trench 2    not applicable
# 1             v1       Trench 1    not applicable
# 2             v1       Trench 3    not applicable
# 3             v1       Trench 3    not applicable
# 4             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (48334, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    1939255  189e94f7-4587-444e-9be9-39ab39f5ab4c    60819392550023
# 1    3818341  bbc81aba-7d73-496e-9dcc-1324bb732884    60838183410016
# 2    2863259  78fce405-fd35-4832-ab50-eb15cbf54b89    60828632590029
# 3    3674309  ff1ed7dc-8a2d-47ce-8515-3ab82a604e3e    60836743090018
# 4    3882789  4c423516-f6cc-410e-b3cf-1200502f5338    60838827890015
#
#          modelDisplayName          aStackScore appln_submit_datetime  \
# 0  alpha_stack_model_cash   0.5352197236516072   2025-10-06 04:14:34
# 1  alpha_stack_model_cash   0.5275226832344673   2025-11-23 16:02:01
# 2  alpha_stack_model_cash  0.48548160881352503   2025-10-02 10:17:03
# 3  alpha_stack_model_cash   0.3923009950652296   2025-12-11 10:52:45
# 4  alpha_stack_model_cash  0.24641727825569962   2025-12-10 22:14:21
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-06           2025-10           Test        1                1
# 1       2025-12-23           2025-11           Test        0                1
# 2       2025-10-02           2025-10           Test        0                1
# 3       2025-12-11           2025-12           Test        0                1
# 4       2025-12-11           2025-12           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 3    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 2    not applicable
# 4         Quick             v1       Trench 1    not applicable

# %%
df_concat['aStackScore'] = pd.to_numeric(df_concat['aStackScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aStackScore', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (5272, 16)
# The shape of the dimension table is:	 (96, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=7226cd49-13a3-422b-a8f7-0eb0a1b6e631>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=ed1f0b97-3486-4ae1-a6b1-76c8664981a9>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = r""" 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (9836, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3718881  7c1dead3-748f-4299-a825-7e76c7d10c81    60837188810013
# 1    2652688  879f37b7-c5e9-4fc5-a91e-14cb39917af4    60826526880025
# 2    3714868  bdda830c-3985-463e-b8bf-a4d02bd00a03    60837148680011
# 3    3307096  e8d69ec8-866a-47c8-a944-067cb83ac800    60833070960021
# 4    2976559  ecab59b9-e3a0-4cdc-a517-6360410a4a1e    60829765590047
#
#          modelDisplayName          aStackScore appln_submit_datetime  \
# 0  alpha_stack_model_cash   0.4690470435815626   2025-10-02 15:31:34
# 1  alpha_stack_model_cash  0.44061356992780776   2025-09-25 10:12:16
# 2  alpha_stack_model_cash   0.3373223022223642   2025-09-30 15:32:10
# 3  alpha_stack_model_cash  0.18204457186790157   2025-09-28 17:18:59
# 4  alpha_stack_model_cash  0.34612718258580144   2025-09-29 07:22:42
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-02           2025-10           Test         0
# 1       2025-09-25           2025-09           Test         0
# 2       2025-10-02           2025-09           Test         0
# 3       2025-09-29           2025-09           Test         0
# 4       2025-09-29           2025-09           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 3
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  trenchCategory
  from parsed p
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (36491, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#          modelDisplayName  aStackScore appln_submit_datetime disbursementdate  \
# 0  alpha_stack_model_cash     0.297889   2024-10-21 22:41:59       2024-10-24
# 1  alpha_stack_model_cash     0.561060   2024-12-27 16:40:09       2024-12-27
# 2  alpha_stack_model_cash     0.704138   2025-05-19 07:45:14       2025-05-20
# 3  alpha_stack_model_cash     0.326280   2025-08-02 09:46:51       2025-08-02
# 4  alpha_stack_model_cash     0.817580   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffpd10  flg_mature_fpd10 new_loan_type  \
# 0           2024-10          Train         0                 1         Quick
# 1           2024-12          Train         0                 1         Quick
# 2           2025-05          Train         0                 1         Quick
# 3           2025-08          Train         0                 1         Quick
# 4           2025-01          Train         0                 1         Quick
#
#   modelVersionId trenchCategory loan_product_type
# 0             v1       Trench 2    not applicable
# 1             v1       Trench 1    not applicable
# 2             v1       Trench 3    not applicable
# 3             v1       Trench 3    not applicable
# 4             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (46292, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3718881  7c1dead3-748f-4299-a825-7e76c7d10c81    60837188810013
# 1    3843582  3150bb2d-e47a-4056-b15a-5d0bd8fba220    60838435820016
# 2    2095967  d1ebbe69-9248-418a-aeb3-84ba881d46ce    60820959670033
# 3    3477025  31a52555-1615-4150-8f82-4f42be6fcec6    60834770250035
# 4    3712217  6b85a5fb-2b6a-4b71-afde-838f71e3f3b2    60837122170013
#
#          modelDisplayName          aStackScore appln_submit_datetime  \
# 0  alpha_stack_model_cash   0.4690470435815626   2025-10-02 15:31:34
# 1  alpha_stack_model_cash  0.49351881856712804   2025-11-28 19:40:08
# 2  alpha_stack_model_cash  0.34576297445174375   2025-10-07 21:37:39
# 3  alpha_stack_model_cash    0.502249427820411   2025-10-01 07:16:27
# 4  alpha_stack_model_cash   0.4176009434556032   2025-10-01 19:16:49
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-02           2025-10           Test         0
# 1       2025-11-29           2025-11           Test         0
# 2       2025-10-07           2025-10           Test         0
# 3       2025-10-01           2025-10           Test         0
# 4       2025-10-03           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['aStackScore'] = pd.to_numeric(df_concat['aStackScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aStackScore', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=515b5ece-6041-4beb-b87a-9767408e4b90>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=7d2d8977-db04-49cd-8bc7-e85c06a94276>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = r""" 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
and modelVersionId = 'v1'
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (4393, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    2863259  78fce405-fd35-4832-ab50-eb15cbf54b89    60828632590029
# 1    3071399  fc78cc72-651b-4e92-b0df-a906c23fc167    60830713990042
# 2    3479077  628bb8f9-78bd-4a36-bd17-80d4f85852d9    60834790770019
# 3    3520056  d24535b1-25cc-42ce-be66-f896efe2450b    60835200560027
# 4    3727978  fb1ae638-3fd0-42e0-9c44-81a2e88d188e    60837279780012
#
#          modelDisplayName          aStackScore appln_submit_datetime  \
# 0  alpha_stack_model_cash  0.48548160881352503   2025-10-02 10:17:03
# 1  alpha_stack_model_cash  0.43455965241990185   2025-09-26 12:34:08
# 2  alpha_stack_model_cash   0.4693781318585817   2025-10-03 19:44:09
# 3  alpha_stack_model_cash  0.07408723173642816   2025-10-22 10:57:06
# 4  alpha_stack_model_cash  0.34381038137538644   2025-10-06 18:44:36
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-10-02           2025-10           Test         0
# 1       2025-09-26           2025-09           Test         0
# 2       2025-10-03           2025-10           Test         0
# 3       2025-11-17           2025-10           Test         0
# 4       2025-10-06           2025-10           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 3
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 2
# 3                 1         Quick             v1       Trench 2
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
and modelVersionId = 'v1'
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  trenchCategory
  from parsed p
  ) ,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (36491, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#          modelDisplayName  aStackScore appln_submit_datetime disbursementdate  \
# 0  alpha_stack_model_cash     0.297889   2024-10-21 22:41:59       2024-10-24
# 1  alpha_stack_model_cash     0.561060   2024-12-27 16:40:09       2024-12-27
# 2  alpha_stack_model_cash     0.704138   2025-05-19 07:45:14       2025-05-20
# 3  alpha_stack_model_cash     0.326280   2025-08-02 09:46:51       2025-08-02
# 4  alpha_stack_model_cash     0.817580   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffpd30  flg_mature_fpd30 new_loan_type  \
# 0           2024-10          Train         0                 1         Quick
# 1           2024-12          Train         0                 1         Quick
# 2           2025-05          Train         0                 1         Quick
# 3           2025-08          Train         0                 1         Quick
# 4           2025-01          Train         0                 1         Quick
#
#   modelVersionId trenchCategory loan_product_type
# 0             v1       Trench 2    not applicable
# 1             v1       Trench 1    not applicable
# 2             v1       Trench 3    not applicable
# 3             v1       Trench 3    not applicable
# 4             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (40849, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    2863259  78fce405-fd35-4832-ab50-eb15cbf54b89    60828632590029
# 1    3479077  628bb8f9-78bd-4a36-bd17-80d4f85852d9    60834790770019
# 2    3520056  d24535b1-25cc-42ce-be66-f896efe2450b    60835200560027
# 3    3727978  fb1ae638-3fd0-42e0-9c44-81a2e88d188e    60837279780012
# 4    3728353  4f50c223-6b13-447b-b003-4f1a1209a9f4    60837283530019
#
#          modelDisplayName          aStackScore appln_submit_datetime  \
# 0  alpha_stack_model_cash  0.48548160881352503   2025-10-02 10:17:03
# 1  alpha_stack_model_cash   0.4693781318585817   2025-10-03 19:44:09
# 2  alpha_stack_model_cash  0.07408723173642816   2025-10-22 10:57:06
# 3  alpha_stack_model_cash  0.34381038137538644   2025-10-06 18:44:36
# 4  alpha_stack_model_cash   0.3964262000350966   2025-10-06 23:27:56
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-10-02           2025-10           Test         0
# 1       2025-10-03           2025-10           Test         0
# 2       2025-11-17           2025-10           Test         0
# 3       2025-10-06           2025-10           Test         0
# 4       2025-10-07           2025-10           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 3
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 2
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['aStackScore'] = pd.to_numeric(df_concat['aStackScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aStackScore', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=c4d4da2b-1c27-4820-abfc-951850336681>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=f33fbfdc-7842-4d2d-bb5f-b0f4d0c6d97b>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = r""" 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
and modelVersionId = 'v1'
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (187, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3338490  9da8823e-ac4c-4d0f-890a-05788b02b3a5    60833384900026
# 1    3740122  0cbfe72f-938e-4e9f-a2b3-fe71018c1b88    60837401220014
# 2    1665988  a026eede-c9c6-4ef6-bce1-5fcbb446e4ef    60816659880016
# 3    3305196  d4ab291c-82f2-49a8-9906-3359d6c7a1d9    60833051960026
# 4    3722116  50b590d0-66dd-4cde-b9fb-1da158fa8e01    60837221160014
#
#          modelDisplayName          aStackScore appln_submit_datetime  \
# 0  alpha_stack_model_cash   0.5400094902394105   2025-10-04 23:10:38
# 1  alpha_stack_model_cash  0.06420186253193465   2025-10-12 18:22:43
# 2  alpha_stack_model_cash  0.39001776471254296   2025-10-06 06:08:45
# 3  alpha_stack_model_cash   0.5085891854250839   2025-10-08 04:05:20
# 4  alpha_stack_model_cash  0.45849350614549417   2025-10-11 19:38:33
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-05           2025-10           Test          0
# 1       2025-10-12           2025-10           Test          0
# 2       2025-10-06           2025-10           Test          0
# 3       2025-10-08           2025-10           Test          0
# 4       2025-10-11           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 3
# 1                   1         Quick             v1       Trench 1
# 2                   1         Quick             v1       Trench 2
# 3                   1         Quick             v1       Trench 3
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
and modelVersionId = 'v1'
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  trenchCategory
  from parsed p
  ) 
  , 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (36472, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#          modelDisplayName  aStackScore appln_submit_datetime disbursementdate  \
# 0  alpha_stack_model_cash     0.297889   2024-10-21 22:41:59       2024-10-24
# 1  alpha_stack_model_cash     0.561060   2024-12-27 16:40:09       2024-12-27
# 2  alpha_stack_model_cash     0.704138   2025-05-19 07:45:14       2025-05-20
# 3  alpha_stack_model_cash     0.326280   2025-08-02 09:46:51       2025-08-02
# 4  alpha_stack_model_cash     0.817580   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffspd30  flg_mature_fspd_30  \
# 0           2024-10          Train          0                   1
# 1           2024-12          Train          0                   1
# 2           2025-05          Train          0                   1
# 3           2025-08          Train          0                   1
# 4           2025-01          Train          1                   1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (36624, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3338490  9da8823e-ac4c-4d0f-890a-05788b02b3a5    60833384900026
# 1    3740122  0cbfe72f-938e-4e9f-a2b3-fe71018c1b88    60837401220014
# 2    1665988  a026eede-c9c6-4ef6-bce1-5fcbb446e4ef    60816659880016
# 3    3305196  d4ab291c-82f2-49a8-9906-3359d6c7a1d9    60833051960026
# 4    3722116  50b590d0-66dd-4cde-b9fb-1da158fa8e01    60837221160014
#
#          modelDisplayName          aStackScore appln_submit_datetime  \
# 0  alpha_stack_model_cash   0.5400094902394105   2025-10-04 23:10:38
# 1  alpha_stack_model_cash  0.06420186253193465   2025-10-12 18:22:43
# 2  alpha_stack_model_cash  0.39001776471254296   2025-10-06 06:08:45
# 3  alpha_stack_model_cash   0.5085891854250839   2025-10-08 04:05:20
# 4  alpha_stack_model_cash  0.45849350614549417   2025-10-11 19:38:33
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-05           2025-10           Test          0
# 1       2025-10-12           2025-10           Test          0
# 2       2025-10-06           2025-10           Test          0
# 3       2025-10-08           2025-10           Test          0
# 4       2025-10-11           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 3
# 1                   1         Quick             v1       Trench 1
# 2                   1         Quick             v1       Trench 2
# 3                   1         Quick             v1       Trench 3
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['aStackScore'] = pd.to_numeric(df_concat['aStackScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aStackScore', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=a47d647a-034c-45a8-b5ba-f53d3cf821f6>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=25a792eb-8eb2-4291-bf22-864c8e4a94f4>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = r""" 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
and modelVersionId = 'v1'
),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,requestPayload as requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Alpha-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  p.start_time,
  p.prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce (p.trenchCategory, REGEXP_EXTRACT(m.requestPayload_clean, r"trenchCategory[:=]['\"]?([^'\"]+)['\"]?")) trenchCategory
  from parsed p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (0, 15)
# Empty DataFrame
# Columns: [customerId, digitalLoanAccountId, loanAccountNumber, modelDisplayName, aStackScore, appln_submit_datetime, disbursementdate, Application_month, Data_selection, deffstpd30, flg_mature_fstpd_30, new_loan_type, modelVersionId, trenchCategory, loan_product_type]
# Index: []

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
and modelVersionId = 'v1'
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction aStackScore,
  case when p.modelDisplayName like 'Alpha%' then 'alpha_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  trenchCategory
  from parsed p
  ) , 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.aStackScore,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.aStackScore is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (34337, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#          modelDisplayName  aStackScore appln_submit_datetime disbursementdate  \
# 0  alpha_stack_model_cash     0.297889   2024-10-21 22:41:59       2024-10-24
# 1  alpha_stack_model_cash     0.561060   2024-12-27 16:40:09       2024-12-27
# 2  alpha_stack_model_cash     0.704138   2025-05-19 07:45:14       2025-05-20
# 3  alpha_stack_model_cash     0.326280   2025-08-02 09:46:51       2025-08-02
# 4  alpha_stack_model_cash     0.817580   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffstpd30  flg_mature_fstpd_30  \
# 0           2024-10          Train           0                    1
# 1           2024-12          Train           0                    1
# 2           2025-05          Train           0                    1
# 3           2025-08          Train           1                    1
# 4           2025-01          Train           1                    1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (34337, 15)
# C:\Users\Dwaipayan\AppData\Local\Temp\ipykernel_49316\2946223290.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#          modelDisplayName  aStackScore appln_submit_datetime disbursementdate  \
# 0  alpha_stack_model_cash     0.297889   2024-10-21 22:41:59       2024-10-24
# 1  alpha_stack_model_cash     0.561060   2024-12-27 16:40:09       2024-12-27
# 2  alpha_stack_model_cash     0.704138   2025-05-19 07:45:14       2025-05-20
# 3  alpha_stack_model_cash     0.326280   2025-08-02 09:46:51       2025-08-02
# 4  alpha_stack_model_cash     0.817580   2025-01-29 17:18:15       2025-01-29
#
#   Application_month Data_selection  deffstpd30  flg_mature_fstpd_30  \
# 0           2024-10          Train           0                    1
# 1           2024-12          Train           0                    1
# 2           2025-05          Train           0                    1
# 3           2025-08          Train           1                    1
# 4           2025-01          Train           1                    1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df_concat['aStackScore'] = pd.to_numeric(df_concat['aStackScore'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'aStackScore', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_model_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (3968, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=61805fc5-a88c-4706-aebe-f97e7dc09066>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=09faca40-92eb-4c41-9c0b-628241bb6755>

# %% [markdown]
# ## Beta-Cash-Demo-Model

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when p.modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p 
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (12385, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3876659  8a3deacb-0fee-4f7f-aae8-ba5facbe969d    60838766590017
# 1    1048670  dde1485a-a006-4e76-9bde-815d49731139    60810486700146
# 2    1665988  a026eede-c9c6-4ef6-bce1-5fcbb446e4ef    60816659880016
# 3    3037186  efb501f6-4db8-47c8-9c80-277b4ec3edab    60830371860011
# 4    3713545  3d4efb65-52d5-4ff2-8740-8f499b6491c7    60837135450011
#
#        modelDisplayName Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash   0.5594011933532865   2025-12-10 21:18:59
# 1  beta_demo_model_cash   0.4519739510897631   2025-10-03 07:48:00
# 2  beta_demo_model_cash  0.39957301633514664   2025-10-06 06:08:45
# 3  beta_demo_model_cash   0.5680718209153103   2025-10-05 10:20:06
# 4  beta_demo_model_cash  0.46916570709919714   2025-09-29 19:36:21
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-12-11           2025-12           Test        0                1
# 1       2025-10-03           2025-10           Test        0                1
# 2       2025-10-06           2025-10           Test        0                1
# 3       2025-10-07           2025-10           Test        0                1
# 4       2025-09-30           2025-09           Test        1                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 1    not applicable
# 1         Quick             v1       Trench 2    not applicable
# 2         Quick             v1       Trench 2    not applicable
# 3         Quick             v1       Trench 2    not applicable
# 4         Quick             v1       Trench 1    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  case when modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ) 
  ,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (38711, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#        modelDisplayName  Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash              0.519114   2024-10-21 22:41:59
# 1  beta_demo_model_cash              0.592263   2024-12-27 16:40:09
# 2  beta_demo_model_cash              0.380366   2025-05-19 07:45:14
# 3  beta_demo_model_cash              0.417802   2025-08-02 09:46:51
# 4  beta_demo_model_cash              0.500240   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2024-10-24           2024-10          Train        0                1
# 1       2024-12-27           2024-12          Train        0                1
# 2       2025-05-20           2025-05          Train        0                1
# 3       2025-08-02           2025-08          Train        0                1
# 4       2025-01-29           2025-01          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (51041, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3876659  8a3deacb-0fee-4f7f-aae8-ba5facbe969d    60838766590017
# 1    1048670  dde1485a-a006-4e76-9bde-815d49731139    60810486700146
# 2    1665988  a026eede-c9c6-4ef6-bce1-5fcbb446e4ef    60816659880016
# 3    3037186  efb501f6-4db8-47c8-9c80-277b4ec3edab    60830371860011
# 4    3883862  564ca526-e0e3-4ceb-84be-8885e398c001    60838838620011
#
#        modelDisplayName Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash   0.5594011933532865   2025-12-10 21:18:59
# 1  beta_demo_model_cash   0.4519739510897631   2025-10-03 07:48:00
# 2  beta_demo_model_cash  0.39957301633514664   2025-10-06 06:08:45
# 3  beta_demo_model_cash   0.5680718209153103   2025-10-05 10:20:06
# 4  beta_demo_model_cash  0.48163151047871366   2025-12-11 11:25:42
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-12-11           2025-12           Test        0                1
# 1       2025-10-03           2025-10           Test        0                1
# 2       2025-10-06           2025-10           Test        0                1
# 3       2025-10-07           2025-10           Test        0                1
# 4       2025-12-11           2025-12           Test        1                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 1    not applicable
# 1         Quick             v1       Trench 2    not applicable
# 2         Quick             v1       Trench 2    not applicable
# 3         Quick             v1       Trench 2    not applicable
# 4         Quick             v1       Trench 1    not applicable

# %%
df_concat['Beta_Cash_Demo_Score'] = pd.to_numeric(df_concat['Beta_Cash_Demo_Score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_Cash_Demo_Score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (5272, 16)
# The shape of the dimension table is:	 (96, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=78004d01-52c5-4be6-b04f-df0a08374d55>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=4d262da4-fc8b-44e8-ae08-d0d06c61e593>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when p.modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p 
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (10232, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    2335443  855135e0-dce2-4a34-aef9-8d5a798c1bb5    60823354430038
# 1    3177894  940a265b-e43b-4985-905f-675f8ea3787b    60831778940018
# 2    3278809  26bf9f80-b3bd-423b-9bfe-36c7925669a0    60832788090031
# 3    3169977  cc4d2ac6-b418-4121-bcd7-7ba549863169    60831699770013
# 4    3716699  ebf77a21-f66f-4aad-a017-50f61cf5ff41    60837166990019
#
#        modelDisplayName Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash   0.4371811166121919   2025-09-30 15:21:22
# 1  beta_demo_model_cash   0.4820533013172368   2025-10-01 18:05:45
# 2  beta_demo_model_cash   0.2326411399269976   2025-12-01 22:09:31
# 3  beta_demo_model_cash  0.41257898743841587   2025-09-26 20:29:59
# 4  beta_demo_model_cash  0.46707556939028344   2025-10-01 15:09:43
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-01           2025-09           Test         0
# 1       2025-10-03           2025-10           Test         0
# 2       2025-12-02           2025-12           Test         0
# 3       2025-09-26           2025-09           Test         0
# 4       2025-10-01           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 3
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 2
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  case when modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  )
  ,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (38711, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#        modelDisplayName  Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash              0.519114   2024-10-21 22:41:59
# 1  beta_demo_model_cash              0.592263   2024-12-27 16:40:09
# 2  beta_demo_model_cash              0.380366   2025-05-19 07:45:14
# 3  beta_demo_model_cash              0.417802   2025-08-02 09:46:51
# 4  beta_demo_model_cash              0.500240   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2024-10-24           2024-10          Train         0
# 1       2024-12-27           2024-12          Train         0
# 2       2025-05-20           2025-05          Train         0
# 3       2025-08-02           2025-08          Train         0
# 4       2025-01-29           2025-01          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (48888, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3177894  940a265b-e43b-4985-905f-675f8ea3787b    60831778940018
# 1    3278809  26bf9f80-b3bd-423b-9bfe-36c7925669a0    60832788090031
# 2    3716699  ebf77a21-f66f-4aad-a017-50f61cf5ff41    60837166990019
# 3    3812039  ca19cc8d-6af3-4041-ad1e-9063d3b51772    60838120390019
# 4    3190544  e5324fe5-34e5-4718-803c-84b1b2402b7d    60831905440011
#
#        modelDisplayName Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash   0.4820533013172368   2025-10-01 18:05:45
# 1  beta_demo_model_cash   0.2326411399269976   2025-12-01 22:09:31
# 2  beta_demo_model_cash  0.46707556939028344   2025-10-01 15:09:43
# 3  beta_demo_model_cash   0.4530701291457141   2025-11-15 17:51:38
# 4  beta_demo_model_cash  0.47523794807523034   2025-10-05 12:24:42
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-03           2025-10           Test         0
# 1       2025-12-02           2025-12           Test         0
# 2       2025-10-01           2025-10           Test         0
# 3       2025-11-30           2025-11           Test         0
# 4       2025-10-06           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['Beta_Cash_Demo_Score'] = pd.to_numeric(df_concat['Beta_Cash_Demo_Score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_Cash_Demo_Score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=15f98f35-2a72-42c4-a11c-4168f1d80e0d>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=331f7ed3-87be-44dc-9bf3-3a0a9a924fbf>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when p.modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p 
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (4589, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3704941  8c979bb5-6c9f-490a-b0da-ee86863eebc4    60837049410017
# 1    2839095  f7c5bf04-8260-4edc-bf79-1ef554397b20    60828390950018
# 2    3307096  e8d69ec8-866a-47c8-a944-067cb83ac800    60833070960021
# 3    2976559  ecab59b9-e3a0-4cdc-a517-6360410a4a1e    60829765590047
# 4    2115774  064ede1f-2c05-4357-a648-cd3643f60c53    60821157740032
#
#        modelDisplayName Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash  0.48017319053394103   2025-09-25 19:31:42
# 1  beta_demo_model_cash   0.5925505149206745   2025-10-01 09:23:09
# 2  beta_demo_model_cash    0.368269602108865   2025-09-28 17:18:59
# 3  beta_demo_model_cash   0.3285000516072791   2025-09-29 07:22:42
# 4  beta_demo_model_cash  0.36579544923775387   2025-09-27 05:43:27
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-09-26           2025-09           Test         0
# 1       2025-10-07           2025-10           Test         0
# 2       2025-09-29           2025-09           Test         0
# 3       2025-09-29           2025-09           Test         0
# 4       2025-09-27           2025-09           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 3
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  case when modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ) ,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (38711, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#        modelDisplayName  Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash              0.519114   2024-10-21 22:41:59
# 1  beta_demo_model_cash              0.592263   2024-12-27 16:40:09
# 2  beta_demo_model_cash              0.380366   2025-05-19 07:45:14
# 3  beta_demo_model_cash              0.417802   2025-08-02 09:46:51
# 4  beta_demo_model_cash              0.500240   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2024-10-24           2024-10          Train         0
# 1       2024-12-27           2024-12          Train         0
# 2       2025-05-20           2025-05          Train         0
# 3       2025-08-02           2025-08          Train         0
# 4       2025-01-29           2025-01          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (43245, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    2839095  f7c5bf04-8260-4edc-bf79-1ef554397b20    60828390950018
# 1    3804146  d26dadf9-4ee4-477c-a98d-5c9dd3b2b40a    60838041460014
# 2    2863259  78fce405-fd35-4832-ab50-eb15cbf54b89    60828632590029
# 3    3357515  58f0e9c2-1805-4158-a3d6-c8f5759aa2af    60833575150024
# 4    3719863  b303f8bd-0058-4094-9fdc-06b2ae5977cb    60837198630015
#
#        modelDisplayName Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash   0.5925505149206745   2025-10-01 09:23:09
# 1  beta_demo_model_cash  0.43202321571409774   2025-11-11 04:10:46
# 2  beta_demo_model_cash   0.3076303999084381   2025-10-02 10:17:03
# 3  beta_demo_model_cash  0.41511694419907225   2025-10-02 16:13:23
# 4  beta_demo_model_cash   0.5256206127993124   2025-10-03 01:45:34
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-10-07           2025-10           Test         0
# 1       2025-11-13           2025-11           Test         0
# 2       2025-10-02           2025-10           Test         0
# 3       2025-10-02           2025-10           Test         0
# 4       2025-10-03           2025-10           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['Beta_Cash_Demo_Score'] = pd.to_numeric(df_concat['Beta_Cash_Demo_Score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_Cash_Demo_Score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=81119e58-bb43-4390-9533-c9aae37fea5e>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=495dc495-16d5-4b7f-a24e-f3abc14b6f75>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when p.modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p 
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (214, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3703482  037a6eee-07c8-4d81-9dce-b61a17021763    60837034820017
# 1    2722716  1f24fed3-c7e8-49f3-a3aa-c7a963e112e9    60827227160049
# 2    3734945  4afa5c84-4240-4821-9533-b3f82d1b5e59    60837349450016
# 3    3063690  7d14e64c-c945-4fdf-b6ab-49af16d488e3    60830636900011
# 4    3174284  006766c8-3f5f-4d30-8257-52f9bfc3a110    60831742840016
#
#        modelDisplayName Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash   0.6492902072427663   2025-09-25 00:37:17
# 1  beta_demo_model_cash   0.3033643226925143   2025-10-11 12:16:52
# 2  beta_demo_model_cash   0.4671979367419429   2025-10-10 13:00:08
# 3  beta_demo_model_cash   0.5266074487793155   2025-10-10 22:18:59
# 4  beta_demo_model_cash   0.5599758927414684   2025-09-29 17:57:23
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-09-25           2025-09           Test          1
# 1       2025-10-11           2025-10           Test          0
# 2       2025-10-10           2025-10           Test          1
# 3       2025-10-11           2025-10           Test          0
# 4       2025-09-30           2025-09           Test          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 1
# 1                   1         Quick             v1       Trench 3
# 2                   1         Quick             v1       Trench 1
# 3                   1         Quick             v1       Trench 2
# 4                   1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  case when modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  )
  , 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (38691, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#        modelDisplayName  Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash              0.519114   2024-10-21 22:41:59
# 1  beta_demo_model_cash              0.592263   2024-12-27 16:40:09
# 2  beta_demo_model_cash              0.380366   2025-05-19 07:45:14
# 3  beta_demo_model_cash              0.417802   2025-08-02 09:46:51
# 4  beta_demo_model_cash              0.500240   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2024-10-24           2024-10          Train          0
# 1       2024-12-27           2024-12          Train          0
# 2       2025-05-20           2025-05          Train          0
# 3       2025-08-02           2025-08          Train          0
# 4       2025-01-29           2025-01          Train          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 2
# 1                   1         Quick             v1       Trench 1
# 2                   1         Quick             v1       Trench 3
# 3                   1         Quick             v1       Trench 3
# 4                   1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (38850, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    2722716  1f24fed3-c7e8-49f3-a3aa-c7a963e112e9    60827227160049
# 1    3734945  4afa5c84-4240-4821-9533-b3f82d1b5e59    60837349450016
# 2    3063690  7d14e64c-c945-4fdf-b6ab-49af16d488e3    60830636900011
# 3    3733400  16003553-7248-400a-92d3-e5d2f7a2f03d    60837334000014
# 4    2473116  70dedacb-577f-433e-bfbf-4d57973ff5ea    60824731160018
#
#        modelDisplayName Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash   0.3033643226925143   2025-10-11 12:16:52
# 1  beta_demo_model_cash   0.4671979367419429   2025-10-10 13:00:08
# 2  beta_demo_model_cash   0.5266074487793155   2025-10-10 22:18:59
# 3  beta_demo_model_cash   0.2841739249025936   2025-10-09 14:46:23
# 4  beta_demo_model_cash   0.5784879945509713   2025-10-03 20:45:57
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-11           2025-10           Test          0
# 1       2025-10-10           2025-10           Test          1
# 2       2025-10-11           2025-10           Test          0
# 3       2025-10-09           2025-10           Test          0
# 4       2025-10-03           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 3
# 1                   1         Quick             v1       Trench 1
# 2                   1         Quick             v1       Trench 2
# 3                   1         Quick             v1       Trench 1
# 4                   1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['Beta_Cash_Demo_Score'] = pd.to_numeric(df_concat['Beta_Cash_Demo_Score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_Cash_Demo_Score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=0efc5af4-bc40-45da-ae48-5f6e5962bf75>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=92df198c-81b8-4be9-99c9-144689dac123>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),
model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when p.modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p 
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (0, 15)
# Empty DataFrame
# Columns: [customerId, digitalLoanAccountId, loanAccountNumber, modelDisplayName, Beta_Cash_Demo_Score, appln_submit_datetime, disbursementdate, Application_month, Data_selection, deffstpd30, flg_mature_fstpd_30, new_loan_type, modelVersionId, trenchCategory, loan_product_type]
# Index: []

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """ 
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in ('Beta-Cash-Demo-Model', 'beta_demo_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_Cash_Demo_Score,
  case when modelDisplayName like 'Beta-Cash-Demo-Model' then 'beta_demo_model_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_Cash_Demo_Score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_Cash_Demo_Score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (36478, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#        modelDisplayName  Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash              0.519114   2024-10-21 22:41:59
# 1  beta_demo_model_cash              0.592263   2024-12-27 16:40:09
# 2  beta_demo_model_cash              0.380366   2025-05-19 07:45:14
# 3  beta_demo_model_cash              0.417802   2025-08-02 09:46:51
# 4  beta_demo_model_cash              0.500240   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-10-24           2024-10          Train           0
# 1       2024-12-27           2024-12          Train           0
# 2       2025-05-20           2025-05          Train           0
# 3       2025-08-02           2025-08          Train           1
# 4       2025-01-29           2025-01          Train           1
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1         Quick             v1       Trench 2
# 1                    1         Quick             v1       Trench 1
# 2                    1         Quick             v1       Trench 3
# 3                    1         Quick             v1       Trench 3
# 4                    1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (36478, 15)
# C:\Users\Dwaipayan\AppData\Local\Temp\ipykernel_49316\2946223290.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#        modelDisplayName  Beta_Cash_Demo_Score appln_submit_datetime  \
# 0  beta_demo_model_cash              0.519114   2024-10-21 22:41:59
# 1  beta_demo_model_cash              0.592263   2024-12-27 16:40:09
# 2  beta_demo_model_cash              0.380366   2025-05-19 07:45:14
# 3  beta_demo_model_cash              0.417802   2025-08-02 09:46:51
# 4  beta_demo_model_cash              0.500240   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-10-24           2024-10          Train           0
# 1       2024-12-27           2024-12          Train           0
# 2       2025-05-20           2025-05          Train           0
# 3       2025-08-02           2025-08          Train           1
# 4       2025-01-29           2025-01          Train           1
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1         Quick             v1       Trench 2
# 1                    1         Quick             v1       Trench 1
# 2                    1         Quick             v1       Trench 3
# 3                    1         Quick             v1       Trench 3
# 4                    1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['Beta_Cash_Demo_Score'] = pd.to_numeric(df_concat['Beta_Cash_Demo_Score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_Cash_Demo_Score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_demo_model_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (3968, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=c653a20b-e9e6-41fd-b384-e05c40a47c06>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=34d8dff0-7cb3-482e-82d9-c7daaf637dc7>

# %% [markdown]
# ## Beta-Cash-AppScore-Model

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  coalesce(SAFE_CAST(JSON_VALUE(p.prediction_clean, "$.combined_score") AS Float64)) AS beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory"))  trenchCategory
  from latest_request p
  left join model_run m on p.digitalLoanAccountId = m.digitalLoanAccountId
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select  distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (7564, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    2510192  48f2a2c9-d45c-4183-aed8-d674f1bfbaa9    60825101920014
# 1    3883281  a032d043-0077-4c16-bfdb-cff96a4c3c24    60838832810016
# 2    3174284  006766c8-3f5f-4d30-8257-52f9bfc3a110    60831742840016
# 3    3201341  35066458-9a4d-4d64-855c-b21ebf440fe8    60832013410025
# 4    3818341  bbc81aba-7d73-496e-9dcc-1324bb732884    60838183410016
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.508208   2025-12-06 00:51:41
# 1  apps_score_cash             0.546624   2025-12-11 11:20:18
# 2  apps_score_cash             0.453937   2025-09-29 17:57:23
# 3  apps_score_cash             0.561418   2025-09-30 16:54:39
# 4  apps_score_cash             0.499778   2025-11-23 16:02:01
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-12-11           2025-12           Test        0                1
# 1       2025-12-11           2025-12           Test        0                1
# 2       2025-09-30           2025-09           Test        1                1
# 3       2025-09-30           2025-09           Test        0                1
# 4       2025-12-23           2025-11           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 2    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 1    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  )
  ,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (50912, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2928450  0000598b-5876-42d6-b8fe-0c3d2c321763    60829284500022
# 1     2630496  00008e64-1df1-421e-b2b7-55f7a5469cd9    60826304960039
# 2     2681396  0000f659-c75c-40b9-baef-77afcb39b909    60826813960027
# 3     2439160  0001c930-62e8-4709-bb91-702ef24f0452    60824391600024
# 4     2759575  00034566-8f87-4b9b-83d9-92591f865054    60827595750021
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.503091   2025-06-27 16:48:11
# 1  apps_score_cash             0.519722   2025-09-11 13:17:40
# 2  apps_score_cash             0.473173   2025-08-20 16:31:57
# 3  apps_score_cash             0.555488   2025-04-10 18:13:23
# 4  apps_score_cash             0.548735   2025-07-11 13:44:34
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-06-27           2025-06          Train        0                1
# 1       2025-09-11           2025-09          Train        0                1
# 2       2025-08-20           2025-08          Train        1                1
# 3       2025-04-10           2025-04          Train        1                1
# 4       2025-07-11           2025-07          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0    SIL Repeat             v1       Trench 3         Appliance
# 1       Flex-up             v1       Trench 3    not applicable
# 2       Flex-up             v1       Trench 3    not applicable
# 3       Flex-up             v1       Trench 3    not applicable
# 4   SIL-Instore             v1       Trench 3         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (58449, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    2510192  48f2a2c9-d45c-4183-aed8-d674f1bfbaa9    60825101920014
# 1    3883281  a032d043-0077-4c16-bfdb-cff96a4c3c24    60838832810016
# 2    3818341  bbc81aba-7d73-496e-9dcc-1324bb732884    60838183410016
# 3    3827425  4035291a-a93d-4029-b98f-864d9be04f13    60838274250011
# 4    3884002  60cc88a8-b9cf-4247-925f-d1dc41d31f23    60838840020019
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.508208   2025-12-06 00:51:41
# 1  apps_score_cash             0.546624   2025-12-11 11:20:18
# 2  apps_score_cash             0.499778   2025-11-23 16:02:01
# 3  apps_score_cash             0.424154   2025-12-10 21:00:09
# 4  apps_score_cash             0.502639   2025-12-11 11:53:30
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-12-11           2025-12           Test        0                1
# 1       2025-12-11           2025-12           Test        0                1
# 2       2025-12-23           2025-11           Test        0                1
# 3       2025-12-11           2025-12           Test        0                1
# 4       2025-12-11           2025-12           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 1    not applicable
# 3         Quick             v1       Trench 1    not applicable
# 4         Quick             v1       Trench 1    not applicable

# %%
df_concat['beta_cash_app_score'] = pd.to_numeric(df_concat['beta_cash_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'beta_cash_app_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (14292, 16)
# The shape of the dimension table is:	 (272, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=a0fbf8f6-f9c4-4f6e-93db-9e2030e0cc6a>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=6f773936-995c-4c3a-a041-771dc56bb00f>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  coalesce(SAFE_CAST(JSON_VALUE(p.prediction_clean, "$.combined_score") AS Float64)) AS beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory"))  trenchCategory
  from latest_request p
  left join model_run m on p.digitalLoanAccountId = m.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (6159, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3727354  8e379611-21ba-40ea-b1e8-ad52ea9cd44e    60837273540016
# 1    3454126  df46c32e-31ad-4938-9c5f-cc955e563420    60834541260029
# 2    3716782  1616f4ec-1811-4744-8ec4-9ec17cf862bb    60837167820013
# 3    3476447  2ca3d55c-b048-4b15-9953-cbc13198e689    60834764470013
# 4    3844138  9e9363f9-aff1-464a-b1fd-969bfadee255    60838441380014
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.457528   2025-10-06 17:04:21
# 1  apps_score_cash             0.459632   2025-11-29 00:02:31
# 2  apps_score_cash             0.507565   2025-10-01 14:33:37
# 3  apps_score_cash             0.503109   2025-12-01 23:34:41
# 4  apps_score_cash             0.379473   2025-11-29 06:43:38
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-07           2025-10           Test         0
# 1       2025-11-29           2025-11           Test         0
# 2       2025-10-06           2025-10           Test         0
# 3       2025-12-02           2025-12           Test         0
# 4       2025-11-29           2025-11           Test         1
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 2
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  )
  ,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (50912, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2928450  0000598b-5876-42d6-b8fe-0c3d2c321763    60829284500022
# 1     2630496  00008e64-1df1-421e-b2b7-55f7a5469cd9    60826304960039
# 2     2681396  0000f659-c75c-40b9-baef-77afcb39b909    60826813960027
# 3     2439160  0001c930-62e8-4709-bb91-702ef24f0452    60824391600024
# 4     2759575  00034566-8f87-4b9b-83d9-92591f865054    60827595750021
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.503091   2025-06-27 16:48:11
# 1  apps_score_cash             0.519722   2025-09-11 13:17:40
# 2  apps_score_cash             0.473173   2025-08-20 16:31:57
# 3  apps_score_cash             0.555488   2025-04-10 18:13:23
# 4  apps_score_cash             0.548735   2025-07-11 13:44:34
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-06-27           2025-06          Train         0
# 1       2025-09-11           2025-09          Train         0
# 2       2025-08-20           2025-08          Train         0
# 3       2025-04-10           2025-04          Train         1
# 4       2025-07-11           2025-07          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1    SIL Repeat             v1       Trench 3
# 1                 1       Flex-up             v1       Trench 3
# 2                 1       Flex-up             v1       Trench 3
# 3                 1       Flex-up             v1       Trench 3
# 4                 1   SIL-Instore             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (57044, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3727354  8e379611-21ba-40ea-b1e8-ad52ea9cd44e    60837273540016
# 1    3454126  df46c32e-31ad-4938-9c5f-cc955e563420    60834541260029
# 2    3716782  1616f4ec-1811-4744-8ec4-9ec17cf862bb    60837167820013
# 3    3476447  2ca3d55c-b048-4b15-9953-cbc13198e689    60834764470013
# 4    3844138  9e9363f9-aff1-464a-b1fd-969bfadee255    60838441380014
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.457528   2025-10-06 17:04:21
# 1  apps_score_cash             0.459632   2025-11-29 00:02:31
# 2  apps_score_cash             0.507565   2025-10-01 14:33:37
# 3  apps_score_cash             0.503109   2025-12-01 23:34:41
# 4  apps_score_cash             0.379473   2025-11-29 06:43:38
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-07           2025-10           Test         0
# 1       2025-11-29           2025-11           Test         0
# 2       2025-10-06           2025-10           Test         0
# 3       2025-12-02           2025-12           Test         0
# 4       2025-11-29           2025-11           Test         1
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 2
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['beta_cash_app_score'] = pd.to_numeric(df_concat['beta_cash_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'beta_cash_app_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=49d403f4-d4ed-45fc-9b59-96832e92596b>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=7cb86e9f-f668-4723-a5fe-3e0b556232c8>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  coalesce(SAFE_CAST(JSON_VALUE(p.prediction_clean, "$.combined_score") AS Float64)) AS beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory"))  trenchCategory
  from latest_request p
  left join model_run m on p.digitalLoanAccountId = m.digitalLoanAccountId
  ), 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (2825, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3724609  4ba81131-474b-44a7-b127-4f1ea1de1fc4    60837246090018
# 1    3190544  e5324fe5-34e5-4718-803c-84b1b2402b7d    60831905440011
# 2    3338490  9da8823e-ac4c-4d0f-890a-05788b02b3a5    60833384900026
# 3    2473116  70dedacb-577f-433e-bfbf-4d57973ff5ea    60824731160018
# 4    3479077  628bb8f9-78bd-4a36-bd17-80d4f85852d9    60834790770019
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.381738   2025-10-05 12:26:56
# 1  apps_score_cash             0.418145   2025-10-05 12:24:42
# 2  apps_score_cash             0.484769   2025-10-04 23:10:38
# 3  apps_score_cash             0.466156   2025-10-03 20:45:57
# 4  apps_score_cash             0.497121   2025-10-03 19:44:09
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-10-06           2025-10           Test         1
# 1       2025-10-06           2025-10           Test         0
# 2       2025-10-05           2025-10           Test         0
# 3       2025-10-03           2025-10           Test         0
# 4       2025-10-03           2025-10           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 2
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (50912, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2928450  0000598b-5876-42d6-b8fe-0c3d2c321763    60829284500022
# 1     2630496  00008e64-1df1-421e-b2b7-55f7a5469cd9    60826304960039
# 2     2681396  0000f659-c75c-40b9-baef-77afcb39b909    60826813960027
# 3     2439160  0001c930-62e8-4709-bb91-702ef24f0452    60824391600024
# 4     2759575  00034566-8f87-4b9b-83d9-92591f865054    60827595750021
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.503091   2025-06-27 16:48:11
# 1  apps_score_cash             0.519722   2025-09-11 13:17:40
# 2  apps_score_cash             0.473173   2025-08-20 16:31:57
# 3  apps_score_cash             0.555488   2025-04-10 18:13:23
# 4  apps_score_cash             0.548735   2025-07-11 13:44:34
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-06-27           2025-06          Train         0
# 1       2025-09-11           2025-09          Train         0
# 2       2025-08-20           2025-08          Train         0
# 3       2025-04-10           2025-04          Train         1
# 4       2025-07-11           2025-07          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1    SIL Repeat             v1       Trench 3
# 1                 1       Flex-up             v1       Trench 3
# 2                 1       Flex-up             v1       Trench 3
# 3                 1       Flex-up             v1       Trench 3
# 4                 1   SIL-Instore             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (53710, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3724609  4ba81131-474b-44a7-b127-4f1ea1de1fc4    60837246090018
# 1    3190544  e5324fe5-34e5-4718-803c-84b1b2402b7d    60831905440011
# 2    3338490  9da8823e-ac4c-4d0f-890a-05788b02b3a5    60833384900026
# 3    2473116  70dedacb-577f-433e-bfbf-4d57973ff5ea    60824731160018
# 4    3479077  628bb8f9-78bd-4a36-bd17-80d4f85852d9    60834790770019
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.381738   2025-10-05 12:26:56
# 1  apps_score_cash             0.418145   2025-10-05 12:24:42
# 2  apps_score_cash             0.484769   2025-10-04 23:10:38
# 3  apps_score_cash             0.466156   2025-10-03 20:45:57
# 4  apps_score_cash             0.497121   2025-10-03 19:44:09
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-10-06           2025-10           Test         1
# 1       2025-10-06           2025-10           Test         0
# 2       2025-10-05           2025-10           Test         0
# 3       2025-10-03           2025-10           Test         0
# 4       2025-10-03           2025-10           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 2
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['beta_cash_app_score'] = pd.to_numeric(df_concat['beta_cash_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'beta_cash_app_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=2f32bc53-72a4-461c-a430-02ac14780d12>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=dbaefa78-502a-45ec-8caf-654d4639bb93>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  coalesce(SAFE_CAST(JSON_VALUE(p.prediction_clean, "$.combined_score") AS Float64)) AS beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory"))  trenchCategory
  from latest_request p
  left join model_run m on p.digitalLoanAccountId = m.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select  distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (130, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3728353  4f50c223-6b13-447b-b003-4f1a1209a9f4    60837283530019
# 1    3306132  03caca37-b929-4b5e-8107-d5eb4504423d    60833061320024
# 2    3090214  8b4e0f30-db10-4bff-ba1d-fd96ffdc34b1    60830902140011
# 3    3307972  578e53fa-13fb-4e8b-9899-ac0098ee3940    60833079720021
# 4    3085915  e390233e-a049-492e-b6a0-0604b1a1ed7a    60830859150033
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.399435   2025-10-06 23:27:56
# 1  apps_score_cash             0.476951   2025-10-11 06:37:44
# 2  apps_score_cash             0.475899   2025-10-05 20:30:05
# 3  apps_score_cash             0.516398   2025-10-12 09:18:42
# 4  apps_score_cash             0.494442   2025-10-11 05:47:35
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-07           2025-10           Test          0
# 1       2025-10-11           2025-10           Test          0
# 2       2025-10-05           2025-10           Test          0
# 3       2025-10-12           2025-10           Test          0
# 4       2025-10-11           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 1
# 1                   1         Quick             v1       Trench 3
# 2                   1         Quick             v1       Trench 2
# 3                   1         Quick             v1       Trench 3
# 4                   1         Quick             v1       Trench 3
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  )
  , 
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (50635, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2928450  0000598b-5876-42d6-b8fe-0c3d2c321763    60829284500022
# 1     2630496  00008e64-1df1-421e-b2b7-55f7a5469cd9    60826304960039
# 2     2681396  0000f659-c75c-40b9-baef-77afcb39b909    60826813960027
# 3     2439160  0001c930-62e8-4709-bb91-702ef24f0452    60824391600024
# 4     2759575  00034566-8f87-4b9b-83d9-92591f865054    60827595750021
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.503091   2025-06-27 16:48:11
# 1  apps_score_cash             0.519722   2025-09-11 13:17:40
# 2  apps_score_cash             0.473173   2025-08-20 16:31:57
# 3  apps_score_cash             0.555488   2025-04-10 18:13:23
# 4  apps_score_cash             0.548735   2025-07-11 13:44:34
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-06-27           2025-06          Train          0
# 1       2025-09-11           2025-09          Train          0
# 2       2025-08-20           2025-08          Train          0
# 3       2025-04-10           2025-04          Train          1
# 4       2025-07-11           2025-07          Train          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1    SIL Repeat             v1       Trench 3
# 1                   1       Flex-up             v1       Trench 3
# 2                   1       Flex-up             v1       Trench 3
# 3                   1       Flex-up             v1       Trench 3
# 4                   1   SIL-Instore             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (50738, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3728353  4f50c223-6b13-447b-b003-4f1a1209a9f4    60837283530019
# 1    3306132  03caca37-b929-4b5e-8107-d5eb4504423d    60833061320024
# 2    3090214  8b4e0f30-db10-4bff-ba1d-fd96ffdc34b1    60830902140011
# 3    3307972  578e53fa-13fb-4e8b-9899-ac0098ee3940    60833079720021
# 4    3085915  e390233e-a049-492e-b6a0-0604b1a1ed7a    60830859150033
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.399435   2025-10-06 23:27:56
# 1  apps_score_cash             0.476951   2025-10-11 06:37:44
# 2  apps_score_cash             0.475899   2025-10-05 20:30:05
# 3  apps_score_cash             0.516398   2025-10-12 09:18:42
# 4  apps_score_cash             0.494442   2025-10-11 05:47:35
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-07           2025-10           Test          0
# 1       2025-10-11           2025-10           Test          0
# 2       2025-10-05           2025-10           Test          0
# 3       2025-10-12           2025-10           Test          0
# 4       2025-10-11           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 1
# 1                   1         Quick             v1       Trench 3
# 2                   1         Quick             v1       Trench 2
# 3                   1         Quick             v1       Trench 3
# 4                   1         Quick             v1       Trench 3
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['beta_cash_app_score'] = pd.to_numeric(df_concat['beta_cash_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'beta_cash_app_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=002c9eb6-b37d-4874-9aa7-33a901c2cb61>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=c2586e66-0bfb-40f4-b2db-6e29a9d2b82e>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  coalesce(SAFE_CAST(JSON_VALUE(p.prediction_clean, "$.combined_score") AS Float64)) AS beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  p.modelVersionId,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory"))  trenchCategory
  from latest_request p
  left join model_run m on p.digitalLoanAccountId = m.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (0, 15)
# Empty DataFrame
# Columns: [customerId, digitalLoanAccountId, loanAccountNumber, modelDisplayName, beta_cash_app_score, appln_submit_datetime, disbursementdate, Application_month, Data_selection, deffstpd30, flg_mature_fstpd_30, new_loan_type, modelVersionId, trenchCategory, loan_product_type]
# Index: []

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-AppScore-Model', 'apps_score_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction beta_cash_app_score,
  case when modelDisplayName like 'Beta-Cash-AppScore-Model' then 'apps_score_cash' else modelDisplayName end as modelDisplayName,
  modelVersionId,
  trenchCategory
  from parsed
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.beta_cash_app_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.beta_cash_app_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (46700, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2928450  0000598b-5876-42d6-b8fe-0c3d2c321763    60829284500022
# 1     2681396  0000f659-c75c-40b9-baef-77afcb39b909    60826813960027
# 2     2439160  0001c930-62e8-4709-bb91-702ef24f0452    60824391600024
# 3     2759575  00034566-8f87-4b9b-83d9-92591f865054    60827595750021
# 4     2425873  00045464-7151-4e39-af4f-140a5d34bb17    60824258730029
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.503091   2025-06-27 16:48:11
# 1  apps_score_cash             0.473173   2025-08-20 16:31:57
# 2  apps_score_cash             0.555488   2025-04-10 18:13:23
# 3  apps_score_cash             0.548735   2025-07-11 13:44:34
# 4  apps_score_cash             0.540626   2025-07-06 15:53:10
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-06-27           2025-06          Train           0
# 1       2025-08-20           2025-08          Train           1
# 2       2025-04-10           2025-04          Train           1
# 3       2025-07-11           2025-07          Train           0
# 4       2025-07-06           2025-07          Train           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1    SIL Repeat             v1       Trench 3
# 1                    1       Flex-up             v1       Trench 3
# 2                    1       Flex-up             v1       Trench 3
# 3                    1   SIL-Instore             v1       Trench 3
# 4                    1    SIL Repeat             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1    not applicable
# 2    not applicable
# 3         Appliance
# 4         Appliance

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (46700, 15)
# C:\Users\Dwaipayan\AppData\Local\Temp\ipykernel_49316\2946223290.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2928450  0000598b-5876-42d6-b8fe-0c3d2c321763    60829284500022
# 1     2681396  0000f659-c75c-40b9-baef-77afcb39b909    60826813960027
# 2     2439160  0001c930-62e8-4709-bb91-702ef24f0452    60824391600024
# 3     2759575  00034566-8f87-4b9b-83d9-92591f865054    60827595750021
# 4     2425873  00045464-7151-4e39-af4f-140a5d34bb17    60824258730029
#
#   modelDisplayName  beta_cash_app_score appln_submit_datetime  \
# 0  apps_score_cash             0.503091   2025-06-27 16:48:11
# 1  apps_score_cash             0.473173   2025-08-20 16:31:57
# 2  apps_score_cash             0.555488   2025-04-10 18:13:23
# 3  apps_score_cash             0.548735   2025-07-11 13:44:34
# 4  apps_score_cash             0.540626   2025-07-06 15:53:10
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2025-06-27           2025-06          Train           0
# 1       2025-08-20           2025-08          Train           1
# 2       2025-04-10           2025-04          Train           1
# 3       2025-07-11           2025-07          Train           0
# 4       2025-07-06           2025-07          Train           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1    SIL Repeat             v1       Trench 3
# 1                    1       Flex-up             v1       Trench 3
# 2                    1       Flex-up             v1       Trench 3
# 3                    1   SIL-Instore             v1       Trench 3
# 4                    1    SIL Repeat             v1       Trench 3
#
#   loan_product_type
# 0         Appliance
# 1    not applicable
# 2    not applicable
# 3         Appliance
# 4         Appliance

# %%
df_concat['beta_cash_app_score'] = pd.to_numeric(df_concat['beta_cash_app_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'beta_cash_app_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='apps_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (12544, 16)
# The shape of the dimension table is:	 (240, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=d0c15e4d-f2d3-41e8-9395-4f9e59f400e9>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=1f87d04d-f294-4fc7-860f-85047a633975>

# %% [markdown]
# ## Beta-Cash-Stack-Model

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
and modelVersionId = 'v1'
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction AS Beta_cash_stack_score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select 
  distinct
  r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and flg_mature_fpd0 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (12385, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    1939255  189e94f7-4587-444e-9be9-39ab39f5ab4c    60819392550023
# 1    1242524  059f2133-161e-43bd-b5fa-0192e86991ab    60812425240046
# 2    1886335  883ef202-4aa4-41d7-99ff-fd6be2ef69db    60818863350053
# 3    3701246  9c698895-ba1e-4a18-a058-c4cae1311e82    60837012460019
# 4    1665988  a026eede-c9c6-4ef6-bce1-5fcbb446e4ef    60816659880016
#
#         modelDisplayName Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash    0.5562532308602035   2025-10-06 04:14:34
# 1  beta_stack_model_cash   0.34483368835441514   2025-10-01 21:40:29
# 2  beta_stack_model_cash   0.46852337037040115   2025-09-28 18:26:57
# 3  beta_stack_model_cash    0.0455749555692561   2025-10-03 20:32:40
# 4  beta_stack_model_cash    0.4022625749503685   2025-10-06 06:08:45
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-06           2025-10           Test        1                1
# 1       2025-10-01           2025-10           Test        0                1
# 2       2025-09-28           2025-09           Test        0                1
# 3       2025-10-03           2025-10           Test        0                1
# 4       2025-10-06           2025-10           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 3    not applicable
# 1         Quick             v1       Trench 2    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 1    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_cash_stack_score,
    case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else modelDisplayName end as modelDisplayName,
    modelVersionId,
  trenchCategory
  from parsed
  )
,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select 
distinct
r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and flg_mature_fpd0 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (38093, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#         modelDisplayName  Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash               0.373461   2024-10-21 22:41:59
# 1  beta_stack_model_cash               0.629311   2024-12-27 16:40:09
# 2  beta_stack_model_cash               0.646851   2025-05-19 07:45:14
# 3  beta_stack_model_cash               0.207139   2025-08-02 09:46:51
# 4  beta_stack_model_cash               0.777512   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2024-10-24           2024-10          Train        0                1
# 1       2024-12-27           2024-12          Train        0                1
# 2       2025-05-20           2025-05          Train        0                1
# 3       2025-08-02           2025-08          Train        0                1
# 4       2025-01-29           2025-01          Train        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (50423, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    1939255  189e94f7-4587-444e-9be9-39ab39f5ab4c    60819392550023
# 1    1242524  059f2133-161e-43bd-b5fa-0192e86991ab    60812425240046
# 2    3701246  9c698895-ba1e-4a18-a058-c4cae1311e82    60837012460019
# 3    1665988  a026eede-c9c6-4ef6-bce1-5fcbb446e4ef    60816659880016
# 4    3037186  efb501f6-4db8-47c8-9c80-277b4ec3edab    60830371860011
#
#         modelDisplayName Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash    0.5562532308602035   2025-10-06 04:14:34
# 1  beta_stack_model_cash   0.34483368835441514   2025-10-01 21:40:29
# 2  beta_stack_model_cash    0.0455749555692561   2025-10-03 20:32:40
# 3  beta_stack_model_cash    0.4022625749503685   2025-10-06 06:08:45
# 4  beta_stack_model_cash    0.4935454262983421   2025-10-05 10:20:06
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-06           2025-10           Test        1                1
# 1       2025-10-01           2025-10           Test        0                1
# 2       2025-10-03           2025-10           Test        0                1
# 3       2025-10-06           2025-10           Test        0                1
# 4       2025-10-07           2025-10           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 3    not applicable
# 1         Quick             v1       Trench 2    not applicable
# 2         Quick             v1       Trench 1    not applicable
# 3         Quick             v1       Trench 2    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df_concat['Beta_cash_stack_score'] = pd.to_numeric(df_concat['Beta_cash_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_cash_stack_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (5272, 16)
# The shape of the dimension table is:	 (96, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=0d012f28-b015-4e3c-8928-9dbade7cbe3e>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=67412147-fdce-48c6-82be-0a37c52191f3>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
and modelVersionId = 'v1'
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction AS Beta_cash_stack_score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (10232, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3812039  ca19cc8d-6af3-4041-ad1e-9063d3b51772    60838120390019
# 1    3712723  91bc7905-8af5-4ab7-901f-e76dfc0007e2    60837127230016
# 2    3400225  9ee9f723-40d8-427e-8bed-a00c757967ec    60834002250021
# 3    3350730  50e7c6a5-0ed4-4407-9532-d162be43fd29    60833507300013
# 4    3357515  58f0e9c2-1805-4158-a3d6-c8f5759aa2af    60833575150024
#
#         modelDisplayName Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash    0.4982554658843384   2025-11-15 17:51:38
# 1  beta_stack_model_cash    0.9247043533186079   2025-09-29 14:28:22
# 2  beta_stack_model_cash    0.4070234376794603   2025-10-07 10:07:59
# 3  beta_stack_model_cash     0.485721892226709   2025-11-28 20:28:34
# 4  beta_stack_model_cash     0.373608810118396   2025-10-02 16:13:23
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-11-30           2025-11           Test         0
# 1       2025-09-29           2025-09           Test         0
# 2       2025-10-07           2025-10           Test         0
# 3       2025-11-29           2025-11           Test         0
# 4       2025-10-02           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 2
# 4                 1         Quick             v1       Trench 3
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_cash_stack_score,
    case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else modelDisplayName end as modelDisplayName,
    modelVersionId,
  trenchCategory
  from parsed
  )
,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and del.flg_mature_fpd10 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (38093, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#         modelDisplayName  Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash               0.373461   2024-10-21 22:41:59
# 1  beta_stack_model_cash               0.629311   2024-12-27 16:40:09
# 2  beta_stack_model_cash               0.646851   2025-05-19 07:45:14
# 3  beta_stack_model_cash               0.207139   2025-08-02 09:46:51
# 4  beta_stack_model_cash               0.777512   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2024-10-24           2024-10          Train         0
# 1       2024-12-27           2024-12          Train         0
# 2       2025-05-20           2025-05          Train         0
# 3       2025-08-02           2025-08          Train         0
# 4       2025-01-29           2025-01          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (48270, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3812039  ca19cc8d-6af3-4041-ad1e-9063d3b51772    60838120390019
# 1    3400225  9ee9f723-40d8-427e-8bed-a00c757967ec    60834002250021
# 2    3350730  50e7c6a5-0ed4-4407-9532-d162be43fd29    60833507300013
# 3    3357515  58f0e9c2-1805-4158-a3d6-c8f5759aa2af    60833575150024
# 4    3719863  b303f8bd-0058-4094-9fdc-06b2ae5977cb    60837198630015
#
#         modelDisplayName Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash    0.4982554658843384   2025-11-15 17:51:38
# 1  beta_stack_model_cash    0.4070234376794603   2025-10-07 10:07:59
# 2  beta_stack_model_cash     0.485721892226709   2025-11-28 20:28:34
# 3  beta_stack_model_cash     0.373608810118396   2025-10-02 16:13:23
# 4  beta_stack_model_cash    0.5374311700503944   2025-10-03 01:45:34
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-11-30           2025-11           Test         0
# 1       2025-10-07           2025-10           Test         0
# 2       2025-11-29           2025-11           Test         0
# 3       2025-10-02           2025-10           Test         0
# 4       2025-10-03           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 2
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['Beta_cash_stack_score'] = pd.to_numeric(df_concat['Beta_cash_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_cash_stack_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=170ddb52-0d12-4b96-8d15-6e150f7fd33f>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=61719c1f-495e-442b-85a3-f38b878db056>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
and modelVersionId = 'v1'
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction AS Beta_cash_stack_score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (4589, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3792646  13a56d04-6419-4e86-9649-3d952e17d5b3    60837926460011
# 1    3719610  4625afe9-909b-49fb-b373-307600575bc0    60837196100016
# 2    1242524  059f2133-161e-43bd-b5fa-0192e86991ab    60812425240046
# 3    1886335  883ef202-4aa4-41d7-99ff-fd6be2ef69db    60818863350053
# 4    3701246  9c698895-ba1e-4a18-a058-c4cae1311e82    60837012460019
#
#         modelDisplayName Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash    0.2270880085151256   2025-11-06 18:12:43
# 1  beta_stack_model_cash   0.41732586840092595   2025-10-02 20:43:28
# 2  beta_stack_model_cash   0.34483368835441514   2025-10-01 21:40:29
# 3  beta_stack_model_cash   0.46852337037040115   2025-09-28 18:26:57
# 4  beta_stack_model_cash    0.0455749555692561   2025-10-03 20:32:40
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-11-15           2025-11           Test         0
# 1       2025-10-07           2025-10           Test         1
# 2       2025-10-01           2025-10           Test         0
# 3       2025-09-28           2025-09           Test         0
# 4       2025-10-03           2025-10           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 2
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_cash_stack_score,
    case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else modelDisplayName end as modelDisplayName,
    modelVersionId,
  trenchCategory
  from parsed
  )
,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and del.flg_mature_fpd30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (38093, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#         modelDisplayName  Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash               0.373461   2024-10-21 22:41:59
# 1  beta_stack_model_cash               0.629311   2024-12-27 16:40:09
# 2  beta_stack_model_cash               0.646851   2025-05-19 07:45:14
# 3  beta_stack_model_cash               0.207139   2025-08-02 09:46:51
# 4  beta_stack_model_cash               0.777512   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2024-10-24           2024-10          Train         0
# 1       2024-12-27           2024-12          Train         0
# 2       2025-05-20           2025-05          Train         0
# 3       2025-08-02           2025-08          Train         0
# 4       2025-01-29           2025-01          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (42627, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3792646  13a56d04-6419-4e86-9649-3d952e17d5b3    60837926460011
# 1    3719610  4625afe9-909b-49fb-b373-307600575bc0    60837196100016
# 2    1242524  059f2133-161e-43bd-b5fa-0192e86991ab    60812425240046
# 3    3701246  9c698895-ba1e-4a18-a058-c4cae1311e82    60837012460019
# 4    3716699  ebf77a21-f66f-4aad-a017-50f61cf5ff41    60837166990019
#
#         modelDisplayName Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash    0.2270880085151256   2025-11-06 18:12:43
# 1  beta_stack_model_cash   0.41732586840092595   2025-10-02 20:43:28
# 2  beta_stack_model_cash   0.34483368835441514   2025-10-01 21:40:29
# 3  beta_stack_model_cash    0.0455749555692561   2025-10-03 20:32:40
# 4  beta_stack_model_cash   0.41478104212618105   2025-10-01 15:09:43
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-11-15           2025-11           Test         0
# 1       2025-10-07           2025-10           Test         1
# 2       2025-10-01           2025-10           Test         0
# 3       2025-10-03           2025-10           Test         0
# 4       2025-10-01           2025-10           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 2
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['Beta_cash_stack_score'] = pd.to_numeric(df_concat['Beta_cash_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_cash_stack_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=2b18b408-3ce2-4321-8536-3aef4fffedfd>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=5b0a0621-5db9-44ad-8e56-0f87f67c7f74>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
and modelVersionId = 'v1'
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction AS Beta_cash_stack_score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (214, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3722116  50b590d0-66dd-4cde-b9fb-1da158fa8e01    60837221160014
# 1    2635437  cf96ce81-c8d6-468b-a510-a6624c3d0c22    60826354370021
# 2    3730502  d2fe391c-42e1-480d-af9e-80d8c7f7b631    60837305020017
# 3    1242524  059f2133-161e-43bd-b5fa-0192e86991ab    60812425240046
# 4    3732410  2fa0c01c-71f4-423c-a295-2ff305d49f52    60837324100012
#
#         modelDisplayName Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash   0.42496725247379735   2025-10-11 19:38:33
# 1  beta_stack_model_cash   0.27825723581534545   2025-10-09 20:22:41
# 2  beta_stack_model_cash   0.42142747721594914   2025-10-08 00:35:10
# 3  beta_stack_model_cash   0.34483368835441514   2025-10-01 21:40:29
# 4  beta_stack_model_cash    0.3904369263786684   2025-10-08 23:45:22
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-11           2025-10           Test          0
# 1       2025-10-11           2025-10           Test          0
# 2       2025-10-08           2025-10           Test          0
# 3       2025-10-01           2025-10           Test          0
# 4       2025-10-09           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 1
# 1                   1         Quick             v1       Trench 3
# 2                   1         Quick             v1       Trench 1
# 3                   1         Quick             v1       Trench 2
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_cash_stack_score,
    case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else modelDisplayName end as modelDisplayName,
    modelVersionId,
  trenchCategory
  from parsed
  )
,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and del.flg_mature_fspd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (38074, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#         modelDisplayName  Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash               0.373461   2024-10-21 22:41:59
# 1  beta_stack_model_cash               0.629311   2024-12-27 16:40:09
# 2  beta_stack_model_cash               0.646851   2025-05-19 07:45:14
# 3  beta_stack_model_cash               0.207139   2025-08-02 09:46:51
# 4  beta_stack_model_cash               0.777512   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2024-10-24           2024-10          Train          0
# 1       2024-12-27           2024-12          Train          0
# 2       2025-05-20           2025-05          Train          0
# 3       2025-08-02           2025-08          Train          0
# 4       2025-01-29           2025-01          Train          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 2
# 1                   1         Quick             v1       Trench 1
# 2                   1         Quick             v1       Trench 3
# 3                   1         Quick             v1       Trench 3
# 4                   1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (38233, 15)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3722116  50b590d0-66dd-4cde-b9fb-1da158fa8e01    60837221160014
# 1    2635437  cf96ce81-c8d6-468b-a510-a6624c3d0c22    60826354370021
# 2    3730502  d2fe391c-42e1-480d-af9e-80d8c7f7b631    60837305020017
# 3    1242524  059f2133-161e-43bd-b5fa-0192e86991ab    60812425240046
# 4    3732410  2fa0c01c-71f4-423c-a295-2ff305d49f52    60837324100012
#
#         modelDisplayName Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash   0.42496725247379735   2025-10-11 19:38:33
# 1  beta_stack_model_cash   0.27825723581534545   2025-10-09 20:22:41
# 2  beta_stack_model_cash   0.42142747721594914   2025-10-08 00:35:10
# 3  beta_stack_model_cash   0.34483368835441514   2025-10-01 21:40:29
# 4  beta_stack_model_cash    0.3904369263786684   2025-10-08 23:45:22
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-11           2025-10           Test          0
# 1       2025-10-11           2025-10           Test          0
# 2       2025-10-08           2025-10           Test          0
# 3       2025-10-01           2025-10           Test          0
# 4       2025-10-09           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 1
# 1                   1         Quick             v1       Trench 3
# 2                   1         Quick             v1       Trench 1
# 3                   1         Quick             v1       Trench 2
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['Beta_cash_stack_score'] = pd.to_numeric(df_concat['Beta_cash_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_cash_stack_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_cash', product='CASH')

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=4d473d09-3181-4f67-9426-f08481476b59>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=a638a92a-331a-40d8-a968-c11b09eceeeb>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
REPLACE(REPLACE(prediction, "'", '"'), "None", "null") AS prediction_clean
FROM `prj-prod-dataplatform.audit_balance.ml_model_run_details`
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
and modelVersionId = 'v1'
),
latest_request as (
select * from parsed
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelDisplayName ORDER BY start_time DESC ) = 1),

model_run as (
select customerId,digitalLoanAccountId,modelName, publish_time,
REPLACE(REPLACE(requestPayload, "'", '"'), "None", "null") AS requestPayload_clean
from `prj-prod-dataplatform.audit_balance.ml_request_details` 
WHERE modelName = 'Beta-Cash-Model-response'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customerId, digitalLoanAccountId,modelName ORDER BY publish_time DESC ) = 1)
, 
  modelname as (
  select p.customerId,
  p.digitalLoanAccountId,
  start_time,
  prediction AS Beta_cash_stack_score,
  coalesce(p.trenchCategory, JSON_VALUE(m.requestPayload_clean, "$.predictions.trenchCategory")) AS trenchCategory,
  case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else p.modelDisplayName end as modelDisplayName,
  p.modelVersionId
  from latest_request p
  left join model_run m on m.digitalLoanAccountId = p.digitalLoanAccountId
  ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *  from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (0, 15)
# Empty DataFrame
# Columns: [customerId, digitalLoanAccountId, loanAccountNumber, modelDisplayName, Beta_cash_stack_score, appln_submit_datetime, disbursementdate, Application_month, Data_selection, deffstpd30, flg_mature_fstpd_30, new_loan_type, modelVersionId, trenchCategory, loan_product_type]
# Index: []

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
WITH parsed as (
select customerId, digitalLoanAccountId,modelDisplayName,modelVersionId,start_time,end_time,prediction,trenchCategory,
REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeatures,
FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details
where modelDisplayName in  ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
),
  modelname as (
  select customerId,
  digitalLoanAccountId,
  start_time,
  prediction Beta_cash_stack_score,
    case when modelDisplayName like 'Beta-Cash-Stack-Model' then 'beta_stack_model_cash' else modelDisplayName end as modelDisplayName,
    modelVersionId,
  trenchCategory
  from parsed
  )
,
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as
(select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  r.Beta_cash_stack_score,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
    del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId,
    trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
    from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  inner join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
  left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and r.Beta_cash_stack_score is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select * from base
  qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
  ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (35887, 15)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#         modelDisplayName  Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash               0.373461   2024-10-21 22:41:59
# 1  beta_stack_model_cash               0.629311   2024-12-27 16:40:09
# 2  beta_stack_model_cash               0.646851   2025-05-19 07:45:14
# 3  beta_stack_model_cash               0.207139   2025-08-02 09:46:51
# 4  beta_stack_model_cash               0.777512   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-10-24           2024-10          Train           0
# 1       2024-12-27           2024-12          Train           0
# 2       2025-05-20           2025-05          Train           0
# 3       2025-08-02           2025-08          Train           1
# 4       2025-01-29           2025-01          Train           1
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1         Quick             v1       Trench 2
# 1                    1         Quick             v1       Trench 1
# 2                    1         Quick             v1       Trench 3
# 3                    1         Quick             v1       Trench 3
# 4                    1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (35887, 15)
# C:\Users\Dwaipayan\AppData\Local\Temp\ipykernel_49316\2946223290.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2439915  0001a902-113a-4700-a4e9-69fd07e765ce    60824399150015
# 1     3145373  0001eed4-83b9-4750-a13e-15eb4dff91f4    60831453730015
# 2     2171825  00069ad5-f245-4299-a021-3d2edade1c77    60821718250022
# 3     2032052  0008dfb8-c3fe-46b1-bb1b-d96dcc59d6fe    60820320520061
# 4     1695254  000f6717-a588-4d33-bba5-a70c6a3af766    60816952540011
#
#         modelDisplayName  Beta_cash_stack_score appln_submit_datetime  \
# 0  beta_stack_model_cash               0.373461   2024-10-21 22:41:59
# 1  beta_stack_model_cash               0.629311   2024-12-27 16:40:09
# 2  beta_stack_model_cash               0.646851   2025-05-19 07:45:14
# 3  beta_stack_model_cash               0.207139   2025-08-02 09:46:51
# 4  beta_stack_model_cash               0.777512   2025-01-29 17:18:15
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-10-24           2024-10          Train           0
# 1       2024-12-27           2024-12          Train           0
# 2       2025-05-20           2025-05          Train           0
# 3       2025-08-02           2025-08          Train           1
# 4       2025-01-29           2025-01          Train           1
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1         Quick             v1       Trench 2
# 1                    1         Quick             v1       Trench 1
# 2                    1         Quick             v1       Trench 3
# 3                    1         Quick             v1       Trench 3
# 4                    1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df_concat['Beta_cash_stack_score'] = pd.to_numeric(df_concat['Beta_cash_stack_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'Beta_cash_stack_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_model_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (3968, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=6fc37691-cab1-42c8-bf3c-bfba5dfd99df>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=7f29126b-7c29-42d5-99a2-2367c85cc62d>

# %% [markdown]
# ## Beta-Cash-Stack-Model- Credo Score

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (12385, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3724609  4ba81131-474b-44a7-b127-4f1ea1de1fc4    60837246090018
# 1    3884770  9c6dff45-ce1d-47d6-9734-8107a8b2922e    60838847700012
# 2    3706096  98118b0f-5bae-4544-8a77-f77404a58b50    60837060960013
# 3    3174284  006766c8-3f5f-4d30-8257-52f9bfc3a110    60831742840016
# 4    3201341  35066458-9a4d-4d64-855c-b21ebf440fe8    60832013410025
#
#         modelDisplayName  credo_score  \
# 0  beta_stack_model_cash       0.2777
# 1  beta_stack_model_cash       0.0406
# 2  beta_stack_model_cash       0.1653
# 3  beta_stack_model_cash       0.1201
# 4  beta_stack_model_cash       0.1055
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": "0.4388754278693267", "credo_sc...   2025-10-05 12:26:56
# 1  {"demo_score": "0.46544706537463126", "credo_s...   2025-12-11 15:19:58
# 2  {"demo_score": "0.36533767334703515", "credo_s...   2025-09-26 17:13:14
# 3  {"demo_score": "0.5599758927414684", "credo_sc...   2025-09-29 17:57:23
# 4  {"demo_score": "0.5742757958216588", "credo_sc...   2025-09-30 16:54:39
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-06           2025-10           Test        1                1
# 1       2025-12-11           2025-12           Test        0                1
# 2       2025-09-27           2025-09           Test        0                1
# 3       2025-09-30           2025-09           Test        1                1
# 4       2025-09-30           2025-09           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 1    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 1    not applicable
# 3         Quick             v1       Trench 2    not applicable
# 4         Quick             v1       Trench 3    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (37995, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2861367  069cd22a-738b-4c1f-9007-b7e2a4e3d1b0    60828613670058
# 1     2934862  0c73bebf-ff98-455a-98b4-ecf78933b67f    60829348620019
# 2     2836589  1056e6ba-4fd5-4c18-a267-c18c6f90f2e0    60828365890013
# 3     2943125  131ed8e5-b46a-4399-bf1f-7d6a22bd0db3    60829431250014
# 4     2731766  14751401-e12b-4b6f-8506-0e053bd12a11    60827317660016
#
#         modelDisplayName  credo_score  \
# 0  Beta-Cash-Stack-Model     0.146064
# 1  Beta-Cash-Stack-Model     0.300374
# 2  Beta-Cash-Stack-Model     0.238684
# 3  Beta-Cash-Stack-Model     0.098189
# 4  Beta-Cash-Stack-Model     0.234211
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.41415249760894657, "apps_scor...   2024-10-18 14:27:11
# 1  {"demo_score": 0.5464570449528784, "apps_score...   2024-10-12 23:15:31
# 2  {"demo_score": 0.5736611563286762, "apps_score...   2024-10-03 03:59:45
# 3  {"demo_score": 0.3527349484462734, "apps_score...   2024-10-15 17:56:18
# 4  {"demo_score": 0.3982423005917363, "credo_scor...   2024-10-18 17:06:25
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2024-10-18           2024-10           Test        0                1
# 1       2024-10-13           2024-10           Test        1                1
# 2       2024-10-03           2024-10           Test        0                1
# 3       2024-10-15           2024-10           Test        1                1
# 4       2024-11-15           2024-10           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 3    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 1    not applicable
# 3         Quick             v1       Trench 1    not applicable
# 4         Quick             v1       Trench 2    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (50325, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3724609  4ba81131-474b-44a7-b127-4f1ea1de1fc4    60837246090018
# 1    3884770  9c6dff45-ce1d-47d6-9734-8107a8b2922e    60838847700012
# 2    3818341  bbc81aba-7d73-496e-9dcc-1324bb732884    60838183410016
# 3    3422202  80ec9afc-7f1f-4faf-8687-d5989f1f059d    60834222020013
# 4    3884002  60cc88a8-b9cf-4247-925f-d1dc41d31f23    60838840020019
#
#         modelDisplayName  credo_score  \
# 0  beta_stack_model_cash       0.2777
# 1  beta_stack_model_cash       0.0406
# 2  beta_stack_model_cash       0.2446
# 3  beta_stack_model_cash       0.2543
# 4  beta_stack_model_cash       0.2773
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": "0.4388754278693267", "credo_sc...   2025-10-05 12:26:56
# 1  {"demo_score": "0.46544706537463126", "credo_s...   2025-12-11 15:19:58
# 2  {"demo_score": "0.5988483435571748", "credo_sc...   2025-11-23 16:02:01
# 3  {"demo_score": "0.6331308670645185", "credo_sc...   2025-12-11 11:31:42
# 4  {"demo_score": "0.406075947330648", "credo_sco...   2025-12-11 11:53:30
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-10-06           2025-10           Test        1                1
# 1       2025-12-11           2025-12           Test        0                1
# 2       2025-12-23           2025-11           Test        0                1
# 3       2025-12-11           2025-12           Test        0                1
# 4       2025-12-11           2025-12           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 1    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 1    not applicable
# 3         Quick             v1       Trench 2    not applicable
# 4         Quick             v1       Trench 1    not applicable

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (5104, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=ca4e0d74-63dc-49ad-96dd-fe7098b277ae>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=9fbefef9-f86f-4dec-a1d4-b09ba2069abf>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd10 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (10232, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3718881  7c1dead3-748f-4299-a825-7e76c7d10c81    60837188810013
# 1    2652688  879f37b7-c5e9-4fc5-a91e-14cb39917af4    60826526880025
# 2    3714868  bdda830c-3985-463e-b8bf-a4d02bd00a03    60837148680011
# 3    2335443  855135e0-dce2-4a34-aef9-8d5a798c1bb5    60823354430038
# 4    3177894  940a265b-e43b-4985-905f-675f8ea3787b    60831778940018
#
#         modelDisplayName  credo_score  \
# 0  beta_stack_model_cash       0.2316
# 1  beta_stack_model_cash       0.0607
# 2  beta_stack_model_cash       0.1617
# 3  beta_stack_model_cash       0.0872
# 4  beta_stack_model_cash       0.1644
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": "0.3114746517368309", "credo_sc...   2025-10-02 15:31:34
# 1  {"demo_score": "0.48529380807020234", "credo_s...   2025-09-25 10:12:16
# 2  {"demo_score": "0.4846354184993574", "credo_sc...   2025-09-30 15:32:10
# 3  {"demo_score": "0.4371811166121919", "credo_sc...   2025-09-30 15:21:22
# 4  {"demo_score": "0.4820533013172368", "credo_sc...   2025-10-01 18:05:45
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-02           2025-10           Test         0
# 1       2025-09-25           2025-09           Test         0
# 2       2025-10-02           2025-09           Test         0
# 3       2025-10-01           2025-09           Test         0
# 4       2025-10-03           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd10 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (37995, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     1001777  0409107a-35e0-4c82-ba2d-c1d755eaae40    60810017770031
# 1     2336055  135e4713-b4d0-418b-afde-824544887cd2    60823360550026
# 2     2941801  1379933e-12bb-4fcb-b626-91cb5041d40c    60829418010019
# 3     2905164  13d0ab6f-8128-45a7-a4eb-b3ab9dd386ec    60829051640019
# 4     1865268  180cc7b6-7b50-4a25-a4c2-7e13519507fb    60818652680013
#
#         modelDisplayName  credo_score  \
# 0  Beta-Cash-Stack-Model     0.214956
# 1  Beta-Cash-Stack-Model     0.091840
# 2  Beta-Cash-Stack-Model     0.363803
# 3  Beta-Cash-Stack-Model     0.143578
# 4  Beta-Cash-Stack-Model     0.130730
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.5759975612165251, "apps_score...   2024-10-14 20:37:10
# 1  {"demo_score": 0.3235545646612255, "apps_score...   2024-10-25 22:08:45
# 2  {"demo_score": 0.6989944535688777, "apps_score...   2024-10-16 10:38:14
# 3  {"demo_score": 0.4888976110742482, "apps_score...   2024-10-03 00:51:04
# 4  {"demo_score": 0.51823816171133, "credo_score"...   2024-10-26 18:58:15
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2024-10-14           2024-10           Test         0
# 1       2024-10-25           2024-10           Test         0
# 2       2024-10-16           2024-10           Test         0
# 3       2024-10-03           2024-10           Test         0
# 4       2024-10-27           2024-10           Test         1
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (48172, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3718881  7c1dead3-748f-4299-a825-7e76c7d10c81    60837188810013
# 1    3177894  940a265b-e43b-4985-905f-675f8ea3787b    60831778940018
# 2    3812039  ca19cc8d-6af3-4041-ad1e-9063d3b51772    60838120390019
# 3    3724335  c4744db6-29c2-40ee-a840-85828101d45d    60837243350011
# 4    3728353  4f50c223-6b13-447b-b003-4f1a1209a9f4    60837283530019
#
#         modelDisplayName  credo_score  \
# 0  beta_stack_model_cash       0.2316
# 1  beta_stack_model_cash       0.1644
# 2  beta_stack_model_cash       0.2642
# 3  beta_stack_model_cash       0.1523
# 4  beta_stack_model_cash       0.0770
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": "0.3114746517368309", "credo_sc...   2025-10-02 15:31:34
# 1  {"demo_score": "0.4820533013172368", "credo_sc...   2025-10-01 18:05:45
# 2  {"demo_score": "0.4530701291457141", "credo_sc...   2025-11-15 17:51:38
# 3  {"demo_score": "0.515435403819825", "credo_sco...   2025-10-06 11:27:21
# 4  {"demo_score": "0.5090837751757106", "credo_sc...   2025-10-06 23:27:56
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-10-02           2025-10           Test         0
# 1       2025-10-03           2025-10           Test         0
# 2       2025-11-30           2025-11           Test         0
# 3       2025-10-06           2025-10           Test         0
# 4       2025-10-07           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (5040, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=16bf9f52-3a74-47ef-a2d6-e256d37fb0d5>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=51f19135-981f-4891-bb87-488d673bba6e>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (4589, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    1242524  059f2133-161e-43bd-b5fa-0192e86991ab    60812425240046
# 1    1886335  883ef202-4aa4-41d7-99ff-fd6be2ef69db    60818863350053
# 2    3701246  9c698895-ba1e-4a18-a058-c4cae1311e82    60837012460019
# 3    1048670  dde1485a-a006-4e76-9bde-815d49731139    60810486700146
# 4    3705891  ec2bf9f2-ee68-44de-9f2e-9690f53ec824    60837058910018
#
#         modelDisplayName  credo_score  \
# 0  beta_stack_model_cash       0.1086
# 1  beta_stack_model_cash       0.0989
# 2  beta_stack_model_cash       0.1183
# 3  beta_stack_model_cash       0.1664
# 4  beta_stack_model_cash       0.1998
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": "0.4693221056660163", "credo_sc...   2025-10-01 21:40:29
# 1  {"demo_score": "0.3754082371818635", "credo_sc...   2025-09-28 18:26:57
# 2  {"demo_score": "0.48297651318600027", "credo_s...   2025-10-03 20:32:40
# 3  {"demo_score": "0.4519739510897631", "credo_sc...   2025-10-03 07:48:00
# 4  {"demo_score": "0.4679185550715055", "credo_sc...   2025-09-26 14:01:57
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-10-01           2025-10           Test         0
# 1       2025-09-28           2025-09           Test         0
# 2       2025-10-03           2025-10           Test         0
# 3       2025-10-03           2025-10           Test         0
# 4       2025-10-02           2025-09           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 2
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (37995, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2974171  0446b98e-777c-4764-9fe6-b20073f1cb01    60829741710019
# 1     2967615  0d7fa3fa-b9f9-4140-b386-c8df3ca05737    60829676150021
# 2     1111232  1d2a30a7-17ab-4ab1-bf4d-4778ac98dd7e    60811112320026
# 3     2914197  25d067d7-ad52-4afd-bd48-45a31290a2ca    60829141970019
# 4     2527431  273cf835-c03f-48b6-8922-3d2174fe7da4    60825274310013
#
#         modelDisplayName  credo_score  \
# 0  Beta-Cash-Stack-Model     0.180370
# 1  Beta-Cash-Stack-Model     0.215380
# 2  Beta-Cash-Stack-Model     0.179750
# 3  Beta-Cash-Stack-Model     0.069558
# 4  Beta-Cash-Stack-Model     0.229724
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.3939677055392488, "apps_score...   2024-10-26 14:50:05
# 1  {"demo_score": 0.3731913581869368, "credo_scor...   2024-10-23 21:44:07
# 2  {"demo_score": 0.3487255233981264, "credo_scor...   2024-10-19 20:43:15
# 3  {"demo_score": 0.5544763880068141, "apps_score...   2024-10-06 13:54:56
# 4  {"demo_score": 0.6130598889824801, "credo_scor...   2024-10-04 13:18:29
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2024-11-02           2024-10           Test         0
# 1       2024-10-24           2024-10           Test         0
# 2       2024-10-19           2024-10           Test         0
# 3       2024-10-06           2024-10           Test         0
# 4       2024-10-31           2024-10           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 2
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (42529, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    1242524  059f2133-161e-43bd-b5fa-0192e86991ab    60812425240046
# 1    3701246  9c698895-ba1e-4a18-a058-c4cae1311e82    60837012460019
# 2    1048670  dde1485a-a006-4e76-9bde-815d49731139    60810486700146
# 3    3716782  1616f4ec-1811-4744-8ec4-9ec17cf862bb    60837167820013
# 4    1939255  189e94f7-4587-444e-9be9-39ab39f5ab4c    60819392550023
#
#         modelDisplayName  credo_score  \
# 0  beta_stack_model_cash       0.1086
# 1  beta_stack_model_cash       0.1183
# 2  beta_stack_model_cash       0.1664
# 3  beta_stack_model_cash       0.0734
# 4  beta_stack_model_cash       0.1731
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": "0.4693221056660163", "credo_sc...   2025-10-01 21:40:29
# 1  {"demo_score": "0.48297651318600027", "credo_s...   2025-10-03 20:32:40
# 2  {"demo_score": "0.4519739510897631", "credo_sc...   2025-10-03 07:48:00
# 3  {"demo_score": "0.37695104300773075", "credo_s...   2025-10-01 14:33:37
# 4  {"demo_score": "0.42494848275987585", "credo_s...   2025-10-06 04:14:34
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-10-01           2025-10           Test         0
# 1       2025-10-03           2025-10           Test         0
# 2       2025-10-03           2025-10           Test         0
# 3       2025-10-06           2025-10           Test         0
# 4       2025-10-06           2025-10           Test         1
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 2
# 1                 1         Quick             v1       Trench 1
# 2                 1         Quick             v1       Trench 2
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 3
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (4752, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=bed7dfe9-734e-469e-9134-5c00db421368>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=385d9341-fe4b-4550-afb1-2b67051067f2>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (214, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    2064618  394fe099-95ea-4c52-8ef4-43bf8f3f1fc4    60820646180028
# 1    3738063  b0665e69-0546-4176-8635-4b01f3ec9b1a    60837380630017
# 2    3550577  ce88da4b-a537-4310-8974-17dc60351136    60835505770022
# 3    3450487  3f85a529-ed37-4e8e-a494-487058987b51    60834504870025
# 4    1809770  7d77f354-adef-4ba9-8ed4-7fd1cb666211    60818097700026
#
#         modelDisplayName  credo_score  \
# 0  beta_stack_model_cash       0.1022
# 1  beta_stack_model_cash       0.1037
# 2  beta_stack_model_cash       0.0486
# 3  beta_stack_model_cash       0.1221
# 4  beta_stack_model_cash       0.1325
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": "0.4252731430511041", "credo_sc...   2025-09-28 04:48:13
# 1  {"demo_score": "0.5357842047016698", "credo_sc...   2025-10-11 20:47:00
# 2  {"demo_score": "0.4024299896610732", "credo_sc...   2025-10-10 15:49:24
# 3  {"demo_score": "0.4812746996670572", "credo_sc...   2025-09-30 11:23:16
# 4  {"demo_score": "0.46474783077383114", "credo_s...   2025-10-10 12:04:33
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-04           2025-09           Test          0
# 1       2025-10-12           2025-10           Test          0
# 2       2025-10-10           2025-10           Test          0
# 3       2025-10-01           2025-09           Test          0
# 4       2025-10-10           2025-10           Test          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 3
# 1                   1         Quick             v1       Trench 1
# 2                   1         Quick             v1       Trench 3
# 3                   1         Quick             v1       Trench 3
# 4                   1         Quick             v1       Trench 3
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (37976, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2293724  046dbb7d-caec-4f9f-9f05-ff40a75c2e34    60822937240014
# 1     2044412  0e8fa7d5-6d76-4937-bc3b-205be579abea    60820444120018
# 2     2922710  1772d30b-7d23-44d4-8f4c-38d7366cb031    60829227100011
# 3     2925438  18f6cbaa-3778-43ab-9641-cf0daa4918f7    60829254380016
# 4     1541420  19bd41c6-0f53-43e2-bdca-13e11ca5878c    60815414200134
#
#         modelDisplayName  credo_score  \
# 0  Beta-Cash-Stack-Model     0.063874
# 1  Beta-Cash-Stack-Model     0.195835
# 2  Beta-Cash-Stack-Model     0.266390
# 3  Beta-Cash-Stack-Model     0.165790
# 4  Beta-Cash-Stack-Model     0.272563
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.61164859281957, "apps_score":...   2024-10-25 14:07:01
# 1  {"demo_score": 0.3906223659727512, "credo_scor...   2024-10-02 18:26:07
# 2  {"demo_score": 0.6143361010944646, "credo_scor...   2024-10-08 17:23:39
# 3  {"demo_score": 0.4143733811203764, "credo_scor...   2024-10-09 22:40:53
# 4  {"demo_score": 0.4634170725980357, "credo_scor...   2024-10-26 07:17:43
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2024-10-26           2024-10           Test          0
# 1       2024-10-02           2024-10           Test          0
# 2       2024-10-09           2024-10           Test          1
# 3       2024-10-16           2024-10           Test          0
# 4       2024-10-26           2024-10           Test          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 2
# 1                   1         Quick             v1       Trench 2
# 2                   1         Quick             v1       Trench 1
# 3                   1         Quick             v1       Trench 1
# 4                   1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (38135, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3738063  b0665e69-0546-4176-8635-4b01f3ec9b1a    60837380630017
# 1    3550577  ce88da4b-a537-4310-8974-17dc60351136    60835505770022
# 2    1809770  7d77f354-adef-4ba9-8ed4-7fd1cb666211    60818097700026
# 3    2324432  8c36386d-de40-4fc4-9a99-edc841845a2e    60823244320028
# 4    3722544  11f1c3fd-97c4-4c0e-baf0-ea0c6cf247c2    60837225440011
#
#         modelDisplayName  credo_score  \
# 0  beta_stack_model_cash       0.1037
# 1  beta_stack_model_cash       0.0486
# 2  beta_stack_model_cash       0.1325
# 3  beta_stack_model_cash       0.1073
# 4  beta_stack_model_cash       0.1861
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": "0.5357842047016698", "credo_sc...   2025-10-11 20:47:00
# 1  {"demo_score": "0.4024299896610732", "credo_sc...   2025-10-10 15:49:24
# 2  {"demo_score": "0.46474783077383114", "credo_s...   2025-10-10 12:04:33
# 3  {"demo_score": "0.5348682904359492", "credo_sc...   2025-10-11 14:13:21
# 4  {"demo_score": "0.39083656903461994", "credo_s...   2025-10-10 10:25:28
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-12           2025-10           Test          0
# 1       2025-10-10           2025-10           Test          0
# 2       2025-10-10           2025-10           Test          1
# 3       2025-10-11           2025-10           Test          1
# 4       2025-10-10           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 1
# 1                   1         Quick             v1       Trench 3
# 2                   1         Quick             v1       Trench 3
# 3                   1         Quick             v1       Trench 3
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (4352, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=a1386cb1-94eb-42bf-a0ba-821562728407>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=72165749-8a86-4c75-b5c1-d638b38e6efa>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (0, 16)
# Empty DataFrame
# Columns: [customerId, digitalLoanAccountId, loanAccountNumber, modelDisplayName, credo_score, calcFeature, appln_submit_datetime, disbursementdate, Application_month, Data_selection, deffstpd30, flg_mature_fstpd_30, new_loan_type, modelVersionId, trenchCategory, loan_product_type]
# Index: []

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Beta-Cash-Stack-Model', 'beta_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fstpd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (35792, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2956722  04998e07-91b6-4e64-bd43-fdf0b84cc550    60829567220016
# 1     2548483  1c9d7319-340a-4270-8d94-0df18e86ae1c    60825484830019
# 2     2563696  2e1ffc86-9095-4096-9421-1c90ade44985    60825636960011
# 3     2935031  31a0425e-6649-46bc-b219-c2dfaa8b7fbf    60829350310012
# 4     2930805  399595a5-4e0d-49bd-8fd4-df386f8a6a11    60829308050014
#
#         modelDisplayName  credo_score  \
# 0  Beta-Cash-Stack-Model     0.461851
# 1  Beta-Cash-Stack-Model     0.282004
# 2  Beta-Cash-Stack-Model     0.157452
# 3  Beta-Cash-Stack-Model     0.261330
# 4  Beta-Cash-Stack-Model     0.137414
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.2794356608439043, "apps_score...   2024-10-20 09:51:53
# 1  {"demo_score": 0.5568523416254098, "apps_score...   2024-10-15 13:17:04
# 2  {"demo_score": 0.599612087959783, "credo_score...   2024-10-15 08:17:37
# 3  {"demo_score": 0.6058230863074885, "apps_score...   2024-10-13 01:58:03
# 4  {"demo_score": 0.5542777309292469, "credo_scor...   2024-10-11 15:01:55
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-10-20           2024-10           Test           1
# 1       2024-10-16           2024-10           Test           0
# 2       2024-10-15           2024-10           Test           1
# 3       2024-10-14           2024-10           Test           1
# 4       2024-10-11           2024-10           Test           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1         Quick             v1       Trench 1
# 1                    1         Quick             v1       Trench 2
# 2                    1         Quick             v1       Trench 2
# 3                    1         Quick             v1       Trench 1
# 4                    1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (35792, 16)
# C:\Users\Dwaipayan\AppData\Local\Temp\ipykernel_49316\2946223290.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2956722  04998e07-91b6-4e64-bd43-fdf0b84cc550    60829567220016
# 1     2548483  1c9d7319-340a-4270-8d94-0df18e86ae1c    60825484830019
# 2     2563696  2e1ffc86-9095-4096-9421-1c90ade44985    60825636960011
# 3     2935031  31a0425e-6649-46bc-b219-c2dfaa8b7fbf    60829350310012
# 4     2930805  399595a5-4e0d-49bd-8fd4-df386f8a6a11    60829308050014
#
#         modelDisplayName  credo_score  \
# 0  Beta-Cash-Stack-Model     0.461851
# 1  Beta-Cash-Stack-Model     0.282004
# 2  Beta-Cash-Stack-Model     0.157452
# 3  Beta-Cash-Stack-Model     0.261330
# 4  Beta-Cash-Stack-Model     0.137414
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.2794356608439043, "apps_score...   2024-10-20 09:51:53
# 1  {"demo_score": 0.5568523416254098, "apps_score...   2024-10-15 13:17:04
# 2  {"demo_score": 0.599612087959783, "credo_score...   2024-10-15 08:17:37
# 3  {"demo_score": 0.6058230863074885, "apps_score...   2024-10-13 01:58:03
# 4  {"demo_score": 0.5542777309292469, "credo_scor...   2024-10-11 15:01:55
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-10-20           2024-10           Test           1
# 1       2024-10-16           2024-10           Test           0
# 2       2024-10-15           2024-10           Test           1
# 3       2024-10-14           2024-10           Test           1
# 4       2024-10-11           2024-10           Test           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1         Quick             v1       Trench 1
# 1                    1         Quick             v1       Trench 2
# 2                    1         Quick             v1       Trench 2
# 3                    1         Quick             v1       Trench 1
# 4                    1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='beta_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (3968, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=ee051d56-4c0b-44aa-8bb2-1d4d5d534499>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=d6903225-a02b-4d5a-8569-f14717f86b58>

# %% [markdown]
# ## Alpha-Cash-Stack-Model- Credo Score

# %% [markdown]
# ### FPD0

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (11863, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3880653  04450baa-488a-4dba-a68c-c6ab62b223ff    60838806530012
# 1    3487395  50d4bb08-2124-407f-8bb3-067d22ab1cfe    60834873950017
# 2    3881447  6d38a851-51e0-4973-9434-defc99af6ba9    60838814470012
# 3    3400225  9ee9f723-40d8-427e-8bed-a00c757967ec    60834002250021
# 4    3883771  7fe269bd-f7c4-4003-bba6-3e421b240429    60838837710019
#
#          modelDisplayName  credo_score  \
# 0  alpha_stack_model_cash       0.3185
# 1  alpha_stack_model_cash       0.1278
# 2  alpha_stack_model_cash       0.2063
# 3  alpha_stack_model_cash       0.1184
# 4  alpha_stack_model_cash       0.1876
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"apps_score": 0.4575116137577463, "c_demo_sco...   2025-12-10 12:43:19
# 1  {"apps_score": null, "c_demo_score": 0.4296130...   2025-09-29 15:29:48
# 2  {"apps_score": null, "c_demo_score": 0.4469659...   2025-12-11 08:48:38
# 3  {"apps_score": 0.4503962693413685, "c_demo_sco...   2025-10-07 10:07:59
# 4  {"apps_score": 0.4596215305262278, "c_demo_sco...   2025-12-11 11:03:34
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-12-11           2025-12           Test        0                1
# 1       2025-10-03           2025-09           Test        0                1
# 2       2025-12-11           2025-12           Test        0                1
# 3       2025-10-07           2025-10           Test        0                1
# 4       2025-12-11           2025-12           Test        1                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 1    not applicable
# 1         Quick             v1       Trench 2    not applicable
# 2         Quick             v1       Trench 1    not applicable
# 3         Quick             v1       Trench 3    not applicable
# 4         Quick             v1       Trench 1    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  deffpd0,
  flg_mature_fpd0,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and flg_mature_fpd0 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (36370, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2404880  03c6e33c-18f7-43ec-944d-40ef31c42148    60824048800016
# 1     2965234  0b74bca9-66cd-46ef-9272-47f3652cb56c    60829652340016
# 2     2923299  1122f54e-69f3-4a43-954f-de215be3aef1    60829232990015
# 3     2916874  186d0200-b93c-4222-a825-b89ae49c61c7    60829168740011
# 4     2611711  19362360-a87c-481a-bf1e-8ab027cee215    60826117110023
#
#          modelDisplayName  credo_score  \
# 0  Alpha-Cash-Stack-Model     0.213430
# 1  Alpha-Cash-Stack-Model     0.261376
# 2  Alpha-Cash-Stack-Model     0.259237
# 3  Alpha-Cash-Stack-Model     0.143590
# 4  Alpha-Cash-Stack-Model     0.137211
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.62719481801651, "credo_score"...   2024-10-27 00:09:15
# 1  {"demo_score": 0.4625627278987716, "credo_scor...   2024-10-23 00:02:10
# 2  {"demo_score": 0.48346716080012325, "credo_sco...   2024-10-10 23:56:35
# 3  {"demo_score": 0.5865322185056687, "credo_scor...   2024-10-06 18:33:09
# 4  {"demo_score": 0.5744270390779554, "credo_scor...   2024-10-09 10:50:57
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2024-10-27           2024-10          Train        0                1
# 1       2024-10-23           2024-10          Train        0                1
# 2       2024-10-11           2024-10          Train        0                1
# 3       2024-10-06           2024-10          Train        1                1
# 4       2024-10-09           2024-10          Train        1                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 2    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 1    not applicable
# 3         Quick             v1       Trench 1    not applicable
# 4         Quick             v1       Trench 3    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (48198, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3880653  04450baa-488a-4dba-a68c-c6ab62b223ff    60838806530012
# 1    3881447  6d38a851-51e0-4973-9434-defc99af6ba9    60838814470012
# 2    3400225  9ee9f723-40d8-427e-8bed-a00c757967ec    60834002250021
# 3    3883771  7fe269bd-f7c4-4003-bba6-3e421b240429    60838837710019
# 4    3724716  ebfbd098-aa48-4161-a112-cf2e0b25ba9a    60837247160011
#
#          modelDisplayName  credo_score  \
# 0  alpha_stack_model_cash       0.3185
# 1  alpha_stack_model_cash       0.2063
# 2  alpha_stack_model_cash       0.1184
# 3  alpha_stack_model_cash       0.1876
# 4  alpha_stack_model_cash       0.2069
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"apps_score": 0.4575116137577463, "c_demo_sco...   2025-12-10 12:43:19
# 1  {"apps_score": null, "c_demo_score": 0.4469659...   2025-12-11 08:48:38
# 2  {"apps_score": 0.4503962693413685, "c_demo_sco...   2025-10-07 10:07:59
# 3  {"apps_score": 0.4596215305262278, "c_demo_sco...   2025-12-11 11:03:34
# 4  {"apps_score": null, "c_demo_score": 0.4562200...   2025-10-05 13:12:34
#
#   disbursementdate Application_month Data_selection  deffpd0  flg_mature_fpd0  \
# 0       2025-12-11           2025-12           Test        0                1
# 1       2025-12-11           2025-12           Test        0                1
# 2       2025-10-07           2025-10           Test        0                1
# 3       2025-12-11           2025-12           Test        1                1
# 4       2025-10-05           2025-10           Test        0                1
#
#   new_loan_type modelVersionId trenchCategory loan_product_type
# 0         Quick             v1       Trench 1    not applicable
# 1         Quick             v1       Trench 1    not applicable
# 2         Quick             v1       Trench 3    not applicable
# 3         Quick             v1       Trench 1    not applicable
# 4         Quick             v1       Trench 1    not applicable

# %%
# # df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd0', 
    'FPD0',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (5272, 16)
# The shape of the dimension table is:	 (96, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=108dcc4d-48c7-4a20-b447-4a0958d65c52>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=5e30cbf3-d7b5-45fd-b651-7e4b6403df6a>

# %% [markdown]
# ### FPD10

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd10 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (9823, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3812039  ca19cc8d-6af3-4041-ad1e-9063d3b51772    60838120390019
# 1    2807107  67527945-fff7-4bb3-add4-a5a452bf9121    60828071070038
# 2    3852178  09e2e9f8-3991-4f07-9a72-60838b2998c3    60838521780019
# 3    3844153  359c099c-67ee-42db-a4fb-33ba4eeadb98    60838441530013
# 4    3066495  75da5a84-b7b6-4c21-9775-4d01a16a903c    60830664950038
#
#          modelDisplayName  credo_score  \
# 0  alpha_stack_model_cash       0.2642
# 1  alpha_stack_model_cash       0.0722
# 2  alpha_stack_model_cash       0.4072
# 3  alpha_stack_model_cash       0.1896
# 4  alpha_stack_model_cash       0.0919
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"apps_score": 0.4997369696591849, "c_demo_sco...   2025-11-15 17:51:38
# 1  {"apps_score": null, "c_demo_score": 0.2986544...   2025-10-03 14:02:40
# 2  {"apps_score": 0.5008864548190528, "c_demo_sco...   2025-12-01 18:04:20
# 3  {"apps_score": null, "c_demo_score": 0.4520857...   2025-11-29 07:25:52
# 4  {"apps_score": 0.5355434994711507, "c_demo_sco...   2025-09-30 18:59:01
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-11-30           2025-11           Test         0
# 1       2025-10-03           2025-10           Test         1
# 2       2025-12-02           2025-12           Test         1
# 3       2025-11-29           2025-11           Test         0
# 4       2025-10-01           2025-09           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 3
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffpd10,
  del.flg_mature_fpd10,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd10 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (36370, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2975733  03409541-b51a-44f9-b945-ec3d67872273    60829757330015
# 1     2790453  05df9f31-0fa1-496b-910b-2a0e0d5cbc50    60827904530034
# 2     1699819  070c5cb3-185a-4aed-8d1f-d908120a240c    60816998190011
# 3     2988321  12133f68-0f4b-46df-919a-4bb6bef68fd9    60829883210016
# 4     2112446  266a20aa-ef9e-4e55-9b64-dafa31feb444    60821124460011
#
#          modelDisplayName  credo_score  \
# 0  Alpha-Cash-Stack-Model     0.165992
# 1  Alpha-Cash-Stack-Model     0.108153
# 2  Alpha-Cash-Stack-Model     0.112891
# 3  Alpha-Cash-Stack-Model     0.151707
# 4  Alpha-Cash-Stack-Model     0.051578
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.5608748962748754, "apps_score...   2024-10-27 08:15:18
# 1  {"demo_score": 0.4185434684786628, "credo_scor...   2024-10-17 20:34:36
# 2  {"demo_score": 0.27960803126639217, "apps_scor...   2024-10-31 18:06:41
# 3  {"demo_score": 0.44890516031144323, "credo_sco...   2024-10-31 17:57:18
# 4  {"demo_score": 0.46557765749439617, "apps_scor...   2024-10-20 17:05:49
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2024-10-27           2024-10          Train         0
# 1       2024-10-17           2024-10          Train         0
# 2       2024-11-11           2024-10          Train         0
# 3       2024-10-31           2024-10          Train         0
# 4       2024-10-23           2024-10          Train         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 2
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 2
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (46158, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3812039  ca19cc8d-6af3-4041-ad1e-9063d3b51772    60838120390019
# 1    2807107  67527945-fff7-4bb3-add4-a5a452bf9121    60828071070038
# 2    3852178  09e2e9f8-3991-4f07-9a72-60838b2998c3    60838521780019
# 3    3844153  359c099c-67ee-42db-a4fb-33ba4eeadb98    60838441530013
# 4    3721729  4a79f936-068e-4436-8c0c-c78982598fa4    60837217290013
#
#          modelDisplayName  credo_score  \
# 0  alpha_stack_model_cash       0.2642
# 1  alpha_stack_model_cash       0.0722
# 2  alpha_stack_model_cash       0.4072
# 3  alpha_stack_model_cash       0.1896
# 4  alpha_stack_model_cash       0.1896
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"apps_score": 0.4997369696591849, "c_demo_sco...   2025-11-15 17:51:38
# 1  {"apps_score": null, "c_demo_score": 0.2986544...   2025-10-03 14:02:40
# 2  {"apps_score": 0.5008864548190528, "c_demo_sco...   2025-12-01 18:04:20
# 3  {"apps_score": null, "c_demo_score": 0.4520857...   2025-11-29 07:25:52
# 4  {"apps_score": null, "c_demo_score": 0.4915565...   2025-10-04 08:37:07
#
#   disbursementdate Application_month Data_selection  deffpd10  \
# 0       2025-11-30           2025-11           Test         0
# 1       2025-10-03           2025-10           Test         1
# 2       2025-12-02           2025-12           Test         1
# 3       2025-11-29           2025-11           Test         0
# 4       2025-10-04           2025-10           Test         0
#
#    flg_mature_fpd10 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 1
# 1                 1         Quick             v1       Trench 3
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd10', 
    'FPD10',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (5208, 16)
# The shape of the dimension table is:	 (96, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=5ad4f2b5-a8c6-442c-a654-0f1205f2977b>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=25656c42-dd65-44dc-a18f-272c2a1ab151>

# %% [markdown]
# ### FPD30

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (4388, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3338490  9da8823e-ac4c-4d0f-890a-05788b02b3a5    60833384900026
# 1    1665988  a026eede-c9c6-4ef6-bce1-5fcbb446e4ef    60816659880016
# 2    3706096  98118b0f-5bae-4544-8a77-f77404a58b50    60837060960013
# 3    3066495  75da5a84-b7b6-4c21-9775-4d01a16a903c    60830664950038
# 4    3705340  026a6ada-efc6-4e5e-968a-0d37e382d9ad    60837053400012
#
#          modelDisplayName  credo_score  \
# 0  alpha_stack_model_cash       0.0890
# 1  alpha_stack_model_cash       0.2112
# 2  alpha_stack_model_cash       0.1653
# 3  alpha_stack_model_cash       0.0919
# 4  alpha_stack_model_cash       0.1894
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"apps_score": 0.4847688455013037, "c_demo_sco...   2025-10-04 23:10:38
# 1  {"apps_score": 0.4581051399562931, "c_demo_sco...   2025-10-06 06:08:45
# 2  {"apps_score": 0.5128957778641947, "c_demo_sco...   2025-09-26 17:13:14
# 3  {"apps_score": 0.5355434994711507, "c_demo_sco...   2025-09-30 18:59:01
# 4  {"apps_score": null, "c_demo_score": 0.4767949...   2025-09-26 14:04:27
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-10-05           2025-10           Test         0
# 1       2025-10-06           2025-10           Test         0
# 2       2025-09-27           2025-09           Test         0
# 3       2025-10-01           2025-09           Test         0
# 4       2025-09-26           2025-09           Test         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 3
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 3
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffpd30,
  del.flg_mature_fpd30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fpd30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (36370, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     1130432  00dd4f91-3db3-4a36-a6b8-f0904a81c061    60811304320052
# 1     1021940  0d2ddb0e-c108-45ec-a752-3aa53eaaa1f7    60810219400109
# 2     2923447  0f4fce4b-db33-4f4f-98f0-34d7a20a736a    60829234470019
# 3     2191225  147cda0b-6832-4f10-9812-3317e9b9bd5e    60821912250016
# 4     2943773  17554583-56cd-421f-b342-e7f80dba0389    60829437730011
#
#          modelDisplayName  credo_score  \
# 0  Alpha-Cash-Stack-Model     0.107326
# 1  Alpha-Cash-Stack-Model     0.095035
# 2  Alpha-Cash-Stack-Model     0.145120
# 3  Alpha-Cash-Stack-Model     0.251840
# 4  Alpha-Cash-Stack-Model     0.076215
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.5237171142832547, "apps_score...   2024-10-04 21:37:05
# 1  {"demo_score": 0.5275419822618007, "apps_score...   2024-10-07 11:40:51
# 2  {"demo_score": 0.5380462055250727, "apps_score...   2024-10-08 23:36:36
# 3  {"demo_score": 0.5962652010887847, "credo_scor...   2024-10-03 20:41:13
# 4  {"demo_score": 0.5524855968241008, "apps_score...   2024-10-15 22:00:32
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2024-10-04           2024-10          Train         0
# 1       2024-10-07           2024-10          Train         0
# 2       2024-10-09           2024-10          Train         0
# 3       2024-10-04           2024-10          Train         0
# 4       2024-10-16           2024-10          Train         0
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 3
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 1
# 3                 1         Quick             v1       Trench 2
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (40723, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3338490  9da8823e-ac4c-4d0f-890a-05788b02b3a5    60833384900026
# 1    1665988  a026eede-c9c6-4ef6-bce1-5fcbb446e4ef    60816659880016
# 2    1939255  189e94f7-4587-444e-9be9-39ab39f5ab4c    60819392550023
# 3    3792646  13a56d04-6419-4e86-9649-3d952e17d5b3    60837926460011
# 4    3719610  4625afe9-909b-49fb-b373-307600575bc0    60837196100016
#
#          modelDisplayName  credo_score  \
# 0  alpha_stack_model_cash       0.0890
# 1  alpha_stack_model_cash       0.2112
# 2  alpha_stack_model_cash       0.1731
# 3  alpha_stack_model_cash       0.0738
# 4  alpha_stack_model_cash       0.1278
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"apps_score": 0.4847688455013037, "c_demo_sco...   2025-10-04 23:10:38
# 1  {"apps_score": 0.4581051399562931, "c_demo_sco...   2025-10-06 06:08:45
# 2  {"apps_score": 0.4436570430664831, "c_demo_sco...   2025-10-06 04:14:34
# 3  {"apps_score": 0.38289759039921045, "c_demo_sc...   2025-11-06 18:12:43
# 4  {"apps_score": null, "c_demo_score": 0.5001950...   2025-10-02 20:43:28
#
#   disbursementdate Application_month Data_selection  deffpd30  \
# 0       2025-10-05           2025-10           Test         0
# 1       2025-10-06           2025-10           Test         0
# 2       2025-10-06           2025-10           Test         1
# 3       2025-11-15           2025-11           Test         0
# 4       2025-10-07           2025-10           Test         1
#
#    flg_mature_fpd30 new_loan_type modelVersionId trenchCategory  \
# 0                 1         Quick             v1       Trench 3
# 1                 1         Quick             v1       Trench 2
# 2                 1         Quick             v1       Trench 3
# 3                 1         Quick             v1       Trench 1
# 4                 1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffpd30', 
    'FPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (4920, 16)
# The shape of the dimension table is:	 (96, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=177ed862-9c7b-4c13-99c0-958da28adccc>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=a9a7be2c-0ba4-4bb4-a858-3e2594a135cd>

# %% [markdown]
# ### FSPD30

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (185, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3527362  81a70f9b-33d3-43a7-9b18-c33753cb5824    60835273620022
# 1    3569649  53a8cef3-7e62-4726-850f-d616880df6e2    60835696490014
# 2    3728357  2504c2f4-7db8-46aa-a4aa-0d3545429cc1    60837283570013
# 3    3740500  d15c4018-4f0f-49d9-9266-9cb8e1a0d302    60837405000011
# 4    3731216  2bed3fa3-7f38-4619-b83d-45b855ccfe70    60837312160018
#
#          modelDisplayName  credo_score  \
# 0  alpha_stack_model_cash       0.1783
# 1  alpha_stack_model_cash       0.1926
# 2  alpha_stack_model_cash       0.1843
# 3  alpha_stack_model_cash       0.1342
# 4  alpha_stack_model_cash       0.2262
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"apps_score": 0.3956296120791039, "c_demo_sco...   2025-10-08 11:36:47
# 1  {"apps_score": 0.47563529640029534, "c_demo_sc...   2025-09-29 21:25:24
# 2  {"apps_score": 0.4499236556760746, "c_demo_sco...   2025-10-06 23:35:25
# 3  {"apps_score": 0.40848731504091046, "c_demo_sc...   2025-10-12 20:00:53
# 4  {"apps_score": 0.4430536427982461, "c_demo_sco...   2025-10-08 13:25:23
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-08           2025-10           Test          0
# 1       2025-09-30           2025-09           Test          1
# 2       2025-10-07           2025-10           Test          0
# 3       2025-10-12           2025-10           Test          0
# 4       2025-10-08           2025-10           Test          1
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 2
# 1                   1         Quick             v1       Trench 2
# 2                   1         Quick             v1       Trench 1
# 3                   1         Quick             v1       Trench 1
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffspd30,
  del.flg_mature_fspd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fspd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (36352, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2926960  051bd0a2-a8cb-4e36-be8f-98390bc2164b    60829269600013
# 1     2228686  07be2b50-fe9d-42e5-a21a-49fcfc5dded1    60822286860011
# 2     2956386  0a407cb9-6f97-4026-b6f6-4077be972d56    60829563860011
# 3     2987267  0f38b852-f364-4e5e-9d5a-b9059b5eb2cb    60829872670013
# 4     2897200  15cb4870-5521-42cb-b23c-d668faa3d41b    60828972000013
#
#          modelDisplayName  credo_score  \
# 0  Alpha-Cash-Stack-Model     0.225188
# 1  Alpha-Cash-Stack-Model     0.123994
# 2  Alpha-Cash-Stack-Model     0.212191
# 3  Alpha-Cash-Stack-Model     0.243220
# 4  Alpha-Cash-Stack-Model     0.163568
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.4940378209751659, "credo_scor...   2024-10-10 10:24:19
# 1  {"demo_score": 0.5269015076061319, "apps_score...   2024-10-23 22:15:36
# 2  {"demo_score": 0.45623141092960384, "credo_sco...   2024-10-20 07:04:02
# 3  {"demo_score": 0.5668087318091404, "apps_score...   2024-10-31 12:54:28
# 4  {"demo_score": 0.4637808434938754, "apps_score...   2024-10-04 14:34:05
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2024-10-14           2024-10          Train          0
# 1       2024-10-24           2024-10          Train          0
# 2       2024-10-20           2024-10          Train          0
# 3       2024-10-31           2024-10          Train          0
# 4       2024-10-04           2024-10          Train          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 1
# 1                   1         Quick             v1       Trench 2
# 2                   1         Quick             v1       Trench 1
# 3                   1         Quick             v1       Trench 1
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (36502, 16)
#   customerId                  digitalLoanAccountId loanAccountNumber  \
# 0    3527362  81a70f9b-33d3-43a7-9b18-c33753cb5824    60835273620022
# 1    3728357  2504c2f4-7db8-46aa-a4aa-0d3545429cc1    60837283570013
# 2    3740500  d15c4018-4f0f-49d9-9266-9cb8e1a0d302    60837405000011
# 3    3731216  2bed3fa3-7f38-4619-b83d-45b855ccfe70    60837312160018
# 4    3730389  1d9d3871-4ad8-4288-90c5-745dd033a8e3    60837303890014
#
#          modelDisplayName  credo_score  \
# 0  alpha_stack_model_cash       0.1783
# 1  alpha_stack_model_cash       0.1843
# 2  alpha_stack_model_cash       0.1342
# 3  alpha_stack_model_cash       0.2262
# 4  alpha_stack_model_cash       0.2430
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"apps_score": 0.3956296120791039, "c_demo_sco...   2025-10-08 11:36:47
# 1  {"apps_score": 0.4499236556760746, "c_demo_sco...   2025-10-06 23:35:25
# 2  {"apps_score": 0.40848731504091046, "c_demo_sc...   2025-10-12 20:00:53
# 3  {"apps_score": 0.4430536427982461, "c_demo_sco...   2025-10-08 13:25:23
# 4  {"apps_score": 0.449818960872097, "c_demo_scor...   2025-10-07 22:22:16
#
#   disbursementdate Application_month Data_selection  deffspd30  \
# 0       2025-10-08           2025-10           Test          0
# 1       2025-10-07           2025-10           Test          0
# 2       2025-10-12           2025-10           Test          0
# 3       2025-10-08           2025-10           Test          1
# 4       2025-10-08           2025-10           Test          0
#
#    flg_mature_fspd_30 new_loan_type modelVersionId trenchCategory  \
# 0                   1         Quick             v1       Trench 2
# 1                   1         Quick             v1       Trench 1
# 2                   1         Quick             v1       Trench 1
# 3                   1         Quick             v1       Trench 1
# 4                   1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffspd30', 
    'FSPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (4448, 16)
# The shape of the dimension table is:	 (96, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=40dadbbb-e829-4f09-ba05-2976006515b0>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=79147fe5-c0d4-4e5f-95f6-09a6141585bd>

# %% [markdown]
# ### FSTPD30

# %% [markdown]
# ### Test

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.audit_balance.ml_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Test' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;



"""
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (0, 16)
# Empty DataFrame
# Columns: [customerId, digitalLoanAccountId, loanAccountNumber, modelDisplayName, credo_score, calcFeature, appln_submit_datetime, disbursementdate, Application_month, Data_selection, deffstpd30, flg_mature_fstpd_30, new_loan_type, modelVersionId, trenchCategory, loan_product_type]
# Index: []

# %%
df1 = dfd.copy()

# %% [markdown]
# ### Train

# %%
sq = """
with modelname as 
  (  SELECT
    mmrd.customerId,mmrd.digitalLoanAccountId,prediction,start_time,end_time,modelDisplayName,modelVersionId, 
  case when trenchCategory is null then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench1' end) 
     when trenchCategory = '' then (case when mt.ln_user_type='1_Repeat Applicant' then 'Trench 3'
    when mt.ln_user_type <>'1_Repeat Applicant' and DATE_DIFF(current_date(), mt.onb_tsa_onboarding_datetime, DAY) >30 then 'Trench 2'
    else 'Trench 1' end) 
    else trenchCategory end  as trenchCategory,
    REPLACE(REPLACE(calcFeature, "'", '"'), "None", "null") AS calcFeature,
    FROM prj-prod-dataplatform.dap_ds_poweruser_playground.ml_training_model_run_details mmrd
  left join prj-prod-dataplatform.risk_credit_mis.model_loan_score_mart mt on mt.digitalLoanAccountId = mmrd.digitalLoanAccountId
  WHERE modelDisplayName in ('Alpha-Cash-Stack-Model', 'alpha_stack_model_cash')
  -- and modelVersionId = 'v1'
      ),
  deliquency as
(select loanAccountNumber,
case when obs_min_inst_def0 >= 1 and min_inst_def0 = 1 then 1 else 0 end deffpd0,
case when obs_min_inst_def10 >=1 and min_inst_def10 =1 then 1 else 0 end deffpd10,
case when obs_min_inst_def30 >=1 and min_inst_def30 =1 then 1 else 0 end deffpd30,
case when obs_min_inst_def30 >=2 and min_inst_def30 in (1,2) then 1 else 0 end deffspd30,
case when obs_min_inst_def30 >=3 and min_inst_def30 in (1,2,3) then 1 else 0 end deffstpd30,
case when obs_min_inst_def0 >= 1 then 1 else 0 end flg_mature_fpd0,
case when obs_min_inst_def10 >=1 then 1 else 0 end flg_mature_fpd10,
case when obs_min_inst_def30 >=1 then 1 else 0 end flg_mature_fpd30,
case when obs_min_inst_def30 >=2 then 1 else 0 end flg_mature_fspd_30,
case when obs_min_inst_def30 >=3 then 1 else 0 end flg_mature_fstpd_30
from prj-prod-dataplatform.risk_credit_mis.loan_deliquency_data),
base as 
  (select distinct r.customerId,
  r.digitalLoanAccountId,
  loanmaster.loanAccountNumber,
  r.modelDisplayName,
  coalesce(cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.credo_score')AS FLOAT64), 
  cast(JSON_VALUE(SAFE.PARSE_JSON(CAST(calcFeature AS STRING)), '$.c_credo_score')AS FLOAT64)) AS credo_score,
  calcFeature,
  coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime)) AS appln_submit_datetime,
  date(loanmaster.disbursementDateTime) disbursementdate,
  format_date('%Y-%m', coalesce(IF(loanmaster.new_loan_type = 'Flex-up', loanmaster.startApplyDateTime, loanmaster.termsAndConditionsSubmitDateTime),  cast(r.start_time as datetime))) as Application_month, 
  'Train' Data_selection,  
  del.deffstpd30,
  del.flg_mature_fstpd_30,
  loanmaster.new_loan_type,
  modelVersionId, trenchCategory,
    case when loanmaster.loantype='BNPL' and store_type =1 then 'Appliance'
    when loanmaster.loantype='BNPL' and store_type =2 then 'Mobile' 
    when loanmaster.loantype='BNPL' and store_type =3 then 'Mall' 
    when loanmaster.loantype='BNPL' and store_type not in (1,2,3) then store_tagging
    else 'not applicable' end as loan_product_type,
  from modelname r
  left join risk_credit_mis.loan_master_table loanmaster  ON loanmaster.digitalLoanAccountId = r.digitalLoanAccountId
  left join deliquency del on del.loanAccountNumber = loanmaster.loanAccountNumber
   left join(SELECT DISTINCT mer_refferal_code, mer_name mer_name,store_type,store_tagging FROM `dl_loans_db_raw.tdbk_merchant_refferal_mtb`
  left join worktable_datachampions.TARGET_SPLIT P on P.STORE_NAME = mer_name
 qualify row_number() over(partition by mer_refferal_code order by  created_dt desc)=1) sil_category on loanmaster.purpleKey=sil_category.mer_refferal_code
  where 
  loanmaster.flagDisbursement = 1
  and loanmaster.disbursementDateTime is not null
  and del.flg_mature_fstpd_30 = 1
  )
  select *
  from base
  where credo_score is not null
 qualify row_number() over(partition by digitalLoanAccountId, modelVersionId order by appln_submit_datetime) = 1
   ;
  """
dfd = client.query(sq).to_dataframe()
# dfd = dfd.drop_duplicates(keep='first')
print(f"The shape of the dataframe downloaded is:\t {dfd.shape}")
dfd.head()
# Out:
# The shape of the dataframe downloaded is:	 (34221, 16)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2962464  00ff81e7-96e6-4d84-939e-6ab96fa8f4a2    60829624640016
# 1     2917558  09470175-45f1-4b91-896e-651d5ac76fb1    60829175580016
# 2     2980874  099db1f1-da61-4dd6-8db5-fa47ab4b7df5    60829808740012
# 3     1810992  0da4b689-d156-418c-a340-3a4cff34b5cb    60818109920019
# 4     2864056  11233829-b5fd-4fab-ba77-d546a099a2e4    60828640560016
#
#          modelDisplayName  credo_score  \
# 0  Alpha-Cash-Stack-Model     0.238521
# 1  Alpha-Cash-Stack-Model     0.274318
# 2  Alpha-Cash-Stack-Model     0.346223
# 3  Alpha-Cash-Stack-Model     0.189623
# 4  Alpha-Cash-Stack-Model     0.319390
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.5810869239201433, "credo_scor...   2024-10-21 22:04:02
# 1  {"demo_score": 0.4542501421825383, "credo_scor...   2024-10-07 00:40:18
# 2  {"demo_score": 0.40716659245127, "apps_score":...   2024-10-28 21:28:41
# 3  {"demo_score": 0.5878738325640587, "credo_scor...   2024-10-17 15:16:35
# 4  {"demo_score": 0.6478998521008034, "apps_score...   2024-10-11 05:41:24
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-10-22           2024-10          Train           0
# 1       2024-10-07           2024-10          Train           1
# 2       2024-10-29           2024-10          Train           0
# 3       2024-10-17           2024-10          Train           0
# 4       2024-10-11           2024-10          Train           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1         Quick             v1       Trench 1
# 1                    1         Quick             v1       Trench 1
# 2                    1         Quick             v1       Trench 1
# 3                    1         Quick             v1       Trench 2
# 4                    1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
df2 = dfd.copy()

# %% [markdown]
# ### Concat

# %%
# df_concat = pd.concat([df1, df2], ignore_index=True)
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")

# df_concat = (df_concat
#              .sort_values(by=['digitalLoanAccountId', 'Data_selection'],
#                           key=lambda s: s.map({'Train': 0, 'Test': 1}))
#              .drop_duplicates(subset=['digitalLoanAccountId'], keep='first')
#              .reset_index(drop=True))
# print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
# df_concat.head()


# 1) Get all IDs present in Train
train_ids = set(df2['digitalLoanAccountId'])

# 2) Keep only Test rows whose ID is NOT in Train
df1_no_dupes = df1[~df1['digitalLoanAccountId'].isin(train_ids)]

# 3) Concatenate
df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)

print(f"The shape of the concatenated dataframe is:\t {df_concat.shape}")
df_concat.head()
# Out:
# The shape of the concatenated dataframe is:	 (34221, 16)
# C:\Users\Dwaipayan\AppData\Local\Temp\ipykernel_49316\2946223290.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_concat = pd.concat([df1_no_dupes, df2], ignore_index=True)
#    customerId                  digitalLoanAccountId loanAccountNumber  \
# 0     2962464  00ff81e7-96e6-4d84-939e-6ab96fa8f4a2    60829624640016
# 1     2917558  09470175-45f1-4b91-896e-651d5ac76fb1    60829175580016
# 2     2980874  099db1f1-da61-4dd6-8db5-fa47ab4b7df5    60829808740012
# 3     1810992  0da4b689-d156-418c-a340-3a4cff34b5cb    60818109920019
# 4     2864056  11233829-b5fd-4fab-ba77-d546a099a2e4    60828640560016
#
#          modelDisplayName  credo_score  \
# 0  Alpha-Cash-Stack-Model     0.238521
# 1  Alpha-Cash-Stack-Model     0.274318
# 2  Alpha-Cash-Stack-Model     0.346223
# 3  Alpha-Cash-Stack-Model     0.189623
# 4  Alpha-Cash-Stack-Model     0.319390
#
#                                          calcFeature appln_submit_datetime  \
# 0  {"demo_score": 0.5810869239201433, "credo_scor...   2024-10-21 22:04:02
# 1  {"demo_score": 0.4542501421825383, "credo_scor...   2024-10-07 00:40:18
# 2  {"demo_score": 0.40716659245127, "apps_score":...   2024-10-28 21:28:41
# 3  {"demo_score": 0.5878738325640587, "credo_scor...   2024-10-17 15:16:35
# 4  {"demo_score": 0.6478998521008034, "apps_score...   2024-10-11 05:41:24
#
#   disbursementdate Application_month Data_selection  deffstpd30  \
# 0       2024-10-22           2024-10          Train           0
# 1       2024-10-07           2024-10          Train           1
# 2       2024-10-29           2024-10          Train           0
# 3       2024-10-17           2024-10          Train           0
# 4       2024-10-11           2024-10          Train           0
#
#    flg_mature_fstpd_30 new_loan_type modelVersionId trenchCategory  \
# 0                    1         Quick             v1       Trench 1
# 1                    1         Quick             v1       Trench 1
# 2                    1         Quick             v1       Trench 1
# 3                    1         Quick             v1       Trench 2
# 4                    1         Quick             v1       Trench 1
#
#   loan_product_type
# 0    not applicable
# 1    not applicable
# 2    not applicable
# 3    not applicable
# 4    not applicable

# %%
# df_concat = df1.copy()

df_concat['credo_score'] = pd.to_numeric(df_concat['credo_score'], errors='coerce')

# %%
fact_table, dimension_table = calculate_periodic_gini_prod_ver_trench_dimfact(
    df_concat, 
    'credo_score', 
    'deffstpd30', 
    'FSTPD30',
    data_selection_column='Data_selection',
    model_version_column='modelVersionId',
    trench_column='trenchCategory',
    loan_type_column='new_loan_type',
    loan_product_type_column='loan_product_type',
    account_id_column='digitalLoanAccountId'
)

# %%
fact_table, dimension_table = update_tables(fact_table, dimension_table, model_name='alpha_stack_credo_score_cash', product='CASH')
print(f"The shape of the fact table is:\t {fact_table.shape}")
print(f"The shape of the dimension table is:\t {dimension_table.shape}")
# Out:
# The shape of the fact table is:	 (3968, 16)
# The shape of the dimension table is:	 (64, 11)

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.fact_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(fact_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=0e7ba5bf-870d-4a9f-9dc4-e889bcfec9f3>

# %%
# Upload to BigQuery
table_id = "prj-prod-dataplatform.dap_ds_poweruser_playground.dimension_table1"
job_config = bigquery.LoadJobConfig(
    write_disposition="WRITE_APPEND",  # or "WRITE_APPEND"
)
job = client.load_table_from_dataframe(dimension_table, table_id, job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# C:\Users\Dwaipayan\AppData\Roaming\Python\Python312\site-packages\google\cloud\bigquery\_pandas_helpers.py:483: FutureWarning: Loading pandas DataFrame into BigQuery will require pandas-gbq package version 0.26.1 or greater in the future. Tried to import pandas-gbq and got: No module named 'pandas_gbq'
#   warnings.warn(
# LoadJob<project=prj-prod-dataplatform, location=asia-southeast1, id=d57211c2-f3a9-409c-ba77-2262311f5130>

# %% [markdown]
# # End
